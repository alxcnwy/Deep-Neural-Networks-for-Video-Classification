# %%
WORKER_ID = 2

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 15:05:21,706 [MainThread  ] [INFO ]  Begin experiment for model_id=194 on GPU:2
# 2019-01-20 15:05:21,707 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 15:05:21,708 [MainThread  ] [INFO ]  Loading data
# 194   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 512, 'layer_2_size': 512, 'sequence_length': 3, 'model_id': 194}
# 2019-01-20 15:05:22,856 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:05:22,857 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 26s 434us/step - loss: 0.3194 - acc: 0.9162 - val_loss: 0.1689 - val_acc: 0.9313
#
# Epoch 00001: val_acc improved from -inf to 0.93129, saving model to /mnt/seals/models/194/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 301us/step - loss: 0.1698 - acc: 0.9316 - val_loss: 0.2005 - val_acc: 0.9029
#
# Epoch 00002: val_acc did not improve from 0.93129
# Epoch 3/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1615 - acc: 0.9354 - val_loss: 0.2112 - val_acc: 0.9021
#
# Epoch 00003: val_acc did not improve from 0.93129
# Epoch 4/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1523 - acc: 0.9395 - val_loss: 0.1795 - val_acc: 0.9194
#
# Epoch 00004: val_acc did not improve from 0.93129
# H1 {'val_acc': [0.931289565131877, 0.902949841224768, 0.9020586605750243, 0.9194145075098396], 'acc': [0.9162245331632588, 0.9315570269446328, 0.9353577102549437, 0.9394839648928526], 'loss': [0.31939463147965, 0.16979920574906596, 0.16149092381318225, 0.1522709963449768], 'val_loss': [0.16886383507932937, 0.2005481084231206, 0.21122040294217675, 0.17952063952991534]}
# stopped_epoch1 1
# 4
# 0.902949841224768
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 315us/step - loss: 0.1297 - acc: 0.9480 - val_loss: 0.1866 - val_acc: 0.9090
#
# Epoch 00001: val_acc improved from -inf to 0.90903, saving model to /mnt/seals/models/194/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1262 - acc: 0.9493 - val_loss: 0.1850 - val_acc: 0.9085
#
# Epoch 00002: val_acc did not improve from 0.90903
# Epoch 3/20
# 60553/60553 [==============================] - 18s 305us/step - loss: 0.1236 - acc: 0.9503 - val_loss: 0.1850 - val_acc: 0.9127
#
# Epoch 00003: val_acc improved from 0.90903 to 0.91269, saving model to /mnt/seals/models/194/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 310us/step - loss: 0.1211 - acc: 0.9515 - val_loss: 0.1876 - val_acc: 0.9117
#
# Epoch 00004: val_acc did not improve from 0.91269
# Epoch 5/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1186 - acc: 0.9523 - val_loss: 0.1965 - val_acc: 0.9074
#
# Epoch 00005: val_acc did not improve from 0.91269
# Epoch 6/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1167 - acc: 0.9532 - val_loss: 0.1908 - val_acc: 0.9117
#
# Epoch 00006: val_acc did not improve from 0.91269
# H2 {'val_acc': [0.9090321889833889, 0.908542037047376, 0.9126860541027185, 0.9117057453225125, 0.9074057730673554, 0.9117057460289929], 'acc': [0.9479841913597835, 0.9493147848564051, 0.9502797004977825, 0.9514946927225482, 0.9522873867753653, 0.9532004001660207], 'loss': [0.12974541598208297, 0.12618971094195028, 0.12360050374860383, 0.1210906976537746, 0.11859663371206808, 0.1167252889963062], 'val_loss': [0.18655929960315107, 0.1849847197978852, 0.1849706488349478, 0.18758063704351746, 0.19649622927251936, 0.19082894515076504]}
# stopped_epoch2 3
# 6
# 0.9117057453225125
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 328us/step - loss: 0.1130 - acc: 0.9546 - val_loss: 0.1806 - val_acc: 0.9158
#
# Epoch 00001: val_acc improved from -inf to 0.91583, saving model to /mnt/seals/models/194/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 20s 327us/step - loss: 0.1124 - acc: 0.9547 - val_loss: 0.1819 - val_acc: 0.9164
#
# Epoch 00002: val_acc improved from 0.91583 to 0.91638, saving model to /mnt/seals/models/194/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 0.1120 - acc: 0.9551 - val_loss: 0.1796 - val_acc: 0.9168
#
# Epoch 00003: val_acc improved from 0.91638 to 0.91676, saving model to /mnt/seals/models/194/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 309us/step - loss: 0.1117 - acc: 0.9551 - val_loss: 0.1832 - val_acc: 0.9153
#
# Epoch 00004: val_acc did not improve from 0.91676
# Epoch 5/20
# 60553/60553 [==============================] - 19s 307us/step - loss: 0.1112 - acc: 0.9553 - val_loss: 0.1829 - val_acc: 0.9160
#
# Epoch 00005: val_acc did not improve from 0.91676
# Epoch 6/20
# 60553/60553 [==============================] - 19s 306us/step - loss: 0.1117 - acc: 0.9553 - val_loss: 0.1830 - val_acc: 0.9158
#
# Epoch 00006: val_acc did not improve from 0.91676
# H3 {'val_acc': [0.9158274853742651, 0.9163844751999368, 0.9167632320413571, 0.915337330984162, 0.9159611630871083, 0.9157829247484784], 'acc': [0.9545640226660808, 0.9547291672767413, 0.9550783302778729, 0.9550854082853909, 0.9552882985431032, 0.9552859405446517], 'loss': [0.11304315602974976, 0.11236763628643849, 0.11198594481598984, 0.11173019219498903, 0.11115349431647248, 0.11173935441614553], 'val_loss': [0.18060952303228123, 0.18187270009993614, 0.1796432521312741, 0.18322577914519378, 0.18286257773098616, 0.18301427463814385]}
# stopped_epoch3 3
# 6
# 0.915337330984162
# best fit round 3 0.915337330984162
# 3137/3137 [==============================] - 0s 107us/step
# 2019-01-20 15:10:41,925 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:10:40",
#     "fit_dt_test_start": "2019-01-20 15:10:39",
#     "fit_dt_train_duration_seconds": "313",
#     "fit_dt_train_end": "2019-01-20 15:10:39",
#     "fit_dt_train_start": "2019-01-20 15:05:25",
#     "fit_num_epochs": 10,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 3,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.5954733822123047,
#     "fit_train_acc": 0.9550854082853909,
#     "fit_train_loss": 0.11173019219498903,
#     "fit_val_acc": 0.915337330984162,
#     "fit_val_loss": 0.18322577914519378,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 512,
#     "layer_3_size": 128,
#     "model_id": 194,
#     "model_param_count": 2689031,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/194/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:10:41,926 [MainThread  ] [INFO ]  model 194 test acc: 0.5954733822123047
# 2019-01-20 15:10:44,943 [MainThread  ] [INFO ]  Begin experiment for model_id=202 on GPU:2
# 2019-01-20 15:10:44,946 [MainThread  ] [INFO ]  Loading data
# 202   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 512, 'layer_2_size': 128, 'sequence_length': 3, 'model_id': 202}
# 2019-01-20 15:10:46,143 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:10:46,144 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 341us/step - loss: 0.2596 - acc: 0.9158 - val_loss: 0.2090 - val_acc: 0.9012
#
# Epoch 00001: val_acc improved from -inf to 0.90123, saving model to /mnt/seals/models/202/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 20s 322us/step - loss: 0.1689 - acc: 0.9328 - val_loss: 0.1997 - val_acc: 0.9039
#
# Epoch 00002: val_acc improved from 0.90123 to 0.90386, saving model to /mnt/seals/models/202/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 20s 326us/step - loss: 0.1537 - acc: 0.9393 - val_loss: 0.1870 - val_acc: 0.9078
#
# Epoch 00003: val_acc improved from 0.90386 to 0.90778, saving model to /mnt/seals/models/202/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 313us/step - loss: 0.1468 - acc: 0.9421 - val_loss: 0.2095 - val_acc: 0.8992
#
# Epoch 00004: val_acc did not improve from 0.90778
# Epoch 5/20
# 60553/60553 [==============================] - 19s 321us/step - loss: 0.1428 - acc: 0.9438 - val_loss: 0.1830 - val_acc: 0.9045
#
# Epoch 00005: val_acc did not improve from 0.90778
# Epoch 6/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1422 - acc: 0.9437 - val_loss: 0.1649 - val_acc: 0.9278
#
# Epoch 00006: val_acc improved from 0.90778 to 0.92784, saving model to /mnt/seals/models/202/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 20s 329us/step - loss: 0.1373 - acc: 0.9457 - val_loss: 0.2652 - val_acc: 0.8948
#
# Epoch 00007: val_acc did not improve from 0.92784
# Epoch 8/20
# 60553/60553 [==============================] - 19s 316us/step - loss: 0.1338 - acc: 0.9478 - val_loss: 0.1750 - val_acc: 0.9231
#
# Epoch 00008: val_acc did not improve from 0.92784
# Epoch 9/20
# 60553/60553 [==============================] - 19s 311us/step - loss: 0.1316 - acc: 0.9484 - val_loss: 0.1936 - val_acc: 0.9130
#
# Epoch 00009: val_acc did not improve from 0.92784
# H1 {'val_acc': [0.9012343094859061, 0.9038633048274111, 0.9077845268597546, 0.8992068611750065, 0.904487141094874, 0.9278362181063228, 0.8948177680029248, 0.9230906530907953, 0.9129534086360087], 'acc': [0.9158423406734097, 0.9327649411707396, 0.9393258978841625, 0.9420767352409474, 0.9438131120504833, 0.943744693802832, 0.9456863219997124, 0.947776581268217, 0.9484418780160356], 'loss': [0.2595756429794189, 0.16886332324280554, 0.1537272240306129, 0.146847879485214, 0.14282225411340818, 0.14221598063148258, 0.13730061892793793, 0.13381174517292477, 0.1315500800774106], 'val_loss': [0.20900796714493877, 0.19974287214944011, 0.18704988402607883, 0.20947976039486682, 0.18296953456630874, 0.16493063463282748, 0.2652165515677154, 0.17498448542223374, 0.193562835901139]}
# stopped_epoch1 6
# 9
# 0.8948177680029248
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 328us/step - loss: 0.1157 - acc: 0.9546 - val_loss: 0.1779 - val_acc: 0.9177
#
# Epoch 00001: val_acc improved from -inf to 0.91765, saving model to /mnt/seals/models/202/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 20s 330us/step - loss: 0.1126 - acc: 0.9558 - val_loss: 0.2009 - val_acc: 0.9096
#
# Epoch 00002: val_acc did not improve from 0.91765
# Epoch 3/20
# 60553/60553 [==============================] - 19s 313us/step - loss: 0.1109 - acc: 0.9562 - val_loss: 0.1681 - val_acc: 0.9258
#
# Epoch 00003: val_acc improved from 0.91765 to 0.92579, saving model to /mnt/seals/models/202/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 322us/step - loss: 0.1100 - acc: 0.9567 - val_loss: 0.1830 - val_acc: 0.9199
#
# Epoch 00004: val_acc did not improve from 0.92579
# Epoch 5/20
# 60553/60553 [==============================] - 19s 322us/step - loss: 0.1101 - acc: 0.9564 - val_loss: 0.1787 - val_acc: 0.9216
#
# Epoch 00005: val_acc did not improve from 0.92579
# Epoch 6/20
# 60553/60553 [==============================] - 20s 336us/step - loss: 0.1088 - acc: 0.9571 - val_loss: 0.1773 - val_acc: 0.9200
#
# Epoch 00006: val_acc did not improve from 0.92579
# H2 {'val_acc': [0.9176544128398336, 0.9096337376500544, 0.9257864885157671, 0.9199492226372789, 0.9215756373262673, 0.9199715013141121], 'acc': [0.9546253612318545, 0.9558261983875335, 0.9561824382169456, 0.9567321344990815, 0.9564348733342652, 0.9571190438402392], 'loss': [0.1156796043073956, 0.11261842372064938, 0.11093412844776003, 0.11000631254249357, 0.11011803396360043, 0.10875023523156689], 'val_loss': [0.17787905972560197, 0.20089744186669087, 0.16810130716039476, 0.1830455137931475, 0.17874990741089591, 0.17734493727953227]}
# stopped_epoch2 3
# 6
# 0.9199492226372789
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 331us/step - loss: 0.1072 - acc: 0.9577 - val_loss: 0.1762 - val_acc: 0.9206
#
# Epoch 00001: val_acc improved from -inf to 0.92064, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 20s 327us/step - loss: 0.1065 - acc: 0.9579 - val_loss: 0.1757 - val_acc: 0.9215
#
# Epoch 00002: val_acc improved from 0.92064 to 0.92153, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 0.1066 - acc: 0.9578 - val_loss: 0.1769 - val_acc: 0.9216
#
# Epoch 00003: val_acc improved from 0.92153 to 0.92164, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 316us/step - loss: 0.1068 - acc: 0.9579 - val_loss: 0.1721 - val_acc: 0.9239
#
# Epoch 00004: val_acc improved from 0.92164 to 0.92391, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 5/20
# 60553/60553 [==============================] - 20s 329us/step - loss: 0.1060 - acc: 0.9577 - val_loss: 0.1760 - val_acc: 0.9222
#
# Epoch 00005: val_acc did not improve from 0.92391
# Epoch 6/20
# 60553/60553 [==============================] - 20s 335us/step - loss: 0.1060 - acc: 0.9583 - val_loss: 0.1745 - val_acc: 0.9234
#
# Epoch 00006: val_acc did not improve from 0.92391
# Epoch 7/20
# 60553/60553 [==============================] - 19s 321us/step - loss: 0.1060 - acc: 0.9580 - val_loss: 0.1723 - val_acc: 0.9243
#
# Epoch 00007: val_acc improved from 0.92391 to 0.92429, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 8/20
# 60553/60553 [==============================] - 20s 333us/step - loss: 0.1055 - acc: 0.9581 - val_loss: 0.1729 - val_acc: 0.9246
#
# Epoch 00008: val_acc improved from 0.92429 to 0.92463, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 9/20
# 60553/60553 [==============================] - 19s 322us/step - loss: 0.1059 - acc: 0.9581 - val_loss: 0.1720 - val_acc: 0.9253
#
# Epoch 00009: val_acc improved from 0.92463 to 0.92530, saving model to /mnt/seals/models/202/model_round_3.h5
# Epoch 10/20
# 60553/60553 [==============================] - 19s 316us/step - loss: 0.1058 - acc: 0.9583 - val_loss: 0.1719 - val_acc: 0.9251
#
# Epoch 00010: val_acc did not improve from 0.92530
# Epoch 11/20
# 60553/60553 [==============================] - 19s 315us/step - loss: 0.1056 - acc: 0.9582 - val_loss: 0.1773 - val_acc: 0.9223
#
# Epoch 00011: val_acc did not improve from 0.92530
# Epoch 12/20
# 60553/60553 [==============================] - 19s 315us/step - loss: 0.1055 - acc: 0.9582 - val_loss: 0.1732 - val_acc: 0.9244
#
# Epoch 00012: val_acc did not improve from 0.92530
# H3 {'val_acc': [0.9206398888743823, 0.9215310753247028, 0.9216424718694395, 0.9239149992345499, 0.9222440247006217, 0.9233580067316889, 0.9242937545886429, 0.9246279469372255, 0.9252963378811656, 0.9250512620247087, 0.9223108628133796, 0.9244051503525328], 'acc': [0.9577371573256432, 0.9578551175133542, 0.957833885502788, 0.957909379255769, 0.9577489526293909, 0.9583010072111857, 0.9580344174785594, 0.9581476593217202, 0.9581051926123598, 0.9582561817798851, 0.9581972020935458, 0.9581877645401963], 'loss': [0.10723569363940334, 0.10647632117428661, 0.10663301051263441, 0.10675838450913469, 0.10603880130453178, 0.106007040615712, 0.10603232383324449, 0.10548924336916249, 0.105876890281225, 0.10580791605785143, 0.10563491505031461, 0.10552871401922954], 'val_loss': [0.17621938217749689, 0.1757016988449073, 0.176912306818974, 0.1721364465063985, 0.17598528992698406, 0.1744756956752657, 0.17225217567297793, 0.1729461239954121, 0.1719947434910669, 0.17193016466578318, 0.17729694163397708, 0.17324359596928282]}
# stopped_epoch3 9
# 12
# 0.9250512620247087
# best fit round 3 0.9250512620247087
# 3137/3137 [==============================] - 0s 142us/step
# 2019-01-20 15:19:48,577 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:19:47",
#     "fit_dt_test_start": "2019-01-20 15:19:46",
#     "fit_dt_train_duration_seconds": "536",
#     "fit_dt_train_end": "2019-01-20 15:19:45",
#     "fit_dt_train_start": "2019-01-20 15:10:49",
#     "fit_num_epochs": 21,
#     "fit_stopped_epoch1": 6,
#     "fit_stopped_epoch2": 3,
#     "fit_stopped_epoch3": 9,
#     "fit_test_acc": 0.5878227605992987,
#     "fit_train_acc": 0.9582561817798851,
#     "fit_train_loss": 0.10580791605785143,
#     "fit_val_acc": 0.9250512620247087,
#     "fit_val_loss": 0.17193016466578318,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 128,
#     "layer_3_size": 128,
#     "model_id": 202,
#     "model_param_count": 2442887,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/202/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:19:48,579 [MainThread  ] [INFO ]  model 202 test acc: 0.5878227605992987
# 2019-01-20 15:19:51,747 [MainThread  ] [INFO ]  Begin experiment for model_id=210 on GPU:2
# 2019-01-20 15:19:51,749 [MainThread  ] [INFO ]  Loading data
# 210   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 256, 'layer_2_size': 512, 'sequence_length': 3, 'model_id': 210}
# 2019-01-20 15:19:52,951 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:19:52,958 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.2133 - acc: 0.9180 - val_loss: 0.2268 - val_acc: 0.8961
#
# Epoch 00001: val_acc improved from -inf to 0.89613, saving model to /mnt/seals/models/210/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 0.1841 - acc: 0.9271 - val_loss: 0.2037 - val_acc: 0.9046
#
# Epoch 00002: val_acc improved from 0.89613 to 0.90458, saving model to /mnt/seals/models/210/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1721 - acc: 0.9316 - val_loss: 0.1991 - val_acc: 0.9096
#
# Epoch 00003: val_acc improved from 0.90458 to 0.90961, saving model to /mnt/seals/models/210/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1646 - acc: 0.9350 - val_loss: 0.2136 - val_acc: 0.9081
#
# Epoch 00004: val_acc did not improve from 0.90961
# Epoch 5/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1648 - acc: 0.9347 - val_loss: 0.3163 - val_acc: 0.8735
#
# Epoch 00005: val_acc did not improve from 0.90961
# Epoch 6/20
# 60553/60553 [==============================] - 18s 292us/step - loss: 0.1582 - acc: 0.9377 - val_loss: 0.2105 - val_acc: 0.9037
#
# Epoch 00006: val_acc did not improve from 0.90961
# H1 {'val_acc': [0.8961322681277675, 0.9045762575498165, 0.9096114608323804, 0.9080964515377266, 0.8735184174586443, 0.9036850729958384], 'acc': [0.9179561921597874, 0.9271382299097236, 0.9316372392045799, 0.9349896724798196, 0.9347443169449594, 0.9376980448872412], 'loss': [0.21330594390833987, 0.18405924437771626, 0.17211548072294977, 0.16462195468822416, 0.16484993891456295, 0.15817818140137246], 'val_loss': [0.2267648521450558, 0.20367110774841296, 0.19909200881022776, 0.21358956054494446, 0.31629826685301005, 0.2105201761274879]}
# stopped_epoch1 3
# 6
# 0.9080964515377266
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 314us/step - loss: 0.1413 - acc: 0.9446 - val_loss: 0.2022 - val_acc: 0.9018
#
# Epoch 00001: val_acc improved from -inf to 0.90179, saving model to /mnt/seals/models/210/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 0.1359 - acc: 0.9467 - val_loss: 0.1871 - val_acc: 0.9062
#
# Epoch 00002: val_acc improved from 0.90179 to 0.90616, saving model to /mnt/seals/models/210/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 0.1337 - acc: 0.9476 - val_loss: 0.2051 - val_acc: 0.8988
#
# Epoch 00003: val_acc did not improve from 0.90616
# Epoch 4/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 0.1326 - acc: 0.9482 - val_loss: 0.1833 - val_acc: 0.9066
#
# Epoch 00004: val_acc improved from 0.90616 to 0.90665, saving model to /mnt/seals/models/210/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 0.1307 - acc: 0.9487 - val_loss: 0.1857 - val_acc: 0.9118
#
# Epoch 00005: val_acc improved from 0.90665 to 0.91177, saving model to /mnt/seals/models/210/model_round_2.h5
# Epoch 6/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1287 - acc: 0.9494 - val_loss: 0.1766 - val_acc: 0.9114
#
# Epoch 00006: val_acc did not improve from 0.91177
# Epoch 7/20
# 60553/60553 [==============================] - 17s 289us/step - loss: 0.1273 - acc: 0.9499 - val_loss: 0.2064 - val_acc: 0.9042
#
# Epoch 00007: val_acc did not improve from 0.91177
# Epoch 8/20
# 60553/60553 [==============================] - 17s 282us/step - loss: 0.1275 - acc: 0.9497 - val_loss: 0.1924 - val_acc: 0.9084
#
# Epoch 00008: val_acc did not improve from 0.91177
# H2 {'val_acc': [0.9017912992372115, 0.9061581133234449, 0.8988058254336537, 0.9066482688290435, 0.9117725858893606, 0.9113715542381582, 0.9042420623381288, 0.9083637986343798], 'acc': [0.9446010870214808, 0.9467361702762772, 0.9476373874802334, 0.9481611318283741, 0.9486707211221934, 0.9493666879083786, 0.9498644796128163, 0.9496993358024229], 'loss': [0.1412670045774615, 0.13588688048015427, 0.1336846047058152, 0.13261819293319332, 0.1307489306336065, 0.12870917920077773, 0.127268808674921, 0.12747699063512263], 'val_loss': [0.20217216801286414, 0.18713777539734533, 0.20509064332329327, 0.18331794619225594, 0.18566115766633545, 0.1765676691561138, 0.20644087171041436, 0.19242781560568237]}
# stopped_epoch2 5
# 8
# 0.9113715542381582
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 292us/step - loss: 0.1253 - acc: 0.9512 - val_loss: 0.1885 - val_acc: 0.9137
#
# Epoch 00001: val_acc improved from -inf to 0.91373, saving model to /mnt/seals/models/210/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 0.1245 - acc: 0.9511 - val_loss: 0.1905 - val_acc: 0.9115
#
# Epoch 00002: val_acc did not improve from 0.91373
# Epoch 3/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 0.1240 - acc: 0.9516 - val_loss: 0.1874 - val_acc: 0.9127
#
# Epoch 00003: val_acc did not improve from 0.91373
# Epoch 4/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1236 - acc: 0.9520 - val_loss: 0.1910 - val_acc: 0.9122
#
# Epoch 00004: val_acc did not improve from 0.91373
# H3 {'val_acc': [0.9137331951207395, 0.911482950002048, 0.9126637710382696, 0.9122404571406483], 'acc': [0.9511856356417259, 0.9511360925775518, 0.9516220900679045, 0.9519830493226704], 'loss': [0.12530233834323407, 0.12449507250467177, 0.12399728829978551, 0.12357045088304847], 'val_loss': [0.1885010558723734, 0.19053448398300654, 0.1874336388452456, 0.19098796221849998]}
# stopped_epoch3 1
# 4
# 0.911482950002048
# best fit round 3 0.911482950002048
# 3137/3137 [==============================] - 1s 186us/step
# 2019-01-20 15:25:16,668 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:25:15",
#     "fit_dt_test_start": "2019-01-20 15:25:14",
#     "fit_dt_train_duration_seconds": "317",
#     "fit_dt_train_end": "2019-01-20 15:25:13",
#     "fit_dt_train_start": "2019-01-20 15:19:56",
#     "fit_num_epochs": 12,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 5,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.5967484858144725,
#     "fit_train_acc": 0.9511360925775518,
#     "fit_train_loss": 0.12449507250467177,
#     "fit_val_acc": 0.911482950002048,
#     "fit_val_loss": 0.19053448398300654,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 512,
#     "layer_3_size": 128,
#     "model_id": 210,
#     "model_param_count": 1378055,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/210/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:25:16,670 [MainThread  ] [INFO ]  model 210 test acc: 0.5967484858144725
# 2019-01-20 15:25:19,301 [MainThread  ] [INFO ]  Begin experiment for model_id=218 on GPU:2
# 2019-01-20 15:25:19,305 [MainThread  ] [INFO ]  Loading data
# 218   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 256, 'layer_2_size': 128, 'sequence_length': 3, 'model_id': 218}
# 2019-01-20 15:25:20,550 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:25:20,558 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 316us/step - loss: 0.2216 - acc: 0.9133 - val_loss: 0.2097 - val_acc: 0.9140
#
# Epoch 00001: val_acc improved from -inf to 0.91405, saving model to /mnt/seals/models/218/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1842 - acc: 0.9214 - val_loss: 0.2083 - val_acc: 0.9149
#
# Epoch 00002: val_acc improved from 0.91405 to 0.91491, saving model to /mnt/seals/models/218/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1772 - acc: 0.9234 - val_loss: 0.1870 - val_acc: 0.9154
#
# Epoch 00003: val_acc improved from 0.91491 to 0.91540, saving model to /mnt/seals/models/218/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1749 - acc: 0.9248 - val_loss: 0.1919 - val_acc: 0.9167
#
# Epoch 00004: val_acc improved from 0.91540 to 0.91670, saving model to /mnt/seals/models/218/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1730 - acc: 0.9255 - val_loss: 0.2154 - val_acc: 0.9122
#
# Epoch 00005: val_acc did not improve from 0.91670
# Epoch 6/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1774 - acc: 0.9240 - val_loss: 0.1839 - val_acc: 0.9147
#
# Epoch 00006: val_acc did not improve from 0.91670
# Epoch 7/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1732 - acc: 0.9250 - val_loss: 0.2156 - val_acc: 0.9132
#
# Epoch 00007: val_acc did not improve from 0.91670
# H1 {'val_acc': [0.9140451212116725, 0.9149140274978323, 0.9154041801031425, 0.9166964012536866, 0.912240468964901, 0.9147135113747656, 0.9131762150370621], 'acc': [0.9133439424165779, 0.921407716865022, 0.9233894491602014, 0.9248474400385998, 0.9254773486171031, 0.924009921499447, 0.9249960711948771], 'loss': [0.22161044743828534, 0.18424103274628179, 0.17715240076144653, 0.1748515557310531, 0.1730065752320539, 0.17738228483083765, 0.17317092604169232], 'val_loss': [0.20971280715648488, 0.20828819699720227, 0.18696660835223874, 0.19185191952505487, 0.21535951556336932, 0.1839118591990236, 0.2155859630533999]}
# stopped_epoch1 4
# 7
# 0.912240468964901
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1617 - acc: 0.9298 - val_loss: 0.1932 - val_acc: 0.9146
#
# Epoch 00001: val_acc improved from -inf to 0.91465, saving model to /mnt/seals/models/218/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1598 - acc: 0.9309 - val_loss: 0.1900 - val_acc: 0.9156
#
# Epoch 00002: val_acc improved from 0.91465 to 0.91565, saving model to /mnt/seals/models/218/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 18s 298us/step - loss: 0.1584 - acc: 0.9324 - val_loss: 0.1831 - val_acc: 0.9155
#
# Epoch 00003: val_acc did not improve from 0.91565
# Epoch 4/20
# 60553/60553 [==============================] - 18s 297us/step - loss: 0.1561 - acc: 0.9337 - val_loss: 0.1857 - val_acc: 0.9146
#
# Epoch 00004: val_acc did not improve from 0.91565
# Epoch 5/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 0.1565 - acc: 0.9337 - val_loss: 0.2049 - val_acc: 0.9049
#
# Epoch 00005: val_acc did not improve from 0.91565
# H2 {'val_acc': [0.9146466719605962, 0.9156492567404463, 0.9155378582993672, 0.9146243912015047, 0.9049104538026335], 'acc': [0.9297711074971413, 0.9309082471879253, 0.9323709551007194, 0.9337463731073009, 0.9336638011430439], 'loss': [0.16172466249673087, 0.15979536529927263, 0.15841689425669064, 0.15611364716233647, 0.15647346968782955], 'val_loss': [0.19315257991059304, 0.19004074854547354, 0.18314523304244987, 0.1856752491915739, 0.20491272870146773]}
# stopped_epoch2 2
# 5
# 0.9155378582993672
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 311us/step - loss: 0.1541 - acc: 0.9354 - val_loss: 0.1907 - val_acc: 0.9096
#
# Epoch 00001: val_acc improved from -inf to 0.90961, saving model to /mnt/seals/models/218/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 289us/step - loss: 0.1537 - acc: 0.9353 - val_loss: 0.1899 - val_acc: 0.9103
#
# Epoch 00002: val_acc improved from 0.90961 to 0.91026, saving model to /mnt/seals/models/218/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 281us/step - loss: 0.1532 - acc: 0.9353 - val_loss: 0.1884 - val_acc: 0.9112
#
# Epoch 00003: val_acc improved from 0.91026 to 0.91119, saving model to /mnt/seals/models/218/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 18s 291us/step - loss: 0.1534 - acc: 0.9355 - val_loss: 0.1879 - val_acc: 0.9118
#
# Epoch 00004: val_acc improved from 0.91119 to 0.91177, saving model to /mnt/seals/models/218/model_round_3.h5
# Epoch 5/20
# 60553/60553 [==============================] - 18s 291us/step - loss: 0.1538 - acc: 0.9353 - val_loss: 0.1896 - val_acc: 0.9109
#
# Epoch 00005: val_acc did not improve from 0.91177
# Epoch 6/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1539 - acc: 0.9351 - val_loss: 0.1869 - val_acc: 0.9120
#
# Epoch 00006: val_acc improved from 0.91177 to 0.91200, saving model to /mnt/seals/models/218/model_round_3.h5
# Epoch 7/20
# 60553/60553 [==============================] - 18s 300us/step - loss: 0.1534 - acc: 0.9355 - val_loss: 0.1911 - val_acc: 0.9104
#
# Epoch 00007: val_acc did not improve from 0.91200
# Epoch 8/20
# 60553/60553 [==============================] - 18s 298us/step - loss: 0.1533 - acc: 0.9354 - val_loss: 0.1901 - val_acc: 0.9110
#
# Epoch 00008: val_acc did not improve from 0.91200
# Epoch 9/20
# 60553/60553 [==============================] - 18s 300us/step - loss: 0.1529 - acc: 0.9356 - val_loss: 0.1903 - val_acc: 0.9111
#
# Epoch 00009: val_acc did not improve from 0.91200
# H3 {'val_acc': [0.9096114661123926, 0.9102575762972412, 0.9111933214770059, 0.9117725923592347, 0.9109036891592791, 0.9119953898363239, 0.9104358152308021, 0.9109705260821751, 0.911104203497553], 'acc': [0.935371867169665, 0.9353435564802622, 0.935277499717589, 0.9355393711105868, 0.9353105286668889, 0.9351217913284681, 0.9354969056936628, 0.9354166925104065, 0.9355794779453467], 'loss': [0.15414474863810199, 0.15372357094559844, 0.15322724625953288, 0.15338456414029292, 0.15377068439221053, 0.15389385305598158, 0.15344116580156938, 0.153288095600803, 0.15285116111381936], 'val_loss': [0.19074052271066572, 0.18994720333156478, 0.1884259274060921, 0.1879287746386906, 0.18961015105693696, 0.18694117673657049, 0.19113612065297397, 0.19014469755863445, 0.19026771551247917]}
# stopped_epoch3 6
# 9
# 0.9104358152308021
# best fit round 2 0.9155378582993672
# 3137/3137 [==============================] - 1s 219us/step
# 2019-01-20 15:31:51,666 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:31:49",
#     "fit_dt_test_start": "2019-01-20 15:31:49",
#     "fit_dt_train_duration_seconds": "384",
#     "fit_dt_train_end": "2019-01-20 15:31:48",
#     "fit_dt_train_start": "2019-01-20 15:25:23",
#     "fit_num_epochs": 15,
#     "fit_stopped_epoch1": 4,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 6,
#     "fit_test_acc": 0.5639145680586548,
#     "fit_train_acc": 0.9323709551007194,
#     "fit_train_loss": 0.15841689425669064,
#     "fit_val_acc": 0.9155378582993672,
#     "fit_val_loss": 0.18314523304244987,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 128,
#     "layer_3_size": 128,
#     "model_id": 218,
#     "model_param_count": 1230215,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/218/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:31:51,667 [MainThread  ] [INFO ]  model 218 test acc: 0.5639145680586548
# 2019-01-20 15:31:54,322 [MainThread  ] [INFO ]  Begin experiment for model_id=226 on GPU:2
# 2019-01-20 15:31:54,326 [MainThread  ] [INFO ]  Loading data
# 226   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 128, 'layer_2_size': 512, 'sequence_length': 3, 'model_id': 226}
# 2019-01-20 15:31:55,655 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:31:55,656 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 312us/step - loss: 0.2351 - acc: 0.9083 - val_loss: 0.2619 - val_acc: 0.9092
#
# Epoch 00001: val_acc improved from -inf to 0.90923, saving model to /mnt/seals/models/226/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.2187 - acc: 0.9124 - val_loss: 0.2345 - val_acc: 0.9129
#
# Epoch 00002: val_acc improved from 0.90923 to 0.91291, saving model to /mnt/seals/models/226/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.2145 - acc: 0.9139 - val_loss: 0.2277 - val_acc: 0.9141
#
# Epoch 00003: val_acc improved from 0.91291 to 0.91409, saving model to /mnt/seals/models/226/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.2115 - acc: 0.9147 - val_loss: 0.2308 - val_acc: 0.9136
#
# Epoch 00004: val_acc did not improve from 0.91409
# Epoch 5/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.2102 - acc: 0.9149 - val_loss: 0.2695 - val_acc: 0.9091
#
# Epoch 00005: val_acc did not improve from 0.91409
# Epoch 6/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.2083 - acc: 0.9154 - val_loss: 0.2204 - val_acc: 0.9152
#
# Epoch 00006: val_acc improved from 0.91409 to 0.91518, saving model to /mnt/seals/models/226/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 0.2073 - acc: 0.9155 - val_loss: 0.2280 - val_acc: 0.9138
#
# Epoch 00007: val_acc did not improve from 0.91518
# Epoch 8/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.2086 - acc: 0.9154 - val_loss: 0.2173 - val_acc: 0.9160
#
# Epoch 00008: val_acc improved from 0.91518 to 0.91601, saving model to /mnt/seals/models/226/model_round_1.h5
# Epoch 9/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.2078 - acc: 0.9156 - val_loss: 0.2220 - val_acc: 0.9130
#
# Epoch 00009: val_acc did not improve from 0.91601
# Epoch 10/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.2093 - acc: 0.9152 - val_loss: 0.2279 - val_acc: 0.9126
#
# Epoch 00010: val_acc did not improve from 0.91601
# Epoch 11/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.2119 - acc: 0.9143 - val_loss: 0.2212 - val_acc: 0.9137
#
# Epoch 00011: val_acc did not improve from 0.91601
# H1 {'val_acc': [0.9092327164845101, 0.912908859685742, 0.9140896795321016, 0.9136218088757448, 0.9091213141763798, 0.9151813864559214, 0.9138446030807138, 0.9160057314098141, 0.9129534232861833, 0.9126192282604115, 0.9136886532352778], 'acc': [0.9082787261472564, 0.9123790307981916, 0.9138558954869151, 0.914669822064123, 0.914851480845765, 0.9154176926346295, 0.915495544575055, 0.9153516336040406, 0.9156323791046338, 0.9151605383409938, 0.9142923509564925], 'loss': [0.23512683019782485, 0.21866197391667497, 0.21451893260476493, 0.21152021360295362, 0.21021310711294616, 0.2083061114690614, 0.2073043503743652, 0.20860610775452804, 0.2078109786827149, 0.2093226616511311, 0.21186188939354858], 'val_loss': [0.2619397285686607, 0.234513892896162, 0.2277466419036137, 0.2308461098691782, 0.26953424679734744, 0.2203785234403402, 0.22797541298943613, 0.21727666680841096, 0.22200747301856652, 0.22794352007968233, 0.22115228855453725]}
# stopped_epoch1 8
# 11
# 0.9129534232861833
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 315us/step - loss: 0.2013 - acc: 0.9171 - val_loss: 0.2253 - val_acc: 0.9142
#
# Epoch 00001: val_acc improved from -inf to 0.91416, saving model to /mnt/seals/models/226/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.2006 - acc: 0.9173 - val_loss: 0.2199 - val_acc: 0.9144
#
# Epoch 00002: val_acc improved from 0.91416 to 0.91442, saving model to /mnt/seals/models/226/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 282us/step - loss: 0.1994 - acc: 0.9174 - val_loss: 0.2261 - val_acc: 0.9128
#
# Epoch 00003: val_acc did not improve from 0.91442
# Epoch 4/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1983 - acc: 0.9178 - val_loss: 0.2256 - val_acc: 0.9117
#
# Epoch 00004: val_acc did not improve from 0.91442
# Epoch 5/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1982 - acc: 0.9178 - val_loss: 0.2257 - val_acc: 0.9125
#
# Epoch 00005: val_acc did not improve from 0.91442
# H2 {'val_acc': [0.9141565227017727, 0.9144238808046485, 0.9128197417062889, 0.9116834780237337, 0.9124632656239601], 'acc': [0.9170903711081311, 0.9172555151833115, 0.9173805533873994, 0.9177651039377133, 0.9177910542987354], 'loss': [0.2012561203592698, 0.20057798026092474, 0.19937194974407138, 0.19829363299062258, 0.19821146970448592], 'val_loss': [0.2252889744244883, 0.21993941037043585, 0.2261339748418859, 0.22555458131092307, 0.22570062611375238]}
# stopped_epoch2 2
# 5
# 0.9128197417062889
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 0.1980 - acc: 0.9179 - val_loss: 0.2258 - val_acc: 0.9111
#
# Epoch 00001: val_acc improved from -inf to 0.91113, saving model to /mnt/seals/models/226/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1970 - acc: 0.9181 - val_loss: 0.2246 - val_acc: 0.9109
#
# Epoch 00002: val_acc did not improve from 0.91113
# Epoch 3/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.1970 - acc: 0.9179 - val_loss: 0.2254 - val_acc: 0.9110
#
# Epoch 00003: val_acc did not improve from 0.91113
# Epoch 4/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1977 - acc: 0.9178 - val_loss: 0.2247 - val_acc: 0.9109
#
# Epoch 00004: val_acc did not improve from 0.91113
# H3 {'val_acc': [0.911126488792993, 0.9109259714800644, 0.9109928078080295, 0.9109482501568976], 'acc': [0.9179090152424183, 0.9180977515000355, 0.9179066553993166, 0.9177509478783821], 'loss': [0.1979561635077235, 0.19698180875675747, 0.19696774957010835, 0.1976980062150649], 'val_loss': [0.22577908155476384, 0.22464915760516824, 0.2254344178636745, 0.22471000489337847]}
# stopped_epoch3 1
# 4
# 0.9109259714800644
# best fit round 1 0.9129534232861833
# 3137/3137 [==============================] - 1s 332us/step
# 2019-01-20 15:38:02,851 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 15:38:01",
#     "fit_dt_test_start": "2019-01-20 15:37:59",
#     "fit_dt_train_duration_seconds": "359",
#     "fit_dt_train_end": "2019-01-20 15:37:58",
#     "fit_dt_train_start": "2019-01-20 15:31:58",
#     "fit_num_epochs": 14,
#     "fit_stopped_epoch1": 8,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.4341727765380937,
#     "fit_train_acc": 0.9156323791046338,
#     "fit_train_loss": 0.2078109786827149,
#     "fit_val_acc": 0.9129534232861833,
#     "fit_val_loss": 0.22200747301856652,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 512,
#     "layer_3_size": 128,
#     "model_id": 226,
#     "model_param_count": 722567,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/226/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:38:02,852 [MainThread  ] [INFO ]  model 226 test acc: 0.4341727765380937
# 2019-01-20 15:38:05,382 [MainThread  ] [INFO ]  Begin experiment for model_id=234 on GPU:2
# 2019-01-20 15:38:05,385 [MainThread  ] [INFO ]  Loading data
# 234   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'inception_resnet_v2', 'layer_1_size': 128, 'layer_2_size': 128, 'sequence_length': 3, 'model_id': 234}
# 2019-01-20 15:38:06,795 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:38:06,797 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 327us/step - loss: 0.2234 - acc: 0.9138 - val_loss: 0.2441 - val_acc: 0.8841
#
# Epoch 00001: val_acc improved from -inf to 0.88406, saving model to /mnt/seals/models/234/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 281us/step - loss: 0.1947 - acc: 0.9200 - val_loss: 0.1961 - val_acc: 0.9044
#
# Epoch 00002: val_acc improved from 0.88406 to 0.90438, saving model to /mnt/seals/models/234/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.1888 - acc: 0.9217 - val_loss: 0.1952 - val_acc: 0.9060
#
# Epoch 00003: val_acc improved from 0.90438 to 0.90598, saving model to /mnt/seals/models/234/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.1852 - acc: 0.9230 - val_loss: 0.1881 - val_acc: 0.9122
#
# Epoch 00004: val_acc improved from 0.90598 to 0.91222, saving model to /mnt/seals/models/234/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1820 - acc: 0.9241 - val_loss: 0.2050 - val_acc: 0.9066
#
# Epoch 00005: val_acc did not improve from 0.91222
# Epoch 6/20
# 60553/60553 [==============================] - 17s 282us/step - loss: 0.1947 - acc: 0.9204 - val_loss: 0.2264 - val_acc: 0.9097
#
# Epoch 00006: val_acc did not improve from 0.91222
# Epoch 7/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.2076 - acc: 0.9175 - val_loss: 0.2159 - val_acc: 0.9095
#
# Epoch 00007: val_acc did not improve from 0.91222
# H1 {'val_acc': [0.8840566925235042, 0.9043757475247921, 0.9059798800789113, 0.9122181855286201, 0.9066259938333455, 0.9097451509644073, 0.9095223487278705], 'acc': [0.9137591635486132, 0.9200464531105264, 0.921686102608151, 0.9229860255506126, 0.9241467560063861, 0.9203507925348511, 0.917489075774692], 'loss': [0.2233588100139182, 0.19474612785305448, 0.18879954736419743, 0.18523668550819755, 0.1819581356082721, 0.1947425228299633, 0.20762202548502914], 'val_loss': [0.2441165349722206, 0.19607271451133532, 0.1952219645603701, 0.18813669728957633, 0.20500948492504995, 0.22641145008954866, 0.21588613840281332]}
# stopped_epoch1 4
# 7
# 0.9066259938333455
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 334us/step - loss: 0.1973 - acc: 0.9195 - val_loss: 0.2124 - val_acc: 0.9099
#
# Epoch 00001: val_acc improved from -inf to 0.90995, saving model to /mnt/seals/models/234/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1957 - acc: 0.9199 - val_loss: 0.2241 - val_acc: 0.9114
#
# Epoch 00002: val_acc improved from 0.90995 to 0.91139, saving model to /mnt/seals/models/234/model_round_2.h5
# Epoch 3/20
# ...
# Epoch 1/20
# 60553/60553 [==============================] - 20s 328us/step - loss: 0.0813 - acc: 0.9677 - val_loss: 0.2574 - val_acc: 0.9259
#
# Epoch 00001: val_acc improved from -inf to 0.92594, saving model to /mnt/seals/models/282/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.0771 - acc: 0.9690 - val_loss: 0.2655 - val_acc: 0.9273
#
# Epoch 00002: val_acc improved from 0.92594 to 0.92735, saving model to /mnt/seals/models/282/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.0752 - acc: 0.9698 - val_loss: 0.2601 - val_acc: 0.9284
#
# Epoch 00003: val_acc improved from 0.92735 to 0.92844, saving model to /mnt/seals/models/282/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.0745 - acc: 0.9698 - val_loss: 0.2672 - val_acc: 0.9276
#
# Epoch 00004: val_acc did not improve from 0.92844
# Epoch 5/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 0.0731 - acc: 0.9704 - val_loss: 0.2633 - val_acc: 0.9253
#
# Epoch 00005: val_acc did not improve from 0.92844
# Epoch 6/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.0722 - acc: 0.9708 - val_loss: 0.2527 - val_acc: 0.9290
#
# Epoch 00006: val_acc improved from 0.92844 to 0.92904, saving model to /mnt/seals/models/282/model_round_2.h5
# Epoch 7/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.0708 - acc: 0.9711 - val_loss: 0.2559 - val_acc: 0.9282
#
# Epoch 00007: val_acc did not improve from 0.92904
# Epoch 8/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.0696 - acc: 0.9714 - val_loss: 0.2714 - val_acc: 0.9286
#
# Epoch 00008: val_acc did not improve from 0.92904
# Epoch 9/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.0688 - acc: 0.9718 - val_loss: 0.2835 - val_acc: 0.9245
#
# Epoch 00009: val_acc did not improve from 0.92904
# H2 {'val_acc': [0.9259424522305308, 0.9273460692565142, 0.9284377717183518, 0.9276134223024769, 0.9253408988044177, 0.9290393224672756, 0.9282372550003541, 0.9285714485387987, 0.924471989952618], 'acc': [0.9677142454662692, 0.969037760798863, 0.9697502415877078, 0.9698045040860948, 0.9704249750256111, 0.9707717796424307, 0.971142174632473, 0.9714488714469279, 0.971814550270761], 'loss': [0.08133622311871308, 0.07711755351543018, 0.07521309966800581, 0.07448915050376581, 0.0730853467816605, 0.07216032387029957, 0.07078960983828073, 0.06964343507216593, 0.06884944746146349], 'val_loss': [0.25744440212743547, 0.2654596341266085, 0.26006562787521204, 0.2671740599631966, 0.2633115586383746, 0.25271702967282017, 0.2559084227809442, 0.2713591775630908, 0.28353751640876085]}
# stopped_epoch2 6
# 9
# 0.9282372550003541
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 336us/step - loss: 0.0664 - acc: 0.9728 - val_loss: 0.2825 - val_acc: 0.9258
#
# Epoch 00001: val_acc improved from -inf to 0.92583, saving model to /mnt/seals/models/282/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.0655 - acc: 0.9730 - val_loss: 0.2863 - val_acc: 0.9258
#
# Epoch 00002: val_acc did not improve from 0.92583
# Epoch 3/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.0661 - acc: 0.9728 - val_loss: 0.2806 - val_acc: 0.9261
#
# Epoch 00003: val_acc improved from 0.92583 to 0.92605, saving model to /mnt/seals/models/282/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 0.0659 - acc: 0.9727 - val_loss: 0.2830 - val_acc: 0.9260
#
# Epoch 00004: val_acc did not improve from 0.92605
# Epoch 5/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 0.0650 - acc: 0.9732 - val_loss: 0.2864 - val_acc: 0.9258
#
# Epoch 00005: val_acc did not improve from 0.92605
# Epoch 6/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.0654 - acc: 0.9730 - val_loss: 0.2860 - val_acc: 0.9258
#
# Epoch 00006: val_acc did not improve from 0.92605
# H3 {'val_acc': [0.925831050219866, 0.9258087709481019, 0.9260538479944207, 0.9259647273377783, 0.9258310523021244, 0.9258310481376076], 'acc': [0.9727676703967582, 0.9730035913883759, 0.972836086740699, 0.9726615052342271, 0.9731852484326605, 0.9730366177852862], 'loss': [0.0663854199639635, 0.06545904806225239, 0.0660829291963239, 0.06592132988405128, 0.06500554954545418, 0.06539261404517126], 'val_loss': [0.28246998498756587, 0.2862831782305605, 0.2805932451804132, 0.2830281991439541, 0.28635273071578793, 0.28599306466946806]}
# stopped_epoch3 3
# 6
# 0.9259647273377783
# best fit round 2 0.9282372550003541
# 3137/3137 [==============================] - 2s 651us/step
# 2019-01-20 16:16:33,199 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "2",
#     "fit_dt_test_end": "2019-01-20 16:16:31",
#     "fit_dt_test_start": "2019-01-20 16:16:29",
#     "fit_dt_train_duration_seconds": "379",
#     "fit_dt_train_end": "2019-01-20 16:16:26",
#     "fit_dt_train_start": "2019-01-20 16:10:06",
#     "fit_num_epochs": 15,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 6,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.693018807778132,
#     "fit_train_acc": 0.971142174632473,
#     "fit_train_loss": 0.07078960983828073,
#     "fit_val_acc": 0.9282372550003541,
#     "fit_val_loss": 0.2559084227809442,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 128,
#     "layer_3_size": 128,
#     "model_id": 282,
#     "model_param_count": 443783,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/282/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:16:33,201 [MainThread  ] [INFO ]  model 282 test acc: 0.693018807778132
# 2019-01-20 16:16:35,732 [MainThread  ] [INFO ]  Begin experiment for model_id=290 on GPU:2
# 2019-01-20 16:16:35,734 [MainThread  ] [INFO ]  Loading data
# 290   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'vgg16', 'layer_1_size': 128, 'layer_2_size': 512, 'sequence_length': 3, 'model_id': 290}
# 2019-01-20 16:16:36,890 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:16:36,891 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 22s 359us/step - loss: 0.1827 - acc: 0.9344 - val_loss: 0.1856 - val_acc: 0.9362
#
# Epoch 00001: val_acc improved from -inf to 0.93619, saving model to /mnt/seals/models/290/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.1326 - acc: 0.9490 - val_loss: 0.1764 - val_acc: 0.9389
#
# Epoch 00002: val_acc improved from 0.93619 to 0.93891, saving model to /mnt/seals/models/290/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 261us/step - loss: 0.1204 - acc: 0.9532 - val_loss: 0.1962 - val_acc: 0.9275
#
# Epoch 00003: val_acc did not improve from 0.93891
# Epoch 4/20
# 60553/60553 [==============================] - 15s 255us/step - loss: 0.1143 - acc: 0.9555 - val_loss: 0.2158 - val_acc: 0.9262
#
# Epoch 00004: val_acc did not improve from 0.93891
# Epoch 5/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.1084 - acc: 0.9578 - val_loss: 0.2668 - val_acc: 0.9178
#
# Epoch 00005: val_acc did not improve from 0.93891
# H1 {'val_acc': [0.9361910906644144, 0.9389092072574927, 0.9275243061078168, 0.9262320836558613, 0.9177658155197957], 'acc': [0.9344305414654483, 0.9490128071690492, 0.9531579363240382, 0.9554510846523152, 0.9577725452980909], 'loss': [0.1827429281824972, 0.13256739400034487, 0.12038528018304226, 0.11426637761365345, 0.10841056024847799], 'val_loss': [0.1855958603503774, 0.1763843775483421, 0.19618036130853392, 0.21584877256520152, 0.2668261481164324]}
# stopped_epoch1 2
# 5
# 0.9275243061078168
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 334us/step - loss: 0.0909 - acc: 0.9635 - val_loss: 0.2260 - val_acc: 0.9315
#
# Epoch 00001: val_acc improved from -inf to 0.93147, saving model to /mnt/seals/models/290/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 258us/step - loss: 0.0866 - acc: 0.9647 - val_loss: 0.2369 - val_acc: 0.9275
#
# Epoch 00002: val_acc did not improve from 0.93147
# Epoch 3/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 0.0847 - acc: 0.9655 - val_loss: 0.2480 - val_acc: 0.9279
#
# Epoch 00003: val_acc did not improve from 0.93147
# Epoch 4/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 0.0830 - acc: 0.9662 - val_loss: 0.2716 - val_acc: 0.9219
#
# Epoch 00004: val_acc did not improve from 0.93147
# H2 {'val_acc': [0.9314677987854256, 0.927524302538231, 0.927880775422806, 0.9219098305672463], 'acc': [0.9634983418566733, 0.9646873821198824, 0.9655036683600579, 0.9662090701432656], 'loss': [0.09093985743185154, 0.08657701460408146, 0.08472733228634388, 0.08296520589104853], 'val_loss': [0.226010682225153, 0.23687091677990543, 0.2479652296135891, 0.27161616577777875]}
# stopped_epoch2 1
# 4
# 0.927524302538231
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 343us/step - loss: 0.0807 - acc: 0.9669 - val_loss: 0.2653 - val_acc: 0.9247
#
# Epoch 00001: val_acc improved from -inf to 0.92467, saving model to /mnt/seals/models/290/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 265us/step - loss: 0.0803 - acc: 0.9669 - val_loss: 0.2621 - val_acc: 0.9249
#
# Epoch 00002: val_acc improved from 0.92467 to 0.92487, saving model to /mnt/seals/models/290/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.0805 - acc: 0.9669 - val_loss: 0.2660 - val_acc: 0.9256
#
# Epoch 00003: val_acc improved from 0.92487 to 0.92563, saving model to /mnt/seals/models/290/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.0798 - acc: 0.9672 - val_loss: 0.2747 - val_acc: 0.9244
#
# Epoch 00004: val_acc did not improve from 0.92563
# Epoch 5/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.0795 - acc: 0.9673 - val_loss: 0.2727 - val_acc: 0.9255
#
# Epoch 00005: val_acc did not improve from 0.92563
# Epoch 6/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.0791 - acc: 0.9672 - val_loss: 0.2774 - val_acc: 0.9249
#
# Epoch 00006: val_acc did not improve from 0.92563
# H3 {'val_acc': [0.9246725072655466, 0.9248730242810098, 0.9256305329069374, 0.9244274305166933, 0.9254745756248646, 0.9249398632861642], 'acc': [0.96690739691036, 0.9669380665156178, 0.9669475035649859, 0.9671645501743777, 0.9672825114960466, 0.9672117343187596], 'loss': [0.08069935627081722, 0.08026992924633368, 0.080530857278544, 0.07984685980683835, 0.07954512302413136, 0.07914730425243455], 'val_loss': [0.2653057981266205, 0.2621390718411299, 0.2660323778540361, 0.27470005566227534, 0.2726570929651028, 0.27741299966537275]}
# stopped_epoch3 3
# 6
# 0.9244274305166933
# best fit round 1 0.9275243061078168
# 3137/3137 [==============================] - 2s 653us/step
# 2019-01-20 16:21:27,794 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "2",
#     "fit_dt_test_end": "2019-01-20 16:21:26",
#     "fit_dt_test_start": "2019-01-20 16:21:24",
#     "fit_dt_train_duration_seconds": "283",
#     "fit_dt_train_end": "2019-01-20 16:21:21",
#     "fit_dt_train_start": "2019-01-20 16:16:38",
#     "fit_num_epochs": 9,
#     "fit_stopped_epoch1": 2,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.6662416321326108,
#     "fit_train_acc": 0.9531579363240382,
#     "fit_train_loss": 0.12038528018304226,
#     "fit_val_acc": 0.9275243061078168,
#     "fit_val_loss": 0.19618036130853392,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 512,
#     "layer_3_size": 128,
#     "model_id": 290,
#     "model_param_count": 329351,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/290/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:21:27,795 [MainThread  ] [INFO ]  model 290 test acc: 0.6662416321326108
# 2019-01-20 16:21:30,308 [MainThread  ] [INFO ]  Begin experiment for model_id=298 on GPU:2
# 2019-01-20 16:21:30,310 [MainThread  ] [INFO ]  Loading data
# 298   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_3_size': 128, 'sequence_model': nan, 'WORKER': 2, 'pooling': 'max', 'sequence_model_layers': nan, 'dropout': 0.2, 'architecture': 'video_MLP_concat', 'pretrained_model_name': 'vgg16', 'layer_1_size': 128, 'layer_2_size': 128, 'sequence_length': 3, 'model_id': 298}
# 2019-01-20 16:21:31,448 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:21:31,450 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 22s 357us/step - loss: 0.2123 - acc: 0.9281 - val_loss: 0.1927 - val_acc: 0.9214
#
# Epoch 00001: val_acc improved from -inf to 0.92138, saving model to /mnt/seals/models/298/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 0.1301 - acc: 0.9484 - val_loss: 0.2242 - val_acc: 0.9088
#
# Epoch 00002: val_acc did not improve from 0.92138
# Epoch 3/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1176 - acc: 0.9533 - val_loss: 0.2253 - val_acc: 0.9262
#
# Epoch 00003: val_acc improved from 0.92138 to 0.92617, saving model to /mnt/seals/models/298/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.1117 - acc: 0.9554 - val_loss: 0.2230 - val_acc: 0.9274
#
# Epoch 00004: val_acc improved from 0.92617 to 0.92744, saving model to /mnt/seals/models/298/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.1067 - acc: 0.9573 - val_loss: 0.2953 - val_acc: 0.9099
#
# Epoch 00005: val_acc did not improve from 0.92744
# Epoch 6/20
# 60553/60553 [==============================] - 16s 264us/step - loss: 0.1016 - acc: 0.9595 - val_loss: 0.2409 - val_acc: 0.9304
#
# Epoch 00006: val_acc improved from 0.92744 to 0.93038, saving model to /mnt/seals/models/298/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 16s 261us/step - loss: 0.0988 - acc: 0.9601 - val_loss: 0.3204 - val_acc: 0.9127
#
# Epoch 00007: val_acc did not improve from 0.93038
# Epoch 8/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 0.0962 - acc: 0.9612 - val_loss: 0.2801 - val_acc: 0.9233
#
# Epoch 00008: val_acc did not improve from 0.93038
# Epoch 9/20
# 51744/60553 [========================>.....] - ETA: 2s - loss: 0.0950 - acc: 0.9619
