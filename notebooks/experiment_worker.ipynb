# %%
WORKER_ID = 0

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 15:05:25,454 [MainThread  ] [INFO ]  Begin experiment for model_id=192 on GPU:0
# 2019-01-20 15:05:25,455 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 15:05:25,456 [MainThread  ] [INFO ]  Loading data
# 192   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 512, 'model_id': 192, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 512, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:05:26,550 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:05:26,551 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 22s 365us/step - loss: 3.9961 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/192/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 18s 294us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 18s 294us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H1 {'loss': [3.996050113182943, 4.000005363699462, 4.000005358856518, 4.000005361053561], 'val_acc': [0.7323767973792159, 0.7323767973792159, 0.7323767973792159, 0.7323767973792159], 'val_loss': [4.290063843902616, 4.290063843902616, 4.290063843902616, 4.290063843902616], 'acc': [0.7504995636878343, 0.7504712535024128, 0.7504712534216971, 0.7504712537544035]}
# stopped_epoch1 1
# 4
# 0.7323767973792159
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 308us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/192/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 18s 301us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H2 {'loss': [4.000005359919603, 4.000005360998438, 4.000005359344749, 4.000005361179556], 'val_acc': [0.7323767973792159, 0.7323767973792159, 0.7323767973792159, 0.7323767973792159], 'val_loss': [4.290063843902616, 4.290063843902616, 4.290063843902616, 4.290063843902616], 'acc': [0.7504712532189234, 0.750471254177669, 0.7504712533941356, 0.7504712542583848]}
# stopped_epoch2 1
# 4
# 0.7323767973792159
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 312us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/192/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 18s 301us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 19s 319us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H3 {'loss': [4.000005361809533, 4.000005360423584, 4.0000053594156215, 4.000005362439509], 'val_acc': [0.7323767973792159, 0.7323767973792159, 0.7323767973792159, 0.7323767973792159], 'val_loss': [4.290063843902616, 4.290063843902616, 4.290063843902616, 4.290063843902616], 'acc': [0.7504712540693917, 0.7504712533764175, 0.7504712534079163, 0.7504712525889468]}
# stopped_epoch3 1
# 4
# 0.7323767973792159
# best fit round 1 0.7323767973792159
# 3137/3137 [==============================] - 0s 109us/step
# 2019-01-20 15:09:21,321 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:09:19",
#     "fit_dt_test_start": "2019-01-20 15:09:19",
#     "fit_dt_train_duration_seconds": "228",
#     "fit_dt_train_end": "2019-01-20 15:09:18",
#     "fit_dt_train_start": "2019-01-20 15:05:29",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.18425247051322924,
#     "fit_train_acc": 0.7504712535024128,
#     "fit_train_loss": 4.000005363699462,
#     "fit_val_acc": 0.7323767973792159,
#     "fit_val_loss": 4.290063843902616,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 512,
#     "layer_3_size": 512,
#     "model_id": 192,
#     "model_param_count": 2888711,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/192/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:09:21,322 [MainThread  ] [INFO ]  model 192 test acc: 0.18425247051322924
# 2019-01-20 15:09:25,131 [MainThread  ] [INFO ]  Begin experiment for model_id=200 on GPU:0
# 2019-01-20 15:09:25,134 [MainThread  ] [INFO ]  Loading data
# 200   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 512, 'model_id': 200, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 128, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:09:26,238 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:09:26,240 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 334us/step - loss: 0.2077 - acc: 0.9206 - val_loss: 0.2225 - val_acc: 0.8886
#
# Epoch 00001: val_acc improved from -inf to 0.88862, saving model to /mnt/seals/models/200/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 19s 309us/step - loss: 0.1587 - acc: 0.9368 - val_loss: 0.2802 - val_acc: 0.8913
#
# Epoch 00002: val_acc improved from 0.88862 to 0.89130, saving model to /mnt/seals/models/200/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 19s 307us/step - loss: 0.1493 - acc: 0.9412 - val_loss: 0.1718 - val_acc: 0.9288
#
# Epoch 00003: val_acc improved from 0.89130 to 0.92879, saving model to /mnt/seals/models/200/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 19s 310us/step - loss: 0.1472 - acc: 0.9421 - val_loss: 0.2012 - val_acc: 0.9081
#
# Epoch 00004: val_acc did not improve from 0.92879
# Epoch 5/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1616 - acc: 0.9377 - val_loss: 0.2085 - val_acc: 0.8957
#
# Epoch 00005: val_acc did not improve from 0.92879
# Epoch 6/20
# 60553/60553 [==============================] - 20s 322us/step - loss: 0.1682 - acc: 0.9336 - val_loss: 0.1738 - val_acc: 0.9239
#
# Epoch 00006: val_acc did not improve from 0.92879
# H1 {'loss': [0.20765446354778327, 0.15866202148249656, 0.14931247135290507, 0.1472340586318223, 0.16156191672718406, 0.16821509295968048], 'val_acc': [0.8886240217660415, 0.8912975822696817, 0.9287942435989808, 0.9080964443985552, 0.8956866761482438, 0.9239150018373729], 'val_loss': [0.22254126869881072, 0.28018461598207706, 0.17179465079848572, 0.20116780880497012, 0.20851315686238683, 0.17378999726964173], 'acc': [0.920626814583162, 0.9368251369896923, 0.941196749759146, 0.9420979684533907, 0.9376697346211039, 0.9335977415503978]}
# stopped_epoch1 3
# 6
# 0.9080964443985552
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 341us/step - loss: 0.1499 - acc: 0.9414 - val_loss: 0.1869 - val_acc: 0.9085
#
# Epoch 00001: val_acc improved from -inf to 0.90850, saving model to /mnt/seals/models/200/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 19s 314us/step - loss: 0.1454 - acc: 0.9429 - val_loss: 0.1874 - val_acc: 0.9083
#
# Epoch 00002: val_acc did not improve from 0.90850
# Epoch 3/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1429 - acc: 0.9439 - val_loss: 0.1911 - val_acc: 0.9066
#
# Epoch 00003: val_acc did not improve from 0.90850
# Epoch 4/20
# 60553/60553 [==============================] - 19s 321us/step - loss: 0.1412 - acc: 0.9445 - val_loss: 0.1843 - val_acc: 0.9082
#
# Epoch 00004: val_acc did not improve from 0.90850
# H2 {'loss': [0.14987204728603065, 0.14542662033545534, 0.1428684339665769, 0.1411563106119424], 'val_acc': [0.9084974766446885, 0.9082969573610512, 0.9066259868057237, 0.9081632799456734], 'val_loss': [0.18693105483233594, 0.18742330101361068, 0.19111209285590178, 0.18431092959527143], 'acc': [0.9413713327293292, 0.9428835832525173, 0.9439169165568492, 0.9445161546835638]}
# stopped_epoch2 1
# 4
# 0.9082969573610512
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 351us/step - loss: 0.1398 - acc: 0.9452 - val_loss: 0.1870 - val_acc: 0.9079
#
# Epoch 00001: val_acc improved from -inf to 0.90792, saving model to /mnt/seals/models/200/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 19s 313us/step - loss: 0.1383 - acc: 0.9453 - val_loss: 0.1888 - val_acc: 0.9076
#
# Epoch 00002: val_acc did not improve from 0.90792
# Epoch 3/20
# 60553/60553 [==============================] - 19s 312us/step - loss: 0.1386 - acc: 0.9458 - val_loss: 0.1913 - val_acc: 0.9061
#
# Epoch 00003: val_acc did not improve from 0.90792
# Epoch 4/20
# 60553/60553 [==============================] - 19s 312us/step - loss: 0.1391 - acc: 0.9455 - val_loss: 0.1898 - val_acc: 0.9067
#
# Epoch 00004: val_acc did not improve from 0.90792
# H3 {'loss': [0.13977990967718326, 0.13825631388239373, 0.13863455446029208, 0.13909673992028065], 'val_acc': [0.9079182070638713, 0.9076062919047945, 0.9061358331964675, 0.9067373833504604], 'val_loss': [0.18696536845571163, 0.18882266184778712, 0.19126804080034746, 0.1897982719237553], 'acc': [0.9452475116736918, 0.9452522289738589, 0.9457736146118715, 0.9455164605436491]}
# stopped_epoch3 1
# 4
# 0.9076062919047945
# best fit round 2 0.9082969573610512
# 3137/3137 [==============================] - 0s 147us/step
# 2019-01-20 15:14:11,416 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:14:09",
#     "fit_dt_test_start": "2019-01-20 15:14:09",
#     "fit_dt_train_duration_seconds": "279",
#     "fit_dt_train_end": "2019-01-20 15:14:08",
#     "fit_dt_train_start": "2019-01-20 15:09:29",
#     "fit_num_epochs": 8,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.5304430985017532,
#     "fit_train_acc": 0.9428835832525173,
#     "fit_train_loss": 0.14542662033545534,
#     "fit_val_acc": 0.9082969573610512,
#     "fit_val_loss": 0.18742330101361068,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 128,
#     "layer_3_size": 512,
#     "model_id": 200,
#     "model_param_count": 2495111,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/200/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:14:11,418 [MainThread  ] [INFO ]  model 200 test acc: 0.5304430985017532
# 2019-01-20 15:14:14,393 [MainThread  ] [INFO ]  Begin experiment for model_id=208 on GPU:0
# 2019-01-20 15:14:14,396 [MainThread  ] [INFO ]  Loading data
# 208   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 256, 'model_id': 208, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 512, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:14:15,530 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:14:15,532 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.2397 - acc: 0.9084 - val_loss: 0.2060 - val_acc: 0.9152
#
# Epoch 00001: val_acc improved from -inf to 0.91518, saving model to /mnt/seals/models/208/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 0.1884 - acc: 0.9203 - val_loss: 0.2245 - val_acc: 0.9125
#
# Epoch 00002: val_acc did not improve from 0.91518
# Epoch 3/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1833 - acc: 0.9217 - val_loss: 0.1989 - val_acc: 0.9148
#
# Epoch 00003: val_acc did not improve from 0.91518
# Epoch 4/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1826 - acc: 0.9224 - val_loss: 0.1996 - val_acc: 0.9131
#
# Epoch 00004: val_acc did not improve from 0.91518
# H1 {'loss': [0.2396694558684742, 0.1883900298990472, 0.18326445660827287, 0.18259129479930805], 'val_acc': [0.9151813869021196, 0.9124855415492376, 0.9147580715171709, 0.9130870954959153], 'val_loss': [0.20596845515876433, 0.22454332173130917, 0.19889433874387855, 0.19955257834379775], 'acc': [0.9083542180378691, 0.9202752973811564, 0.9217356456998865, 0.9224150989854247]}
# stopped_epoch1 1
# 4
# 0.9124855415492376
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 311us/step - loss: 0.1651 - acc: 0.9289 - val_loss: 0.2025 - val_acc: 0.9069
#
# Epoch 00001: val_acc improved from -inf to 0.90694, saving model to /mnt/seals/models/208/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1632 - acc: 0.9298 - val_loss: 0.1986 - val_acc: 0.9102
#
# Epoch 00002: val_acc improved from 0.90694 to 0.91021, saving model to /mnt/seals/models/208/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1605 - acc: 0.9310 - val_loss: 0.2271 - val_acc: 0.8975
#
# Epoch 00003: val_acc did not improve from 0.91021
# Epoch 4/20
# 60553/60553 [==============================] - 17s 289us/step - loss: 0.1591 - acc: 0.9320 - val_loss: 0.2050 - val_acc: 0.9051
#
# Epoch 00004: val_acc did not improve from 0.91021
# Epoch 5/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1574 - acc: 0.9335 - val_loss: 0.1965 - val_acc: 0.9045
#
# Epoch 00005: val_acc did not improve from 0.91021
# H2 {'loss': [0.16507376310547883, 0.16323509466655386, 0.16045271707439854, 0.15912606081594857, 0.15736380694575083], 'val_acc': [0.9069379021507163, 0.910213016972866, 0.8974690505362122, 0.9050886937401403, 0.9045094213705842], 'val_loss': [0.20247680645061894, 0.1986052468372596, 0.2270964183475699, 0.20501567624132855, 0.19645602082693048], 'acc': [0.9289430273303075, 0.9298064982641258, 0.9310497984241152, 0.9320477440483479, 0.9334561902197115]}
# stopped_epoch2 2
# 5
# 0.8974690505362122
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 303us/step - loss: 0.1545 - acc: 0.9348 - val_loss: 0.2108 - val_acc: 0.8987
#
# Epoch 00001: val_acc improved from -inf to 0.89869, saving model to /mnt/seals/models/208/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 293us/step - loss: 0.1541 - acc: 0.9351 - val_loss: 0.2098 - val_acc: 0.8980
#
# Epoch 00002: val_acc did not improve from 0.89869
# Epoch 3/20
# 60553/60553 [==============================] - 18s 290us/step - loss: 0.1536 - acc: 0.9352 - val_loss: 0.2117 - val_acc: 0.8974
#
# Epoch 00003: val_acc did not improve from 0.89869
# Epoch 4/20
# 60553/60553 [==============================] - 17s 281us/step - loss: 0.1526 - acc: 0.9358 - val_loss: 0.2118 - val_acc: 0.8963
#
# Epoch 00004: val_acc did not improve from 0.89869
# H3 {'loss': [0.15450987927697465, 0.15411576588450165, 0.15355924035660914, 0.15255216033846727], 'val_acc': [0.8986944297069471, 0.8980037580039154, 0.8973799306604168, 0.896265943274971], 'val_loss': [0.21075577376711316, 0.20976419001352914, 0.21166068718013953, 0.21181347532080474], 'acc': [0.9348386857416416, 0.9350981999827189, 0.9352232364642146, 0.9357965246128146]}
# stopped_epoch3 1
# 4
# 0.8980037580039154
# best fit round 1 0.9124855415492376
# 3137/3137 [==============================] - 1s 191us/step
# 2019-01-20 15:18:17,675 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:18:16",
#     "fit_dt_test_start": "2019-01-20 15:18:15",
#     "fit_dt_train_duration_seconds": "235",
#     "fit_dt_train_end": "2019-01-20 15:18:14",
#     "fit_dt_train_start": "2019-01-20 15:14:18",
#     "fit_num_epochs": 7,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.5932419509085114,
#     "fit_train_acc": 0.9202752973811564,
#     "fit_train_loss": 0.1883900298990472,
#     "fit_val_acc": 0.9124855415492376,
#     "fit_val_loss": 0.22454332173130917,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 512,
#     "layer_3_size": 512,
#     "model_id": 208,
#     "model_param_count": 1577735,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/208/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:18:17,676 [MainThread  ] [INFO ]  model 208 test acc: 0.5932419509085114
# 2019-01-20 15:18:20,399 [MainThread  ] [INFO ]  Begin experiment for model_id=216 on GPU:0
# 2019-01-20 15:18:20,402 [MainThread  ] [INFO ]  Loading data
# 216   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 256, 'model_id': 216, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 128, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:18:21,506 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:18:21,512 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 310us/step - loss: 0.2116 - acc: 0.9171 - val_loss: 0.2000 - val_acc: 0.8978
#
# Epoch 00001: val_acc improved from -inf to 0.89785, saving model to /mnt/seals/models/216/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1783 - acc: 0.9284 - val_loss: 0.1868 - val_acc: 0.9031
#
# Epoch 00002: val_acc improved from 0.89785 to 0.90311, saving model to /mnt/seals/models/216/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1698 - acc: 0.9323 - val_loss: 0.2195 - val_acc: 0.9064
#
# Epoch 00003: val_acc improved from 0.90311 to 0.90638, saving model to /mnt/seals/models/216/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 0.1681 - acc: 0.9331 - val_loss: 0.2040 - val_acc: 0.8986
#
# Epoch 00004: val_acc did not improve from 0.90638
# Epoch 5/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1640 - acc: 0.9344 - val_loss: 0.1843 - val_acc: 0.9124
#
# Epoch 00005: val_acc improved from 0.90638 to 0.91240, saving model to /mnt/seals/models/216/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 18s 292us/step - loss: 0.1643 - acc: 0.9344 - val_loss: 0.1957 - val_acc: 0.9040
#
# Epoch 00006: val_acc did not improve from 0.91240
# Epoch 7/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 0.1664 - acc: 0.9330 - val_loss: 0.1840 - val_acc: 0.9189
#
# Epoch 00007: val_acc improved from 0.91240 to 0.91888, saving model to /mnt/seals/models/216/model_round_1.h5
# Epoch 8/20
# 60553/60553 [==============================] - 18s 292us/step - loss: 0.1698 - acc: 0.9315 - val_loss: 0.2034 - val_acc: 0.9121
#
# Epoch 00008: val_acc did not improve from 0.91888
# Epoch 9/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1666 - acc: 0.9335 - val_loss: 0.1948 - val_acc: 0.9118
#
# Epoch 00009: val_acc did not improve from 0.91888
# Epoch 10/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1603 - acc: 0.9357 - val_loss: 0.2106 - val_acc: 0.9015
#
# Epoch 00010: val_acc did not improve from 0.91888
# H1 {'loss': [0.21159299037860996, 0.17828784979450563, 0.169786142288163, 0.1680518303457705, 0.16399559952394832, 0.16432492474032112, 0.1664236286769836, 0.16984664746085443, 0.16658586071193845, 0.1602561054685603], 'val_acc': [0.8978477990857825, 0.9031058033034717, 0.9063809110979996, 0.8986275900696786, 0.9123964199630157, 0.9040415520528221, 0.9188798046900344, 0.9120622220741387, 0.9118171444328889, 0.9014793896927955], 'val_loss': [0.19996588077124253, 0.1867674165361759, 0.2194994867349965, 0.2039511938970385, 0.18428090823603954, 0.19565795944842115, 0.1839650989471193, 0.20341020647764058, 0.19483770088932326, 0.21059760788754234], 'acc': [0.9171092352748927, 0.9283673776366848, 0.932274225057269, 0.9331046669974921, 0.9344352605078944, 0.9344329020379448, 0.9329914248708419, 0.9314886086832008, 0.933475061843821, 0.9356809228960375]}
# stopped_epoch1 7
# 10
# 0.9120622220741387
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 328us/step - loss: 0.1428 - acc: 0.9421 - val_loss: 0.1974 - val_acc: 0.9048
#
# Epoch 00001: val_acc improved from -inf to 0.90484, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 297us/step - loss: 0.1402 - acc: 0.9435 - val_loss: 0.1910 - val_acc: 0.9073
#
# Epoch 00002: val_acc improved from 0.90484 to 0.90734, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1384 - acc: 0.9437 - val_loss: 0.1910 - val_acc: 0.9068
#
# Epoch 00003: val_acc did not improve from 0.90734
# Epoch 4/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1360 - acc: 0.9450 - val_loss: 0.1785 - val_acc: 0.9123
#
# Epoch 00004: val_acc improved from 0.90734 to 0.91229, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1360 - acc: 0.9451 - val_loss: 0.1788 - val_acc: 0.9105
#
# Epoch 00005: val_acc did not improve from 0.91229
# Epoch 6/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1350 - acc: 0.9455 - val_loss: 0.1753 - val_acc: 0.9127
#
# Epoch 00006: val_acc improved from 0.91229 to 0.91266, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 7/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 0.1335 - acc: 0.9462 - val_loss: 0.1813 - val_acc: 0.9106
#
# Epoch 00007: val_acc did not improve from 0.91266
# Epoch 8/20
# 60553/60553 [==============================] - 18s 294us/step - loss: 0.1335 - acc: 0.9458 - val_loss: 0.1781 - val_acc: 0.9146
#
# Epoch 00008: val_acc improved from 0.91266 to 0.91458, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 9/20
# 60553/60553 [==============================] - 18s 289us/step - loss: 0.1321 - acc: 0.9469 - val_loss: 0.1769 - val_acc: 0.9163
#
# Epoch 00009: val_acc improved from 0.91458 to 0.91625, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 10/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1319 - acc: 0.9464 - val_loss: 0.1771 - val_acc: 0.9151
#
# Epoch 00010: val_acc did not improve from 0.91625
# Epoch 11/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1307 - acc: 0.9472 - val_loss: 0.1810 - val_acc: 0.9126
#
# Epoch 00011: val_acc did not improve from 0.91625
# Epoch 12/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1308 - acc: 0.9470 - val_loss: 0.1759 - val_acc: 0.9176
#
# Epoch 00012: val_acc improved from 0.91625 to 0.91763, saving model to /mnt/seals/models/216/model_round_2.h5
# Epoch 13/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1307 - acc: 0.9468 - val_loss: 0.1806 - val_acc: 0.9148
#
# Epoch 00013: val_acc did not improve from 0.91763
# Epoch 14/20
# 60553/60553 [==============================] - 18s 290us/step - loss: 0.1290 - acc: 0.9477 - val_loss: 0.1761 - val_acc: 0.9169
#
# Epoch 00014: val_acc did not improve from 0.91763
# Epoch 15/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1285 - acc: 0.9479 - val_loss: 0.1839 - val_acc: 0.9176
#
# Epoch 00015: val_acc did not improve from 0.91763
# H2 {'loss': [0.14276774875609158, 0.14020682851273505, 0.13841548165558348, 0.13599920038653038, 0.13602970735151845, 0.13504421039526168, 0.1334636084873324, 0.13350788528825944, 0.1321062047928466, 0.13193300798353982, 0.13066768448363603, 0.13081505876290733, 0.13071860471663188, 0.12899975364010624, 0.12847297172459726], 'val_acc': [0.9048436159501578, 0.907338934657132, 0.9067596634774377, 0.9122850209641888, 0.9105249246581227, 0.9126637721537652, 0.9105694875892668, 0.9145798261881023, 0.9162508007220306, 0.9151145384524364, 0.9125523746794488, 0.9176321360965259, 0.9148248972851116, 0.9168523523633508, 0.91760985645293], 'val_loss': [0.19741220806660834, 0.19098746040353756, 0.19099537424013455, 0.17848810008817068, 0.1788403431531123, 0.17531968360384478, 0.18132359106430618, 0.1780927605225158, 0.17691773931941462, 0.17710643195206124, 0.18097198509604798, 0.17587547420674537, 0.1805521151700469, 0.17610107550975015, 0.1838826141596138], 'acc': [0.9420555009122643, 0.9435182107740485, 0.9437470541184162, 0.9449856389085262, 0.945068209737841, 0.9455258976373125, 0.9462100674316097, 0.9457924863127594, 0.9469013155484132, 0.9464436291343082, 0.9471608270894503, 0.9470287114172619, 0.9467927918923084, 0.9476892906040637, 0.9478969007271291]}
# stopped_epoch2 12
# 15
# 0.9148248972851116
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1265 - acc: 0.9487 - val_loss: 0.1806 - val_acc: 0.9185
#
# Epoch 00001: val_acc improved from -inf to 0.91855, saving model to /mnt/seals/models/216/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1260 - acc: 0.9492 - val_loss: 0.1797 - val_acc: 0.9194
#
# Epoch 00002: val_acc improved from 0.91855 to 0.91941, saving model to /mnt/seals/models/216/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 0.1252 - acc: 0.9492 - val_loss: 0.1800 - val_acc: 0.9201
#
# Epoch 00003: val_acc improved from 0.91941 to 0.92011, saving model to /mnt/seals/models/216/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 282us/step - loss: 0.1263 - acc: 0.9486 - val_loss: 0.1797 - val_acc: 0.9197
#
# Epoch 00004: val_acc did not improve from 0.92011
# Epoch 5/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1251 - acc: 0.9493 - val_loss: 0.1804 - val_acc: 0.9188
#
# Epoch 00005: val_acc did not improve from 0.92011
# Epoch 6/20
# 60553/60553 [==============================] - 17s 281us/step - loss: 0.1256 - acc: 0.9490 - val_loss: 0.1802 - val_acc: 0.9206
#
# Epoch 00006: val_acc improved from 0.92011 to 0.92064, saving model to /mnt/seals/models/216/model_round_3.h5
# Epoch 7/20
# 60553/60553 [==============================] - 18s 297us/step - loss: 0.1252 - acc: 0.9493 - val_loss: 0.1768 - val_acc: 0.9228
#
# Epoch 00007: val_acc improved from 0.92064 to 0.92285, saving model to /mnt/seals/models/216/model_round_3.h5
# Epoch 8/20
# 60553/60553 [==============================] - 18s 290us/step - loss: 0.1251 - acc: 0.9492 - val_loss: 0.1801 - val_acc: 0.9187
#
# Epoch 00008: val_acc did not improve from 0.92285
# Epoch 9/20
# 60553/60553 [==============================] - 18s 300us/step - loss: 0.1259 - acc: 0.9487 - val_loss: 0.1788 - val_acc: 0.9209
#
# Epoch 00009: val_acc did not improve from 0.92285
# Epoch 10/20
# 60553/60553 [==============================] - 18s 298us/step - loss: 0.1253 - acc: 0.9489 - val_loss: 0.1782 - val_acc: 0.9204
#
# Epoch 00010: val_acc did not improve from 0.92285
# H3 {'loss': [0.12654660971635898, 0.12596602360640513, 0.12521557950624365, 0.12630919825567502, 0.12510278616199907, 0.1256036126051855, 0.1251760680108075, 0.12513372949356308, 0.1258733552474961, 0.12530984016892013], 'val_acc': [0.9185456005171991, 0.919414508179137, 0.9201051819644269, 0.9197041464461733, 0.9187683997790812, 0.9206398934107308, 0.92284557433405, 0.9186792826920246, 0.9209072482414864, 0.9204393752054059], 'val_loss': [0.1806160541099083, 0.17974297282142485, 0.17999129603411804, 0.17971204848714864, 0.18038996298351812, 0.1801814813299322, 0.1767804398342586, 0.1801177920472674, 0.1787719565931143, 0.17821697840561215], 'acc': [0.9486518470096763, 0.9491708740468222, 0.9492487269459934, 0.9485645558789466, 0.9493195028003295, 0.9490269613305758, 0.949274677639722, 0.9491708730664211, 0.9486777986572289, 0.9489113594415396]}
# stopped_epoch3 7
# 10
# 0.9186792826920246
# best fit round 3 0.9186792826920246
# 3137/3137 [==============================] - 1s 261us/step
# 2019-01-20 15:28:48,221 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:28:46",
#     "fit_dt_test_start": "2019-01-20 15:28:45",
#     "fit_dt_train_duration_seconds": "619",
#     "fit_dt_train_end": "2019-01-20 15:28:44",
#     "fit_dt_train_start": "2019-01-20 15:18:24",
#     "fit_num_epochs": 29,
#     "fit_stopped_epoch1": 7,
#     "fit_stopped_epoch2": 12,
#     "fit_stopped_epoch3": 7,
#     "fit_test_acc": 0.5569014982467326,
#     "fit_train_acc": 0.9491708730664211,
#     "fit_train_loss": 0.12513372949356308,
#     "fit_val_acc": 0.9186792826920246,
#     "fit_val_loss": 0.1801177920472674,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 128,
#     "layer_3_size": 512,
#     "model_id": 216,
#     "model_param_count": 1282439,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/216/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:28:48,222 [MainThread  ] [INFO ]  model 216 test acc: 0.5569014982467326
# 2019-01-20 15:28:52,905 [MainThread  ] [INFO ]  Begin experiment for model_id=224 on GPU:0
# 2019-01-20 15:28:52,908 [MainThread  ] [INFO ]  Loading data
# 224   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 128, 'model_id': 224, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 512, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:28:54,045 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:28:54,047 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.2320 - acc: 0.9090 - val_loss: 0.2639 - val_acc: 0.9095
#
# Epoch 00001: val_acc improved from -inf to 0.90952, saving model to /mnt/seals/models/224/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 0.2164 - acc: 0.9133 - val_loss: 0.2243 - val_acc: 0.9141
#
# Epoch 00002: val_acc improved from 0.90952 to 0.91411, saving model to /mnt/seals/models/224/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 264us/step - loss: 0.2152 - acc: 0.9135 - val_loss: 0.2240 - val_acc: 0.9133
#
# Epoch 00003: val_acc did not improve from 0.91411
# Epoch 4/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.2134 - acc: 0.9142 - val_loss: 0.2340 - val_acc: 0.9134
#
# Epoch 00004: val_acc did not improve from 0.91411
# Epoch 5/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.2106 - acc: 0.9148 - val_loss: 0.2316 - val_acc: 0.9105
#
# Epoch 00005: val_acc did not improve from 0.91411
# H1 {'loss': [0.23200921564907914, 0.2163959594010547, 0.21521554914708593, 0.2134347184932673, 0.2105961261146136], 'val_acc': [0.9095223504382971, 0.9141119669841664, 0.9133098965425902, 0.9133544550861185, 0.9105026598134341], 'val_loss': [0.2638853239552051, 0.22427161574289342, 0.22402660205672104, 0.2340349442257557, 0.231582590465388], 'acc': [0.9090313129833903, 0.9133062005818688, 0.9135326838764237, 0.9141885440975579, 0.914787783511787]}
# stopped_epoch1 2
# 5
# 0.9133098965425902
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 308us/step - loss: 0.2020 - acc: 0.9167 - val_loss: 0.2226 - val_acc: 0.9140
#
# Epoch 00001: val_acc improved from -inf to 0.91400, saving model to /mnt/seals/models/224/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.2011 - acc: 0.9168 - val_loss: 0.2274 - val_acc: 0.9134
#
# Epoch 00002: val_acc did not improve from 0.91400
# Epoch 3/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.2006 - acc: 0.9169 - val_loss: 0.2240 - val_acc: 0.9119
#
# Epoch 00003: val_acc did not improve from 0.91400
# Epoch 4/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1996 - acc: 0.9172 - val_loss: 0.2199 - val_acc: 0.9118
#
# Epoch 00004: val_acc did not improve from 0.91400
# H2 {'loss': [0.20200396991858047, 0.2010695406404799, 0.20062991308716702, 0.199607052325222], 'val_acc': [0.9140005661633634, 0.9133544568709113, 0.9119062798140722, 0.9117948778034075], 'val_loss': [0.22258460026232063, 0.22741703847126893, 0.22398945621342042, 0.21985260876394105], 'acc': [0.9167364904278621, 0.916826138477224, 0.916870965532683, 0.9172224860233632]}
# stopped_epoch2 1
# 4
# 0.9133544568709113
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 0.1998 - acc: 0.9172 - val_loss: 0.2249 - val_acc: 0.9111
#
# Epoch 00001: val_acc improved from -inf to 0.91115, saving model to /mnt/seals/models/224/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1986 - acc: 0.9172 - val_loss: 0.2247 - val_acc: 0.9108
#
# Epoch 00002: val_acc did not improve from 0.91115
# Epoch 3/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1991 - acc: 0.9172 - val_loss: 0.2248 - val_acc: 0.9112
#
# Epoch 00003: val_acc improved from 0.91115 to 0.91124, saving model to /mnt/seals/models/224/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1998 - acc: 0.9170 - val_loss: 0.2254 - val_acc: 0.9110
#
# Epoch 00004: val_acc did not improve from 0.91124
# Epoch 5/20
# 60553/60553 [==============================] - 17s 275us/step - loss: 0.1979 - acc: 0.9176 - val_loss: 0.2258 - val_acc: 0.9109
#
# Epoch 00005: val_acc did not improve from 0.91124
# Epoch 6/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1996 - acc: 0.9169 - val_loss: 0.2271 - val_acc: 0.9108
#
# Epoch 00006: val_acc did not improve from 0.91124
# H3 {'loss': [0.19975354894509673, 0.1986162383003207, 0.19914905914155415, 0.19983302103742343, 0.19788094453675176, 0.19959365475081892], 'val_acc': [0.9111487673210934, 0.9107922915362301, 0.9112378855980119, 0.910992809741555, 0.9109482503056303, 0.910792292131161], 'val_loss': [0.2248679902485885, 0.22469955418753906, 0.22476597606243376, 0.22542692291424263, 0.22578443401839982, 0.22713552757456237], 'acc': [0.9171611462330724, 0.917220126225541, 0.9172248437649024, 0.9169936427784138, 0.9175763658807253, 0.916925224701053]}
# stopped_epoch3 3
# 6
# 0.910992809741555
# best fit round 2 0.9133544568709113
# 3137/3137 [==============================] - 1s 334us/step
# 2019-01-20 15:33:31,520 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 15:33:29",
#     "fit_dt_test_start": "2019-01-20 15:33:28",
#     "fit_dt_train_duration_seconds": "269",
#     "fit_dt_train_end": "2019-01-20 15:33:26",
#     "fit_dt_train_start": "2019-01-20 15:28:57",
#     "fit_num_epochs": 9,
#     "fit_stopped_epoch1": 2,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.42684093082562957,
#     "fit_train_acc": 0.916826138477224,
#     "fit_train_loss": 0.2010695406404799,
#     "fit_val_acc": 0.9133544568709113,
#     "fit_val_loss": 0.22741703847126893,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 512,
#     "layer_3_size": 512,
#     "model_id": 224,
#     "model_param_count": 922247,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/224/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:33:31,521 [MainThread  ] [INFO ]  model 224 test acc: 0.42684093082562957
# 2019-01-20 15:33:34,047 [MainThread  ] [INFO ]  Begin experiment for model_id=232 on GPU:0
# 2019-01-20 15:33:34,050 [MainThread  ] [INFO ]  Loading data
# 232   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 128, 'model_id': 232, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 128, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 15:33:35,203 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:33:35,204 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 323us/step - loss: 0.2293 - acc: 0.9100 - val_loss: 0.2222 - val_acc: 0.9127
#
# Epoch 00001: val_acc improved from -inf to 0.91269, saving model to /mnt/seals/models/232/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.2152 - acc: 0.9137 - val_loss: 0.2345 - val_acc: 0.9143
#
# Epoch 00002: val_acc improved from 0.91269 to 0.91433, saving model to /mnt/seals/models/232/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.2119 - acc: 0.9146 - val_loss: 0.2261 - val_acc: 0.9135
#
# Epoch 00003: val_acc did not improve from 0.91433
# Epoch 4/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.2113 - acc: 0.9148 - val_loss: 0.2377 - val_acc: 0.9124
#
# Epoch 00004: val_acc did not improve from 0.91433
# Epoch 5/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.2102 - acc: 0.9150 - val_loss: 0.2379 - val_acc: 0.9122
#
# Epoch 00005: val_acc did not improve from 0.91433
# H1 {'loss': [0.22927222186748572, 0.21524860878904228, 0.21194812117655615, 0.21134570514226775, 0.21019206189044], 'val_acc': [0.9126860683066951, 0.914334759701808, 0.9134658547170595, 0.9124409900705144, 0.9122404751373095], 'val_loss': [0.2222227297365405, 0.23452389675308152, 0.22612066682211995, 0.237741240944553, 0.2378680916852826], 'acc': [0.9100386952612872, 0.9137379358031855, 0.9145636584086141, 0.9147712690494414, 0.9150189854570213]}
# stopped_epoch1 2
# 5
# 0.9134658547170595
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 329us/step - loss: 0.2061 - acc: 0.9153 - val_loss: 0.2316 - val_acc: 0.9132
#
# Epoch 00001: val_acc improved from -inf to 0.91322, saving model to /mnt/seals/models/232/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.2007 - acc: 0.9169 - val_loss: 0.2339 - val_acc: 0.9129
#
# Epoch 00002: val_acc did not improve from 0.91322
# Epoch 3/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.2006 - acc: 0.9170 - val_loss: 0.2266 - val_acc: 0.9135
#
# Epoch 00003: val_acc improved from 0.91322 to 0.91353, saving model to /mnt/seals/models/232/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.2002 - acc: 0.9171 - val_loss: 0.2310 - val_acc: 0.9124
#
# Epoch 00004: val_acc did not improve from 0.91353
# Epoch 5/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.2003 - acc: 0.9170 - val_loss: 0.2354 - val_acc: 0.9104
#
# Epoch 00005: val_acc did not improve from 0.91353
# Epoch 6/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1985 - acc: 0.9171 - val_loss: 0.2269 - val_acc: 0.9098
#
# Epoch 00006: val_acc did not improve from 0.91353
# H2 {'loss': [0.2061486544668504, 0.20070082255781604, 0.20060323139370012, 0.20023912937654864, 0.2003349899744146, 0.19852933400622597], 'val_acc': [0.9132207794555336, 0.9128643033732047, 0.9135326937222139, 0.9123518732809233, 0.9103689847777802, 0.9098342724390798], 'val_loss': [0.23157356470284132, 0.23394141046426778, 0.22656694027645768, 0.23101562474455153, 0.23542174479400674, 0.2268922049610301], 'acc': [0.9153115285696358, 0.9169464601410541, 0.9169700511491752, 0.9171092436988609, 0.9170408271698646, 0.9170856520430453]}
# stopped_epoch2 3
# 6
# 0.9123518732809233
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 333us/step - loss: 0.1980 - acc: 0.9173 - val_loss: 0.2307 - val_acc: 0.9091
#
# Epoch 00001: val_acc improved from -inf to 0.90905, saving model to /mnt/seals/models/232/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1972 - acc: 0.9175 - val_loss: 0.2321 - val_acc: 0.9088
#
# Epoch 00002: val_acc did not improve from 0.90905
# Epoch 3/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 0.1967 - acc: 0.9175 - val_loss: 0.2300 - val_acc: 0.9095
#
# Epoch 00003: val_acc improved from 0.90905 to 0.90946, saving model to /mnt/seals/models/232/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 18s 290us/step - loss: 0.1968 - acc: 0.9175 - val_loss: 0.2318 - val_acc: 0.9087
#
# Epoch 00004: val_acc did not improve from 0.90946
# Epoch 5/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1976 - acc: 0.9173 - val_loss: 0.2289 - val_acc: 0.9093
#
# Epoch 00005: val_acc did not improve from 0.90946
# Epoch 6/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1964 - acc: 0.9176 - val_loss: 0.2303 - val_acc: 0.9092
#
# Epoch 00006: val_acc did not improve from 0.90946
# H3 {'loss': [0.19798123911622356, 0.19718702497615068, 0.19665485848397612, 0.19678720846180853, 0.19761814110888742, 0.1963853833268971], 'val_acc': [0.9090544845413879, 0.9088094080900001, 0.9094555182748486, 0.9086757306746223, 0.9092772811260806, 0.909232720500294], 'val_loss': [0.23073325937826486, 0.23208318554046223, 0.230002123130461, 0.23179441269345383, 0.2289228919087093, 0.23025559739477547], 'acc': [0.9173333682537574, 0.9175032302010055, 0.9174725620988327, 0.9175150268995608, 0.9173003393182384, 0.9176471436919263]}
# stopped_epoch3 3
# 6
# 0.9086757306746223
# best fit round 1 0.9134658547170595
# 3137/3137 [==============================] - 1s 391us/step
# 2019-01-20 15:39:03,424 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 15:39:01",
#     "fit_dt_test_start": "2019-01-20 15:39:00",
#     "fit_dt_train_duration_seconds": "319",
#     "fit_dt_train_end": "2019-01-20 15:38:58",
#     "fit_dt_train_start": "2019-01-20 15:33:38",
#     "fit_num_epochs": 11,
#     "fit_stopped_epoch1": 2,
#     "fit_stopped_epoch2": 3,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.43481032833917754,
#     "fit_train_acc": 0.9145636584086141,
#     "fit_train_loss": 0.21194812117655615,
#     "fit_val_acc": 0.9134658547170595,
#     "fit_val_loss": 0.22612066682211995,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 128,
#     "layer_3_size": 512,
#     "model_id": 232,
#     "model_param_count": 676103,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/232/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:39:03,427 [MainThread  ] [INFO ]  model 232 test acc: 0.43481032833917754
# 2019-01-20 15:39:06,232 [MainThread  ] [INFO ]  Begin experiment for model_id=240 on GPU:0
# 2019-01-20 15:39:06,235 [MainThread  ] [INFO ]  Loading data
# ...
#
# Epoch 00004: val_acc improved from 0.92153 to 0.92182, saving model to /mnt/seals/models/280/model_round_3.h5
# Epoch 5/20
# 60553/60553 [==============================] - 16s 264us/step - loss: 0.0677 - acc: 0.9723 - val_loss: 0.2538 - val_acc: 0.9226
#
# Epoch 00005: val_acc improved from 0.92182 to 0.92260, saving model to /mnt/seals/models/280/model_round_3.h5
# Epoch 6/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.0678 - acc: 0.9720 - val_loss: 0.2591 - val_acc: 0.9222
#
# Epoch 00006: val_acc did not improve from 0.92260
# Epoch 7/20
# 60553/60553 [==============================] - 17s 282us/step - loss: 0.0673 - acc: 0.9720 - val_loss: 0.2556 - val_acc: 0.9223
#
# Epoch 00007: val_acc did not improve from 0.92260
# Epoch 8/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.0671 - acc: 0.9722 - val_loss: 0.2604 - val_acc: 0.9209
#
# Epoch 00008: val_acc did not improve from 0.92260
# H3 {'loss': [0.06888717338711034, 0.06830527083183392, 0.06849222051016124, 0.06750467877538564, 0.06773713062727947, 0.06780015578312265, 0.0673087281643672, 0.06710099450698308], 'val_acc': [0.9209963650682608, 0.9215087966478697, 0.921531079191754, 0.9218207126993428, 0.9226005004111187, 0.9221549074276492, 0.9223331443905012, 0.9209072464938768], 'val_loss': [0.25021764396208196, 0.25693178656542964, 0.2536672249817506, 0.25442828051164906, 0.25379292729193914, 0.2591294760415499, 0.25555806595388236, 0.26035130657929595], 'acc': [0.971698947427901, 0.9719348687935673, 0.9716824330324902, 0.9723241378016301, 0.9722580801569898, 0.9720363150268511, 0.9720174415580913, 0.9722038183870133]}
# stopped_epoch3 5
# 8
# 0.9221549074276492
# best fit round 1 0.9241600763924183
# 3137/3137 [==============================] - 2s 544us/step
# 2019-01-20 16:10:44,142 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 16:10:42",
#     "fit_dt_test_start": "2019-01-20 16:10:40",
#     "fit_dt_train_duration_seconds": "346",
#     "fit_dt_train_end": "2019-01-20 16:10:38",
#     "fit_dt_train_start": "2019-01-20 16:04:51",
#     "fit_num_epochs": 13,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 5,
#     "fit_test_acc": 0.6933375836786739,
#     "fit_train_acc": 0.9585628789191718,
#     "fit_train_loss": 0.10568139234890055,
#     "fit_val_acc": 0.9241600763924183,
#     "fit_val_loss": 0.18094785385070855,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 128,
#     "layer_3_size": 512,
#     "model_id": 280,
#     "model_param_count": 496007,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/280/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:10:44,144 [MainThread  ] [INFO ]  model 280 test acc: 0.6933375836786739
# 2019-01-20 16:11:10,843 [MainThread  ] [INFO ]  Begin experiment for model_id=288 on GPU:0
# 2019-01-20 16:11:10,846 [MainThread  ] [INFO ]  Loading data
# 288   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'vgg16', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 128, 'model_id': 288, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 512, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 16:11:11,842 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:11:11,843 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 20s 335us/step - loss: 0.1902 - acc: 0.9341 - val_loss: 0.1839 - val_acc: 0.9314
#
# Epoch 00001: val_acc improved from -inf to 0.93140, saving model to /mnt/seals/models/288/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.1310 - acc: 0.9485 - val_loss: 0.1876 - val_acc: 0.9295
#
# Epoch 00002: val_acc did not improve from 0.93140
# Epoch 3/20
# 60553/60553 [==============================] - 16s 261us/step - loss: 0.1218 - acc: 0.9519 - val_loss: 0.2498 - val_acc: 0.9047
#
# Epoch 00003: val_acc did not improve from 0.93140
# Epoch 4/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 0.1151 - acc: 0.9539 - val_loss: 0.1875 - val_acc: 0.9270
#
# Epoch 00004: val_acc did not improve from 0.93140
# H1 {'loss': [0.19019926876775153, 0.131035981024845, 0.1217777885402735, 0.11510308813098535], 'val_acc': [0.9314009645397189, 0.9294626316054494, 0.9046876592630159, 0.9270118724459495], 'val_loss': [0.1838868562589938, 0.18761674186920124, 0.2498439431227674, 0.18754170581242924], 'acc': [0.9341332806786181, 0.9484607523175457, 0.9519028356088556, 0.9539388324902036]}
# stopped_epoch1 1
# 4
# 0.9294626316054494
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 348us/step - loss: 0.0947 - acc: 0.9606 - val_loss: 0.2337 - val_acc: 0.9224
#
# Epoch 00001: val_acc improved from -inf to 0.92238, saving model to /mnt/seals/models/288/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.0902 - acc: 0.9626 - val_loss: 0.2403 - val_acc: 0.9221
#
# Epoch 00002: val_acc did not improve from 0.92238
# Epoch 3/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.0879 - acc: 0.9632 - val_loss: 0.2496 - val_acc: 0.9198
#
# Epoch 00003: val_acc did not improve from 0.92238
# Epoch 4/20
# 60553/60553 [==============================] - 16s 264us/step - loss: 0.0858 - acc: 0.9637 - val_loss: 0.2581 - val_acc: 0.9196
#
# Epoch 00004: val_acc did not improve from 0.92238
# H2 {'loss': [0.09470949750861497, 0.0901911546652182, 0.0879037169897375, 0.08576849626051378], 'val_acc': [0.9223777011864198, 0.9221326249953143, 0.9198378206637972, 0.9196373021610067], 'val_loss': [0.23370156649567525, 0.24028541263906344, 0.24955749526592025, 0.25813195159564667], 'acc': [0.9605682063940985, 0.9625924058888387, 0.9631586162878174, 0.9637436990117546]}
# stopped_epoch2 1
# 4
# 0.9221326249953143
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 22s 367us/step - loss: 0.0826 - acc: 0.9647 - val_loss: 0.2573 - val_acc: 0.9206
#
# Epoch 00001: val_acc improved from -inf to 0.92055, saving model to /mnt/seals/models/288/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.0825 - acc: 0.9651 - val_loss: 0.2590 - val_acc: 0.9208
#
# Epoch 00002: val_acc improved from 0.92055 to 0.92084, saving model to /mnt/seals/models/288/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.0822 - acc: 0.9651 - val_loss: 0.2648 - val_acc: 0.9220
#
# Epoch 00003: val_acc improved from 0.92084 to 0.92204, saving model to /mnt/seals/models/288/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 0.0826 - acc: 0.9649 - val_loss: 0.2679 - val_acc: 0.9205
#
# Epoch 00004: val_acc did not improve from 0.92204
# Epoch 5/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.0826 - acc: 0.9646 - val_loss: 0.2576 - val_acc: 0.9223
#
# Epoch 00005: val_acc improved from 0.92204 to 0.92233, saving model to /mnt/seals/models/288/model_round_3.h5
# Epoch 6/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.0820 - acc: 0.9652 - val_loss: 0.2630 - val_acc: 0.9208
#
# Epoch 00006: val_acc did not improve from 0.92233
# Epoch 7/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.0812 - acc: 0.9652 - val_loss: 0.2582 - val_acc: 0.9217
#
# Epoch 00007: val_acc did not improve from 0.92233
# Epoch 8/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.0807 - acc: 0.9652 - val_loss: 0.2641 - val_acc: 0.9212
#
# Epoch 00008: val_acc did not improve from 0.92233
# H3 {'loss': [0.0825861605811729, 0.08254799965945679, 0.0822088611132492, 0.08262079605926086, 0.08261438403948862, 0.08199482541140357, 0.08116683819269446, 0.08070768778348991], 'val_acc': [0.92055076903577, 0.9208404037332207, 0.9220435070530445, 0.9204839288407538, 0.9223331414530297, 0.9207512860884164, 0.9216870333504394, 0.9211968804476638], 'val_loss': [0.25725059797818856, 0.25903127469350157, 0.2648339379004813, 0.26792785437941474, 0.2575580639461391, 0.2629666323596362, 0.25819289160012754, 0.2641320296250056], 'acc': [0.9647392844778973, 0.9650507016449529, 0.9651120401437916, 0.9648902747163828, 0.9646401982816297, 0.9651545054032215, 0.9652417962829448, 0.9652394366288362]}
# stopped_epoch3 5
# 8
# 0.9207512860884164
# best fit round 1 0.9294626316054494
# 3137/3137 [==============================] - 2s 744us/step
# 2019-01-20 16:16:25,528 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "2",
#     "fit_dt_test_end": "2019-01-20 16:16:23",
#     "fit_dt_test_start": "2019-01-20 16:16:21",
#     "fit_dt_train_duration_seconds": "305",
#     "fit_dt_train_end": "2019-01-20 16:16:18",
#     "fit_dt_train_start": "2019-01-20 16:11:12",
#     "fit_num_epochs": 10,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 5,
#     "fit_test_acc": 0.6936563595792158,
#     "fit_train_acc": 0.9484607523175457,
#     "fit_train_loss": 0.131035981024845,
#     "fit_val_acc": 0.9294626316054494,
#     "fit_val_loss": 0.18761674186920124,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 512,
#     "layer_3_size": 512,
#     "model_id": 288,
#     "model_param_count": 529031,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/288/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:16:25,530 [MainThread  ] [INFO ]  model 288 test acc: 0.6936563595792158
# 2019-01-20 16:16:32,702 [MainThread  ] [INFO ]  Begin experiment for model_id=296 on GPU:0
# 2019-01-20 16:16:32,705 [MainThread  ] [INFO ]  Loading data
# 296   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'vgg16', 'layer_3_size': 512, 'architecture': 'video_MLP_concat', 'pooling': 'max', 'layer_1_size': 128, 'model_id': 296, 'dropout': 0.2, 'sequence_length': 3, 'layer_2_size': 128, 'WORKER': 0, 'sequence_model_layers': nan, 'sequence_model': nan}
# 2019-01-20 16:16:33,872 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:16:33,873 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 23s 373us/step - loss: 0.1884 - acc: 0.9309 - val_loss: 0.1917 - val_acc: 0.9189
#
# Epoch 00001: val_acc improved from -inf to 0.91886, saving model to /mnt/seals/models/296/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1335 - acc: 0.9458 - val_loss: 0.2075 - val_acc: 0.9223
#
# Epoch 00002: val_acc improved from 0.91886 to 0.92229, saving model to /mnt/seals/models/296/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.1223 - acc: 0.9502 - val_loss: 0.2433 - val_acc: 0.9185
#
# Epoch 00003: val_acc did not improve from 0.92229
# Epoch 4/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.1136 - acc: 0.9546 - val_loss: 0.2412 - val_acc: 0.9278
#
# Epoch 00004: val_acc improved from 0.92229 to 0.92779, saving model to /mnt/seals/models/296/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.1089 - acc: 0.9568 - val_loss: 0.2131 - val_acc: 0.9211
#
# Epoch 00005: val_acc did not improve from 0.92779
# Epoch 6/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.1052 - acc: 0.9585 - val_loss: 0.2348 - val_acc: 0.9117
#
# Epoch 00006: val_acc did not improve from 0.92779
# Epoch 7/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.1032 - acc: 0.9588 - val_loss: 0.2120 - val_acc: 0.9298
#
# Epoch 00007: val_acc improved from 0.92779 to 0.92975, saving model to /mnt/seals/models/296/model_round_1.h5
# Epoch 8/20
# 60553/60553 [==============================] - 16s 261us/step - loss: 0.1020 - acc: 0.9599 - val_loss: 0.2362 - val_acc: 0.9246
#
# Epoch 00008: val_acc did not improve from 0.92975
# Epoch 9/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.0989 - acc: 0.9612 - val_loss: 0.2697 - val_acc: 0.9217
#
# Epoch 00009: val_acc did not improve from 0.92975
# Epoch 10/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.0990 - acc: 0.9609 - val_loss: 0.2994 - val_acc: 0.9186
#
# Epoch 00010: val_acc did not improve from 0.92975
# H1 {'loss': [0.18844071675013913, 0.13345492306599074, 0.12228901418340575, 0.11363478583563444, 0.10887085817727322, 0.10517760595982903, 0.10318535420733999, 0.10203942188070371, 0.09891921605637309, 0.09898831401388615], 'val_acc': [0.9188575243399579, 0.9222885853264083, 0.9185233248522039, 0.927791658075467, 0.9211077625053938, 0.9116611937322396, 0.9297522714713626, 0.9245833886911626, 0.921687035469881, 0.9186347213969406], 'val_loss': [0.19171416931463195, 0.20752148707620963, 0.24333695504937555, 0.24120223588186432, 0.2131422702420598, 0.23481897531973148, 0.21201094220893799, 0.23624988733160443, 0.2697177665239561, 0.2993666461982061], 'acc': [0.9309011681586641, 0.9457783330381216, 0.9502419533171316, 0.9546277212009515, 0.9568194251405949, 0.9585227725529571, 0.9587728495192528, 0.9598863956957902, 0.9612358615902112, 0.96085367079244]}
# stopped_epoch1 7
# 10
# 0.9245833886911626
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 21s 352us/step - loss: 0.0856 - acc: 0.9655 - val_loss: 0.2720 - val_acc: 0.9246
#
# Epoch 00001: val_acc improved from -inf to 0.92458, saving model to /mnt/seals/models/296/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.0816 - acc: 0.9665 - val_loss: 0.2716 - val_acc: 0.9249
#
# Epoch 00002: val_acc improved from 0.92458 to 0.92494, saving model to /mnt/seals/models/296/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 265us/step - loss: 0.0802 - acc: 0.9668 - val_loss: 0.2909 - val_acc: 0.9235
#
# Epoch 00003: val_acc did not improve from 0.92494
# Epoch 4/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.0792 - acc: 0.9673 - val_loss: 0.2956 - val_acc: 0.9243
#
# Epoch 00004: val_acc did not improve from 0.92494
# Epoch 5/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.0780 - acc: 0.9675 - val_loss: 0.2984 - val_acc: 0.9253
#
# Epoch 00005: val_acc improved from 0.92494 to 0.92534, saving model to /mnt/seals/models/296/model_round_2.h5
# Epoch 6/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.0769 - acc: 0.9679 - val_loss: 0.3045 - val_acc: 0.9251
#
# Epoch 00006: val_acc did not improve from 0.92534
# Epoch 7/20
# 41408/60553 [===================>..........] - ETA: 5s - loss: 0.0775 - acc: 0.9680
