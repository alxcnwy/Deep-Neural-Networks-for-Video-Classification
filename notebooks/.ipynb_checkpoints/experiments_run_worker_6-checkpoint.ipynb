# %%
WORKER_ID = 6

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 13:22:09,868 [MainThread  ] [INFO ]  Begin experiment for model_id=54 on GPU:6
# 2019-01-20 13:22:09,869 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 13:22:09,870 [MainThread  ] [INFO ]  Loading data
# 54   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 54, 'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 0, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 256, 'sequence_model_layers': nan}
# 2019-01-20 13:22:10,820 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 13:22:10,821 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 15s 248us/step - loss: 0.2263 - acc: 0.9270 - val_loss: 0.3691 - val_acc: 0.8990
#
# Epoch 00001: val_acc improved from -inf to 0.89902, saving model to /mnt/seals/models/54/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 124us/step - loss: 0.1877 - acc: 0.9397 - val_loss: 0.2709 - val_acc: 0.9226
#
# Epoch 00002: val_acc improved from 0.89902 to 0.92263, saving model to /mnt/seals/models/54/model_round_1.h5
# Epoch 3/20
# 60597/60597 [==============================] - 8s 127us/step - loss: 0.1803 - acc: 0.9429 - val_loss: 0.3350 - val_acc: 0.9113
#
# Epoch 00003: val_acc did not improve from 0.92263
# Epoch 4/20
# 60597/60597 [==============================] - 8s 129us/step - loss: 0.1723 - acc: 0.9448 - val_loss: 0.2943 - val_acc: 0.9209
#
# Epoch 00004: val_acc did not improve from 0.92263
# Epoch 5/20
# 60597/60597 [==============================] - 8s 126us/step - loss: 0.1697 - acc: 0.9460 - val_loss: 0.4681 - val_acc: 0.8797
#
# Epoch 00005: val_acc did not improve from 0.92263
# H1 {'val_loss': [0.36911867257960124, 0.27091686368137224, 0.33496285019967326, 0.2943010937766244, 0.468074331780027], 'val_acc': [0.8990247750520112, 0.9226264913480478, 0.9112932151392511, 0.9209120252780486, 0.8796535611449929], 'acc': [0.9269789587975902, 0.9396646410472236, 0.9428519753071511, 0.9447639027800476, 0.94599451617439], 'loss': [0.22629264025357124, 0.18773205755453215, 0.1803054894268919, 0.17232933681767645, 0.16969115029958567]}
# stopped_epoch1 2
# 5
# 0.9112932151392511
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1175 - acc: 0.9588 - val_loss: 0.2579 - val_acc: 0.9247
#
# Epoch 00001: val_acc improved from -inf to 0.92472, saving model to /mnt/seals/models/54/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 127us/step - loss: 0.1126 - acc: 0.9598 - val_loss: 0.2577 - val_acc: 0.9217
#
# Epoch 00002: val_acc did not improve from 0.92472
# Epoch 3/20
# 60597/60597 [==============================] - 8s 134us/step - loss: 0.1107 - acc: 0.9602 - val_loss: 0.2463 - val_acc: 0.9241
#
# Epoch 00003: val_acc did not improve from 0.92472
# Epoch 4/20
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.1096 - acc: 0.9607 - val_loss: 0.2786 - val_acc: 0.9109
#
# Epoch 00004: val_acc did not improve from 0.92472
# H2 {'val_loss': [0.2579360510271386, 0.25770196203430396, 0.2462942810947461, 0.27863826359299354], 'val_acc': [0.9247194703974926, 0.9217135930001884, 0.9241405624403918, 0.9109369605556688], 'acc': [0.9588334322072103, 0.9598353674652289, 0.9602455698932529, 0.960698210394579], 'loss': [0.11745230313646543, 0.11262473350772469, 0.11065969161113492, 0.10964862315392805]}
# stopped_epoch2 1
# 4
# 0.9217135930001884
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 8s 140us/step - loss: 0.1042 - acc: 0.9626 - val_loss: 0.2507 - val_acc: 0.9196
#
# Epoch 00001: val_acc improved from -inf to 0.91958, saving model to /mnt/seals/models/54/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1040 - acc: 0.9627 - val_loss: 0.2502 - val_acc: 0.9189
#
# Epoch 00002: val_acc did not improve from 0.91958
# Epoch 3/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1038 - acc: 0.9627 - val_loss: 0.2550 - val_acc: 0.9173
#
# Epoch 00003: val_acc did not improve from 0.91958
# Epoch 4/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1037 - acc: 0.9629 - val_loss: 0.2486 - val_acc: 0.9198
#
# Epoch 00004: val_acc improved from 0.91958 to 0.91980, saving model to /mnt/seals/models/54/model_round_3.h5
# Epoch 5/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1037 - acc: 0.9628 - val_loss: 0.2468 - val_acc: 0.9199
#
# Epoch 00005: val_acc improved from 0.91980 to 0.91993, saving model to /mnt/seals/models/54/model_round_3.h5
# Epoch 6/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1036 - acc: 0.9630 - val_loss: 0.2447 - val_acc: 0.9214
#
# Epoch 00006: val_acc improved from 0.91993 to 0.92142, saving model to /mnt/seals/models/54/model_round_3.h5
# Epoch 7/20
# 60597/60597 [==============================] - 9s 142us/step - loss: 0.1036 - acc: 0.9628 - val_loss: 0.2508 - val_acc: 0.9186
#
# Epoch 00007: val_acc did not improve from 0.92142
# Epoch 8/20
# 60597/60597 [==============================] - 8s 138us/step - loss: 0.1034 - acc: 0.9630 - val_loss: 0.2449 - val_acc: 0.9211
#
# Epoch 00008: val_acc did not improve from 0.92142
# Epoch 9/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1034 - acc: 0.9629 - val_loss: 0.2489 - val_acc: 0.9195
#
# Epoch 00009: val_acc did not improve from 0.92142
# H3 {'val_loss': [0.2507130812454105, 0.2502196185160753, 0.25503979195977683, 0.2486176560644497, 0.24681032558629043, 0.24472501149349973, 0.25084531875768507, 0.2448950669637642, 0.24886048679934475], 'val_acc': [0.9195760788762956, 0.9188635750601714, 0.9172827078219958, 0.9197987371549344, 0.9199323321221178, 0.9214241376838779, 0.9185963860176448, 0.9210901530900798, 0.91948701526756], 'acc': [0.9626384268130107, 0.9627256552169808, 0.9626572887464736, 0.9629142551024185, 0.962812881971414, 0.9629661197786054, 0.9628270275689553, 0.9630368456111925, 0.9629472609878202], 'loss': [0.10424510106909858, 0.10400524592899081, 0.10384274009196344, 0.10374851476915095, 0.10369567216334805, 0.10355753204222855, 0.10357916823264161, 0.10337076722549672, 0.10337867686363889]}
# stopped_epoch3 6
# 9
# 0.9185963860176448
# best fit round 2 0.9217135930001884
# 3139/3139 [==============================] - 0s 47us/step
# 2019-01-20 13:24:49,059 [MainThread  ] [INFO ]  {'frame_size': (299, 299), 'model_weights_path': None, 'fit_stopped_epoch1': 2, 'fit_train_acc': 0.9598353674652289, 'fit_train_loss': 0.11262473350772469, 'data_total_rows_test': 3139, 'sequence_length': 1.0, 'model_param_count': 0, 'fit_dt_train_start': '2019-01-20 13:22:11', 'fit_val_loss': 0.25770196203430396, 'num_features': 1536, 'sequence_model': nan, 'fit_test_acc': 0.5176807900605288, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:24:47', 'layer_1_size': 0, 'fit_dt_train_duration_seconds': '154', 'fit_val_acc': 0.9217135930001884, 'layer_2_size': 256, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 54, 'fit_best_round': 2, 'fit_num_epochs': 12, 'pretrained_model_name': 'inception_resnet_v2', 'fit_dt_test_start': '2019-01-20 13:24:47', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'fit_dt_train_end': '2019-01-20 13:24:46', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 6, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 1, 'path_model': '/mnt/seals/models/54/'}
# 2019-01-20 13:24:49,061 [MainThread  ] [INFO ]  model 54 test acc: 0.5176807900605288
# 2019-01-20 13:24:49,246 [MainThread  ] [INFO ]  Begin experiment for model_id=62 on GPU:6
# 2019-01-20 13:24:49,248 [MainThread  ] [INFO ]  Loading data
# 62   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 62, 'pretrained_model_name': 'inception_resnet_v2', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 0, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 0, 'sequence_model_layers': nan}
# 2019-01-20 13:24:50,349 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 13:24:50,350 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 9s 141us/step - loss: 0.2265 - acc: 0.9282 - val_loss: 0.5041 - val_acc: 0.8705
#
# Epoch 00001: val_acc improved from -inf to 0.87052, saving model to /mnt/seals/models/62/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1843 - acc: 0.9402 - val_loss: 0.2585 - val_acc: 0.9209
#
# Epoch 00002: val_acc improved from 0.87052 to 0.92093, saving model to /mnt/seals/models/62/model_round_1.h5
# Epoch 3/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1793 - acc: 0.9424 - val_loss: 0.2916 - val_acc: 0.9160
#
# Epoch 00003: val_acc did not improve from 0.92093
# Epoch 4/20
# 60597/60597 [==============================] - 8s 134us/step - loss: 0.1712 - acc: 0.9452 - val_loss: 0.3886 - val_acc: 0.9172
#
# Epoch 00004: val_acc did not improve from 0.92093
# Epoch 5/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1706 - acc: 0.9457 - val_loss: 0.2836 - val_acc: 0.9298
#
# Epoch 00005: val_acc improved from 0.92093 to 0.92984, saving model to /mnt/seals/models/62/model_round_1.h5
# Epoch 6/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1636 - acc: 0.9480 - val_loss: 0.2697 - val_acc: 0.9268
#
# Epoch 00006: val_acc did not improve from 0.92984
# Epoch 7/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1679 - acc: 0.9475 - val_loss: 0.3182 - val_acc: 0.9098
#
# Epoch 00007: val_acc did not improve from 0.92984
# Epoch 8/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1616 - acc: 0.9490 - val_loss: 0.3765 - val_acc: 0.9049
#
# Epoch 00008: val_acc did not improve from 0.92984
# H1 {'val_loss': [0.5040528919185486, 0.25854437322613605, 0.29164137312227356, 0.38855777227521837, 0.2836108899621892, 0.26974006823991004, 0.31821504454511657, 0.37647855423037846], 'val_acc': [0.8705245943140805, 0.9209342912545525, 0.9159912905490903, 0.9171936406458999, 0.9298405937125855, 0.926790190159234, 0.9098459406386588, 0.9048806717270925], 'acc': [0.9282449339495175, 0.9402398699110569, 0.9423804758153642, 0.9452354016147738, 0.9456503212236521, 0.9480290331685024, 0.9475457471746921, 0.9489932493695151], 'loss': [0.22653367263262725, 0.1842838153180359, 0.17931802493875892, 0.17123345304558085, 0.17059314524983604, 0.16361507765505773, 0.1678799173461807, 0.16160162745256743]}
# stopped_epoch1 5
# 8
# 0.926790190159234
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 9s 140us/step - loss: 0.1128 - acc: 0.9611 - val_loss: 0.2752 - val_acc: 0.9251
#
# Epoch 00001: val_acc improved from -inf to 0.92505, saving model to /mnt/seals/models/62/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1093 - acc: 0.9615 - val_loss: 0.2626 - val_acc: 0.9211
#
# Epoch 00002: val_acc did not improve from 0.92505
# Epoch 3/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1077 - acc: 0.9619 - val_loss: 0.2707 - val_acc: 0.9167
#
# Epoch 00003: val_acc did not improve from 0.92505
# Epoch 4/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1065 - acc: 0.9623 - val_loss: 0.2479 - val_acc: 0.9256
#
# Epoch 00004: val_acc improved from 0.92505 to 0.92561, saving model to /mnt/seals/models/62/model_round_2.h5
# Epoch 5/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1055 - acc: 0.9626 - val_loss: 0.2626 - val_acc: 0.9208
#
# Epoch 00005: val_acc did not improve from 0.92561
# Epoch 6/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1050 - acc: 0.9624 - val_loss: 0.2638 - val_acc: 0.9253
#
# Epoch 00006: val_acc did not improve from 0.92561
# Epoch 7/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.1046 - acc: 0.9626 - val_loss: 0.2582 - val_acc: 0.9276
#
# Epoch 00007: val_acc improved from 0.92561 to 0.92761, saving model to /mnt/seals/models/62/model_round_2.h5
# Epoch 8/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1041 - acc: 0.9628 - val_loss: 0.2616 - val_acc: 0.9180
#
# Epoch 00008: val_acc did not improve from 0.92761
# Epoch 9/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1039 - acc: 0.9628 - val_loss: 0.2425 - val_acc: 0.9257
#
# Epoch 00009: val_acc did not improve from 0.92761
# Epoch 10/20
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1036 - acc: 0.9632 - val_loss: 0.2625 - val_acc: 0.9252
#
# Epoch 00010: val_acc did not improve from 0.92761
# H2 {'val_loss': [0.2751708957099558, 0.262592663974536, 0.27067429916073854, 0.2479228974503472, 0.26257925257644155, 0.2638346005481972, 0.25816624351496115, 0.2616224871980876, 0.24245314989378328, 0.26248184242227723], 'val_acc': [0.9250534548426507, 0.9210901486308795, 0.9167260610849185, 0.925610101579728, 0.9207784268921451, 0.9252761126753696, 0.9276140185068373, 0.9180174734527036, 0.9256991634047834, 0.9252315854788421], 'acc': [0.9611060573133771, 0.9615044730288822, 0.9618533819745173, 0.9622541565199619, 0.9625700602677482, 0.9624026792787952, 0.9625629870051989, 0.9627940219540501, 0.9627515877690125, 0.963154719298135], 'loss': [0.11275328270553557, 0.10928629236985432, 0.10774039670038474, 0.10649520332106785, 0.10550911536111261, 0.10501793188816297, 0.10462235582250935, 0.10407497574779455, 0.10385930665304705, 0.10361023145707418]}
# stopped_epoch2 7
# 10
# 0.9180174734527036
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 9s 143us/step - loss: 0.0986 - acc: 0.9651 - val_loss: 0.2558 - val_acc: 0.9188
#
# Epoch 00001: val_acc improved from -inf to 0.91882, saving model to /mnt/seals/models/62/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.0983 - acc: 0.9651 - val_loss: 0.2468 - val_acc: 0.9234
#
# Epoch 00002: val_acc improved from 0.91882 to 0.92338, saving model to /mnt/seals/models/62/model_round_3.h5
# Epoch 3/20
# 60597/60597 [==============================] - 8s 136us/step - loss: 0.0983 - acc: 0.9650 - val_loss: 0.2542 - val_acc: 0.9202
#
# Epoch 00003: val_acc did not improve from 0.92338
# Epoch 4/20
# 60597/60597 [==============================] - 8s 137us/step - loss: 0.0983 - acc: 0.9652 - val_loss: 0.2508 - val_acc: 0.9215
#
# Epoch 00004: val_acc did not improve from 0.92338
# Epoch 5/20
# 60597/60597 [==============================] - 8s 134us/step - loss: 0.0983 - acc: 0.9652 - val_loss: 0.2528 - val_acc: 0.9200
#
# Epoch 00005: val_acc did not improve from 0.92338
# H3 {'val_loss': [0.2558060849916905, 0.24684252067842982, 0.25421260947598484, 0.25076466750474347, 0.2527668124942708], 'val_acc': [0.9188190426612436, 0.9233835248875797, 0.920244050293492, 0.9215354644449572, 0.9200436603695972], 'acc': [0.9650949376828305, 0.9651326578011664, 0.9649817780557044, 0.9652198839221459, 0.9652033831517779], 'loss': [0.09858553039047831, 0.09832276828312993, 0.0983283807411769, 0.09826800757362981, 0.09828818462192614]}
# stopped_epoch3 2
# 5
# 0.920244050293492
# best fit round 1 0.926790190159234
# 3139/3139 [==============================] - 0s 63us/step
# 2019-01-20 13:28:07,258 [MainThread  ] [INFO ]  {'frame_size': (299, 299), 'model_weights_path': None, 'fit_stopped_epoch1': 5, 'fit_train_acc': 0.9480290331685024, 'fit_train_loss': 0.16361507765505773, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:28:04', 'sequence_length': 1.0, 'model_param_count': 0, 'fit_dt_train_start': '2019-01-20 13:24:51', 'fit_val_loss': 0.26974006823991004, 'num_features': 1536, 'sequence_model': nan, 'fit_test_acc': 0.5173622172666454, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:28:05', 'layer_1_size': 0, 'fit_dt_train_duration_seconds': '193', 'fit_val_acc': 0.926790190159234, 'layer_2_size': 0, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 62, 'fit_best_round': 1, 'fit_num_epochs': 17, 'pretrained_model_name': 'inception_resnet_v2', 'fit_dt_test_start': '2019-01-20 13:28:05', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 2, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 7, 'path_model': '/mnt/seals/models/62/'}
# 2019-01-20 13:28:07,260 [MainThread  ] [INFO ]  model 62 test acc: 0.5173622172666454
# 2019-01-20 13:28:07,482 [MainThread  ] [INFO ]  Begin experiment for model_id=70 on GPU:6
# 2019-01-20 13:28:07,485 [MainThread  ] [INFO ]  Loading data
# 70   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 70, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 512, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 256, 'sequence_model_layers': nan}
# 2019-01-20 13:28:08,567 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:28:08,568 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.2072 - acc: 0.9320 - val_loss: 0.2144 - val_acc: 0.9141
#
# Epoch 00001: val_acc improved from -inf to 0.91414, saving model to /mnt/seals/models/70/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 13s 223us/step - loss: 0.1288 - acc: 0.9490 - val_loss: 0.2253 - val_acc: 0.9096
#
# Epoch 00002: val_acc did not improve from 0.91414
# Epoch 3/20
# 60597/60597 [==============================] - 14s 223us/step - loss: 0.1174 - acc: 0.9537 - val_loss: 0.1642 - val_acc: 0.9322
#
# Epoch 00003: val_acc improved from 0.91414 to 0.93216, saving model to /mnt/seals/models/70/model_round_1.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 224us/step - loss: 0.1108 - acc: 0.9562 - val_loss: 0.1773 - val_acc: 0.9272
#
# Epoch 00004: val_acc did not improve from 0.93216
# Epoch 5/20
# 60597/60597 [==============================] - 13s 222us/step - loss: 0.1048 - acc: 0.9589 - val_loss: 0.1755 - val_acc: 0.9383
#
# Epoch 00005: val_acc improved from 0.93216 to 0.93826, saving model to /mnt/seals/models/70/model_round_1.h5
# Epoch 6/20
# 60597/60597 [==============================] - 14s 226us/step - loss: 0.1004 - acc: 0.9604 - val_loss: 0.1825 - val_acc: 0.9352
#
# Epoch 00006: val_acc did not improve from 0.93826
# Epoch 7/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.0983 - acc: 0.9611 - val_loss: 0.1622 - val_acc: 0.9399
#
# Epoch 00007: val_acc improved from 0.93826 to 0.93995, saving model to /mnt/seals/models/70/model_round_1.h5
# Epoch 8/20
# 60597/60597 [==============================] - 14s 223us/step - loss: 0.0948 - acc: 0.9625 - val_loss: 0.1772 - val_acc: 0.9375
#
# Epoch 00008: val_acc did not improve from 0.93995
# Epoch 9/20
# 60597/60597 [==============================] - 14s 223us/step - loss: 0.0921 - acc: 0.9638 - val_loss: 0.1773 - val_acc: 0.9319
#
# Epoch 00009: val_acc did not improve from 0.93995
# Epoch 10/20
# 60597/60597 [==============================] - 13s 216us/step - loss: 0.0895 - acc: 0.9647 - val_loss: 0.2106 - val_acc: 0.9299
#
# Epoch 00010: val_acc did not improve from 0.93995
# H1 {'val_loss': [0.21442951570425248, 0.22528347049716702, 0.16423356657536547, 0.1772676669897284, 0.17553035244159865, 0.18253666149484843, 0.16217033669092412, 0.17719842305876074, 0.177335674365857, 0.21059596820959725], 'val_acc': [0.9141432292146279, 0.9095787495151719, 0.9321562393645099, 0.9271687064087599, 0.9382570547950535, 0.9351621137890138, 0.9399492519157486, 0.9375000184313614, 0.9318890457141429, 0.9298628631078097], 'acc': [0.9319579890984692, 0.9490215394088399, 0.9537318131995559, 0.9561883228654202, 0.9589442338906419, 0.9603799469955274, 0.9611437771887579, 0.9624851916183239, 0.9637653096057771, 0.9647012354615581], 'loss': [0.20718169256075677, 0.1288095797735356, 0.11735441763776737, 0.11082083030270946, 0.10483375863140806, 0.10044147562849928, 0.09826542913629951, 0.0947884768063175, 0.09205986004805541, 0.08950634651050939]}
# stopped_epoch1 7
# 10
# 0.9375000184313614
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 15s 241us/step - loss: 0.0750 - acc: 0.9694 - val_loss: 0.1889 - val_acc: 0.9384
#
# Epoch 00001: val_acc improved from -inf to 0.93841, saving model to /mnt/seals/models/70/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 225us/step - loss: 0.0710 - acc: 0.9709 - val_loss: 0.1794 - val_acc: 0.9391
#
# Epoch 00002: val_acc improved from 0.93841 to 0.93913, saving model to /mnt/seals/models/70/model_round_2.h5
# Epoch 3/20
# 60597/60597 [==============================] - 14s 225us/step - loss: 0.0689 - acc: 0.9714 - val_loss: 0.1825 - val_acc: 0.9399
#
# Epoch 00003: val_acc improved from 0.93913 to 0.93993, saving model to /mnt/seals/models/70/model_round_2.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 226us/step - loss: 0.0675 - acc: 0.9719 - val_loss: 0.1965 - val_acc: 0.9387
#
# Epoch 00004: val_acc did not improve from 0.93993
# Epoch 5/20
# 60597/60597 [==============================] - 14s 224us/step - loss: 0.0662 - acc: 0.9725 - val_loss: 0.1989 - val_acc: 0.9393
#
# Epoch 00005: val_acc did not improve from 0.93993
# Epoch 6/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.0654 - acc: 0.9728 - val_loss: 0.2037 - val_acc: 0.9387
#
# Epoch 00006: val_acc did not improve from 0.93993
# H2 {'val_loss': [0.18888006782962793, 0.17935282190764634, 0.18252266980614745, 0.19651124644978088, 0.1988621323631886, 0.20368386998289542], 'val_acc': [0.9384129155901008, 0.939125419554865, 0.9399269854933247, 0.9387469004811789, 0.9393035470696162, 0.938746901670299], 'acc': [0.969395007002536, 0.9709415244033577, 0.9714059513280173, 0.9718750931830001, 0.9724738962981151, 0.972827519466848], 'loss': [0.07501070023533188, 0.07095134354917439, 0.06889607246113044, 0.06751429639767868, 0.06622675171625356, 0.06537944745108686]}
# stopped_epoch2 3
# 6
# 0.9387469004811789
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 15s 242us/step - loss: 0.0635 - acc: 0.9733 - val_loss: 0.2057 - val_acc: 0.9389
#
# Epoch 00001: val_acc improved from -inf to 0.93890, saving model to /mnt/seals/models/70/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 224us/step - loss: 0.0630 - acc: 0.9738 - val_loss: 0.2040 - val_acc: 0.9399
#
# Epoch 00002: val_acc improved from 0.93890 to 0.93990, saving model to /mnt/seals/models/70/model_round_3.h5
# Epoch 3/20
# 60597/60597 [==============================] - 14s 226us/step - loss: 0.0627 - acc: 0.9740 - val_loss: 0.2048 - val_acc: 0.9391
#
# Epoch 00003: val_acc did not improve from 0.93990
# Epoch 4/20
# 60597/60597 [==============================] - 14s 226us/step - loss: 0.0622 - acc: 0.9737 - val_loss: 0.2061 - val_acc: 0.9389
#
# Epoch 00004: val_acc did not improve from 0.93990
# Epoch 5/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.0620 - acc: 0.9738 - val_loss: 0.2083 - val_acc: 0.9392
#
# Epoch 00005: val_acc did not improve from 0.93990
# H3 {'val_loss': [0.20571007824821066, 0.20397299106355915, 0.20478195139669123, 0.2061153957782838, 0.20834021541543138], 'val_acc': [0.9389027626139862, 0.9399047218950609, 0.9390808902773774, 0.9389027651408663, 0.9391922192680568], 'acc': [0.9733320243335359, 0.9737799477405665, 0.973975620881668, 0.9736762175708014, 0.9737964510280276], 'loss': [0.06352249914202841, 0.06300685460487072, 0.06266642816719238, 0.062247589791079964, 0.06201577166924294]}
# stopped_epoch3 2
# 5
# 0.9390808902773774
# best fit round 3 0.9390808902773774
# 3139/3139 [==============================] - 0s 118us/step
# 2019-01-20 13:33:08,224 [MainThread  ] [INFO ]  {'frame_size': (224, 224), 'model_weights_path': None, 'fit_stopped_epoch1': 7, 'fit_train_acc': 0.973975620881668, 'fit_train_loss': 0.06266642816719238, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:33:05', 'sequence_length': 1.0, 'model_param_count': 427783, 'fit_dt_train_start': '2019-01-20 13:28:08', 'fit_val_loss': 0.20478195139669123, 'num_features': 512, 'sequence_model': nan, 'fit_test_acc': 0.6670914303918445, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:33:06', 'layer_1_size': 512, 'fit_dt_train_duration_seconds': '296', 'fit_val_acc': 0.9390808902773774, 'layer_2_size': 256, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 70, 'fit_best_round': 3, 'fit_num_epochs': 15, 'pretrained_model_name': 'vgg16', 'fit_dt_test_start': '2019-01-20 13:33:06', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 2, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 3, 'path_model': '/mnt/seals/models/70/'}
# 2019-01-20 13:33:08,226 [MainThread  ] [INFO ]  model 70 test acc: 0.6670914303918445
# 2019-01-20 13:33:08,534 [MainThread  ] [INFO ]  Begin experiment for model_id=78 on GPU:6
# 2019-01-20 13:33:08,536 [MainThread  ] [INFO ]  Loading data
# 78   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 78, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 512, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 0, 'sequence_model_layers': nan}
# 2019-01-20 13:33:09,609 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:33:09,610 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 11s 184us/step - loss: 0.4428 - acc: 0.9325 - val_loss: 0.1621 - val_acc: 0.9375
#
# Epoch 00001: val_acc improved from -inf to 0.93748, saving model to /mnt/seals/models/78/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 10s 168us/step - loss: 0.1220 - acc: 0.9513 - val_loss: 0.1836 - val_acc: 0.9267
#
# Epoch 00002: val_acc did not improve from 0.93748
# Epoch 3/20
# 60597/60597 [==============================] - 10s 169us/step - loss: 0.1117 - acc: 0.9557 - val_loss: 0.1724 - val_acc: 0.9294
#
# Epoch 00003: val_acc did not improve from 0.93748
# Epoch 4/20
# 60597/60597 [==============================] - 10s 168us/step - loss: 0.1068 - acc: 0.9573 - val_loss: 0.1909 - val_acc: 0.9251
#
# Epoch 00004: val_acc did not improve from 0.93748
# H1 {'val_loss': [0.1620870777161936, 0.18357936915316783, 0.172362432701332, 0.1908626651526092], 'val_acc': [0.9374777548330978, 0.9267456537470259, 0.9293507486210202, 0.9250757230487547], 'acc': [0.932535576125345, 0.9513106646873315, 0.9557427565325608, 0.9573482091494483], 'loss': [0.44279403343949436, 0.12198777652989579, 0.11171336924304627, 0.10675509673080465]}
# stopped_epoch1 1
# 4
# 0.9267456537470259
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 11s 188us/step - loss: 0.0858 - acc: 0.9655 - val_loss: 0.1661 - val_acc: 0.9372
#
# Epoch 00001: val_acc improved from -inf to 0.93723, saving model to /mnt/seals/models/78/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 10s 169us/step - loss: 0.0808 - acc: 0.9675 - val_loss: 0.1647 - val_acc: 0.9388
#
# Epoch 00002: val_acc improved from 0.93723 to 0.93881, saving model to /mnt/seals/models/78/model_round_2.h5
# Epoch 3/20
# 60597/60597 [==============================] - 10s 168us/step - loss: 0.0784 - acc: 0.9681 - val_loss: 0.1733 - val_acc: 0.9374
#
# Epoch 00003: val_acc did not improve from 0.93881
# Epoch 4/20
# 60597/60597 [==============================] - 10s 172us/step - loss: 0.0766 - acc: 0.9688 - val_loss: 0.1772 - val_acc: 0.9352
#
# Epoch 00004: val_acc did not improve from 0.93881
# Epoch 5/20
# 60597/60597 [==============================] - 10s 172us/step - loss: 0.0747 - acc: 0.9693 - val_loss: 0.1803 - val_acc: 0.9347
#
# Epoch 00005: val_acc did not improve from 0.93881
# H2 {'val_loss': [0.16605838739366602, 0.1647002077905317, 0.17327817791417946, 0.177225112246159, 0.180274810539814], 'val_acc': [0.937232829834755, 0.9388136972215705, 0.9374109543767059, 0.9351843745631173, 0.9346945321470722], 'acc': [0.9654627064333667, 0.9674925094197949, 0.9681172462820442, 0.9688127063338838, 0.9693455003880784], 'loss': [0.0857565315869987, 0.08084161512734801, 0.07836184951943498, 0.07658437309432235, 0.07467135522636735]}
# stopped_epoch2 2
# 5
# 0.9374109543767059
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 11s 189us/step - loss: 0.0718 - acc: 0.9704 - val_loss: 0.1771 - val_acc: 0.9385
#
# Epoch 00001: val_acc improved from -inf to 0.93846, saving model to /mnt/seals/models/78/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 10s 171us/step - loss: 0.0706 - acc: 0.9708 - val_loss: 0.1778 - val_acc: 0.9380
#
# Epoch 00002: val_acc did not improve from 0.93846
# Epoch 3/20
# 60597/60597 [==============================] - 10s 171us/step - loss: 0.0701 - acc: 0.9710 - val_loss: 0.1773 - val_acc: 0.9379
#
# Epoch 00003: val_acc did not improve from 0.93846
# Epoch 4/20
# 60597/60597 [==============================] - 10s 171us/step - loss: 0.0704 - acc: 0.9709 - val_loss: 0.1760 - val_acc: 0.9389
#
# Epoch 00004: val_acc improved from 0.93846 to 0.93890, saving model to /mnt/seals/models/78/model_round_3.h5
# Epoch 5/20
# 60597/60597 [==============================] - 10s 171us/step - loss: 0.0698 - acc: 0.9714 - val_loss: 0.1783 - val_acc: 0.9383
#
# Epoch 00005: val_acc did not improve from 0.93890
# Epoch 6/20
# 60597/60597 [==============================] - 10s 171us/step - loss: 0.0697 - acc: 0.9713 - val_loss: 0.1780 - val_acc: 0.9387
#
# Epoch 00006: val_acc did not improve from 0.93890
# Epoch 7/20
# 60597/60597 [==============================] - 10s 170us/step - loss: 0.0694 - acc: 0.9713 - val_loss: 0.1800 - val_acc: 0.9380
#
# Epoch 00007: val_acc did not improve from 0.93890
# H3 {'val_loss': [0.17710877141155804, 0.17784682510796926, 0.1773345060925234, 0.17596619485173737, 0.17830908476860446, 0.17800195953643827, 0.1800037995166612], 'val_acc': [0.9384574450162283, 0.9380121296480707, 0.937923065147495, 0.938902759492546, 0.9383015852616612, 0.9386801032948673, 0.9379898639688468], 'acc': [0.9703945856093416, 0.9708260061872799, 0.9709792435626605, 0.9708542960623395, 0.9714035932072704, 0.9712739308208893, 0.9712503565637058], 'loss': [0.07175868725323026, 0.0705716303358715, 0.07007123176556526, 0.07035608706134835, 0.06983753959801157, 0.06972375293067039, 0.06940701211804767]}
# stopped_epoch3 4
# 7
# 0.9383015852616612
# best fit round 3 0.9383015852616612
# 3139/3139 [==============================] - 0s 132us/step
# 2019-01-20 13:36:08,252 [MainThread  ] [INFO ]  {'frame_size': (224, 224), 'model_weights_path': None, 'fit_stopped_epoch1': 1, 'fit_train_acc': 0.9714035932072704, 'fit_train_loss': 0.06983753959801157, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:36:05', 'sequence_length': 1.0, 'model_param_count': 266247, 'fit_dt_train_start': '2019-01-20 13:33:10', 'fit_val_loss': 0.17830908476860446, 'num_features': 512, 'sequence_model': nan, 'fit_test_acc': 0.6559413826059255, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:36:06', 'layer_1_size': 512, 'fit_dt_train_duration_seconds': '175', 'fit_val_acc': 0.9383015852616612, 'layer_2_size': 0, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 78, 'fit_best_round': 3, 'fit_num_epochs': 10, 'pretrained_model_name': 'vgg16', 'fit_dt_test_start': '2019-01-20 13:36:06', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 4, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 2, 'path_model': '/mnt/seals/models/78/'}
# 2019-01-20 13:36:08,253 [MainThread  ] [INFO ]  model 78 test acc: 0.6559413826059255
# 2019-01-20 13:36:08,604 [MainThread  ] [INFO ]  Begin experiment for model_id=86 on GPU:6
# 2019-01-20 13:36:08,606 [MainThread  ] [INFO ]  Loading data
# 86   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 86, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 256, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 256, 'sequence_model_layers': nan}
# 2019-01-20 13:36:09,714 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:36:09,717 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 15s 246us/step - loss: 0.1975 - acc: 0.9309 - val_loss: 0.1765 - val_acc: 0.9297
#
# Epoch 00001: val_acc improved from -inf to 0.92971, saving model to /mnt/seals/models/86/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 223us/step - loss: 0.1300 - acc: 0.9479 - val_loss: 0.1842 - val_acc: 0.9205
#
# Epoch 00002: val_acc did not improve from 0.92971
# Epoch 3/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.1190 - acc: 0.9529 - val_loss: 0.1617 - val_acc: 0.9355
#
# Epoch 00003: val_acc improved from 0.92971 to 0.93552, saving model to /mnt/seals/models/86/model_round_1.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 225us/step - loss: 0.1123 - acc: 0.9555 - val_loss: 0.1641 - val_acc: 0.9316
#
# Epoch 00004: val_acc did not improve from 0.93552
# Epoch 5/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.1060 - acc: 0.9579 - val_loss: 0.1759 - val_acc: 0.9358
#
# Epoch 00005: val_acc improved from 0.93552 to 0.93579, saving model to /mnt/seals/models/86/model_round_1.h5
# Epoch 6/20
# 60597/60597 [==============================] - 14s 229us/step - loss: 0.1026 - acc: 0.9594 - val_loss: 0.1910 - val_acc: 0.9318
#
# Epoch 00006: val_acc did not improve from 0.93579
# Epoch 7/20
# 60597/60597 [==============================] - 14s 229us/step - loss: 0.0999 - acc: 0.9604 - val_loss: 0.2001 - val_acc: 0.9183
#
# Epoch 00007: val_acc did not improve from 0.93579
# Epoch 8/20
# 60597/60597 [==============================] - 14s 227us/step - loss: 0.0966 - acc: 0.9620 - val_loss: 0.2012 - val_acc: 0.9184
#
# Epoch 00008: val_acc did not improve from 0.93579
# H1 {'val_loss': [0.17650775849224623, 0.1841971156305803, 0.16167298031789704, 0.16412593511646228, 0.1759322914956811, 0.19099403159725398, 0.20013406794713323, 0.20123365588318975], 'val_acc': [0.9297070024614025, 0.9205112391873785, 0.9355183685212362, 0.9316441251750004, 0.9357855566719226, 0.9318445137611351, 0.9182623984510464, 0.9184405234389175], 'acc': [0.9309206918133527, 0.947946520441426, 0.9529420530136826, 0.9555329386516379, 0.9578951496362809, 0.9594393086035633, 0.9604105955224908, 0.9619877588240004], 'loss': [0.1974952671863947, 0.13003247197986265, 0.11901075109333611, 0.11227989933400831, 0.1059875550729059, 0.10261816758747484, 0.09989967262922743, 0.09655749105485215]}
# stopped_epoch1 5
# 8
# 0.9318445137611351
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 15s 255us/step - loss: 0.0812 - acc: 0.9668 - val_loss: 0.1926 - val_acc: 0.9272
#
# Epoch 00001: val_acc improved from -inf to 0.92719, saving model to /mnt/seals/models/86/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 230us/step - loss: 0.0776 - acc: 0.9682 - val_loss: 0.1898 - val_acc: 0.9302
#
# Epoch 00002: val_acc improved from 0.92719 to 0.93020, saving model to /mnt/seals/models/86/model_round_2.h5
# Epoch 3/20
# 60597/60597 [==============================] - 14s 230us/step - loss: 0.0749 - acc: 0.9693 - val_loss: 0.1907 - val_acc: 0.9271
#
# Epoch 00003: val_acc did not improve from 0.93020
# Epoch 4/20
# 60597/60597 [==============================] - 14s 231us/step - loss: 0.0736 - acc: 0.9697 - val_loss: 0.1915 - val_acc: 0.9333
#
# Epoch 00004: val_acc improved from 0.93020 to 0.93331, saving model to /mnt/seals/models/86/model_round_2.h5
# Epoch 5/20
# 60597/60597 [==============================] - 14s 231us/step - loss: 0.0727 - acc: 0.9702 - val_loss: 0.1902 - val_acc: 0.9281
#
# Epoch 00005: val_acc did not improve from 0.93331
# Epoch 6/20
# 60597/60597 [==============================] - 14s 232us/step - loss: 0.0718 - acc: 0.9703 - val_loss: 0.1914 - val_acc: 0.9306
#
# Epoch 00006: val_acc did not improve from 0.93331
# Epoch 7/20
# 60597/60597 [==============================] - 14s 233us/step - loss: 0.0704 - acc: 0.9710 - val_loss: 0.2072 - val_acc: 0.9251
#
# Epoch 00007: val_acc did not improve from 0.93331
# H2 {'val_loss': [0.19262612956643402, 0.18977594542830364, 0.19068878119871802, 0.19145016479967836, 0.19022505204576506, 0.19135763797156533, 0.20716731913592157], 'val_acc': [0.9271909700070237, 0.930196850079848, 0.9270796448809845, 0.9333140546841514, 0.9281261303181065, 0.9305976296303575, 0.9250757224541947], 'acc': [0.9667781887535317, 0.9681691107221615, 0.9693266400303807, 0.9696614037955309, 0.9702366331472415, 0.9703215022786414, 0.9709957460278121], 'loss': [0.08118875396721212, 0.07762192371172022, 0.07487191838766567, 0.07364090961858809, 0.07270804153917329, 0.07182103937032945, 0.07042613921277481]}
# stopped_epoch2 4
# 7
# 0.9281261303181065
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 16s 261us/step - loss: 0.0681 - acc: 0.9718 - val_loss: 0.2041 - val_acc: 0.9282
#
# Epoch 00001: val_acc improved from -inf to 0.92822, saving model to /mnt/seals/models/86/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 230us/step - loss: 0.0680 - acc: 0.9717 - val_loss: 0.2065 - val_acc: 0.9280
#
# Epoch 00002: val_acc did not improve from 0.92822
# Epoch 3/20
# 60597/60597 [==============================] - 14s 233us/step - loss: 0.0677 - acc: 0.9717 - val_loss: 0.2049 - val_acc: 0.9284
#
# Epoch 00003: val_acc improved from 0.92822 to 0.92844, saving model to /mnt/seals/models/86/model_round_3.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 232us/step - loss: 0.0676 - acc: 0.9719 - val_loss: 0.2027 - val_acc: 0.9294
#
# Epoch 00004: val_acc improved from 0.92844 to 0.92935, saving model to /mnt/seals/models/86/model_round_3.h5
# Epoch 5/20
# 60597/60597 [==============================] - 14s 232us/step - loss: 0.0675 - acc: 0.9717 - val_loss: 0.2072 - val_acc: 0.9281
#
# Epoch 00005: val_acc did not improve from 0.92935
# Epoch 6/20
# 60597/60597 [==============================] - 14s 234us/step - loss: 0.0672 - acc: 0.9720 - val_loss: 0.2057 - val_acc: 0.9287
#
# Epoch 00006: val_acc did not improve from 0.92935
# Epoch 7/20
# 60597/60597 [==============================] - 14s 234us/step - loss: 0.0670 - acc: 0.9722 - val_loss: 0.2064 - val_acc: 0.9286
#
# Epoch 00007: val_acc did not improve from 0.92935
# H3 {'val_loss': [0.204095908326847, 0.20651505690560376, 0.20485170754113993, 0.2026666973966018, 0.20722251387308363, 0.20567062001052938, 0.2064296428179206], 'val_acc': [0.9282151986833225, 0.9279702750227398, 0.9284378563674014, 0.9293507527829405, 0.928103869395363, 0.928682778541584, 0.9286159826930325], 'acc': [0.9717548597631517, 0.9716888501779599, 0.9716582019706743, 0.9719033827560873, 0.9716511301766753, 0.9719623193138159, 0.9721650637620227], 'loss': [0.06814725809972853, 0.06803126459016692, 0.06769165519243733, 0.06762120655502685, 0.06753567997274898, 0.06721071030077828, 0.06704800884657308]}
# stopped_epoch3 4
# 7
# 0.928103869395363
# best fit round 1 0.9318445137611351
# 3139/3139 [==============================] - 1s 198us/step
# 2019-01-20 13:41:36,148 [MainThread  ] [INFO ]  {'frame_size': (224, 224), 'model_weights_path': None, 'fit_stopped_epoch1': 5, 'fit_train_acc': 0.9594393086035633, 'fit_train_loss': 0.10261816758747484, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:41:32', 'sequence_length': 1.0, 'model_param_count': 230919, 'fit_dt_train_start': '2019-01-20 13:36:10', 'fit_val_loss': 0.19099403159725398, 'num_features': 512, 'sequence_model': nan, 'fit_test_acc': 0.6632685568652437, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:41:34', 'layer_1_size': 256, 'fit_dt_train_duration_seconds': '322', 'fit_val_acc': 0.9318445137611351, 'layer_2_size': 256, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 86, 'fit_best_round': 1, 'fit_num_epochs': 16, 'pretrained_model_name': 'vgg16', 'fit_dt_test_start': '2019-01-20 13:41:33', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 4, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 4, 'path_model': '/mnt/seals/models/86/'}
# 2019-01-20 13:41:36,150 [MainThread  ] [INFO ]  model 86 test acc: 0.6632685568652437
# 2019-01-20 13:41:36,595 [MainThread  ] [INFO ]  Begin experiment for model_id=94 on GPU:6
# 2019-01-20 13:41:36,597 [MainThread  ] [INFO ]  Loading data
# 94   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 94, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 256, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 0, 'sequence_model_layers': nan}
# 2019-01-20 13:41:37,705 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:41:37,706 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 12s 199us/step - loss: 0.3081 - acc: 0.9351 - val_loss: 0.2344 - val_acc: 0.9032
#
# Epoch 00001: val_acc improved from -inf to 0.90321, saving model to /mnt/seals/models/94/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.1227 - acc: 0.9510 - val_loss: 0.2026 - val_acc: 0.9098
#
# Epoch 00002: val_acc improved from 0.90321 to 0.90978, saving model to /mnt/seals/models/94/model_round_1.h5
# Epoch 3/20
# 60597/60597 [==============================] - 11s 174us/step - loss: 0.1135 - acc: 0.9545 - val_loss: 0.1759 - val_acc: 0.9353
#
# Epoch 00003: val_acc improved from 0.90978 to 0.93525, saving model to /mnt/seals/models/94/model_round_1.h5
# Epoch 4/20
# 60597/60597 [==============================] - 11s 174us/step - loss: 0.1068 - acc: 0.9570 - val_loss: 0.1831 - val_acc: 0.9289
#
# Epoch 00004: val_acc did not improve from 0.93525
# Epoch 5/20
# 60597/60597 [==============================] - 11s 174us/step - loss: 0.1029 - acc: 0.9584 - val_loss: 0.1888 - val_acc: 0.9375
#
# Epoch 00005: val_acc improved from 0.93525 to 0.93750, saving model to /mnt/seals/models/94/model_round_1.h5
# Epoch 6/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.0989 - acc: 0.9601 - val_loss: 0.1650 - val_acc: 0.9398
#
# Epoch 00006: val_acc improved from 0.93750 to 0.93979, saving model to /mnt/seals/models/94/model_round_1.h5
# Epoch 7/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.0960 - acc: 0.9617 - val_loss: 0.2048 - val_acc: 0.9253
#
# Epoch 00007: val_acc did not improve from 0.93979
# Epoch 8/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.0937 - acc: 0.9620 - val_loss: 0.1859 - val_acc: 0.9308
#
# Epoch 00008: val_acc did not improve from 0.93979
# Epoch 9/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.0909 - acc: 0.9638 - val_loss: 0.1987 - val_acc: 0.9285
#
# Epoch 00009: val_acc did not improve from 0.93979
# H1 {'val_loss': [0.23436127712676055, 0.20261476945104148, 0.17588381511983728, 0.18309756007946637, 0.18877999421367028, 0.16498918063994358, 0.20483099661786064, 0.18591993389432865, 0.19869791437637183], 'val_acc': [0.9032107416233814, 0.909779143155067, 0.9352511762086293, 0.928905438603903, 0.9375000175395214, 0.9397933905261413, 0.9253206443310973, 0.9308425526963803, 0.9284601184792649], 'acc': [0.9351288197384708, 0.9509735436896466, 0.9545333625619253, 0.957020518214053, 0.9584232275601312, 0.9601324106192477, 0.9616600675404023, 0.9620301950057941, 0.9637865272107639], 'loss': [0.30806579815014884, 0.12269193558243849, 0.11345124177889597, 0.1067945386505045, 0.10286252899726318, 0.0988713130818414, 0.09597878768148208, 0.09373218163729642, 0.09089907652456686]}
# stopped_epoch1 6
# 9
# 0.9253206443310973
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 12s 202us/step - loss: 0.0749 - acc: 0.9689 - val_loss: 0.1989 - val_acc: 0.9336
#
# Epoch 00001: val_acc improved from -inf to 0.93365, saving model to /mnt/seals/models/94/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 11s 175us/step - loss: 0.0721 - acc: 0.9699 - val_loss: 0.2074 - val_acc: 0.9351
#
# Epoch 00002: val_acc improved from 0.93365 to 0.93510, saving model to /mnt/seals/models/94/model_round_2.h5
# Epoch 3/20
# 60597/60597 [==============================] - 11s 173us/step - loss: 0.0706 - acc: 0.9707 - val_loss: 0.1990 - val_acc: 0.9385
#
# Epoch 00003: val_acc improved from 0.93510 to 0.93846, saving model to /mnt/seals/models/94/model_round_2.h5
# Epoch 4/20
# 60597/60597 [==============================] - 11s 174us/step - loss: 0.0693 - acc: 0.9711 - val_loss: 0.2057 - val_acc: 0.9365
#
# Epoch 00004: val_acc did not improve from 0.93846
# Epoch 5/20
# 60597/60597 [==============================] - 11s 174us/step - loss: 0.0685 - acc: 0.9715 - val_loss: 0.2092 - val_acc: 0.9363
#
# Epoch 00005: val_acc did not improve from 0.93846
# Epoch 6/20
# 60597/60597 [==============================] - 11s 176us/step - loss: 0.0678 - acc: 0.9715 - val_loss: 0.2216 - val_acc: 0.9311
#
# Epoch 00006: val_acc did not improve from 0.93846
# H2 {'val_loss': [0.1989455571644324, 0.20736190797459159, 0.19903594551798412, 0.2056798128099959, 0.20920680951968096, 0.22156090382254331], 'val_acc': [0.9336480407643497, 0.9350953176431822, 0.9384574453135084, 0.9365203255727107, 0.9363421961256393, 0.9310652115695791], 'acc': [0.9689282237128979, 0.9698924383047023, 0.9706963445514035, 0.9710546840757305, 0.9714790337114878, 0.9715096811987609], 'loss': [0.07488842467751504, 0.0720761278985245, 0.07059076225147555, 0.0693140142984606, 0.0685269759846292, 0.06775051618518162]}
# stopped_epoch2 3
# 6
# 0.9365203255727107
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0654 - acc: 0.9725 - val_loss: 0.2193 - val_acc: 0.9341
#
# ...
#
# Epoch 00007: val_acc did not improve from 0.93494
# Epoch 8/20
# 60597/60597 [==============================] - 11s 176us/step - loss: 0.0645 - acc: 0.9730 - val_loss: 0.2207 - val_acc: 0.9340
#
# Epoch 00008: val_acc did not improve from 0.93494
# H3 {'val_loss': [0.21925886396197905, 0.21890792161449232, 0.21762513687968849, 0.21876841483456536, 0.21802322079713207, 0.21990367970859023, 0.22067729502619057, 0.2206565521453087], 'val_acc': [0.9340710928315237, 0.9341601564402592, 0.9342714827554184, 0.934182421822203, 0.9349394558076549, 0.9342492179680346, 0.9338706993402686, 0.9339597623544441], 'acc': [0.9724998282678415, 0.9726294907781593, 0.9728770277603512, 0.9728039447867064, 0.9729548247013516, 0.9731434249723697, 0.9729477522148815, 0.9729548245085614], 'loss': [0.06535569962016287, 0.06487112101824316, 0.06487914619614374, 0.06477240386958777, 0.06449955438843914, 0.06403774399697837, 0.06434673293403272, 0.06448414226787388]}
# stopped_epoch3 5
# 8
# 0.9342492179680346
# best fit round 2 0.9365203255727107
# 3139/3139 [==============================] - 1s 224us/step
# 2019-01-20 13:46:02,702 [MainThread  ] [INFO ]  {'frame_size': (224, 224), 'model_weights_path': None, 'fit_stopped_epoch1': 6, 'fit_train_acc': 0.9710546840757305, 'fit_train_loss': 0.0693140142984606, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:45:58', 'sequence_length': 1.0, 'model_param_count': 133127, 'fit_dt_train_start': '2019-01-20 13:41:38', 'fit_val_loss': 0.2056798128099959, 'num_features': 512, 'sequence_model': nan, 'fit_test_acc': 0.6352341510035042, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:46:00', 'layer_1_size': 256, 'fit_dt_train_duration_seconds': '260', 'fit_val_acc': 0.9365203255727107, 'layer_2_size': 0, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 94, 'fit_best_round': 2, 'fit_num_epochs': 17, 'pretrained_model_name': 'vgg16', 'fit_dt_test_start': '2019-01-20 13:46:00', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 5, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 3, 'path_model': '/mnt/seals/models/94/'}
# 2019-01-20 13:46:02,704 [MainThread  ] [INFO ]  model 94 test acc: 0.6352341510035042
# 2019-01-20 13:46:03,206 [MainThread  ] [INFO ]  Begin experiment for model_id=102 on GPU:6
# 2019-01-20 13:46:03,208 [MainThread  ] [INFO ]  Loading data
# 102   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 102, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 128, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 256, 'sequence_model_layers': nan}
# 2019-01-20 13:46:04,292 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:46:04,294 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 16s 269us/step - loss: 0.2023 - acc: 0.9296 - val_loss: 0.1890 - val_acc: 0.9270
#
# Epoch 00001: val_acc improved from -inf to 0.92699, saving model to /mnt/seals/models/102/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 235us/step - loss: 0.1328 - acc: 0.9478 - val_loss: 0.2070 - val_acc: 0.9187
#
# Epoch 00002: val_acc did not improve from 0.92699
# Epoch 3/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.1210 - acc: 0.9526 - val_loss: 0.1740 - val_acc: 0.9326
#
# Epoch 00003: val_acc improved from 0.92699 to 0.93265, saving model to /mnt/seals/models/102/model_round_1.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.1132 - acc: 0.9555 - val_loss: 0.2020 - val_acc: 0.9147
#
# Epoch 00004: val_acc did not improve from 0.93265
# Epoch 5/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.1096 - acc: 0.9571 - val_loss: 0.1910 - val_acc: 0.9231
#
# Epoch 00005: val_acc did not improve from 0.93265
# Epoch 6/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.1048 - acc: 0.9586 - val_loss: 0.1758 - val_acc: 0.9336
#
# Epoch 00006: val_acc improved from 0.93265 to 0.93356, saving model to /mnt/seals/models/102/model_round_1.h5
# Epoch 7/20
# 60597/60597 [==============================] - 14s 235us/step - loss: 0.1034 - acc: 0.9595 - val_loss: 0.1817 - val_acc: 0.9280
#
# Epoch 00007: val_acc did not improve from 0.93356
# Epoch 8/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0995 - acc: 0.9608 - val_loss: 0.1916 - val_acc: 0.9117
#
# Epoch 00008: val_acc did not improve from 0.93356
# Epoch 9/20
# 60597/60597 [==============================] - 14s 234us/step - loss: 0.0984 - acc: 0.9613 - val_loss: 0.1771 - val_acc: 0.9353
#
# Epoch 00009: val_acc improved from 0.93356 to 0.93527, saving model to /mnt/seals/models/102/model_round_1.h5
# Epoch 10/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0961 - acc: 0.9623 - val_loss: 0.1885 - val_acc: 0.9317
#
# Epoch 00010: val_acc did not improve from 0.93527
# Epoch 11/20
# 60597/60597 [==============================] - 14s 234us/step - loss: 0.0958 - acc: 0.9622 - val_loss: 0.1839 - val_acc: 0.9325
#
# Epoch 00011: val_acc did not improve from 0.93527
# Epoch 12/20
# 60597/60597 [==============================] - 14s 231us/step - loss: 0.0940 - acc: 0.9631 - val_loss: 0.2015 - val_acc: 0.9246
#
# Epoch 00012: val_acc did not improve from 0.93527
# H1 {'val_loss': [0.189022683703394, 0.20695445502636736, 0.1739529736916026, 0.20203980922401696, 0.19098514812694226, 0.1757996941445177, 0.18167703307031693, 0.19160889728259564, 0.17714811103450984, 0.18850588014446887, 0.18387158248489932, 0.2015076234304994], 'val_acc': [0.9269905782994486, 0.9186631812716363, 0.9326460807400748, 0.9146998775867453, 0.9230940729899894, 0.9335589813175345, 0.9280148048947874, 0.9117385318451688, 0.9352734463470536, 0.9316886526688078, 0.9325347538303556, 0.924630406342837], 'acc': [0.9295887064152386, 0.9478262887960346, 0.9525931441673936, 0.9554622141292375, 0.9570582388035446, 0.9586094698904056, 0.9595312496833912, 0.9608325867906117, 0.9613488788124492, 0.9622824459071443, 0.9621527840292965, 0.9630934254704941], 'loss': [0.2022699160694059, 0.1327771207191591, 0.12097632225471859, 0.11320387202244472, 0.10963055977480504, 0.10476329425048567, 0.10336007646956766, 0.09945705617275018, 0.09842897777698267, 0.0961016693935252, 0.09584373127700634, 0.09403820128836825]}
# stopped_epoch1 9
# 12
# 0.9316886526688078
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 17s 272us/step - loss: 0.0809 - acc: 0.9672 - val_loss: 0.1944 - val_acc: 0.9276
#
# Epoch 00001: val_acc improved from -inf to 0.92764, saving model to /mnt/seals/models/102/model_round_2.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 238us/step - loss: 0.0775 - acc: 0.9684 - val_loss: 0.1929 - val_acc: 0.9273
#
# Epoch 00002: val_acc did not improve from 0.92764
# Epoch 3/20
# 60597/60597 [==============================] - 14s 239us/step - loss: 0.0766 - acc: 0.9684 - val_loss: 0.1810 - val_acc: 0.9344
#
# Epoch 00003: val_acc improved from 0.92764 to 0.93441, saving model to /mnt/seals/models/102/model_round_2.h5
# Epoch 4/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0754 - acc: 0.9693 - val_loss: 0.1879 - val_acc: 0.9314
#
# Epoch 00004: val_acc did not improve from 0.93441
# Epoch 5/20
# 60597/60597 [==============================] - 14s 239us/step - loss: 0.0741 - acc: 0.9698 - val_loss: 0.1976 - val_acc: 0.9286
#
# Epoch 00005: val_acc did not improve from 0.93441
# Epoch 6/20
# 60597/60597 [==============================] - 14s 238us/step - loss: 0.0740 - acc: 0.9695 - val_loss: 0.2029 - val_acc: 0.9267
#
# Epoch 00006: val_acc did not improve from 0.93441
# H2 {'val_loss': [0.1944242461661151, 0.1928680521108563, 0.18103063853452925, 0.18789042881748028, 0.19762111282408087, 0.2028572925754319], 'val_acc': [0.9276362858211014, 0.9272800362912794, 0.9344050753443616, 0.9314437315351053, 0.928615977787912, 0.9267456549361459], 'acc': [0.9671553868778209, 0.9684072173981253, 0.968435507364662, 0.969251201053731, 0.969779279070042, 0.9694963808968324], 'loss': [0.08088557901862081, 0.0774634797866539, 0.07656106075965204, 0.07536168510487212, 0.07410101277590583, 0.07403753879547458]}
# stopped_epoch2 3
# 6
# 0.9314437315351053
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 17s 273us/step - loss: 0.0724 - acc: 0.9699 - val_loss: 0.2016 - val_acc: 0.9279
#
# Epoch 00001: val_acc improved from -inf to 0.92786, saving model to /mnt/seals/models/102/model_round_3.h5
# Epoch 2/20
# 60597/60597 [==============================] - 14s 233us/step - loss: 0.0718 - acc: 0.9704 - val_loss: 0.1996 - val_acc: 0.9292
#
# Epoch 00002: val_acc improved from 0.92786 to 0.92922, saving model to /mnt/seals/models/102/model_round_3.h5
# Epoch 3/20
# 60597/60597 [==============================] - 14s 236us/step - loss: 0.0717 - acc: 0.9705 - val_loss: 0.2031 - val_acc: 0.9282
#
# Epoch 00003: val_acc did not improve from 0.92922
# Epoch 4/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0715 - acc: 0.9705 - val_loss: 0.2025 - val_acc: 0.9281
#
# Epoch 00004: val_acc did not improve from 0.92922
# Epoch 5/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0717 - acc: 0.9702 - val_loss: 0.2008 - val_acc: 0.9296
#
# Epoch 00005: val_acc improved from 0.92922 to 0.92957, saving model to /mnt/seals/models/102/model_round_3.h5
# Epoch 6/20
# 60597/60597 [==============================] - 14s 234us/step - loss: 0.0711 - acc: 0.9705 - val_loss: 0.2026 - val_acc: 0.9288
#
# Epoch 00006: val_acc did not improve from 0.92957
# Epoch 7/20
# 60597/60597 [==============================] - 14s 239us/step - loss: 0.0716 - acc: 0.9704 - val_loss: 0.2002 - val_acc: 0.9292
#
# Epoch 00007: val_acc did not improve from 0.92957
# Epoch 8/20
# 60597/60597 [==============================] - 14s 237us/step - loss: 0.0709 - acc: 0.9706 - val_loss: 0.1995 - val_acc: 0.9303
#
# Epoch 00008: val_acc improved from 0.92957 to 0.93029, saving model to /mnt/seals/models/102/model_round_3.h5
# Epoch 9/20
# 60597/60597 [==============================] - 14s 238us/step - loss: 0.0711 - acc: 0.9706 - val_loss: 0.2017 - val_acc: 0.9296
#
# Epoch 00009: val_acc did not improve from 0.93029
# Epoch 10/20
# 60597/60597 [==============================] - 14s 238us/step - loss: 0.0712 - acc: 0.9706 - val_loss: 0.2035 - val_acc: 0.9280
#
# Epoch 00010: val_acc did not improve from 0.93029
# Epoch 11/20
# 60597/60597 [==============================] - 14s 238us/step - loss: 0.0713 - acc: 0.9705 - val_loss: 0.2033 - val_acc: 0.9282
#
# Epoch 00011: val_acc did not improve from 0.93029
# H3 {'val_loss': [0.20164645405630222, 0.19964724091668973, 0.20308077379949668, 0.20253920467788739, 0.20079054345290856, 0.2026316837553966, 0.2002054664150735, 0.19950017046898677, 0.2016585859983342, 0.203505240362184, 0.20331637851169282], 'val_acc': [0.9278589446943002, 0.9292171558834371, 0.928237459903346, 0.9281483970378105, 0.9295734079401392, 0.9288163726169272, 0.9291948907987733, 0.9302859132426635, 0.9295956749571231, 0.928037068047131, 0.9282374625788663], 'acc': [0.9698735792965363, 0.9703757258457526, 0.9704841701412369, 0.9704888855525522, 0.9702012710119452, 0.9705383929303018, 0.9704464505235655, 0.9706397653048996, 0.9706279776687581, 0.9705879008401918, 0.9704629532641317], 'loss': [0.07236116032329454, 0.07181640161081755, 0.07167658394377706, 0.07151046907585332, 0.07166831311803211, 0.07105361615947338, 0.07159474888633245, 0.07094721278896493, 0.07111274302963572, 0.0712438461890227, 0.0713261156548332]}
# stopped_epoch3 8
# 11
# 0.9295956749571231
# best fit round 1 0.9316886526688078
# 3139/3139 [==============================] - 1s 295us/step
# 2019-01-20 13:53:26,500 [MainThread  ] [INFO ]  {'frame_size': (224, 224), 'model_weights_path': None, 'fit_stopped_epoch1': 9, 'fit_train_acc': 0.9622824459071443, 'fit_train_loss': 0.0961016693935252, 'data_total_rows_test': 3139, 'fit_dt_train_end': '2019-01-20 13:53:22', 'sequence_length': 1.0, 'model_param_count': 132487, 'fit_dt_train_start': '2019-01-20 13:46:04', 'fit_val_loss': 0.18850588014446887, 'num_features': 512, 'sequence_model': nan, 'fit_test_acc': 0.6559413826059255, 'data_total_rows_valid': 6416, 'fit_dt_test_end': '2019-01-20 13:53:24', 'layer_1_size': 128, 'fit_dt_train_duration_seconds': '437', 'fit_val_acc': 0.9316886526688078, 'layer_2_size': 256, 'pooling': 'max', 'sequence_model_layers': nan, 'model_id': 102, 'fit_best_round': 1, 'fit_num_epochs': 23, 'pretrained_model_name': 'vgg16', 'fit_dt_test_start': '2019-01-20 13:53:23', 'layer_3_size': 128, 'verbose': True, 'architecture': 'image_mlp_frozen', 'convolution_kernel_size': 3, 'fit_stopped_epoch3': 8, 'data_total_rows_train': 60597, 'dropout': 0.2, 'batch_size': 32, 'fit_dt_test_duration_seconds': '0', 'fit_stopped_epoch2': 3, 'path_model': '/mnt/seals/models/102/'}
# 2019-01-20 13:53:26,501 [MainThread  ] [INFO ]  model 102 test acc: 0.6559413826059255
# 2019-01-20 13:53:27,030 [MainThread  ] [INFO ]  Begin experiment for model_id=110 on GPU:6
# 2019-01-20 13:53:27,032 [MainThread  ] [INFO ]  Loading data
# 110   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'model_id': 110, 'pretrained_model_name': 'vgg16', 'layer_3_size': 128, 'sequence_length': 1.0, 'architecture': 'image_MLP_frozen', 'dropout': 0.2, 'layer_1_size': 128, 'sequence_model': nan, 'pooling': 'max', 'WORKER': 6, 'layer_2_size': 0, 'sequence_model_layers': nan}
# 2019-01-20 13:53:28,192 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 13:53:28,193 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/20
# 60597/60597 [==============================] - 13s 217us/step - loss: 0.2390 - acc: 0.9307 - val_loss: 0.2083 - val_acc: 0.9130
#
# Epoch 00001: val_acc improved from -inf to 0.91301, saving model to /mnt/seals/models/110/model_round_1.h5
# Epoch 2/20
# 60597/60597 [==============================] - 11s 180us/step - loss: 0.1301 - acc: 0.9476 - val_loss: 0.1980 - val_acc: 0.9138
#
# Epoch 00002: val_acc improved from 0.91301 to 0.91379, saving model to /mnt/seals/models/110/model_round_1.h5
# Epoch 3/20
# 60597/60597 [==============================] - 11s 181us/step - loss: 0.1209 - acc: 0.9513 - val_loss: 0.1833 - val_acc: 0.9304
#
# Epoch 00003: val_acc improved from 0.91379 to 0.93042, saving model to /mnt/seals/models/110/model_round_1.h5
# Epoch 4/20
# 60597/60597 [==============================] - 11s 180us/step - loss: 0.1141 - acc: 0.9542 - val_loss: 0.1689 - val_acc: 0.9329
#
# Epoch 00004: val_acc improved from 0.93042 to 0.93291, saving model to /mnt/seals/models/110/model_round_1.h5
# Epoch 5/20
# 60597/60597 [==============================] - 11s 180us/step - loss: 0.1096 - acc: 0.9561 - val_loss: 0.1989 - val_acc: 0.9209
#
# Epoch 00005: val_acc did not improve from 0.93291
# Epoch 6/20
# 60597/60597 [==============================] - 11s 180us/step - loss: 0.1054 - acc: 0.9574 - val_loss: 0.1759 - val_acc: 0.9349
#
# Epoch 00006: val_acc improved from 0.93291 to 0.93492, saving model to /mnt/seals/models/110/model_round_1.h5
# Epoch 7/20
# 60597/60597 [==============================] - 11s 180us/step - loss: 0.1021 - acc: 0.9585 - val_loss: 0.1889 - val_acc: 0.9251
#
# Epoch 00007: val_acc did not improve from 0.93492
# Epoch 8/20
# 12224/60597 [=====>........................] - ETA: 8s - loss: 0.1012 - acc: 0.9598
