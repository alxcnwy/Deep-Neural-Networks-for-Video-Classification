# %%
WORKER_ID = 2

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 11:40:40,865 [MainThread  ] [INFO ]  XXXXXX CUDAVISIBLE 2
# 2019-01-20 11:40:40,866 [MainThread  ] [INFO ]  Begin experiment for model_id=50
# 2019-01-20 11:40:40,868 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 11:40:40,869 [MainThread  ] [INFO ]  Loading data
# 50   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'sequence_length': 1.0, 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 0, 'sequence_model': nan, 'architecture': 'image_MLP_frozen', 'layer_3_size': 128, 'WORKER': 2, 'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_2_size': 512, 'model_id': 50}
# 2019-01-20 11:40:41,913 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 11:40:41,914 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 19s 307us/step - loss: 0.2326 - acc: 0.9265 - val_loss: 0.4390 - val_acc: 0.8870
#
# Epoch 00001: val_acc improved from -inf to 0.88696, saving model to /mnt/seals/models/50/model_round_1.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 139us/step - loss: 0.1856 - acc: 0.9394 - val_loss: 0.3337 - val_acc: 0.9091
#
# Epoch 00002: val_acc improved from 0.88696 to 0.90911, saving model to /mnt/seals/models/50/model_round_1.h5
# Epoch 3/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1735 - acc: 0.9436 - val_loss: 0.4083 - val_acc: 0.8877
#
# Epoch 00003: val_acc did not improve from 0.90911
# Epoch 4/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1711 - acc: 0.9449 - val_loss: 0.3091 - val_acc: 0.9107
#
# Epoch 00004: val_acc improved from 0.90911 to 0.91067, saving model to /mnt/seals/models/50/model_round_1.h5
# Epoch 5/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1713 - acc: 0.9461 - val_loss: 0.3004 - val_acc: 0.9188
#
# Epoch 00005: val_acc improved from 0.91067 to 0.91882, saving model to /mnt/seals/models/50/model_round_1.h5
# Epoch 6/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1631 - acc: 0.9476 - val_loss: 0.2898 - val_acc: 0.9295
#
# Epoch 00006: val_acc improved from 0.91882 to 0.92946, saving model to /mnt/seals/models/50/model_round_1.h5
# Epoch 7/10
# 60597/60597 [==============================] - 8s 134us/step - loss: 0.1676 - acc: 0.9476 - val_loss: 0.3367 - val_acc: 0.9123
#
# Epoch 00007: val_acc did not improve from 0.92946
# Epoch 8/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1593 - acc: 0.9495 - val_loss: 0.6797 - val_acc: 0.8501
#
# Epoch 00008: val_acc did not improve from 0.92946
# Epoch 9/10
# 60597/60597 [==============================] - 8s 134us/step - loss: 0.1628 - acc: 0.9492 - val_loss: 0.3047 - val_acc: 0.9185
#
# Epoch 00009: val_acc did not improve from 0.92946
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 8s 140us/step - loss: 0.1121 - acc: 0.9611 - val_loss: 0.2910 - val_acc: 0.9191
#
# Epoch 00001: val_acc improved from -inf to 0.91913, saving model to /mnt/seals/models/50/model_round_2.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 131us/step - loss: 0.1082 - acc: 0.9621 - val_loss: 0.2696 - val_acc: 0.9229
#
# Epoch 00002: val_acc improved from 0.91913 to 0.92289, saving model to /mnt/seals/models/50/model_round_2.h5
# Epoch 3/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1068 - acc: 0.9621 - val_loss: 0.2717 - val_acc: 0.9185
#
# Epoch 00003: val_acc did not improve from 0.92289
# Epoch 4/10
# 60597/60597 [==============================] - 8s 135us/step - loss: 0.1059 - acc: 0.9623 - val_loss: 0.2706 - val_acc: 0.9204
#
# Epoch 00004: val_acc did not improve from 0.92289
# Epoch 5/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1051 - acc: 0.9627 - val_loss: 0.2541 - val_acc: 0.9257
#
# Epoch 00005: val_acc improved from 0.92289 to 0.92574, saving model to /mnt/seals/models/50/model_round_2.h5
# Epoch 6/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1042 - acc: 0.9628 - val_loss: 0.2722 - val_acc: 0.9188
#
# Epoch 00006: val_acc did not improve from 0.92574
# Epoch 7/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1043 - acc: 0.9626 - val_loss: 0.2906 - val_acc: 0.9123
#
# Epoch 00007: val_acc did not improve from 0.92574
# Epoch 8/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1035 - acc: 0.9628 - val_loss: 0.2690 - val_acc: 0.9204
#
# Epoch 00008: val_acc did not improve from 0.92574
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 8s 137us/step - loss: 0.0986 - acc: 0.9650 - val_loss: 0.2606 - val_acc: 0.9192
#
# Epoch 00001: val_acc improved from -inf to 0.91918, saving model to /mnt/seals/models/50/model_round_3.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.0983 - acc: 0.9651 - val_loss: 0.2625 - val_acc: 0.9187
#
# Epoch 00002: val_acc did not improve from 0.91918
# Epoch 3/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.0982 - acc: 0.9650 - val_loss: 0.2594 - val_acc: 0.9202
#
# Epoch 00003: val_acc improved from 0.91918 to 0.92024, saving model to /mnt/seals/models/50/model_round_3.h5
# Epoch 4/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.0982 - acc: 0.9650 - val_loss: 0.2584 - val_acc: 0.9212
#
# Epoch 00004: val_acc improved from 0.92024 to 0.92125, saving model to /mnt/seals/models/50/model_round_3.h5
# Epoch 5/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.0981 - acc: 0.9649 - val_loss: 0.2588 - val_acc: 0.9191
#
# Epoch 00005: val_acc did not improve from 0.92125
# Epoch 6/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.0981 - acc: 0.9649 - val_loss: 0.2583 - val_acc: 0.9199
#
# Epoch 00006: val_acc did not improve from 0.92125
# Epoch 7/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.0981 - acc: 0.9651 - val_loss: 0.2582 - val_acc: 0.9195
#
# Epoch 00007: val_acc did not improve from 0.92125
# best fit round 3 0.9190862342306503
# 3139/3139 [==============================] - 0s 48us/step
# 2019-01-20 11:44:13,091 [MainThread  ] [INFO ]  {'model_weights_path': None, 'data_total_rows_test': 3139, 'convolution_kernel_size': 3, 'fit_dt_test_duration_seconds': '0', 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 0, 'fit_train_acc': 0.9649016224136191, 'fit_train_loss': 0.09810843165735011, 'num_features': 1536, 'data_total_rows_valid': 6416, 'data_total_rows_train': 60597, 'fit_best_round': 3, 'batch_size': 32, 'pretrained_model_name': 'inception_resnet_v2', 'frame_size': (299, 299), 'verbose': True, 'layer_2_size': 512, 'model_id': 50, 'fit_dt_test_end': '2019-01-20 11:44:11', 'sequence_length': 1.0, 'model_param_count': 0, 'fit_val_loss': 0.2587608737392616, 'fit_num_epochs': 18, 'fit_stopped_epoch1': 6, 'fit_dt_train_start': '2019-01-20 11:40:42', 'fit_val_acc': 0.9190862342306503, 'fit_dt_test_start': '2019-01-20 11:44:11', 'sequence_model': nan, 'fit_dt_train_end': '2019-01-20 11:44:10', 'architecture': 'image_mlp_frozen', 'fit_test_acc': 0.5164064988849952, 'pooling': 'max', 'fit_stopped_epoch3': 4, 'layer_3_size': 128, 'fit_dt_train_duration_seconds': '207', 'path_model': '/mnt/seals/models/50/', 'fit_stopped_epoch2': 5}
# 2019-01-20 11:44:13,093 [MainThread  ] [INFO ]  model 50 test acc: 0.5164064988849952
# 2019-01-20 11:44:13,095 [MainThread  ] [INFO ]  XXXXXX CUDAVISIBLE 2
# 2019-01-20 11:44:13,097 [MainThread  ] [INFO ]  Begin experiment for model_id=58
# 2019-01-20 11:44:13,098 [MainThread  ] [INFO ]  Loading data
# 58   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'sequence_length': 1.0, 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 0, 'sequence_model': nan, 'architecture': 'image_MLP_frozen', 'layer_3_size': 128, 'WORKER': 2, 'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_2_size': 128, 'model_id': 58}
# 2019-01-20 11:44:14,201 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 11:44:14,203 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 8s 138us/step - loss: 0.2221 - acc: 0.9279 - val_loss: 0.3096 - val_acc: 0.9041
#
# Epoch 00001: val_acc improved from -inf to 0.90415, saving model to /mnt/seals/models/58/model_round_1.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 131us/step - loss: 0.1824 - acc: 0.9406 - val_loss: 0.2499 - val_acc: 0.9283
#
# Epoch 00002: val_acc improved from 0.90415 to 0.92835, saving model to /mnt/seals/models/58/model_round_1.h5
# Epoch 3/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1782 - acc: 0.9426 - val_loss: 0.2998 - val_acc: 0.9259
#
# Epoch 00003: val_acc did not improve from 0.92835
# Epoch 4/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1689 - acc: 0.9452 - val_loss: 0.3268 - val_acc: 0.9058
#
# Epoch 00004: val_acc did not improve from 0.92835
# Epoch 5/10
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.1709 - acc: 0.9456 - val_loss: 0.3707 - val_acc: 0.9001
#
# Epoch 00005: val_acc did not improve from 0.92835
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 8s 139us/step - loss: 0.1161 - acc: 0.9591 - val_loss: 0.2802 - val_acc: 0.9121
#
# Epoch 00001: val_acc improved from -inf to 0.91207, saving model to /mnt/seals/models/58/model_round_2.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.1124 - acc: 0.9598 - val_loss: 0.2639 - val_acc: 0.9170
#
# Epoch 00002: val_acc improved from 0.91207 to 0.91699, saving model to /mnt/seals/models/58/model_round_2.h5
# Epoch 3/10
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.1106 - acc: 0.9603 - val_loss: 0.2476 - val_acc: 0.9222
#
# Epoch 00003: val_acc improved from 0.91699 to 0.92220, saving model to /mnt/seals/models/58/model_round_2.h5
# Epoch 4/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1097 - acc: 0.9607 - val_loss: 0.2495 - val_acc: 0.9199
#
# Epoch 00004: val_acc did not improve from 0.92220
# Epoch 5/10
# 60597/60597 [==============================] - 8s 130us/step - loss: 0.1089 - acc: 0.9606 - val_loss: 0.3141 - val_acc: 0.9015
#
# Epoch 00005: val_acc did not improve from 0.92220
# Epoch 6/10
# 60597/60597 [==============================] - 8s 133us/step - loss: 0.1079 - acc: 0.9609 - val_loss: 0.2348 - val_acc: 0.9237
#
# Epoch 00006: val_acc improved from 0.92220 to 0.92370, saving model to /mnt/seals/models/58/model_round_2.h5
# Epoch 7/10
# 60597/60597 [==============================] - 8s 129us/step - loss: 0.1076 - acc: 0.9610 - val_loss: 0.2568 - val_acc: 0.9159
#
# Epoch 00007: val_acc did not improve from 0.92370
# Epoch 8/10
# 60597/60597 [==============================] - 8s 132us/step - loss: 0.1073 - acc: 0.9613 - val_loss: 0.2494 - val_acc: 0.9200
#
# Epoch 00008: val_acc did not improve from 0.92370
# Epoch 9/10
# 60597/60597 [==============================] - 8s 130us/step - loss: 0.1063 - acc: 0.9617 - val_loss: 0.2548 - val_acc: 0.9150
#
# Epoch 00009: val_acc did not improve from 0.92370
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 9s 141us/step - loss: 0.1017 - acc: 0.9634 - val_loss: 0.2487 - val_acc: 0.9166
#
# Epoch 00001: val_acc improved from -inf to 0.91664, saving model to /mnt/seals/models/58/model_round_3.h5
# Epoch 2/10
# 60597/60597 [==============================] - 8s 126us/step - loss: 0.1014 - acc: 0.9636 - val_loss: 0.2499 - val_acc: 0.9167
#
# Epoch 00002: val_acc improved from 0.91664 to 0.91673, saving model to /mnt/seals/models/58/model_round_3.h5
# Epoch 3/10
# 60597/60597 [==============================] - 8s 127us/step - loss: 0.1014 - acc: 0.9636 - val_loss: 0.2380 - val_acc: 0.9233
#
# Epoch 00003: val_acc improved from 0.91673 to 0.92329, saving model to /mnt/seals/models/58/model_round_3.h5
# Epoch 4/10
# 60597/60597 [==============================] - 8s 127us/step - loss: 0.1013 - acc: 0.9637 - val_loss: 0.2396 - val_acc: 0.9230
#
# Epoch 00004: val_acc did not improve from 0.92329
# Epoch 5/10
# 60597/60597 [==============================] - 8s 128us/step - loss: 0.1012 - acc: 0.9637 - val_loss: 0.2483 - val_acc: 0.9173
#
# Epoch 00005: val_acc did not improve from 0.92329
# Epoch 6/10
# 60597/60597 [==============================] - 8s 127us/step - loss: 0.1012 - acc: 0.9638 - val_loss: 0.2431 - val_acc: 0.9205
#
# Epoch 00006: val_acc did not improve from 0.92329
# best fit round 1 0.9259218221293424
# 3139/3139 [==============================] - 0s 56us/step
# 2019-01-20 11:47:00,056 [MainThread  ] [INFO ]  {'model_weights_path': None, 'data_total_rows_test': 3139, 'convolution_kernel_size': 3, 'fit_dt_test_duration_seconds': '0', 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 0, 'fit_train_acc': 0.9425785046132352, 'fit_train_loss': 0.17818955426382593, 'num_features': 1536, 'data_total_rows_valid': 6416, 'data_total_rows_train': 60597, 'fit_best_round': 1, 'batch_size': 32, 'pretrained_model_name': 'inception_resnet_v2', 'frame_size': (299, 299), 'verbose': True, 'layer_2_size': 128, 'model_id': 58, 'fit_dt_test_end': '2019-01-20 11:46:58', 'sequence_length': 1.0, 'model_param_count': 0, 'fit_val_loss': 0.2997873198064485, 'fit_num_epochs': 14, 'fit_dt_train_start': '2019-01-20 11:44:15', 'fit_stopped_epoch1': 2, 'fit_val_acc': 0.9259218221293424, 'fit_dt_test_start': '2019-01-20 11:46:58', 'sequence_model': nan, 'fit_dt_train_end': '2019-01-20 11:46:57', 'architecture': 'image_mlp_frozen', 'fit_test_acc': 0.5179993628544122, 'pooling': 'max', 'fit_stopped_epoch3': 3, 'layer_3_size': 128, 'fit_dt_train_duration_seconds': '162', 'path_model': '/mnt/seals/models/58/', 'fit_stopped_epoch2': 6}
# 2019-01-20 11:47:00,057 [MainThread  ] [INFO ]  model 58 test acc: 0.5179993628544122
# 2019-01-20 11:47:00,060 [MainThread  ] [INFO ]  XXXXXX CUDAVISIBLE 2
# 2019-01-20 11:47:00,061 [MainThread  ] [INFO ]  Begin experiment for model_id=66
# 2019-01-20 11:47:00,062 [MainThread  ] [INFO ]  Loading data
# 66   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'sequence_length': 1.0, 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 512, 'sequence_model': nan, 'architecture': 'image_MLP_frozen', 'layer_3_size': 128, 'WORKER': 2, 'pretrained_model_name': 'vgg16', 'pooling': 'max', 'layer_2_size': 512, 'model_id': 66}
# 2019-01-20 11:47:01,064 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 11:47:01,066 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 13s 220us/step - loss: 0.1989 - acc: 0.9334 - val_loss: 0.2131 - val_acc: 0.9107
#
# Epoch 00001: val_acc improved from -inf to 0.91074, saving model to /mnt/seals/models/66/model_round_1.h5
# Epoch 2/10
# 60597/60597 [==============================] - 13s 208us/step - loss: 0.1287 - acc: 0.9492 - val_loss: 0.1637 - val_acc: 0.9383
#
# Epoch 00002: val_acc improved from 0.91074 to 0.93830, saving model to /mnt/seals/models/66/model_round_1.h5
# Epoch 3/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.1183 - acc: 0.9532 - val_loss: 0.1908 - val_acc: 0.9210
#
# Epoch 00003: val_acc did not improve from 0.93830
# Epoch 4/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.1104 - acc: 0.9563 - val_loss: 0.2003 - val_acc: 0.9154
#
# Epoch 00004: val_acc did not improve from 0.93830
# Epoch 5/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.1044 - acc: 0.9588 - val_loss: 0.1512 - val_acc: 0.9431
#
# Epoch 00005: val_acc improved from 0.93830 to 0.94309, saving model to /mnt/seals/models/66/model_round_1.h5
# Epoch 6/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.1022 - acc: 0.9596 - val_loss: 0.1707 - val_acc: 0.9361
#
# Epoch 00006: val_acc did not improve from 0.94309
# Epoch 7/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.0993 - acc: 0.9607 - val_loss: 0.2111 - val_acc: 0.9308
#
# Epoch 00007: val_acc did not improve from 0.94309
# Epoch 8/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.0953 - acc: 0.9625 - val_loss: 0.1798 - val_acc: 0.9362
#
# Epoch 00008: val_acc did not improve from 0.94309
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 14s 224us/step - loss: 0.0776 - acc: 0.9681 - val_loss: 0.1789 - val_acc: 0.9370
#
# Epoch 00001: val_acc improved from -inf to 0.93699, saving model to /mnt/seals/models/66/model_round_2.h5
# Epoch 2/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0735 - acc: 0.9699 - val_loss: 0.1967 - val_acc: 0.9355
#
# Epoch 00002: val_acc did not improve from 0.93699
# Epoch 3/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.0718 - acc: 0.9703 - val_loss: 0.1883 - val_acc: 0.9366
#
# Epoch 00003: val_acc did not improve from 0.93699
# Epoch 4/10
# 60597/60597 [==============================] - 13s 212us/step - loss: 0.0692 - acc: 0.9711 - val_loss: 0.2047 - val_acc: 0.9372
#
# Epoch 00004: val_acc improved from 0.93699 to 0.93723, saving model to /mnt/seals/models/66/model_round_2.h5
# Epoch 5/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0683 - acc: 0.9715 - val_loss: 0.1919 - val_acc: 0.9412
#
# Epoch 00005: val_acc improved from 0.93723 to 0.94117, saving model to /mnt/seals/models/66/model_round_2.h5
# Epoch 6/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.0670 - acc: 0.9720 - val_loss: 0.1953 - val_acc: 0.9389
#
# Epoch 00006: val_acc did not improve from 0.94117
# Epoch 7/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0659 - acc: 0.9725 - val_loss: 0.1952 - val_acc: 0.9385
#
# Epoch 00007: val_acc did not improve from 0.94117
# Epoch 8/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.0645 - acc: 0.9730 - val_loss: 0.2033 - val_acc: 0.9390
#
# Epoch 00008: val_acc did not improve from 0.94117
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 14s 224us/step - loss: 0.0624 - acc: 0.9738 - val_loss: 0.2059 - val_acc: 0.9396
#
# Epoch 00001: val_acc improved from -inf to 0.93957, saving model to /mnt/seals/models/66/model_round_3.h5
# Epoch 2/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.2088 - val_acc: 0.9393
#
# Epoch 00002: val_acc did not improve from 0.93957
# Epoch 3/10
# 60597/60597 [==============================] - 13s 213us/step - loss: 0.0620 - acc: 0.9738 - val_loss: 0.2083 - val_acc: 0.9396
#
# Epoch 00003: val_acc improved from 0.93957 to 0.93964, saving model to /mnt/seals/models/66/model_round_3.h5
# Epoch 4/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.0611 - acc: 0.9741 - val_loss: 0.2078 - val_acc: 0.9398
#
# Epoch 00004: val_acc improved from 0.93964 to 0.93984, saving model to /mnt/seals/models/66/model_round_3.h5
# Epoch 5/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.0612 - acc: 0.9741 - val_loss: 0.2125 - val_acc: 0.9387
#
# Epoch 00005: val_acc did not improve from 0.93984
# Epoch 6/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0609 - acc: 0.9744 - val_loss: 0.2114 - val_acc: 0.9401
#
# Epoch 00006: val_acc improved from 0.93984 to 0.94013, saving model to /mnt/seals/models/66/model_round_3.h5
# Epoch 7/10
# 60597/60597 [==============================] - 13s 210us/step - loss: 0.0607 - acc: 0.9744 - val_loss: 0.2113 - val_acc: 0.9400
#
# Epoch 00007: val_acc did not improve from 0.94013
# Epoch 8/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0609 - acc: 0.9740 - val_loss: 0.2132 - val_acc: 0.9401
#
# Epoch 00008: val_acc did not improve from 0.94013
# Epoch 9/10
# 60597/60597 [==============================] - 13s 211us/step - loss: 0.0601 - acc: 0.9747 - val_loss: 0.2152 - val_acc: 0.9395
#
# Epoch 00009: val_acc did not improve from 0.94013
# best fit round 3 0.9400383147812841
# 3139/3139 [==============================] - 0s 99us/step
# 2019-01-20 11:52:31,541 [MainThread  ] [INFO ]  {'model_weights_path': None, 'data_total_rows_test': 3139, 'convolution_kernel_size': 3, 'fit_dt_test_duration_seconds': '0', 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 512, 'fit_train_acc': 0.9744188297842844, 'fit_train_loss': 0.0607289314632239, 'num_features': 512, 'data_total_rows_valid': 6416, 'data_total_rows_train': 60597, 'fit_best_round': 3, 'batch_size': 32, 'pretrained_model_name': 'vgg16', 'frame_size': (224, 224), 'verbose': True, 'layer_2_size': 512, 'model_id': 66, 'fit_dt_test_end': '2019-01-20 11:52:30', 'sequence_length': 1.0, 'model_param_count': 591879, 'fit_val_loss': 0.2112976434150539, 'fit_num_epochs': 19, 'fit_dt_train_start': '2019-01-20 11:47:01', 'fit_stopped_epoch1': 5, 'fit_val_acc': 0.9400383147812841, 'fit_dt_test_start': '2019-01-20 11:52:29', 'sequence_model': nan, 'fit_dt_train_end': '2019-01-20 11:52:29', 'architecture': 'image_mlp_frozen', 'fit_test_acc': 0.6591271105447595, 'pooling': 'max', 'fit_stopped_epoch3': 6, 'layer_3_size': 128, 'fit_dt_train_duration_seconds': '327', 'path_model': '/mnt/seals/models/66/', 'fit_stopped_epoch2': 5}
# 2019-01-20 11:52:31,543 [MainThread  ] [INFO ]  model 66 test acc: 0.6591271105447595
# 2019-01-20 11:52:31,545 [MainThread  ] [INFO ]  XXXXXX CUDAVISIBLE 2
# 2019-01-20 11:52:31,546 [MainThread  ] [INFO ]  Begin experiment for model_id=74
# 2019-01-20 11:52:31,548 [MainThread  ] [INFO ]  Loading data
# 74   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'sequence_length': 1.0, 'dropout': 0.2, 'sequence_model_layers': nan, 'layer_1_size': 512, 'sequence_model': nan, 'architecture': 'image_MLP_frozen', 'layer_3_size': 128, 'WORKER': 2, 'pretrained_model_name': 'vgg16', 'pooling': 'max', 'layer_2_size': 128, 'model_id': 74}
# 2019-01-20 11:52:32,487 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 11:52:32,489 [MainThread  ] [INFO ]  Loading features data into memory [may take a few minutes]
# Done initializing data with #samples: train=60597, valid=6416, test=3139
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 13s 218us/step - loss: 0.2138 - acc: 0.9262 - val_loss: 0.1852 - val_acc: 0.9178
#
# Epoch 00001: val_acc improved from -inf to 0.91779, saving model to /mnt/seals/models/74/model_round_1.h5
# Epoch 2/10
# 60597/60597 [==============================] - 12s 204us/step - loss: 0.1316 - acc: 0.9478 - val_loss: 0.1695 - val_acc: 0.9287
#
# Epoch 00002: val_acc improved from 0.91779 to 0.92873, saving model to /mnt/seals/models/74/model_round_1.h5
# Epoch 3/10
# 60597/60597 [==============================] - 12s 206us/step - loss: 0.1176 - acc: 0.9535 - val_loss: 0.1542 - val_acc: 0.9419
#
# Epoch 00003: val_acc improved from 0.92873 to 0.94186, saving model to /mnt/seals/models/74/model_round_1.h5
# Epoch 4/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.1102 - acc: 0.9564 - val_loss: 0.1690 - val_acc: 0.9388
#
# Epoch 00004: val_acc did not improve from 0.94186
# Epoch 5/10
# 60597/60597 [==============================] - 13s 208us/step - loss: 0.1047 - acc: 0.9589 - val_loss: 0.1712 - val_acc: 0.9332
#
# Epoch 00005: val_acc did not improve from 0.94186
# Epoch 6/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.1005 - acc: 0.9603 - val_loss: 0.1499 - val_acc: 0.9428
#
# Epoch 00006: val_acc improved from 0.94186 to 0.94280, saving model to /mnt/seals/models/74/model_round_1.h5
# Epoch 7/10
# 60597/60597 [==============================] - 13s 208us/step - loss: 0.0980 - acc: 0.9613 - val_loss: 0.1608 - val_acc: 0.9357
#
# Epoch 00007: val_acc did not improve from 0.94280
# Epoch 8/10
# 60597/60597 [==============================] - 13s 209us/step - loss: 0.0932 - acc: 0.9628 - val_loss: 0.1801 - val_acc: 0.9295
#
# Epoch 00008: val_acc did not improve from 0.94280
# Epoch 9/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0919 - acc: 0.9635 - val_loss: 0.1740 - val_acc: 0.9304
#
# Epoch 00009: val_acc did not improve from 0.94280
# Train on 60597 samples, validate on 6416 samples
# Epoch 1/10
# 60597/60597 [==============================] - 13s 219us/step - loss: 0.0768 - acc: 0.9690 - val_loss: 0.1743 - val_acc: 0.9385
#
# Epoch 00001: val_acc improved from -inf to 0.93846, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 2/10
# 60597/60597 [==============================] - 12s 206us/step - loss: 0.0727 - acc: 0.9703 - val_loss: 0.1778 - val_acc: 0.9400
#
# Epoch 00002: val_acc improved from 0.93846 to 0.94004, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 3/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0711 - acc: 0.9710 - val_loss: 0.1779 - val_acc: 0.9407
#
# Epoch 00003: val_acc improved from 0.94004 to 0.94073, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 4/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0700 - acc: 0.9711 - val_loss: 0.1724 - val_acc: 0.9394
#
# Epoch 00004: val_acc did not improve from 0.94073
# Epoch 5/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0679 - acc: 0.9719 - val_loss: 0.1758 - val_acc: 0.9411
#
# Epoch 00005: val_acc improved from 0.94073 to 0.94111, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 6/10
# 60597/60597 [==============================] - 12s 204us/step - loss: 0.0666 - acc: 0.9723 - val_loss: 0.1877 - val_acc: 0.9386
#
# Epoch 00006: val_acc did not improve from 0.94111
# Epoch 7/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0661 - acc: 0.9724 - val_loss: 0.1766 - val_acc: 0.9425
#
# Epoch 00007: val_acc improved from 0.94111 to 0.94249, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 8/10
# 60597/60597 [==============================] - 12s 205us/step - loss: 0.0651 - acc: 0.9730 - val_loss: 0.1858 - val_acc: 0.9399
#
# Epoch 00008: val_acc did not improve from 0.94249
# Epoch 9/10
# 60597/60597 [==============================] - 12s 204us/step - loss: 0.0640 - acc: 0.9732 - val_loss: 0.1887 - val_acc: 0.9426
#
# Epoch 00009: val_acc improved from 0.94249 to 0.94264, saving model to /mnt/seals/models/74/model_round_2.h5
# Epoch 10/10
# 60597/60597 [==============================] - 12s 204us/step - loss: 0.0635 - acc: 0.9737 - val_loss: 0.1861 - val_acc: 0.9403
#
# Epoch 00010: val_acc did not improve from 0.94264
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-9dc3c032d44c> in <module>
#      34                                         verbose=True)
#      35
# ---> 36             architecture.train_model()
#
# /mnt/seals/deepvideoclassification/architectures.py in train_model(self, epochs, patience)
#     969
#     970         # update best fit round
# --> 971         best_val_acc_2 = history2.history['val_acc'][stopped_epoch2]
#     972         if best_val_acc_2 > best_fit_round_val_acc:
#     973             best_fit_round_val_acc = best_val_acc_2
#
# IndexError: list index out of range
