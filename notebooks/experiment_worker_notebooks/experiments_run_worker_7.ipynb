# %%
WORKER_ID = 7

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
os.environ["CUDA_VISIBLE_DEVICES"]
# Out:
# '7'

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 15:05:10,633 [MainThread  ] [INFO ]  Begin experiment for model_id=199 on GPU:7
# 2019-01-20 15:05:10,634 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 15:05:10,635 [MainThread  ] [INFO ]  Loading data
# 199   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 199, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 256, 'layer_1_size': 512, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:05:11,528 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:05:11,529 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 36s 592us/step - loss: 2.7136 - acc: 0.8303 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00001: val_acc improved from -inf to 0.83673, saving model to /mnt/seals/models/199/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.83673
# Epoch 3/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 2.7175 - acc: 0.8305 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.83673
# Epoch 4/20
# 60553/60553 [==============================] - 16s 265us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.83673
# H1 {'val_acc': [0.8367346979942607, 0.8367346979942607, 0.8367346979942607, 0.8367346979942607], 'val_loss': [2.6171817786977654, 2.6171817786977654, 2.6171817786977654, 2.6171817786977654], 'acc': [0.8303422504689355, 0.8303823565152403, 0.830453131577184, 0.8303823555072777], 'loss': [2.713640484564106, 2.7190112655779757, 2.717500380106772, 2.719011264318022]}
# stopped_epoch1 1
# 4
# 0.8367346979942607
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00001: val_acc improved from -inf to 0.83673, saving model to /mnt/seals/models/199/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.83673
# Epoch 3/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.83673
# Epoch 4/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.83673
# H2 {'val_acc': [0.8367346979942607, 0.8367346979942607, 0.8367346979942607, 0.8367346979942607], 'val_loss': [2.6171817786977654, 2.6171817786977654, 2.6171817786977654, 2.6171817786977654], 'acc': [0.8303823557907672, 0.8303823573164918, 0.8303823559305432, 0.8303823569375215], 'loss': [2.719011265136992, 2.719011265369296, 2.719011262183977, 2.719011265337797]}
# stopped_epoch2 1
# 4
# 0.8367346979942607
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00001: val_acc improved from -inf to 0.83673, saving model to /mnt/seals/models/199/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.83673
# Epoch 3/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.83673
# Epoch 4/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.83673
# H3 {'val_acc': [0.8367346979942607, 0.8367346979942607, 0.8367346979942607, 0.8367346979942607], 'val_loss': [2.6171817786977654, 2.6171817786977654, 2.6171817786977654, 2.6171817786977654], 'acc': [0.830382355048576, 0.8303823568568057, 0.8303823565605198, 0.8303823565280367], 'loss': [2.719011262912387, 2.719011264940124, 2.7190112643613333, 2.7190112624399045]}
# stopped_epoch3 1
# 4
# 0.8367346979942607
# best fit round 1 0.8367346979942607
# 3137/3137 [==============================] - 0s 96us/step
# 2019-01-20 15:08:58,736 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:08:57",
#     "fit_dt_test_start": "2019-01-20 15:08:56",
#     "fit_dt_train_duration_seconds": "221",
#     "fit_dt_train_end": "2019-01-20 15:08:56",
#     "fit_dt_train_start": "2019-01-20 15:05:14",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.17468919349697165,
#     "fit_train_acc": 0.8303823565152403,
#     "fit_train_loss": 2.7190112655779757,
#     "fit_val_acc": 0.8367346979942607,
#     "fit_val_loss": 2.6171817786977654,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 256,
#     "layer_3_size": 0,
#     "model_id": 199,
#     "model_param_count": 2492935,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/199/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:08:58,737 [MainThread  ] [INFO ]  model 199 test acc: 0.17468919349697165
# 2019-01-20 15:09:01,495 [MainThread  ] [INFO ]  Begin experiment for model_id=207 on GPU:7
# 2019-01-20 15:09:01,498 [MainThread  ] [INFO ]  Loading data
# 207   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 207, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 0, 'layer_1_size': 512, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:09:02,683 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:09:02,685 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 3.9965 - acc: 0.7506 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/207/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 256us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H1 {'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'val_loss': [4.290063818171853, 4.290063818171853, 4.290063818171853, 4.290063818171853], 'acc': [0.7505538254617481, 0.7504712531421449, 0.7504712531244269, 0.7504712529669327], 'loss': [3.996543080954816, 4.000005363683713, 4.000005364077449, 4.000005361431547]}
# stopped_epoch1 1
# 4
# 0.7323767991640088
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/207/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 16s 257us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 16s 256us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H2 {'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'val_loss': [4.290063818171853, 4.290063818171853, 4.290063818171853, 4.290063818171853], 'acc': [0.7504712531244269, 0.7504712538036203, 0.750471253659907, 0.7504712535161936], 'loss': [4.000005358533655, 4.000005358517905, 4.000005359289626, 4.000005360746448]}
# stopped_epoch2 1
# 4
# 0.7323767991640088
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/207/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 256us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H3 {'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'val_loss': [4.290063818171853, 4.290063818171853, 4.290063818171853, 4.290063818171853], 'acc': [0.7504712526027275, 0.7504712539118976, 0.7504712539433964, 0.7504712538941796], 'loss': [4.00000536578626, 4.000005359919603, 4.000005357021711, 4.0000053599904755]}
# stopped_epoch3 1
# 4
# 0.7323767991640088
# best fit round 1 0.7323767991640088
# 3137/3137 [==============================] - 0s 109us/step
# 2019-01-20 15:12:19,535 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:12:17",
#     "fit_dt_test_start": "2019-01-20 15:12:17",
#     "fit_dt_train_duration_seconds": "191",
#     "fit_dt_train_end": "2019-01-20 15:12:16",
#     "fit_dt_train_start": "2019-01-20 15:09:05",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.18425247051322924,
#     "fit_train_acc": 0.7504712531421449,
#     "fit_train_loss": 4.000005363683713,
#     "fit_val_acc": 0.7323767991640088,
#     "fit_val_loss": 4.290063818171853,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 207,
#     "model_param_count": 2363399,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/207/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:12:19,537 [MainThread  ] [INFO ]  model 207 test acc: 0.18425247051322924
# 2019-01-20 15:12:22,403 [MainThread  ] [INFO ]  Begin experiment for model_id=215 on GPU:7
# 2019-01-20 15:12:22,405 [MainThread  ] [INFO ]  Loading data
# 215   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 215, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 256, 'layer_1_size': 256, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:12:23,525 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:12:23,526 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 255us/step - loss: 0.2688 - acc: 0.9123 - val_loss: 0.2115 - val_acc: 0.9160
#
# Epoch 00001: val_acc improved from -inf to 0.91598, saving model to /mnt/seals/models/215/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 237us/step - loss: 0.1899 - acc: 0.9221 - val_loss: 0.2109 - val_acc: 0.9146
#
# Epoch 00002: val_acc did not improve from 0.91598
# Epoch 3/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 0.1855 - acc: 0.9231 - val_loss: 0.2057 - val_acc: 0.9138
#
# Epoch 00003: val_acc did not improve from 0.91598
# Epoch 4/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.1833 - acc: 0.9238 - val_loss: 0.1969 - val_acc: 0.9165
#
# Epoch 00004: val_acc improved from 0.91598 to 0.91650, saving model to /mnt/seals/models/215/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.1789 - acc: 0.9248 - val_loss: 0.1972 - val_acc: 0.9174
#
# Epoch 00005: val_acc improved from 0.91650 to 0.91743, saving model to /mnt/seals/models/215/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 14s 231us/step - loss: 0.1782 - acc: 0.9254 - val_loss: 0.2047 - val_acc: 0.9162
#
# Epoch 00006: val_acc did not improve from 0.91743
# Epoch 7/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.1774 - acc: 0.9253 - val_loss: 0.1981 - val_acc: 0.9170
#
# Epoch 00007: val_acc did not improve from 0.91743
# Epoch 8/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1768 - acc: 0.9253 - val_loss: 0.2018 - val_acc: 0.9148
#
# Epoch 00008: val_acc did not improve from 0.91743
# H1 {'val_acc': [0.9159834525842482, 0.9145575550966388, 0.9138223238461328, 0.9164958800737069, 0.917431625959952, 0.9162285247595698, 0.9170305949036806, 0.9148249117865536], 'val_loss': [0.211457421500015, 0.21086294866322133, 0.20567321527286833, 0.1968581720080438, 0.19723532802041294, 0.20467541778154547, 0.19807670789254284, 0.20184025312503726], 'acc': [0.9123365611919232, 0.9221390722930051, 0.9230686002050665, 0.9238117497989019, 0.9248498017942711, 0.92542308754896, 0.9252508664880049, 0.9253357985148711], 'loss': [0.26876222069061906, 0.18986148785740004, 0.18549080379501062, 0.18330468135299552, 0.17887707268290284, 0.17815054480246725, 0.17737609475539515, 0.17675301795682788]}
# stopped_epoch1 5
# 8
# 0.9162285247595698
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 0.1676 - acc: 0.9280 - val_loss: 0.2094 - val_acc: 0.9144
#
# Epoch 00001: val_acc improved from -inf to 0.91436, saving model to /mnt/seals/models/215/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 234us/step - loss: 0.1653 - acc: 0.9290 - val_loss: 0.2068 - val_acc: 0.9149
#
# Epoch 00002: val_acc improved from 0.91436 to 0.91487, saving model to /mnt/seals/models/215/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 245us/step - loss: 0.1644 - acc: 0.9293 - val_loss: 0.2055 - val_acc: 0.9152
#
# Epoch 00003: val_acc improved from 0.91487 to 0.91525, saving model to /mnt/seals/models/215/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 14s 238us/step - loss: 0.1637 - acc: 0.9294 - val_loss: 0.2070 - val_acc: 0.9148
#
# Epoch 00004: val_acc did not improve from 0.91525
# Epoch 5/20
# 60553/60553 [==============================] - 15s 250us/step - loss: 0.1632 - acc: 0.9297 - val_loss: 0.2096 - val_acc: 0.9142
#
# Epoch 00005: val_acc did not improve from 0.91525
# Epoch 6/20
# 60553/60553 [==============================] - 15s 240us/step - loss: 0.1626 - acc: 0.9301 - val_loss: 0.2097 - val_acc: 0.8847
#
# Epoch 00006: val_acc did not improve from 0.91525
# H2 {'val_acc': [0.9143570355899023, 0.9148694667604962, 0.9152482227095201, 0.9147803502683705, 0.9142456385246011, 0.8847250829468797], 'val_loss': [0.20942738367777947, 0.20679092667508855, 0.20545136148641055, 0.20702335415076853, 0.20960035261071183, 0.2097034901287581], 'acc': [0.9280205769847805, 0.929049192124696, 0.9292685968398323, 0.9294313816310152, 0.9297310021969651, 0.9300612892054934], 'loss': [0.16758615357604972, 0.1653385178235816, 0.16439394920411268, 0.16374367995240333, 0.16324945284353937, 0.1626252223001791]}
# stopped_epoch2 3
# 6
# 0.9147803502683705
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1621 - acc: 0.9300 - val_loss: 0.2073 - val_acc: 0.9148
#
# Epoch 00001: val_acc improved from -inf to 0.91476, saving model to /mnt/seals/models/215/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1621 - acc: 0.9299 - val_loss: 0.2055 - val_acc: 0.9150
#
# Epoch 00002: val_acc improved from 0.91476 to 0.91500, saving model to /mnt/seals/models/215/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 246us/step - loss: 0.1613 - acc: 0.9307 - val_loss: 0.2080 - val_acc: 0.9148
#
# Epoch 00003: val_acc did not improve from 0.91500
# Epoch 4/20
# 60553/60553 [==============================] - 14s 234us/step - loss: 0.1620 - acc: 0.9300 - val_loss: 0.2059 - val_acc: 0.9150
#
# Epoch 00004: val_acc did not improve from 0.91500
# Epoch 5/20
# 60553/60553 [==============================] - 14s 236us/step - loss: 0.1613 - acc: 0.9304 - val_loss: 0.2081 - val_acc: 0.9147
#
# Epoch 00005: val_acc did not improve from 0.91500
# H3 {'val_acc': [0.9147580704016753, 0.9150031465555978, 0.9148249091093643, 0.9149808669863682, 0.9147357912414608], 'val_loss': [0.20730793190723795, 0.20552241643257463, 0.2080266721365382, 0.20593736461565335, 0.20814630307410556], 'acc': [0.9299881530808526, 0.9298772708691607, 0.9307289464992313, 0.9299598440431697, 0.93038214352921], 'loss': [0.16211022321328167, 0.16209170812590165, 0.16134126444110022, 0.1619666682693556, 0.1613443907235688]}
# stopped_epoch3 2
# 5
# 0.9148249091093643
# best fit round 1 0.9162285247595698
# 3137/3137 [==============================] - 0s 146us/step
# 2019-01-20 15:17:14,679 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:17:13",
#     "fit_dt_test_start": "2019-01-20 15:17:12",
#     "fit_dt_train_duration_seconds": "285",
#     "fit_dt_train_end": "2019-01-20 15:17:11",
#     "fit_dt_train_start": "2019-01-20 15:12:26",
#     "fit_num_epochs": 13,
#     "fit_stopped_epoch1": 5,
#     "fit_stopped_epoch2": 3,
#     "fit_stopped_epoch3": 2,
#     "fit_test_acc": 0.5412814791201785,
#     "fit_train_acc": 0.92542308754896,
#     "fit_train_loss": 0.17815054480246725,
#     "fit_val_acc": 0.9162285247595698,
#     "fit_val_loss": 0.20467541778154547,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 256,
#     "layer_3_size": 0,
#     "model_id": 215,
#     "model_param_count": 1247495,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/215/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:17:14,681 [MainThread  ] [INFO ]  model 215 test acc: 0.5412814791201785
# 2019-01-20 15:17:19,457 [MainThread  ] [INFO ]  Begin experiment for model_id=223 on GPU:7
# 2019-01-20 15:17:19,460 [MainThread  ] [INFO ]  Loading data
# 223   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 223, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 0, 'layer_1_size': 256, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:17:20,593 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:17:20,594 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 237us/step - loss: 0.6165 - acc: 0.9012 - val_loss: 0.2023 - val_acc: 0.9097
#
# Epoch 00001: val_acc improved from -inf to 0.90970, saving model to /mnt/seals/models/223/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 218us/step - loss: 0.1774 - acc: 0.9285 - val_loss: 0.1891 - val_acc: 0.9128
#
# Epoch 00002: val_acc improved from 0.90970 to 0.91275, saving model to /mnt/seals/models/223/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 213us/step - loss: 0.1693 - acc: 0.9314 - val_loss: 0.1796 - val_acc: 0.9113
#
# Epoch 00003: val_acc did not improve from 0.91275
# Epoch 4/20
# 60553/60553 [==============================] - 13s 218us/step - loss: 0.1637 - acc: 0.9333 - val_loss: 0.1721 - val_acc: 0.9337
#
# Epoch 00004: val_acc improved from 0.91275 to 0.93370, saving model to /mnt/seals/models/223/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 13s 219us/step - loss: 0.1594 - acc: 0.9358 - val_loss: 0.1902 - val_acc: 0.9207
#
# Epoch 00005: val_acc did not improve from 0.93370
# Epoch 6/20
# 60553/60553 [==============================] - 13s 212us/step - loss: 0.1575 - acc: 0.9369 - val_loss: 0.1889 - val_acc: 0.9264
#
# Epoch 00006: val_acc did not improve from 0.93370
# Epoch 7/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1545 - acc: 0.9385 - val_loss: 0.2198 - val_acc: 0.9120
#
# Epoch 00007: val_acc did not improve from 0.93370
# H1 {'val_acc': [0.9097005866946686, 0.912752900767609, 0.9113047234133044, 0.9336957682019387, 0.9206844496117186, 0.9264103218085753, 0.9120176627869466], 'val_loss': [0.20233746815568124, 0.18906976297469863, 0.17956466141318947, 0.1721178928038067, 0.19017989855406064, 0.18892620792536904, 0.21984578274464653], 'acc': [0.9011727821056592, 0.9285325220996945, 0.9313564947710095, 0.9332650944831977, 0.9357611365921343, 0.936912429286863, 0.9384624283097157], 'loss': [0.6164639823517315, 0.17740216619767255, 0.16925150308790443, 0.16367004172657432, 0.15942585004225884, 0.15752286390679607, 0.15448484887938463]}
# stopped_epoch1 4
# 7
# 0.9206844496117186
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 225us/step - loss: 0.1439 - acc: 0.9428 - val_loss: 0.2138 - val_acc: 0.9172
#
# Epoch 00001: val_acc improved from -inf to 0.91723, saving model to /mnt/seals/models/223/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 211us/step - loss: 0.1437 - acc: 0.9428 - val_loss: 0.2092 - val_acc: 0.9156
#
# Epoch 00002: val_acc did not improve from 0.91723
# Epoch 3/20
# 60553/60553 [==============================] - 13s 211us/step - loss: 0.1424 - acc: 0.9433 - val_loss: 0.2169 - val_acc: 0.9154
#
# Epoch 00003: val_acc did not improve from 0.91723
# Epoch 4/20
# 60553/60553 [==============================] - 13s 213us/step - loss: 0.1422 - acc: 0.9432 - val_loss: 0.2173 - val_acc: 0.9171
#
# Epoch 00004: val_acc did not improve from 0.91723
# H2 {'val_acc': [0.9172311019168671, 0.9155824083279462, 0.9153596133421305, 0.9171197052605808], 'val_loss': [0.21375247169139605, 0.20918737867811063, 0.21690057816259278, 0.21729802612635915], 'acc': [0.9427538288005202, 0.9427821398088486, 0.9432704952563106, 0.9431997184127142], 'loss': [0.14387136742999515, 0.14366592230417727, 0.14242656491040404, 0.14216965891379868]}
# stopped_epoch2 1
# 4
# 0.9155824083279462
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 238us/step - loss: 0.1412 - acc: 0.9436 - val_loss: 0.2190 - val_acc: 0.9163
#
# Epoch 00001: val_acc improved from -inf to 0.91634, saving model to /mnt/seals/models/223/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 218us/step - loss: 0.1401 - acc: 0.9439 - val_loss: 0.2190 - val_acc: 0.9164
#
# Epoch 00002: val_acc improved from 0.91634 to 0.91636, saving model to /mnt/seals/models/223/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 217us/step - loss: 0.1403 - acc: 0.9438 - val_loss: 0.2187 - val_acc: 0.9167
#
# Epoch 00003: val_acc improved from 0.91636 to 0.91672, saving model to /mnt/seals/models/223/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 13s 222us/step - loss: 0.1401 - acc: 0.9438 - val_loss: 0.2219 - val_acc: 0.9161
#
# Epoch 00004: val_acc did not improve from 0.91672
# Epoch 5/20
# 60553/60553 [==============================] - 13s 215us/step - loss: 0.1402 - acc: 0.9440 - val_loss: 0.2235 - val_acc: 0.9149
#
# Epoch 00005: val_acc did not improve from 0.91672
# Epoch 6/20
# 60553/60553 [==============================] - 13s 213us/step - loss: 0.1402 - acc: 0.9438 - val_loss: 0.2253 - val_acc: 0.9154
#
# Epoch 00006: val_acc did not improve from 0.91672
# H3 {'val_acc': [0.916339916767958, 0.916362198419446, 0.9167186740927598, 0.916117122562989, 0.9148917403060499, 0.9154264523472848], 'val_loss': [0.2189770253724927, 0.21898813704197212, 0.21866207335118718, 0.2218870873460157, 0.2234844735179257, 0.22527319326745818], 'acc': [0.9435583190705509, 0.9439027637005554, 0.9437753663374809, 0.9438485015348749, 0.9439664611378887, 0.9438060373464052], 'loss': [0.14120745815827274, 0.1400915847265108, 0.14027870679005816, 0.14012927207193582, 0.1402479895283016, 0.14015908769335086]}
# stopped_epoch3 3
# 6
# 0.916117122562989
# best fit round 1 0.9206844496117186
# 3137/3137 [==============================] - 1s 161us/step
# 2019-01-20 15:21:19,506 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:21:17",
#     "fit_dt_test_start": "2019-01-20 15:21:17",
#     "fit_dt_train_duration_seconds": "232",
#     "fit_dt_train_end": "2019-01-20 15:21:16",
#     "fit_dt_train_start": "2019-01-20 15:17:23",
#     "fit_num_epochs": 11,
#     "fit_stopped_epoch1": 4,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.5792158112846668,
#     "fit_train_acc": 0.9357611365921343,
#     "fit_train_loss": 0.15942585004225884,
#     "fit_val_acc": 0.9206844496117186,
#     "fit_val_loss": 0.19017989855406064,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 223,
#     "model_param_count": 1181703,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/223/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:21:19,509 [MainThread  ] [INFO ]  model 223 test acc: 0.5792158112846668
# 2019-01-20 15:21:21,867 [MainThread  ] [INFO ]  Begin experiment for model_id=231 on GPU:7
# 2019-01-20 15:21:21,871 [MainThread  ] [INFO ]  Loading data
# 231   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 231, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 256, 'layer_1_size': 128, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:21:22,971 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:21:22,972 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 254us/step - loss: 0.2465 - acc: 0.9079 - val_loss: 0.2397 - val_acc: 0.9110
#
# Epoch 00001: val_acc improved from -inf to 0.91102, saving model to /mnt/seals/models/231/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 232us/step - loss: 0.2147 - acc: 0.9136 - val_loss: 0.2330 - val_acc: 0.9126
#
# Epoch 00002: val_acc improved from 0.91102 to 0.91255, saving model to /mnt/seals/models/231/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 223us/step - loss: 0.2112 - acc: 0.9147 - val_loss: 0.2384 - val_acc: 0.9117
#
# Epoch 00003: val_acc did not improve from 0.91255
# Epoch 4/20
# 60553/60553 [==============================] - 13s 217us/step - loss: 0.2099 - acc: 0.9147 - val_loss: 0.2434 - val_acc: 0.9113
#
# Epoch 00004: val_acc did not improve from 0.91255
# Epoch 5/20
# 60553/60553 [==============================] - 13s 216us/step - loss: 0.2088 - acc: 0.9151 - val_loss: 0.2245 - val_acc: 0.9138
#
# Epoch 00005: val_acc improved from 0.91255 to 0.91380, saving model to /mnt/seals/models/231/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 13s 218us/step - loss: 0.2073 - acc: 0.9157 - val_loss: 0.2273 - val_acc: 0.9139
#
# Epoch 00006: val_acc improved from 0.91380 to 0.91393, saving model to /mnt/seals/models/231/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 13s 217us/step - loss: 0.2082 - acc: 0.9154 - val_loss: 0.2273 - val_acc: 0.9129
#
# Epoch 00007: val_acc did not improve from 0.91393
# Epoch 8/20
# 60553/60553 [==============================] - 13s 216us/step - loss: 0.2096 - acc: 0.9150 - val_loss: 0.2264 - val_acc: 0.9139
#
# Epoch 00008: val_acc did not improve from 0.91393
# Epoch 9/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.2079 - acc: 0.9155 - val_loss: 0.2256 - val_acc: 0.9144
#
# Epoch 00009: val_acc improved from 0.91393 to 0.91440, saving model to /mnt/seals/models/231/model_round_1.h5
# Epoch 10/20
# 60553/60553 [==============================] - 14s 229us/step - loss: 0.2054 - acc: 0.9162 - val_loss: 0.2199 - val_acc: 0.9140
#
# Epoch 00010: val_acc did not improve from 0.91440
# Epoch 11/20
# 60553/60553 [==============================] - 14s 229us/step - loss: 0.2058 - acc: 0.9162 - val_loss: 0.2272 - val_acc: 0.9132
#
# Epoch 00011: val_acc did not improve from 0.91440
# Epoch 12/20
# 60553/60553 [==============================] - 13s 219us/step - loss: 0.2049 - acc: 0.9163 - val_loss: 0.2274 - val_acc: 0.9120
#
# Epoch 00012: val_acc did not improve from 0.91440
# H1 {'val_acc': [0.9110150893851511, 0.912552386801167, 0.9116611971902758, 0.9113047231902053, 0.9138000448346509, 0.9139337254477826, 0.9129311442375183, 0.9139337243322871, 0.9144015969965358, 0.9139560053144777, 0.9132207771501761, 0.912017675354863], 'val_loss': [0.23967464781335496, 0.23300171635594133, 0.23844202258812958, 0.2433565754631647, 0.22449942806959897, 0.22734921909427167, 0.22729001323915018, 0.22643628037875693, 0.22560921421068875, 0.21991243283598408, 0.22719261546619818, 0.22736862086164006], 'acc': [0.9078658639271387, 0.9136317704329591, 0.9147170074369592, 0.9147099287679658, 0.9151039160940017, 0.9157149516890241, 0.9153752263130985, 0.9149741600621413, 0.915490826963837, 0.9162080259584403, 0.9161797160348528, 0.9163236272617952], 'loss': [0.24651143141260054, 0.2146670328207068, 0.2112205714032138, 0.2098635782526618, 0.20878455343308355, 0.2072987010732913, 0.2081985396362246, 0.209554816995067, 0.20788470993566172, 0.20543369193837036, 0.20583101109027305, 0.20492681418143735]}
# stopped_epoch1 9
# 12
# 0.9139560053144777
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 239us/step - loss: 0.2018 - acc: 0.9167 - val_loss: 0.2181 - val_acc: 0.9144
#
# Epoch 00001: val_acc improved from -inf to 0.91438, saving model to /mnt/seals/models/231/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 220us/step - loss: 0.1992 - acc: 0.9175 - val_loss: 0.2272 - val_acc: 0.9139
#
# Epoch 00002: val_acc did not improve from 0.91438
# Epoch 3/20
# 60553/60553 [==============================] - 13s 220us/step - loss: 0.1983 - acc: 0.9176 - val_loss: 0.2254 - val_acc: 0.9136
#
# Epoch 00003: val_acc did not improve from 0.91438
# Epoch 4/20
# 60553/60553 [==============================] - 13s 220us/step - loss: 0.1983 - acc: 0.9180 - val_loss: 0.2265 - val_acc: 0.9128
#
# Epoch 00004: val_acc did not improve from 0.91438
# H2 {'val_acc': [0.9143793174273062, 0.9139114446886911, 0.9136218114785678, 0.9128197425986854], 'val_loss': [0.21812209754680292, 0.2272424521441766, 0.22539166912799022, 0.2264591608654315], 'acc': [0.9167482859383208, 0.9175433389886929, 0.9175622120204063, 0.9180198988666358], 'loss': [0.2017765067350543, 0.19916923890270852, 0.1982561959779629, 0.19834713723047925]}
# stopped_epoch2 1
# 4
# 0.9139114446886911
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 262us/step - loss: 0.1978 - acc: 0.9179 - val_loss: 0.2250 - val_acc: 0.9133
#
# Epoch 00001: val_acc improved from -inf to 0.91327, saving model to /mnt/seals/models/231/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 226us/step - loss: 0.1978 - acc: 0.9180 - val_loss: 0.2248 - val_acc: 0.9137
#
# Epoch 00002: val_acc improved from 0.91327 to 0.91367, saving model to /mnt/seals/models/231/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 221us/step - loss: 0.1977 - acc: 0.9180 - val_loss: 0.2258 - val_acc: 0.9132
#
# Epoch 00003: val_acc did not improve from 0.91367
# Epoch 4/20
# 60553/60553 [==============================] - 13s 220us/step - loss: 0.1977 - acc: 0.9180 - val_loss: 0.2248 - val_acc: 0.9128
#
# Epoch 00004: val_acc did not improve from 0.91367
# Epoch 5/20
# 60553/60553 [==============================] - 13s 220us/step - loss: 0.1973 - acc: 0.9181 - val_loss: 0.2248 - val_acc: 0.9131
#
# Epoch 00005: val_acc did not improve from 0.91367
# H3 {'val_acc': [0.9132653365861009, 0.9136663715094235, 0.9131539391117846, 0.9127974629550893, 0.9130648201655687], 'val_loss': [0.2249618873176765, 0.22479712013073883, 0.22577956590292533, 0.2247926154251182, 0.22483518647165948], 'acc': [0.9179208121978858, 0.9179915880650183, 0.9180434921111738, 0.9179538402140328, 0.9180788779682781], 'loss': [0.19777032982099618, 0.1978318171087403, 0.19774573849715885, 0.19772311332977716, 0.19730507768281472]}
# stopped_epoch3 2
# 5
# 0.9131539391117846
# best fit round 1 0.9139560053144777
# 3137/3137 [==============================] - 1s 200us/step
# 2019-01-20 15:26:26,737 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:26:25",
#     "fit_dt_test_start": "2019-01-20 15:26:24",
#     "fit_dt_train_duration_seconds": "297",
#     "fit_dt_train_end": "2019-01-20 15:26:23",
#     "fit_dt_train_start": "2019-01-20 15:21:26",
#     "fit_num_epochs": 15,
#     "fit_stopped_epoch1": 9,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 2,
#     "fit_test_acc": 0.43226012113484225,
#     "fit_train_acc": 0.9162080259584403,
#     "fit_train_loss": 0.20543369193837036,
#     "fit_val_acc": 0.9139560053144777,
#     "fit_val_loss": 0.21991243283598408,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 256,
#     "layer_3_size": 0,
#     "model_id": 231,
#     "model_param_count": 624775,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/231/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:26:26,738 [MainThread  ] [INFO ]  model 231 test acc: 0.43226012113484225
# 2019-01-20 15:26:29,005 [MainThread  ] [INFO ]  Begin experiment for model_id=239 on GPU:7
# 2019-01-20 15:26:29,007 [MainThread  ] [INFO ]  Loading data
# 239   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 239, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 0, 'layer_1_size': 128, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:26:30,154 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:26:30,155 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 228us/step - loss: 0.2907 - acc: 0.9062 - val_loss: 0.2261 - val_acc: 0.9143
#
# Epoch 00001: val_acc improved from -inf to 0.91429, saving model to /mnt/seals/models/239/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 12s 195us/step - loss: 0.2189 - acc: 0.9105 - val_loss: 0.2351 - val_acc: 0.9123
#
# Epoch 00002: val_acc did not improve from 0.91429
# Epoch 3/20
# 60553/60553 [==============================] - 12s 194us/step - loss: 0.2134 - acc: 0.9116 - val_loss: 0.2220 - val_acc: 0.9126
#
# Epoch 00003: val_acc did not improve from 0.91429
# Epoch 4/20
# 60553/60553 [==============================] - 12s 195us/step - loss: 0.2108 - acc: 0.9121 - val_loss: 0.2153 - val_acc: 0.9139
#
# Epoch 00004: val_acc did not improve from 0.91429
# H1 {'val_acc': [0.9142901978861594, 0.9122627529217464, 0.9125746645112374, 0.9139337235886235], 'val_loss': [0.22614022028758538, 0.23510116700336328, 0.22204617905899351, 0.21528298309722396], 'acc': [0.9062191368619955, 0.9104845865202795, 0.9115934136681515, 0.9120817702318532], 'loss': [0.290669138204034, 0.21889916281321126, 0.21337897836657052, 0.21084031744190163]}
# stopped_epoch1 1
# 4
# 0.9122627529217464
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 230us/step - loss: 0.2042 - acc: 0.9136 - val_loss: 0.2339 - val_acc: 0.9133
#
# Epoch 00001: val_acc improved from -inf to 0.91329, saving model to /mnt/seals/models/239/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 12s 200us/step - loss: 0.2041 - acc: 0.9137 - val_loss: 0.2492 - val_acc: 0.9128
#
# Epoch 00002: val_acc did not improve from 0.91329
# Epoch 3/20
# 60553/60553 [==============================] - 12s 202us/step - loss: 0.2031 - acc: 0.9138 - val_loss: 0.2178 - val_acc: 0.9135
#
# Epoch 00003: val_acc improved from 0.91329 to 0.91349, saving model to /mnt/seals/models/239/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 12s 203us/step - loss: 0.2022 - acc: 0.9137 - val_loss: 0.2360 - val_acc: 0.9136
#
# Epoch 00004: val_acc improved from 0.91349 to 0.91362, saving model to /mnt/seals/models/239/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 12s 206us/step - loss: 0.2026 - acc: 0.9139 - val_loss: 0.2258 - val_acc: 0.9132
#
# Epoch 00005: val_acc did not improve from 0.91362
# Epoch 6/20
# 60553/60553 [==============================] - 13s 208us/step - loss: 0.2021 - acc: 0.9141 - val_loss: 0.2312 - val_acc: 0.9136
#
# Epoch 00006: val_acc improved from 0.91362 to 0.91362, saving model to /mnt/seals/models/239/model_round_2.h5
# Epoch 7/20
# 60553/60553 [==============================] - 12s 206us/step - loss: 0.2019 - acc: 0.9141 - val_loss: 0.2335 - val_acc: 0.9131
#
# Epoch 00007: val_acc did not improve from 0.91362
# Epoch 8/20
# 60553/60553 [==============================] - 12s 205us/step - loss: 0.2009 - acc: 0.9143 - val_loss: 0.2304 - val_acc: 0.9136
#
# Epoch 00008: val_acc did not improve from 0.91362
# Epoch 9/20
# 60553/60553 [==============================] - 12s 197us/step - loss: 0.2008 - acc: 0.9143 - val_loss: 0.2275 - val_acc: 0.9135
#
# Epoch 00009: val_acc did not improve from 0.91362
# H2 {'val_acc': [0.9132876125113785, 0.9128420199369239, 0.9134881307167034, 0.9136218075371503, 0.9132207732087586, 0.9136218078346158, 0.9131316537419781, 0.9136218075371503, 0.9135104087986057], 'val_loss': [0.2338705912130145, 0.24923445884875037, 0.21776186128705274, 0.23599132654708546, 0.2258285787223803, 0.231169579637772, 0.23353826647353634, 0.23039492274996495, 0.22752906105069168], 'acc': [0.9135893051420304, 0.9137426529734199, 0.9138346616444953, 0.9137450122987596, 0.9138511784111772, 0.914103612237045, 0.914098893491869, 0.9143277385686723, 0.9142640382068694], 'loss': [0.20422545238152315, 0.20406079565820404, 0.20308151719548623, 0.20215625050933017, 0.2025769719451003, 0.2020565329866953, 0.20187172530322592, 0.20085276124353477, 0.20076604837324177]}
# stopped_epoch2 6
# 9
# 0.9131316537419781
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 226us/step - loss: 0.1995 - acc: 0.9145 - val_loss: 0.2297 - val_acc: 0.9134
#
# Epoch 00001: val_acc improved from -inf to 0.91342, saving model to /mnt/seals/models/239/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 12s 197us/step - loss: 0.1996 - acc: 0.9146 - val_loss: 0.2294 - val_acc: 0.9134
#
# Epoch 00002: val_acc did not improve from 0.91342
# Epoch 3/20
# 60553/60553 [==============================] - 12s 201us/step - loss: 0.1998 - acc: 0.9146 - val_loss: 0.2281 - val_acc: 0.9135
#
# Epoch 00003: val_acc improved from 0.91342 to 0.91347, saving model to /mnt/seals/models/239/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 12s 201us/step - loss: 0.1998 - acc: 0.9144 - val_loss: 0.2265 - val_acc: 0.9134
#
# Epoch 00004: val_acc did not improve from 0.91347
# Epoch 5/20
# 60553/60553 [==============================] - 12s 200us/step - loss: 0.1994 - acc: 0.9146 - val_loss: 0.2281 - val_acc: 0.9132
#
# Epoch 00005: val_acc did not improve from 0.91347
# Epoch 6/20
# 60553/60553 [==============================] - 12s 206us/step - loss: 0.2000 - acc: 0.9144 - val_loss: 0.2303 - val_acc: 0.9134
#
# Epoch 00006: val_acc did not improve from 0.91347
# H3 {'val_acc': [0.9134212905216872, 0.9133767313832278, 0.9134658496601464, 0.913399011844854, 0.9131984939369944, 0.9134435700909168], 'val_loss': [0.22974679556327243, 0.22937025997092853, 0.2281060891919633, 0.22647680279915583, 0.22814303179197734, 0.23032481180119352], 'acc': [0.9145495033434647, 0.9146249981270481, 0.9146438717218032, 0.9143914361949987, 0.9146037651439557, 0.9144480564034259], 'loss': [0.19953627290192077, 0.1995585588040211, 0.199832884237514, 0.19977095527797895, 0.1993943590017408, 0.2000248067198726]}
# stopped_epoch3 3
# 6
# 0.913399011844854
# best fit round 3 0.913399011844854
# 3137/3137 [==============================] - 1s 271us/step
# 2019-01-20 15:30:44,267 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:30:42",
#     "fit_dt_test_start": "2019-01-20 15:30:41",
#     "fit_dt_train_duration_seconds": "246",
#     "fit_dt_train_end": "2019-01-20 15:30:40",
#     "fit_dt_train_start": "2019-01-20 15:26:33",
#     "fit_num_epochs": 13,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 6,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.4714695569014983,
#     "fit_train_acc": 0.9143914361949987,
#     "fit_train_loss": 0.19977095527797895,
#     "fit_val_acc": 0.913399011844854,
#     "fit_val_loss": 0.22647680279915583,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 239,
#     "model_param_count": 590855,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/239/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:30:44,269 [MainThread  ] [INFO ]  model 239 test acc: 0.4714695569014983
# 2019-01-20 15:30:47,561 [MainThread  ] [INFO ]  Begin experiment for model_id=247 on GPU:7
# 2019-01-20 15:30:47,564 [MainThread  ] [INFO ]  Loading data
# 247   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 247, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'inception_resnet_v2', 'layer_2_size': 256, 'layer_1_size': 0, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 15:30:48,726 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:30:48,727 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 12s 198us/step - loss: 0.5561 - acc: 0.9159 - val_loss: 1.1774 - val_acc: 0.8363
#
# Epoch 00001: val_acc improved from -inf to 0.83633, saving model to /mnt/seals/models/247/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 10s 165us/step - loss: 0.4941 - acc: 0.9269 - val_loss: 1.1919 - val_acc: 0.8607
#
# Epoch 00002: val_acc improved from 0.83633 to 0.86066, saving model to /mnt/seals/models/247/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 10s 165us/step - loss: 0.5338 - acc: 0.9280 - val_loss: 1.2876 - val_acc: 0.8703
#
# Epoch 00003: val_acc improved from 0.86066 to 0.87027, saving model to /mnt/seals/models/247/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 10s 167us/step - loss: 0.4940 - acc: 0.9319 - val_loss: 1.2532 - val_acc: 0.8750
#
# Epoch 00004: val_acc improved from 0.87027 to 0.87499, saving model to /mnt/seals/models/247/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 10s 164us/step - loss: 0.5069 - acc: 0.9332 - val_loss: 1.2621 - val_acc: 0.8689
#
# Epoch 00005: val_acc did not improve from 0.87499
# Epoch 6/20
# ...
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:13:54,523 [MainThread  ] [INFO ]  model 311 test acc: 0.6726171501434491
# 2019-01-20 16:13:57,095 [MainThread  ] [INFO ]  Begin experiment for model_id=319 on GPU:7
# 2019-01-20 16:13:57,097 [MainThread  ] [INFO ]  Loading data
# 319   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 319, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'vgg16', 'layer_2_size': 0, 'layer_1_size': 0, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 16:13:58,186 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:13:58,187 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 0.9421 - acc: 0.9188 - val_loss: 1.5388 - val_acc: 0.8838
#
# Epoch 00001: val_acc improved from -inf to 0.88379, saving model to /mnt/seals/models/319/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 10s 171us/step - loss: 0.8604 - acc: 0.9272 - val_loss: 1.6047 - val_acc: 0.8814
#
# Epoch 00002: val_acc did not improve from 0.88379
# Epoch 3/20
# 60553/60553 [==============================] - 10s 171us/step - loss: 0.8426 - acc: 0.9298 - val_loss: 1.7987 - val_acc: 0.8688
#
# Epoch 00003: val_acc did not improve from 0.88379
# Epoch 4/20
# 60553/60553 [==============================] - 10s 168us/step - loss: 0.8510 - acc: 0.9299 - val_loss: 1.7283 - val_acc: 0.8814
#
# Epoch 00004: val_acc did not improve from 0.88379
# H1 {'val_acc': [0.8837893416341661, 0.8813608586974093, 0.8688174121393238, 0.8813608584743102], 'val_loss': [1.5388195432132286, 1.604714430724541, 1.798730386173584, 1.728287091867967], 'acc': [0.91882438181122, 0.9272373187075976, 0.929806496423413, 0.929853681269628], 'loss': [0.9421372337929785, 0.8604086052081356, 0.8425692638205042, 0.8509905123859071]}
# stopped_epoch1 1
# 4
# 0.8813608586974093
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.7793 - acc: 0.9376 - val_loss: 1.7778 - val_acc: 0.8722
#
# Epoch 00001: val_acc improved from -inf to 0.87223, saving model to /mnt/seals/models/319/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 10s 171us/step - loss: 0.7607 - acc: 0.9382 - val_loss: 1.6362 - val_acc: 0.8810
#
# Epoch 00002: val_acc improved from 0.87223 to 0.88098, saving model to /mnt/seals/models/319/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 10s 170us/step - loss: 0.7458 - acc: 0.9387 - val_loss: 1.7097 - val_acc: 0.8743
#
# Epoch 00003: val_acc did not improve from 0.88098
# Epoch 4/20
# 60553/60553 [==============================] - 10s 173us/step - loss: 0.7352 - acc: 0.9389 - val_loss: 1.7505 - val_acc: 0.8722
#
# Epoch 00004: val_acc did not improve from 0.88098
# Epoch 5/20
# 60553/60553 [==============================] - 10s 172us/step - loss: 0.7269 - acc: 0.9390 - val_loss: 1.7024 - val_acc: 0.8737
#
# Epoch 00005: val_acc did not improve from 0.88098
# H2 {'val_acc': [0.8722261972376799, 0.8809821051281091, 0.8743204841819021, 0.8722484741297203, 0.8737189346228401], 'val_loss': [1.7777917056401966, 1.6362466885756495, 1.7096947392150155, 1.7504599547282056, 1.7024069105322035], 'acc': [0.9375706500440731, 0.938205276543861, 0.9387030694245831, 0.9389177574370458, 0.939023921340608], 'loss': [0.7792619480124323, 0.7607038054600563, 0.7457581561414905, 0.7352114930543951, 0.7268782611928025]}
# stopped_epoch2 2
# 5
# 0.8743204841819021
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 234us/step - loss: 0.7135 - acc: 0.9399 - val_loss: 1.6719 - val_acc: 0.8751
#
# Epoch 00001: val_acc improved from -inf to 0.87514, saving model to /mnt/seals/models/319/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 10s 172us/step - loss: 0.7109 - acc: 0.9400 - val_loss: 1.6578 - val_acc: 0.8754
#
# Epoch 00002: val_acc improved from 0.87514 to 0.87539, saving model to /mnt/seals/models/319/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 10s 173us/step - loss: 0.7093 - acc: 0.9399 - val_loss: 1.6715 - val_acc: 0.8745
#
# Epoch 00003: val_acc did not improve from 0.87539
# Epoch 4/20
# 60553/60553 [==============================] - 11s 174us/step - loss: 0.7077 - acc: 0.9399 - val_loss: 1.6618 - val_acc: 0.8748
#
# Epoch 00004: val_acc did not improve from 0.87539
# Epoch 5/20
# 60553/60553 [==============================] - 10s 173us/step - loss: 0.7064 - acc: 0.9400 - val_loss: 1.6829 - val_acc: 0.8737
#
# Epoch 00005: val_acc did not improve from 0.87539
# H3 {'val_acc': [0.8751448309949541, 0.875389907669441, 0.8745432816589912, 0.8748106361922813, 0.8736520929404965], 'val_loss': [1.6718546310515234, 1.657826881370021, 1.6714985803448255, 1.6617678938548563, 1.6829262075763305], 'acc': [0.9398897508024517, 0.9400430987096354, 0.9399463720089981, 0.9399487299936689, 0.9400077111476568], 'loss': [0.7135269254972159, 0.7109179987324957, 0.7092887349701883, 0.7077246873533846, 0.7064163747163437]}
# stopped_epoch3 2
# 5
# 0.8745432816589912
# best fit round 1 0.8813608586974093
# 3137/3137 [==============================] - 2s 522us/step
# 2019-01-20 16:17:07,086 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 16:17:05",
#     "fit_dt_test_start": "2019-01-20 16:17:03",
#     "fit_dt_train_duration_seconds": "182",
#     "fit_dt_train_end": "2019-01-20 16:17:01",
#     "fit_dt_train_start": "2019-01-20 16:13:59",
#     "fit_num_epochs": 8,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 2,
#     "fit_test_acc": 0.5470194453299331,
#     "fit_train_acc": 0.9272373187075976,
#     "fit_train_loss": 0.8604086052081356,
#     "fit_val_acc": 0.8813608586974093,
#     "fit_val_loss": 1.604714430724541,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 0,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 319,
#     "model_param_count": 10759,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/319/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:17:07,088 [MainThread  ] [INFO ]  model 319 test acc: 0.5470194453299331
# 2019-01-20 16:17:09,301 [MainThread  ] [INFO ]  Begin experiment for model_id=327 on GPU:7
# 2019-01-20 16:17:09,303 [MainThread  ] [INFO ]  Loading data
# 327   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 327, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'resnet50', 'layer_2_size': 256, 'layer_1_size': 512, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 16:17:10,376 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/resnet50/max/
# 2019-01-20 16:17:10,377 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 26s 426us/step - loss: 1.9153 - acc: 0.8799 - val_loss: 2.4420 - val_acc: 0.8477
#
# Epoch 00001: val_acc improved from -inf to 0.84765, saving model to /mnt/seals/models/327/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 21s 342us/step - loss: 2.7053 - acc: 0.8312 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.84765
# Epoch 3/20
# 60553/60553 [==============================] - 21s 347us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.84765
# Epoch 4/20
# 60553/60553 [==============================] - 21s 341us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.84765
# H1 {'val_acc': [0.8476517300492737, 0.8367346938297441, 0.8367346938297441, 0.8367346938297441], 'val_loss': [2.4419625671074976, 2.6171817882166604, 2.6171817882166604, 2.6171817882166604], 'acc': [0.879854972530092, 0.8312363903140528, 0.8303823577574754, 0.8303823555249958], 'loss': [1.915343389037366, 2.7052685541907633, 2.7190112637589183, 2.719011267145042]}
# stopped_epoch1 1
# 4
# 0.8367346938297441
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 25s 410us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00001: val_acc improved from -inf to 0.83673, saving model to /mnt/seals/models/327/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 21s 347us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.83673
# Epoch 3/20
# 60553/60553 [==============================] - 21s 353us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.83673
# Epoch 4/20
# 60553/60553 [==============================] - 21s 346us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.83673
# H2 {'val_acc': [0.8367346938297441, 0.8367346938297441, 0.8367346938297441, 0.8367346938297441], 'val_loss': [2.6171817882166604, 2.6171817882166604, 2.6171817882166604, 2.6171817882166604], 'acc': [0.8303823567042332, 0.8303823566097368, 0.8303823565693789, 0.8303823562770304], 'loss': [2.71901126545198, 2.7190112675939004, 2.7190112639400366, 2.71901126499131]}
# stopped_epoch2 1
# 4
# 0.8367346938297441
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 26s 428us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00001: val_acc improved from -inf to 0.83673, saving model to /mnt/seals/models/327/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 21s 348us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00002: val_acc did not improve from 0.83673
# Epoch 3/20
# 60553/60553 [==============================] - 21s 351us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00003: val_acc did not improve from 0.83673
# Epoch 4/20
# 60553/60553 [==============================] - 21s 348us/step - loss: 2.7190 - acc: 0.8304 - val_loss: 2.6172 - val_acc: 0.8367
#
# Epoch 00004: val_acc did not improve from 0.83673
# H3 {'val_acc': [0.8367346938297441, 0.8367346938297441, 0.8367346938297441, 0.8367346938297441], 'val_loss': [2.6171817882166604, 2.6171817882166604, 2.6171817882166604, 2.6171817882166604], 'acc': [0.8303823552149292, 0.8303823572574315, 0.8303823563715269, 0.8303823561155989], 'loss': [2.719011268979849, 2.7190112675230282, 2.7190112646763214, 2.7190112630265704]}
# stopped_epoch3 1
# 4
# 0.8367346938297441
# best fit round 1 0.8367346938297441
# 3137/3137 [==============================] - 2s 644us/step
# 2019-01-20 16:22:12,590 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "2",
#     "fit_dt_test_end": "2019-01-20 16:22:10",
#     "fit_dt_test_start": "2019-01-20 16:22:08",
#     "fit_dt_train_duration_seconds": "292",
#     "fit_dt_train_end": "2019-01-20 16:22:06",
#     "fit_dt_train_start": "2019-01-20 16:17:13",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.17468919349697165,
#     "fit_train_acc": 0.8312363903140528,
#     "fit_train_loss": 2.7052685541907633,
#     "fit_val_acc": 0.8367346938297441,
#     "fit_val_loss": 2.6171817882166604,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 256,
#     "layer_3_size": 0,
#     "model_id": 327,
#     "model_param_count": 3279367,
#     "model_weights_path": null,
#     "num_features": 2048,
#     "path_model": "/mnt/seals/models/327/",
#     "pooling": "max",
#     "pretrained_model_name": "resnet50",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:22:12,591 [MainThread  ] [INFO ]  model 327 test acc: 0.17468919349697165
# 2019-01-20 16:22:16,728 [MainThread  ] [INFO ]  Begin experiment for model_id=335 on GPU:7
# 2019-01-20 16:22:16,730 [MainThread  ] [INFO ]  Loading data
# 335   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pooling': 'max', 'layer_3_size': 0, 'model_id': 335, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'sequence_length': 3, 'pretrained_model_name': 'resnet50', 'layer_2_size': 0, 'layer_1_size': 512, 'WORKER': 7, 'dropout': 0.2}
# 2019-01-20 16:22:17,825 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/resnet50/max/
# 2019-01-20 16:22:17,826 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 25s 410us/step - loss: 2.0672 - acc: 0.8704 - val_loss: 2.3476 - val_acc: 0.8535
#
# Epoch 00001: val_acc improved from -inf to 0.85349, saving model to /mnt/seals/models/335/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 2.1593 - acc: 0.8651 - val_loss: 2.4716 - val_acc: 0.8458
#
# Epoch 00002: val_acc did not improve from 0.85349
# Epoch 3/20
# 60553/60553 [==============================] - 19s 319us/step - loss: 2.2233 - acc: 0.8612 - val_loss: 2.4641 - val_acc: 0.8461
#
# Epoch 00003: val_acc did not improve from 0.85349
# Epoch 4/20
# 60553/60553 [==============================] - 20s 324us/step - loss: 2.1939 - acc: 0.8631 - val_loss: 2.4108 - val_acc: 0.8496
#
# Epoch 00004: val_acc did not improve from 0.85349
# H1 {'val_acc': [0.8534889977869211, 0.8457802367894559, 0.846136710492061, 0.8496123402474154], 'val_loss': [2.347609076214372, 2.471629364149911, 2.464078587364273, 2.4107501369227635], 'acc': [0.8704039815151274, 0.8651240700959053, 0.861240811478524, 0.8630857133527532], 'loss': [2.0672166083740335, 2.1593356873911027, 2.223263024508155, 2.1939075246029773]}
# stopped_epoch1 1
# 4
# 0.8457802367894559
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 24s 394us/step - loss: 2.1633 - acc: 0.8650 - val_loss: 2.4091 - val_acc: 0.8497
#
# Epoch 00001: val_acc improved from -inf to 0.84970, saving model to /mnt/seals/models/335/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 19s 321us/step - loss: 2.1759 - acc: 0.8641 - val_loss: 2.4112 - val_acc: 0.8495
#
# Epoch 00002: val_acc did not improve from 0.84970
# Epoch 3/20
# 60553/60553 [==============================] - 20s 329us/step - loss: 2.1626 - acc: 0.8649 - val_loss: 2.4250 - val_acc: 0.8486
#
# Epoch 00003: val_acc did not improve from 0.84970
# Epoch 4/20
# 23360/60553 [==========>...................] - ETA: 11s - loss: 2.1452 - acc: 0.8660
