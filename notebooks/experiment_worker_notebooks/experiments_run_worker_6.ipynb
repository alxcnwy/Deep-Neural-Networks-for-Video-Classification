# %%
WORKER_ID = 6

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 15:05:13,504 [MainThread  ] [INFO ]  Begin experiment for model_id=198 on GPU:6
# 2019-01-20 15:05:13,505 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 15:05:13,506 [MainThread  ] [INFO ]  Loading data
# 198   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 512, 'layer_2_size': 256, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 198, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:05:14,441 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:05:14,443 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 35s 571us/step - loss: 0.3007 - acc: 0.9172 - val_loss: 0.1921 - val_acc: 0.9044
#
# Epoch 00001: val_acc improved from -inf to 0.90435, saving model to /mnt/seals/models/198/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 302us/step - loss: 0.1664 - acc: 0.9305 - val_loss: 0.2030 - val_acc: 0.9079
#
# Epoch 00002: val_acc improved from 0.90435 to 0.90785, saving model to /mnt/seals/models/198/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1747 - acc: 0.9246 - val_loss: 0.1916 - val_acc: 0.9114
#
# Epoch 00003: val_acc improved from 0.90785 to 0.91137, saving model to /mnt/seals/models/198/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1662 - acc: 0.9279 - val_loss: 0.2298 - val_acc: 0.8827
#
# Epoch 00004: val_acc did not improve from 0.91137
# Epoch 5/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1701 - acc: 0.9266 - val_loss: 0.1860 - val_acc: 0.9160
#
# Epoch 00005: val_acc improved from 0.91137 to 0.91603, saving model to /mnt/seals/models/198/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 18s 298us/step - loss: 0.1639 - acc: 0.9281 - val_loss: 0.2146 - val_acc: 0.8842
#
# Epoch 00006: val_acc did not improve from 0.91603
# Epoch 7/20
# 60553/60553 [==============================] - 18s 299us/step - loss: 0.1736 - acc: 0.9246 - val_loss: 0.2039 - val_acc: 0.8821
#
# Epoch 00007: val_acc did not improve from 0.91603
# Epoch 8/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1690 - acc: 0.9261 - val_loss: 0.1820 - val_acc: 0.8890
#
# Epoch 00008: val_acc did not improve from 0.91603
# H1 {'acc': [0.9172201175367858, 0.93053549086154, 0.9246138782955434, 0.9278601476544246, 0.9266144870252941, 0.9281479724894239, 0.9246469073609952, 0.9260765860784048], 'val_loss': [0.19208121441039752, 0.20297754249644145, 0.19159749631798423, 0.22984061834965358, 0.18598746546937464, 0.21462152858339692, 0.20389281716186108, 0.18204305168991897], 'val_acc': [0.9043534631589317, 0.9078513688395637, 0.9113715604105668, 0.8827421942950039, 0.9160280112021429, 0.884190371351843, 0.8821406393815634, 0.8890473344366178], 'loss': [0.3007330352685423, 0.16635028302335833, 0.17468486097242555, 0.16618381641124624, 0.1700576921946512, 0.1639069963385068, 0.173571240792587, 0.16900895614422273]}
# stopped_epoch1 5
# 8
# 0.884190371351843
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 313us/step - loss: 0.1526 - acc: 0.9316 - val_loss: 0.1900 - val_acc: 0.9150
#
# Epoch 00001: val_acc improved from -inf to 0.91496, saving model to /mnt/seals/models/198/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 301us/step - loss: 0.1505 - acc: 0.9325 - val_loss: 0.1912 - val_acc: 0.9132
#
# Epoch 00002: val_acc did not improve from 0.91496
# Epoch 3/20
# 60553/60553 [==============================] - 18s 301us/step - loss: 0.1474 - acc: 0.9348 - val_loss: 0.2000 - val_acc: 0.9100
#
# Epoch 00003: val_acc did not improve from 0.91496
# Epoch 4/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1466 - acc: 0.9344 - val_loss: 0.1892 - val_acc: 0.9152
#
# Epoch 00004: val_acc improved from 0.91496 to 0.91523, saving model to /mnt/seals/models/198/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 19s 320us/step - loss: 0.1466 - acc: 0.9347 - val_loss: 0.1942 - val_acc: 0.9103
#
# Epoch 00005: val_acc did not improve from 0.91523
# Epoch 6/20
# 60553/60553 [==============================] - 18s 304us/step - loss: 0.1454 - acc: 0.9362 - val_loss: 0.1840 - val_acc: 0.9143
#
# Epoch 00006: val_acc did not improve from 0.91523
# Epoch 7/20
# 60553/60553 [==============================] - 18s 302us/step - loss: 0.1436 - acc: 0.9366 - val_loss: 0.1937 - val_acc: 0.9093
#
# Epoch 00007: val_acc did not improve from 0.91523
# H2 {'acc': [0.9316254440898252, 0.9325431764195712, 0.9347561148178303, 0.9344494174363963, 0.9347230856224459, 0.9361975906304836, 0.9366293258695184], 'val_loss': [0.1899901284921638, 0.19121168478533246, 0.19999073718163793, 0.18920213101212113, 0.19423032775567758, 0.1840291132665915, 0.19374532234423322], 'val_acc': [0.9149585859298112, 0.9132430540422165, 0.9100347782995875, 0.9152259377859119, 0.910324415376762, 0.9142679175732661, 0.9092995471606311], 'loss': [0.15257677763505834, 0.1504888818886818, 0.14738799274748324, 0.14661613440418328, 0.14657220197971488, 0.1454105163337438, 0.14363751744730058]}
# stopped_epoch2 4
# 7
# 0.910324415376762
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 315us/step - loss: 0.1426 - acc: 0.9377 - val_loss: 0.1883 - val_acc: 0.9115
#
# Epoch 00001: val_acc improved from -inf to 0.91146, saving model to /mnt/seals/models/198/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 19s 313us/step - loss: 0.1421 - acc: 0.9378 - val_loss: 0.1908 - val_acc: 0.9103
#
# Epoch 00002: val_acc did not improve from 0.91146
# Epoch 3/20
# 60553/60553 [==============================] - 19s 317us/step - loss: 0.1416 - acc: 0.9380 - val_loss: 0.1891 - val_acc: 0.9109
#
# Epoch 00003: val_acc did not improve from 0.91146
# Epoch 4/20
# 60553/60553 [==============================] - 19s 310us/step - loss: 0.1423 - acc: 0.9377 - val_loss: 0.1930 - val_acc: 0.9099
#
# Epoch 00004: val_acc did not improve from 0.91146
# H3 {'acc': [0.9377074833855555, 0.9378254442347418, 0.9379717140271147, 0.9376838915220443], 'val_loss': [0.18825431848531654, 0.19079647026839883, 0.18905166626274028, 0.19301796087754644], 'val_acc': [0.911460680249179, 0.9103466955409225, 0.9108814084745539, 0.9098565432330779], 'loss': [0.1425700340506568, 0.1420834239255391, 0.1415745330429659, 0.14230557617094203]}
# stopped_epoch3 1
# 4
# 0.9103466955409225
# best fit round 3 0.9103466955409225
# 3137/3137 [==============================] - 0s 105us/step
# 2019-01-20 15:11:34,759 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:11:33",
#     "fit_dt_test_start": "2019-01-20 15:11:32",
#     "fit_dt_train_duration_seconds": "374",
#     "fit_dt_train_end": "2019-01-20 15:11:32",
#     "fit_dt_train_start": "2019-01-20 15:05:17",
#     "fit_num_epochs": 13,
#     "fit_stopped_epoch1": 5,
#     "fit_stopped_epoch2": 4,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.5798533630857508,
#     "fit_train_acc": 0.9378254442347418,
#     "fit_train_loss": 0.1420834239255391,
#     "fit_val_acc": 0.9103466955409225,
#     "fit_val_loss": 0.19079647026839883,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 256,
#     "layer_3_size": 128,
#     "model_id": 198,
#     "model_param_count": 2524935,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/198/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:11:34,760 [MainThread  ] [INFO ]  model 198 test acc: 0.5798533630857508
# 2019-01-20 15:11:37,647 [MainThread  ] [INFO ]  Begin experiment for model_id=206 on GPU:6
# 2019-01-20 15:11:37,649 [MainThread  ] [INFO ]  Loading data
# 206   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 512, 'layer_2_size': 0, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 206, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:11:38,783 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:11:38,785 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 3.8107 - acc: 0.7621 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00001: val_acc improved from -inf to 0.75332, saving model to /mnt/seals/models/206/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 250us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00002: val_acc did not improve from 0.75332
# Epoch 3/20
# 60553/60553 [==============================] - 16s 257us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00003: val_acc did not improve from 0.75332
# Epoch 4/20
# 60553/60553 [==============================] - 15s 256us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00004: val_acc did not improve from 0.75332
# H1 {'acc': [0.7620832725037647, 0.7619983409178821, 0.7619983409041015, 0.7619983399453558], 'val_loss': [3.9543445682942084, 3.9543445682942084, 3.9543445682942084, 3.9543445682942084], 'val_acc': [0.7533196688665127, 0.7533196688665127, 0.7533196688665127, 0.7533196688665127], 'loss': [3.810662835823122, 3.8152233373045283, 3.8152233377376374, 3.815223336461935]}
# stopped_epoch1 1
# 4
# 0.7533196688665127
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00001: val_acc improved from -inf to 0.75332, saving model to /mnt/seals/models/206/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 257us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00002: val_acc did not improve from 0.75332
# Epoch 3/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00003: val_acc did not improve from 0.75332
# Epoch 4/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00004: val_acc did not improve from 0.75332
# H2 {'acc': [0.7619983416777915, 0.7619983408863833, 0.7619983413313043, 0.7619983405261155], 'val_loss': [3.9543445682942084, 3.9543445682942084, 3.9543445682942084, 3.9543445682942084], 'val_acc': [0.7533196688665127, 0.7533196688665127, 0.7533196688665127, 0.7533196688665127], 'loss': [3.815223336461935, 3.815223330878767, 3.815223336965916, 3.8152233357217122]}
# stopped_epoch2 1
# 4
# 0.7533196688665127
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 265us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00001: val_acc improved from -inf to 0.75332, saving model to /mnt/seals/models/206/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00002: val_acc did not improve from 0.75332
# Epoch 3/20
# 60553/60553 [==============================] - 15s 254us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00003: val_acc did not improve from 0.75332
# Epoch 4/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 3.8152 - acc: 0.7620 - val_loss: 3.9543 - val_acc: 0.7533
#
# Epoch 00004: val_acc did not improve from 0.75332
# H3 {'acc': [0.7619983412505885, 0.7619983410478148, 0.7619983409395376, 0.7619983408096049], 'val_loss': [3.9543445682942084, 3.9543445682942084, 3.9543445682942084, 3.9543445682942084], 'val_acc': [0.7533196688665127, 0.7533196688665127, 0.7533196688665127, 0.7533196688665127], 'loss': [3.8152233376116422, 3.8152233352019818, 3.815223332268653, 3.815223332067848]}
# stopped_epoch3 1
# 4
# 0.7533196688665127
# best fit round 1 0.7533196688665127
# 3137/3137 [==============================] - 0s 125us/step
# 2019-01-20 15:14:57,264 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:14:55",
#     "fit_dt_test_start": "2019-01-20 15:14:55",
#     "fit_dt_train_duration_seconds": "192",
#     "fit_dt_train_end": "2019-01-20 15:14:54",
#     "fit_dt_train_start": "2019-01-20 15:11:41",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.21581128466687916,
#     "fit_train_acc": 0.7619983409178821,
#     "fit_train_loss": 3.8152233373045283,
#     "fit_val_acc": 0.7533196688665127,
#     "fit_val_loss": 3.9543445682942084,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 0,
#     "layer_3_size": 128,
#     "model_id": 206,
#     "model_param_count": 2363399,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/206/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:14:57,265 [MainThread  ] [INFO ]  model 206 test acc: 0.21581128466687916
# 2019-01-20 15:15:02,013 [MainThread  ] [INFO ]  Begin experiment for model_id=214 on GPU:6
# 2019-01-20 15:15:02,016 [MainThread  ] [INFO ]  Loading data
# 214   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 256, 'layer_2_size': 256, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 214, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:15:03,153 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:15:03,154 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 289us/step - loss: 0.2222 - acc: 0.9143 - val_loss: 0.2093 - val_acc: 0.9144
#
# Epoch 00001: val_acc improved from -inf to 0.91442, saving model to /mnt/seals/models/214/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1894 - acc: 0.9201 - val_loss: 0.1953 - val_acc: 0.9157
#
# Epoch 00002: val_acc improved from 0.91442 to 0.91567, saving model to /mnt/seals/models/214/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.1797 - acc: 0.9230 - val_loss: 0.1968 - val_acc: 0.9162
#
# Epoch 00003: val_acc improved from 0.91567 to 0.91618, saving model to /mnt/seals/models/214/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 16s 265us/step - loss: 0.1731 - acc: 0.9246 - val_loss: 0.2050 - val_acc: 0.9161
#
# Epoch 00004: val_acc did not improve from 0.91618
# Epoch 5/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1701 - acc: 0.9257 - val_loss: 0.2057 - val_acc: 0.8825
#
# Epoch 00005: val_acc did not improve from 0.91618
# Epoch 6/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 0.1719 - acc: 0.9256 - val_loss: 0.1943 - val_acc: 0.9151
#
# Epoch 00006: val_acc did not improve from 0.91618
# H1 {'acc': [0.9143466055083153, 0.92008184146096, 0.9229978216733298, 0.9246138785160352, 0.925743938470803, 0.925611823524072], 'val_loss': [0.20930441585616327, 0.19534528640308607, 0.19680197043338568, 0.20503051916435966, 0.2057001705438884, 0.19427248720295787], 'val_acc': [0.9144238798378856, 0.9156715377598201, 0.9161839690791468, 0.9160502922586999, 0.8825416737843215, 0.9151145497189412], 'loss': [0.22220606245173707, 0.18935887011908134, 0.17973357300667764, 0.1730558942108468, 0.1701137321593228, 0.1718811545897961]}
# stopped_epoch1 3
# 6
# 0.9160502922586999
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1554 - acc: 0.9312 - val_loss: 0.1997 - val_acc: 0.9066
#
# Epoch 00001: val_acc improved from -inf to 0.90656, saving model to /mnt/seals/models/214/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1520 - acc: 0.9349 - val_loss: 0.1840 - val_acc: 0.9093
#
# Epoch 00002: val_acc improved from 0.90656 to 0.90934, saving model to /mnt/seals/models/214/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1491 - acc: 0.9363 - val_loss: 0.1991 - val_acc: 0.9051
#
# Epoch 00003: val_acc did not improve from 0.90934
# Epoch 4/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1479 - acc: 0.9371 - val_loss: 0.1836 - val_acc: 0.9097
#
# Epoch 00004: val_acc improved from 0.90934 to 0.90966, saving model to /mnt/seals/models/214/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.1457 - acc: 0.9380 - val_loss: 0.1877 - val_acc: 0.9049
#
# Epoch 00005: val_acc did not improve from 0.90966
# Epoch 6/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1450 - acc: 0.9382 - val_loss: 0.1919 - val_acc: 0.9026
#
# Epoch 00006: val_acc did not improve from 0.90966
# Epoch 7/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.1436 - acc: 0.9391 - val_loss: 0.2000 - val_acc: 0.8988
#
# Epoch 00007: val_acc did not improve from 0.90966
# H2 {'acc': [0.9311724774426395, 0.9348882299004, 0.9362848817119964, 0.9370563416802463, 0.9380236174383717, 0.9381675281623171, 0.9391371627240828], 'val_loss': [0.19967154817364027, 0.1839806114742329, 0.1991377620494745, 0.18364767963560535, 0.18773715607984617, 0.1918777408669758, 0.19995277802124667], 'val_acc': [0.9065591514073382, 0.9093441103520575, 0.9050886894268909, 0.9096560213094343, 0.9048881756463649, 0.9025933710917486, 0.8988058279621103], 'loss': [0.1554102234283612, 0.15196293945387546, 0.1491353790616472, 0.14792599602422674, 0.1457249452210401, 0.14503168982950412, 0.14363117500266778]}
# stopped_epoch2 4
# 7
# 0.9048881756463649
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 285us/step - loss: 0.1412 - acc: 0.9402 - val_loss: 0.1938 - val_acc: 0.9019
#
# Epoch 00001: val_acc improved from -inf to 0.90186, saving model to /mnt/seals/models/214/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.1412 - acc: 0.9404 - val_loss: 0.1966 - val_acc: 0.9020
#
# Epoch 00002: val_acc improved from 0.90186 to 0.90199, saving model to /mnt/seals/models/214/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.1411 - acc: 0.9406 - val_loss: 0.1940 - val_acc: 0.9030
#
# Epoch 00003: val_acc improved from 0.90199 to 0.90297, saving model to /mnt/seals/models/214/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.1413 - acc: 0.9405 - val_loss: 0.1950 - val_acc: 0.9028
#
# Epoch 00004: val_acc did not improve from 0.90297
# Epoch 5/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1404 - acc: 0.9404 - val_loss: 0.1976 - val_acc: 0.9019
#
# Epoch 00005: val_acc did not improve from 0.90297
# Epoch 6/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.1413 - acc: 0.9400 - val_loss: 0.1985 - val_acc: 0.9013
#
# Epoch 00006: val_acc did not improve from 0.90297
# H3 {'acc': [0.940189369618248, 0.9403663082599065, 0.9405503281573998, 0.9405361728540407, 0.9403899008203292, 0.9400289423126762], 'val_loss': [0.19380679152120447, 0.19663375387397022, 0.19396676955115996, 0.19497441345650332, 0.19763587098231705, 0.19848562355942825], 'val_acc': [0.9018581414401197, 0.9019918200453594, 0.9029721249585143, 0.9027716084636157, 0.9019027014709754, 0.9013457116453036], 'loss': [0.14120615373808978, 0.14119267143724876, 0.14109643163026328, 0.1413114262858014, 0.14038718704409778, 0.1413177446670509]}
# stopped_epoch3 3
# 6
# 0.9027716084636157
# best fit round 1 0.9160502922586999
# 3137/3137 [==============================] - 1s 161us/step
# 2019-01-20 15:20:36,216 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:20:34",
#     "fit_dt_test_start": "2019-01-20 15:20:34",
#     "fit_dt_train_duration_seconds": "327",
#     "fit_dt_train_end": "2019-01-20 15:20:33",
#     "fit_dt_train_start": "2019-01-20 15:15:06",
#     "fit_num_epochs": 13,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 4,
#     "fit_stopped_epoch3": 3,
#     "fit_test_acc": 0.5604080331526937,
#     "fit_train_acc": 0.9246138785160352,
#     "fit_train_loss": 0.1730558942108468,
#     "fit_val_acc": 0.9160502922586999,
#     "fit_val_loss": 0.20503051916435966,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 256,
#     "layer_3_size": 128,
#     "model_id": 214,
#     "model_param_count": 1279495,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/214/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:20:36,217 [MainThread  ] [INFO ]  model 214 test acc: 0.5604080331526937
# 2019-01-20 15:20:38,863 [MainThread  ] [INFO ]  Begin experiment for model_id=222 on GPU:6
# 2019-01-20 15:20:38,865 [MainThread  ] [INFO ]  Loading data
# 222   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 256, 'layer_2_size': 0, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 222, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:20:40,008 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:20:40,010 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 3.9967 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/222/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 213us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 13s 222us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 13s 222us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H1 {'acc': [0.7505137194056, 0.7504712536914058, 0.750471254055611, 0.7504712533449187], 'val_loss': [4.290063819064249, 4.290063819064249, 4.290063819064249, 4.290063819064249], 'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'loss': [3.9967317908764586, 4.000005361053561, 4.000005362675751, 4.000005360297589]}
# stopped_epoch1 1
# 4
# 0.7323767991640088
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/222/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 217us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 13s 214us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 13s 213us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H2 {'acc': [0.7504712535969094, 0.7504712530299303, 0.7504712534531959, 0.7504712526834433], 'val_loss': [4.290063819064249, 4.290063819064249, 4.290063819064249, 4.290063819064249], 'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'loss': [4.000005367101337, 4.0000053625655045, 4.000005361376424, 4.000005365715388]}
# stopped_epoch2 1
# 4
# 0.7323767991640088
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 14s 236us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00001: val_acc improved from -inf to 0.73238, saving model to /mnt/seals/models/222/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 215us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00002: val_acc did not improve from 0.73238
# Epoch 3/20
# 60553/60553 [==============================] - 13s 218us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00003: val_acc did not improve from 0.73238
# Epoch 4/20
# 60553/60553 [==============================] - 14s 230us/step - loss: 4.0000 - acc: 0.7505 - val_loss: 4.2901 - val_acc: 0.7324
#
# Epoch 00004: val_acc did not improve from 0.73238
# H3 {'acc': [0.75047125361069, 0.7504712540063941, 0.7504712526558818, 0.7504712530752099], 'val_loss': [4.290063819064249, 4.290063819064249, 4.290063819064249, 4.290063819064249], 'val_acc': [0.7323767991640088, 0.7323767991640088, 0.7323767991640088, 0.7323767991640088], 'loss': [4.000005360746448, 4.000005364959416, 4.00000536276631, 4.00000535986448]}
# stopped_epoch3 1
# 4
# 0.7323767991640088
# best fit round 1 0.7323767991640088
# 3137/3137 [==============================] - 1s 199us/step
# 2019-01-20 15:23:38,303 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:23:36",
#     "fit_dt_test_start": "2019-01-20 15:23:35",
#     "fit_dt_train_duration_seconds": "171",
#     "fit_dt_train_end": "2019-01-20 15:23:34",
#     "fit_dt_train_start": "2019-01-20 15:20:43",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.18425247051322924,
#     "fit_train_acc": 0.7504712536914058,
#     "fit_train_loss": 4.000005361053561,
#     "fit_val_acc": 0.7323767991640088,
#     "fit_val_loss": 4.290063819064249,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 0,
#     "layer_3_size": 128,
#     "model_id": 222,
#     "model_param_count": 1181703,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/222/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:23:38,306 [MainThread  ] [INFO ]  model 222 test acc: 0.18425247051322924
# 2019-01-20 15:23:41,464 [MainThread  ] [INFO ]  Begin experiment for model_id=230 on GPU:6
# 2019-01-20 15:23:41,466 [MainThread  ] [INFO ]  Loading data
# 230   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 128, 'layer_2_size': 256, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 230, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:23:42,614 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:23:42,615 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.2143 - acc: 0.9180 - val_loss: 0.2402 - val_acc: 0.8964
#
# Epoch 00001: val_acc improved from -inf to 0.89642, saving model to /mnt/seals/models/230/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 250us/step - loss: 0.1881 - acc: 0.9246 - val_loss: 0.1901 - val_acc: 0.9051
#
# Epoch 00002: val_acc improved from 0.89642 to 0.90511, saving model to /mnt/seals/models/230/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 0.1799 - acc: 0.9278 - val_loss: 0.2697 - val_acc: 0.8979
#
# Epoch 00003: val_acc did not improve from 0.90511
# Epoch 4/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 0.1772 - acc: 0.9295 - val_loss: 0.1831 - val_acc: 0.9164
#
# Epoch 00004: val_acc improved from 0.90511 to 0.91641, saving model to /mnt/seals/models/230/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 0.1747 - acc: 0.9313 - val_loss: 0.2051 - val_acc: 0.9039
#
# Epoch 00005: val_acc did not improve from 0.91641
# Epoch 6/20
# 60553/60553 [==============================] - 15s 255us/step - loss: 0.1816 - acc: 0.9313 - val_loss: 0.2147 - val_acc: 0.9021
#
# Epoch 00006: val_acc did not improve from 0.91641
# Epoch 7/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 0.1763 - acc: 0.9318 - val_loss: 0.1845 - val_acc: 0.9157
#
# Epoch 00007: val_acc did not improve from 0.91641
# H1 {'acc': [0.9179845027231949, 0.9246138758071358, 0.9277964498253244, 0.9294738457653463, 0.931349415953381, 0.9312927961003, 0.9318354125617665], 'val_loss': [0.24023044557401857, 0.190073829299944, 0.2697271517084601, 0.18312906565438639, 0.20507680721864505, 0.21465508549643247, 0.18454861141745924], 'val_acc': [0.8964219038663472, 0.9051109731606373, 0.8978923623887584, 0.9164067606069264, 0.9038633074674172, 0.9020809388428425, 0.9157160851112099], 'loss': [0.21434555691532708, 0.18814762933381063, 0.17993671006190382, 0.17722400106947253, 0.1747482218142495, 0.18155813036389334, 0.176274174396016]}
# stopped_epoch1 4
# 7
# 0.9038633074674172
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 277us/step - loss: 0.1592 - acc: 0.9388 - val_loss: 0.1924 - val_acc: 0.9120
#
# Epoch 00001: val_acc improved from -inf to 0.91202, saving model to /mnt/seals/models/230/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1552 - acc: 0.9400 - val_loss: 0.1837 - val_acc: 0.9151
#
# Epoch 00002: val_acc improved from 0.91202 to 0.91507, saving model to /mnt/seals/models/230/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 256us/step - loss: 0.1524 - acc: 0.9410 - val_loss: 0.1933 - val_acc: 0.9124
#
# Epoch 00003: val_acc did not improve from 0.91507
# Epoch 4/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 0.1517 - acc: 0.9418 - val_loss: 0.1934 - val_acc: 0.9117
#
# Epoch 00004: val_acc did not improve from 0.91507
# Epoch 5/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1508 - acc: 0.9417 - val_loss: 0.2110 - val_acc: 0.9077
#
# Epoch 00005: val_acc did not improve from 0.91507
# H2 {'acc': [0.9388115915628381, 0.9400006322040331, 0.9410150912964297, 0.9417511642145571, 0.9416638745317891], 'val_loss': [0.19237363461174967, 0.18367812689103266, 0.1932794314786485, 0.19338102647087682, 0.21099224690340937], 'val_acc': [0.9120176598866583, 0.9150699731415685, 0.9123518594487786, 0.9117280284613278, 0.9076508507086051], 'loss': [0.15924043876664942, 0.15523780094469466, 0.15244352675753753, 0.15169686657410225, 0.15078036327405903]}
# stopped_epoch2 2
# 5
# 0.9123518594487786
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1483 - acc: 0.9426 - val_loss: 0.1878 - val_acc: 0.9150
#
# Epoch 00001: val_acc improved from -inf to 0.91498, saving model to /mnt/seals/models/230/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 264us/step - loss: 0.1490 - acc: 0.9431 - val_loss: 0.1922 - val_acc: 0.9131
#
# Epoch 00002: val_acc did not improve from 0.91498
# Epoch 3/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.1477 - acc: 0.9434 - val_loss: 0.1950 - val_acc: 0.9118
#
# Epoch 00003: val_acc did not improve from 0.91498
# Epoch 4/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.1473 - acc: 0.9432 - val_loss: 0.1917 - val_acc: 0.9135
#
# Epoch 00004: val_acc did not improve from 0.91498
# H3 {'acc': [0.9425627322991754, 0.9430699628671171, 0.9433577845433744, 0.9431784864060856], 'val_loss': [0.18780559825659243, 0.19223845933685432, 0.1949503743696867, 0.19171466927043512], 'val_acc': [0.9149808593266321, 0.9130648086387815, 0.9118394290590316, 0.9135326816748621], 'loss': [0.1482933172024525, 0.14896313806147157, 0.1476611413742412, 0.1472791293573059]}
# stopped_epoch3 1
# 4
# 0.9130648086387815
# best fit round 3 0.9130648086387815
# 3137/3137 [==============================] - 1s 284us/step
# 2019-01-20 15:28:14,880 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:28:13",
#     "fit_dt_test_start": "2019-01-20 15:28:12",
#     "fit_dt_train_duration_seconds": "264",
#     "fit_dt_train_end": "2019-01-20 15:28:10",
#     "fit_dt_train_start": "2019-01-20 15:23:45",
#     "fit_num_epochs": 10,
#     "fit_stopped_epoch1": 4,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.5451067899266815,
#     "fit_train_acc": 0.9430699628671171,
#     "fit_train_loss": 0.14896313806147157,
#     "fit_val_acc": 0.9130648086387815,
#     "fit_val_loss": 0.19223845933685432,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 256,
#     "layer_3_size": 128,
#     "model_id": 230,
#     "model_param_count": 656775,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/230/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:28:14,881 [MainThread  ] [INFO ]  model 230 test acc: 0.5451067899266815
# 2019-01-20 15:28:17,041 [MainThread  ] [INFO ]  Begin experiment for model_id=238 on GPU:6
# 2019-01-20 15:28:17,044 [MainThread  ] [INFO ]  Loading data
# 238   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 128, 'layer_2_size': 0, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 238, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:28:18,209 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:28:18,210 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.2679 - acc: 0.9174 - val_loss: 0.2252 - val_acc: 0.8925
#
# Epoch 00001: val_acc improved from -inf to 0.89255, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1851 - acc: 0.9272 - val_loss: 0.2009 - val_acc: 0.9006
#
# Epoch 00002: val_acc improved from 0.89255 to 0.90059, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 207us/step - loss: 0.1776 - acc: 0.9288 - val_loss: 0.1939 - val_acc: 0.9058
#
# Epoch 00003: val_acc improved from 0.90059 to 0.90585, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 12s 202us/step - loss: 0.1729 - acc: 0.9294 - val_loss: 0.2111 - val_acc: 0.9044
#
# Epoch 00004: val_acc did not improve from 0.90585
# Epoch 5/20
# 60553/60553 [==============================] - 12s 199us/step - loss: 0.1689 - acc: 0.9301 - val_loss: 0.1920 - val_acc: 0.9106
#
# Epoch 00005: val_acc improved from 0.90585 to 0.91061, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 12s 205us/step - loss: 0.1673 - acc: 0.9299 - val_loss: 0.1901 - val_acc: 0.9131
#
# Epoch 00006: val_acc improved from 0.91061 to 0.91311, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 12s 198us/step - loss: 0.1648 - acc: 0.9305 - val_loss: 0.1863 - val_acc: 0.9142
#
# Epoch 00007: val_acc improved from 0.91311 to 0.91416, saving model to /mnt/seals/models/238/model_round_1.h5
# Epoch 8/20
# 60553/60553 [==============================] - 12s 205us/step - loss: 0.1635 - acc: 0.9310 - val_loss: 0.1985 - val_acc: 0.9064
#
# Epoch 00008: val_acc did not improve from 0.91416
# Epoch 9/20
# 60553/60553 [==============================] - 12s 205us/step - loss: 0.1629 - acc: 0.9315 - val_loss: 0.2192 - val_acc: 0.8968
#
# Epoch 00009: val_acc did not improve from 0.91416
# Epoch 10/20
# 60553/60553 [==============================] - 12s 202us/step - loss: 0.1623 - acc: 0.9314 - val_loss: 0.2251 - val_acc: 0.8962
#
# Epoch 00010: val_acc did not improve from 0.91416
# H1 {'acc': [0.9173805478121065, 0.9271618242655797, 0.9287613669875048, 0.9293959949903775, 0.930134426595009, 0.9299008658146355, 0.9304977450707748, 0.9309507115476698, 0.931488609696085, 0.9313848039927637], 'val_loss': [0.22519351409995697, 0.20088358982904805, 0.19387148275125496, 0.2110553176159124, 0.19204663462513918, 0.19011833902195105, 0.18628300435455308, 0.1984615379657436, 0.2192149360153501, 0.22513631578355897], 'val_acc': [0.8925452464012079, 0.9005881966610514, 0.9058462051548068, 0.9044425821795139, 0.9106140478432215, 0.9131093700082319, 0.9141565100966731, 0.9064254694927951, 0.8968006563201518, 0.8962213884125779], 'loss': [0.2678674676942051, 0.1850733117843807, 0.17758426891668344, 0.1729313909068418, 0.1688709300710092, 0.16734363763558333, 0.1648363405218322, 0.16346918160829974, 0.16292926217752401, 0.16234622504726093]}
# stopped_epoch1 7
# 10
# 0.9064254694927951
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 247us/step - loss: 0.1535 - acc: 0.9353 - val_loss: 0.1974 - val_acc: 0.9070
#
# Epoch 00001: val_acc improved from -inf to 0.90696, saving model to /mnt/seals/models/238/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 212us/step - loss: 0.1528 - acc: 0.9360 - val_loss: 0.1793 - val_acc: 0.9194
#
# Epoch 00002: val_acc improved from 0.90696 to 0.91939, saving model to /mnt/seals/models/238/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 13s 209us/step - loss: 0.1516 - acc: 0.9361 - val_loss: 0.1933 - val_acc: 0.9103
#
# Epoch 00003: val_acc did not improve from 0.91939
# Epoch 4/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1517 - acc: 0.9361 - val_loss: 0.1894 - val_acc: 0.9153
#
# Epoch 00004: val_acc did not improve from 0.91939
# Epoch 5/20
# 60553/60553 [==============================] - 13s 212us/step - loss: 0.1511 - acc: 0.9363 - val_loss: 0.1843 - val_acc: 0.9168
#
# Epoch 00005: val_acc did not improve from 0.91939
# H2 {'acc': [0.9353388357014432, 0.9359994142149575, 0.9361480448702066, 0.9361386067410191, 0.9362895975287655], 'val_loss': [0.1974221827579675, 0.17927078570861482, 0.19325074344799062, 0.18937052168179808, 0.18428560739577152], 'val_acc': [0.906960183356006, 0.9193922296882197, 0.9103021317173821, 0.915315052753527, 0.9168300685180549], 'loss': [0.15354881088062808, 0.15275197991265207, 0.1516296061970984, 0.15172682277356367, 0.1511137635044844]}
# stopped_epoch2 2
# 5
# 0.9103021317173821
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 0.1488 - acc: 0.9373 - val_loss: 0.1850 - val_acc: 0.9170
#
# Epoch 00001: val_acc improved from -inf to 0.91701, saving model to /mnt/seals/models/238/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1489 - acc: 0.9372 - val_loss: 0.1879 - val_acc: 0.9153
#
# Epoch 00002: val_acc did not improve from 0.91701
# Epoch 3/20
# 60553/60553 [==============================] - 13s 211us/step - loss: 0.1498 - acc: 0.9368 - val_loss: 0.1869 - val_acc: 0.9160
#
# Epoch 00003: val_acc did not improve from 0.91701
# Epoch 4/20
# 60553/60553 [==============================] - 13s 209us/step - loss: 0.1492 - acc: 0.9371 - val_loss: 0.1834 - val_acc: 0.9184
#
# Epoch 00004: val_acc improved from 0.91701 to 0.91841, saving model to /mnt/seals/models/238/model_round_3.h5
# Epoch 5/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1484 - acc: 0.9374 - val_loss: 0.1871 - val_acc: 0.9161
#
# Epoch 00005: val_acc did not improve from 0.91841
# Epoch 6/20
# 60553/60553 [==============================] - 13s 207us/step - loss: 0.1498 - acc: 0.9368 - val_loss: 0.1833 - val_acc: 0.9180
#
# Epoch 00006: val_acc did not improve from 0.91841
# Epoch 7/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.1498 - acc: 0.9369 - val_loss: 0.1860 - val_acc: 0.9156
#
# Epoch 00007: val_acc did not improve from 0.91841
# H3 {'acc': [0.9372710285144559, 0.9371978922953187, 0.9368487282409449, 0.937058698620534, 0.937419657159686, 0.9368416509490409, 0.9368959129887261], 'val_loss': [0.18500250733166432, 0.1879196804451407, 0.18694689581246207, 0.18342372166667964, 0.18705803026687481, 0.18331192463115834, 0.18603840608356598], 'val_acc': [0.9170083068566849, 0.9152704927226714, 0.9159834419126742, 0.9184119232877374, 0.9160725610819892, 0.9180108898517421, 0.915604689533236], 'loss': [0.14883347573985986, 0.1489363960836742, 0.14978984016336647, 0.14919764224631252, 0.1484442616244137, 0.14983808749045294, 0.1498297060869562]}
# stopped_epoch3 4
# 7
# 0.9160725610819892
# best fit round 3 0.9160725610819892
# 3137/3137 [==============================] - 1s 238us/step
# 2019-01-20 15:33:21,812 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:33:20",
#     "fit_dt_test_start": "2019-01-20 15:33:19",
#     "fit_dt_train_duration_seconds": "296",
#     "fit_dt_train_end": "2019-01-20 15:33:18",
#     "fit_dt_train_start": "2019-01-20 15:28:21",
#     "fit_num_epochs": 16,
#     "fit_stopped_epoch1": 7,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 4,
#     "fit_test_acc": 0.5441504622250558,
#     "fit_train_acc": 0.937419657159686,
#     "fit_train_loss": 0.1484442616244137,
#     "fit_val_acc": 0.9160725610819892,
#     "fit_val_loss": 0.18705803026687481,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 0,
#     "layer_3_size": 128,
#     "model_id": 238,
#     "model_param_count": 590855,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/238/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:33:21,813 [MainThread  ] [INFO ]  model 238 test acc: 0.5441504622250558
# 2019-01-20 15:33:23,973 [MainThread  ] [INFO ]  Begin experiment for model_id=246 on GPU:6
# 2019-01-20 15:33:23,977 [MainThread  ] [INFO ]  Loading data
# 246   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'inception_resnet_v2', 'pooling': 'max', 'layer_1_size': 0, 'layer_2_size': 256, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 246, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 15:33:25,121 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:33:25,123 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 13s 210us/step - loss: 0.7587 - acc: 0.9032 - val_loss: 1.3422 - val_acc: 0.8368
#
# Epoch 00001: val_acc improved from -inf to 0.83682, saving model to /mnt/seals/models/246/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 10s 173us/step - loss: 0.7540 - acc: 0.9085 - val_loss: 1.1705 - val_acc: 0.8711
#
# Epoch 00002: val_acc improved from 0.83682 to 0.87111, saving model to /mnt/seals/models/246/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 10s 167us/step - loss: 0.6894 - acc: 0.9152 - val_loss: 1.0913 - val_acc: 0.8692
#
# Epoch 00003: val_acc did not improve from 0.87111
# Epoch 4/20
# 60553/60553 [==============================] - 10s 169us/step - loss: 0.6700 - acc: 0.9209 - val_loss: 1.1583 - val_acc: 0.8907
#
# Epoch 00004: val_acc improved from 0.87111 to 0.89072, saving model to /mnt/seals/models/246/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 10s 169us/step - loss: 0.6973 - acc: 0.9204 - val_loss: 1.2798 - val_acc: 0.8632
#
# Epoch 00005: val_acc did not improve from 0.89072
# Epoch 6/20
# ...
# Epoch 1/20
# 60553/60553 [==============================] - 14s 239us/step - loss: 0.5482 - acc: 0.9507 - val_loss: 1.6357 - val_acc: 0.8814
#
# Epoch 00001: val_acc improved from -inf to 0.88143, saving model to /mnt/seals/models/310/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 11s 184us/step - loss: 0.5453 - acc: 0.9509 - val_loss: 1.6340 - val_acc: 0.8812
#
# Epoch 00002: val_acc did not improve from 0.88143
# Epoch 3/20
# 60553/60553 [==============================] - 11s 178us/step - loss: 0.5438 - acc: 0.9509 - val_loss: 1.6276 - val_acc: 0.8822
#
# Epoch 00003: val_acc improved from 0.88143 to 0.88216, saving model to /mnt/seals/models/310/model_round_3.h5
# Epoch 4/20
# 60553/60553 [==============================] - 11s 174us/step - loss: 0.5426 - acc: 0.9509 - val_loss: 1.6253 - val_acc: 0.8819
#
# Epoch 00004: val_acc did not improve from 0.88216
# Epoch 5/20
# 60553/60553 [==============================] - 11s 177us/step - loss: 0.5412 - acc: 0.9510 - val_loss: 1.6054 - val_acc: 0.8830
#
# Epoch 00005: val_acc improved from 0.88216 to 0.88303, saving model to /mnt/seals/models/310/model_round_3.h5
# Epoch 6/20
# 60553/60553 [==============================] - 11s 177us/step - loss: 0.5400 - acc: 0.9509 - val_loss: 1.6300 - val_acc: 0.8812
#
# Epoch 00006: val_acc did not improve from 0.88303
# Epoch 7/20
# 60553/60553 [==============================] - 11s 178us/step - loss: 0.5393 - acc: 0.9509 - val_loss: 1.6263 - val_acc: 0.8822
#
# Epoch 00007: val_acc did not improve from 0.88303
# Epoch 8/20
# 60553/60553 [==============================] - 11s 175us/step - loss: 0.5383 - acc: 0.9510 - val_loss: 1.6180 - val_acc: 0.8824
#
# Epoch 00008: val_acc did not improve from 0.88303
# H3 {'acc': [0.9507444663860697, 0.9508978148346394, 0.9509119703899892, 0.9508577085983574, 0.9509567948674659, 0.9509025346684936, 0.9509261262160321, 0.9509685925070486], 'val_loss': [1.6356543232631624, 1.6339865412774566, 1.6276336704576604, 1.6253056971638633, 1.6054198160367836, 1.6300467524912234, 1.6263040844827463, 1.6180276698197562], 'val_acc': [0.881427696772984, 0.8812049019730842, 0.8821629282094059, 0.8819178499732252, 0.8830318340865508, 0.8812271800549865, 0.8821629264246131, 0.882408002876001], 'loss': [0.5481600804345494, 0.545313614358814, 0.5437757172003905, 0.5426107751442235, 0.5411812688695715, 0.5400182497629731, 0.5393063113772077, 0.5382991810704033]}
# stopped_epoch3 5
# 8
# 0.8812271800549865
# best fit round 3 0.8812271800549865
# 3137/3137 [==============================] - 2s 679us/step
# 2019-01-20 16:16:21,687 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "2",
#     "fit_dt_test_end": "2019-01-20 16:16:19",
#     "fit_dt_test_start": "2019-01-20 16:16:17",
#     "fit_dt_train_duration_seconds": "230",
#     "fit_dt_train_end": "2019-01-20 16:16:14",
#     "fit_dt_train_start": "2019-01-20 16:12:24",
#     "fit_num_epochs": 12,
#     "fit_stopped_epoch1": 2,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 5,
#     "fit_test_acc": 0.590372967803634,
#     "fit_train_acc": 0.9509025346684936,
#     "fit_train_loss": 0.5400182497629731,
#     "fit_val_acc": 0.8812271800549865,
#     "fit_val_loss": 1.6300467524912234,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 0,
#     "layer_2_size": 256,
#     "layer_3_size": 128,
#     "model_id": 310,
#     "model_param_count": 10759,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/310/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:16:21,689 [MainThread  ] [INFO ]  model 310 test acc: 0.590372967803634
# 2019-01-20 16:16:24,074 [MainThread  ] [INFO ]  Begin experiment for model_id=318 on GPU:6
# 2019-01-20 16:16:24,077 [MainThread  ] [INFO ]  Loading data
# 318   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'vgg16', 'pooling': 'max', 'layer_1_size': 0, 'layer_2_size': 0, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 318, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 16:16:25,214 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/vgg16/max/
# 2019-01-20 16:16:25,221 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.8270 - acc: 0.9228 - val_loss: 1.5545 - val_acc: 0.8821
#
# Epoch 00001: val_acc improved from -inf to 0.88207, saving model to /mnt/seals/models/318/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 11s 180us/step - loss: 0.6979 - acc: 0.9355 - val_loss: 1.7620 - val_acc: 0.8772
#
# Epoch 00002: val_acc did not improve from 0.88207
# Epoch 3/20
# 60553/60553 [==============================] - 11s 177us/step - loss: 0.6904 - acc: 0.9378 - val_loss: 1.6661 - val_acc: 0.8798
#
# Epoch 00003: val_acc did not improve from 0.88207
# Epoch 4/20
# 60553/60553 [==============================] - 11s 178us/step - loss: 0.6837 - acc: 0.9399 - val_loss: 1.6552 - val_acc: 0.8829
#
# Epoch 00004: val_acc improved from 0.88207 to 0.88292, saving model to /mnt/seals/models/318/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 11s 181us/step - loss: 0.6836 - acc: 0.9404 - val_loss: 1.5621 - val_acc: 0.8907
#
# Epoch 00005: val_acc improved from 0.88292 to 0.89072, saving model to /mnt/seals/models/318/model_round_1.h5
# Epoch 6/20
# 60553/60553 [==============================] - 11s 173us/step - loss: 0.6742 - acc: 0.9415 - val_loss: 1.5798 - val_acc: 0.8858
#
# Epoch 00006: val_acc did not improve from 0.89072
# Epoch 7/20
# 60553/60553 [==============================] - 11s 174us/step - loss: 0.6796 - acc: 0.9417 - val_loss: 1.7155 - val_acc: 0.8792
#
# Epoch 00007: val_acc did not improve from 0.89072
# Epoch 8/20
# 60553/60553 [==============================] - 11s 174us/step - loss: 0.6650 - acc: 0.9435 - val_loss: 1.5907 - val_acc: 0.8876
#
# Epoch 00008: val_acc did not improve from 0.89072
# H1 {'acc': [0.9228232388606409, 0.935518139117739, 0.9377900574641714, 0.9398897514412874, 0.9403875454500613, 0.9414963721343099, 0.9417157799865328, 0.9434663118257819], 'val_loss': [1.554534502201949, 1.7620056850495223, 1.6660733855819225, 1.655230168915509, 1.5621177628868754, 1.579834625413101, 1.7155091049369247, 1.5906975848631641], 'val_acc': [0.8820738081848778, 0.8771945599162125, 0.8798012820096293, 0.8829204371699823, 0.8907183146595732, 0.8857945123093618, 0.8791551742045045, 0.8875546033354157], 'loss': [0.8270317076447637, 0.6979432933497244, 0.6903668507622812, 0.6836593447585106, 0.6836328708239418, 0.6742104330169746, 0.6796165591184888, 0.664952110329651]}
# stopped_epoch1 5
# 8
# 0.8857945123093618
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 247us/step - loss: 0.5970 - acc: 0.9495 - val_loss: 1.6731 - val_acc: 0.8823
#
# Epoch 00001: val_acc improved from -inf to 0.88225, saving model to /mnt/seals/models/318/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 11s 178us/step - loss: 0.5860 - acc: 0.9503 - val_loss: 1.6309 - val_acc: 0.8834
#
# Epoch 00002: val_acc improved from 0.88225 to 0.88341, saving model to /mnt/seals/models/318/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 11s 175us/step - loss: 0.5758 - acc: 0.9506 - val_loss: 1.6628 - val_acc: 0.8810
#
# Epoch 00003: val_acc did not improve from 0.88341
# Epoch 4/20
# 60553/60553 [==============================] - 11s 176us/step - loss: 0.5721 - acc: 0.9508 - val_loss: 1.6332 - val_acc: 0.8845
#
# Epoch 00004: val_acc improved from 0.88341 to 0.88455, saving model to /mnt/seals/models/318/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 11s 176us/step - loss: 0.5669 - acc: 0.9511 - val_loss: 1.7152 - val_acc: 0.8772
#
# Epoch 00005: val_acc did not improve from 0.88455
# Epoch 6/20
# 60553/60553 [==============================] - 11s 177us/step - loss: 0.5613 - acc: 0.9513 - val_loss: 1.6444 - val_acc: 0.8827
#
# Epoch 00006: val_acc did not improve from 0.88455
# Epoch 7/20
# 60553/60553 [==============================] - 11s 175us/step - loss: 0.5574 - acc: 0.9514 - val_loss: 1.6519 - val_acc: 0.8817
#
# Epoch 00007: val_acc did not improve from 0.88455
# H2 {'acc': [0.9495129594774823, 0.9503245279263058, 0.9505887595128298, 0.9507987288037407, 0.9511408139371306, 0.9512776469685463, 0.9513932481587023], 'val_loss': [1.6731240884705922, 1.63089978300774, 1.662815251279011, 1.6331856975091374, 1.7152446688374205, 1.6444204012751207, 1.651912323177716], 'val_acc': [0.8822520450361803, 0.8834105868006378, 0.8810043864821316, 0.8845468486984001, 0.8772391208394646, 0.8826976364207729, 0.8817396122667095], 'loss': [0.5970368824276798, 0.5859956300077948, 0.5758152650417058, 0.572136666329237, 0.5668742692979404, 0.5612889558288245, 0.5573920087824378]}
# stopped_epoch2 4
# 7
# 0.8772391208394646
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 15s 250us/step - loss: 0.5456 - acc: 0.9525 - val_loss: 1.6725 - val_acc: 0.8804
#
# Epoch 00001: val_acc improved from -inf to 0.88038, saving model to /mnt/seals/models/318/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 11s 179us/step - loss: 0.5438 - acc: 0.9526 - val_loss: 1.6735 - val_acc: 0.8817
#
# Epoch 00002: val_acc improved from 0.88038 to 0.88165, saving model to /mnt/seals/models/318/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 11s 183us/step - loss: 0.5426 - acc: 0.9525 - val_loss: 1.6633 - val_acc: 0.8809
#
# Epoch 00003: val_acc did not improve from 0.88165
# Epoch 4/20
# 60553/60553 [==============================] - 11s 180us/step - loss: 0.5416 - acc: 0.9526 - val_loss: 1.6710 - val_acc: 0.8817
#
# Epoch 00004: val_acc did not improve from 0.88165
# Epoch 5/20
# 60553/60553 [==============================] - 11s 177us/step - loss: 0.5409 - acc: 0.9526 - val_loss: 1.6648 - val_acc: 0.8811
#
# Epoch 00005: val_acc did not improve from 0.88165
# H3 {'acc': [0.9524643295256524, 0.9525775710036236, 0.9525303861308314, 0.9525893665731426, 0.9525917265914566], 'val_loss': [1.6724885284194184, 1.6735421555977796, 1.6633493264466617, 1.6709861387257567, 1.6648187429846932], 'val_acc': [0.8803805540817199, 0.8816504945847219, 0.8809152646356274, 0.881650493989791, 0.8810712231075623], 'loss': [0.5456470495113175, 0.5437563716016366, 0.5426410594764217, 0.5416482255051481, 0.540885409366009]}
# stopped_epoch3 2
# 5
# 0.8809152646356274
# best fit round 1 0.8857945123093618
# 3137/3137 [==============================] - 2s 532us/step
# 2019-01-20 16:20:46,339 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "1",
#     "fit_dt_test_end": "2019-01-20 16:20:44",
#     "fit_dt_test_start": "2019-01-20 16:20:43",
#     "fit_dt_train_duration_seconds": "254",
#     "fit_dt_train_end": "2019-01-20 16:20:40",
#     "fit_dt_train_start": "2019-01-20 16:16:26",
#     "fit_num_epochs": 14,
#     "fit_stopped_epoch1": 5,
#     "fit_stopped_epoch2": 4,
#     "fit_stopped_epoch3": 2,
#     "fit_test_acc": 0.5932419509085114,
#     "fit_train_acc": 0.9414963721343099,
#     "fit_train_loss": 0.6742104330169746,
#     "fit_val_acc": 0.8857945123093618,
#     "fit_val_loss": 1.579834625413101,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 0,
#     "layer_2_size": 0,
#     "layer_3_size": 128,
#     "model_id": 318,
#     "model_param_count": 10759,
#     "model_weights_path": null,
#     "num_features": 512,
#     "path_model": "/mnt/seals/models/318/",
#     "pooling": "max",
#     "pretrained_model_name": "vgg16",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 16:20:46,340 [MainThread  ] [INFO ]  model 318 test acc: 0.5932419509085114
# 2019-01-20 16:20:48,651 [MainThread  ] [INFO ]  Begin experiment for model_id=326 on GPU:6
# 2019-01-20 16:20:48,655 [MainThread  ] [INFO ]  Loading data
# 326   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'resnet50', 'pooling': 'max', 'layer_1_size': 512, 'layer_2_size': 256, 'sequence_model_layers': nan, 'sequence_model': nan, 'architecture': 'video_MLP_concat', 'WORKER': 6, 'sequence_length': 3, 'model_id': 326, 'dropout': 0.2, 'layer_3_size': 128}
# 2019-01-20 16:20:49,765 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/resnet50/max/
# 2019-01-20 16:20:49,772 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 29s 483us/step - loss: 0.6903 - acc: 0.9032 - val_loss: 0.1752 - val_acc: 0.9193
#
# Epoch 00001: val_acc improved from -inf to 0.91926, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 23s 386us/step - loss: 0.1421 - acc: 0.9441 - val_loss: 0.1606 - val_acc: 0.9312
#
# Epoch 00002: val_acc improved from 0.91926 to 0.93122, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 23s 381us/step - loss: 0.1167 - acc: 0.9545 - val_loss: 0.1841 - val_acc: 0.9166
#
# Epoch 00003: val_acc did not improve from 0.93122
# Epoch 4/20
# 60553/60553 [==============================] - 24s 397us/step - loss: 0.1053 - acc: 0.9589 - val_loss: 0.1475 - val_acc: 0.9371
#
# Epoch 00004: val_acc improved from 0.93122 to 0.93710, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 23s 378us/step - loss: 0.0987 - acc: 0.9610 - val_loss: 0.1640 - val_acc: 0.9337
#
# Epoch 00005: val_acc did not improve from 0.93710
# Epoch 6/20
# 60553/60553 [==============================] - 23s 383us/step - loss: 0.0939 - acc: 0.9631 - val_loss: 0.1660 - val_acc: 0.9402
#
# Epoch 00006: val_acc improved from 0.93710 to 0.94025, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 23s 380us/step - loss: 0.0905 - acc: 0.9640 - val_loss: 0.1562 - val_acc: 0.9373
#
# Epoch 00007: val_acc did not improve from 0.94025
# Epoch 8/20
# 60553/60553 [==============================] - 23s 383us/step - loss: 0.0870 - acc: 0.9656 - val_loss: 0.1527 - val_acc: 0.9421
#
# Epoch 00008: val_acc improved from 0.94025 to 0.94214, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 9/20
# 60553/60553 [==============================] - 23s 376us/step - loss: 0.0845 - acc: 0.9663 - val_loss: 0.2294 - val_acc: 0.9234
#
# Epoch 00009: val_acc did not improve from 0.94214
# Epoch 10/20
# 60553/60553 [==============================] - 23s 382us/step - loss: 0.0825 - acc: 0.9674 - val_loss: 0.1448 - val_acc: 0.9446
#
# Epoch 00010: val_acc improved from 0.94214 to 0.94461, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 11/20
# 60553/60553 [==============================] - 23s 381us/step - loss: 0.0799 - acc: 0.9688 - val_loss: 0.1562 - val_acc: 0.9462
#
# Epoch 00011: val_acc improved from 0.94461 to 0.94617, saving model to /mnt/seals/models/326/model_round_1.h5
# Epoch 12/20
# 34368/60553 [================>.............] - ETA: 9s - loss: 0.0766 - acc: 0.9692
