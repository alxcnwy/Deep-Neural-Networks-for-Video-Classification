# %%
WORKER_ID = 3

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.architectures import Architecture
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run experiments

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
print(experiments.shape)
# Out:
# (5376, 12)

# %%
###################
### Run experiments
###################

for row in experiments.values:
    
    # get experiment params from dataframe row
    experiment = dict(zip(experiments.columns, row))
    
    # only run experiment if not already run
    if not os.path.exists(pwd + 'models/' + str(experiment["model_id"]) + '/results.json'):

        # only run experiment if matches this worker id
        if experiment['WORKER'] == WORKER_ID:
            
            print(str(experiment["model_id"]) + "   " + "X"*60)
            logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
            print(experiment)

            architecture = Architecture(model_id = experiment['model_id'], 
                                        architecture = experiment['architecture'], 
                                        sequence_length = experiment['sequence_length'], 
                                        pretrained_model_name = experiment['pretrained_model_name'],
                                        pooling = experiment['pooling'],
                                        sequence_model = experiment['sequence_model'],
                                        sequence_model_layers = experiment['sequence_model_layers'],
                                        layer_1_size = experiment['layer_1_size'],
                                        layer_2_size = experiment['layer_2_size'],
                                        layer_3_size = experiment['layer_3_size'],
                                        dropout = experiment['dropout'],
                                        verbose=True)

            architecture.train_model()
            
            gc.collect()
# Out:
# 2019-01-20 15:05:19,488 [MainThread  ] [INFO ]  Begin experiment for model_id=195 on GPU:3
# 2019-01-20 15:05:19,489 [MainThread  ] [INFO ]  Model folder exists but no results found - potential error in previous model training
# 2019-01-20 15:05:19,490 [MainThread  ] [INFO ]  Loading data
# 195   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 512, 'sequence_model': nan, 'layer_1_size': 512, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 195, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:05:20,436 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:05:20,437 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 27s 448us/step - loss: 4.2122 - acc: 0.7370 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00001: val_acc improved from -inf to 0.72360, saving model to /mnt/seals/models/195/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 271us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00002: val_acc did not improve from 0.72360
# Epoch 3/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00003: val_acc did not improve from 0.72360
# Epoch 4/20
# 60553/60553 [==============================] - 16s 270us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00004: val_acc did not improve from 0.72360
# H1 {'loss': [4.212159820298539, 4.22041256158883, 4.220412566085288, 4.220412560974603], 'val_loss': [4.430780214736853, 4.430780214736853, 4.430780214736853, 4.430780214736853], 'val_acc': [0.7235986128570285, 0.7235986128570285, 0.7235986128570285, 0.7235986128570285], 'acc': [0.7369624300030456, 0.7367217910438794, 0.7367217903784665, 0.7367217914041472]}
# stopped_epoch1 1
# 4
# 0.7235986128570285
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00001: val_acc improved from -inf to 0.72360, saving model to /mnt/seals/models/195/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00002: val_acc did not improve from 0.72360
# Epoch 3/20
# 60553/60553 [==============================] - 16s 267us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00003: val_acc did not improve from 0.72360
# Epoch 4/20
# 60553/60553 [==============================] - 16s 269us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00004: val_acc did not improve from 0.72360
# H2 {'loss': [4.220412563045651, 4.220412566518397, 4.220412567022378, 4.220412564825335], 'val_loss': [4.430780214736853, 4.430780214736853, 4.430780214736853, 4.430780214736853], 'val_acc': [0.7235986128570285, 0.7235986128570285, 0.7235986128570285, 0.7235986128570285], 'acc': [0.7367217910123804, 0.7367217909946624, 0.7367217897662081, 0.7367217917014174]}
# stopped_epoch2 1
# 4
# 0.7235986128570285
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 18s 295us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00001: val_acc improved from -inf to 0.72360, saving model to /mnt/seals/models/195/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00002: val_acc did not improve from 0.72360
# Epoch 3/20
# 60553/60553 [==============================] - 17s 273us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00003: val_acc did not improve from 0.72360
# Epoch 4/20
# 60553/60553 [==============================] - 16s 272us/step - loss: 4.2204 - acc: 0.7367 - val_loss: 4.4308 - val_acc: 0.7236
#
# Epoch 00004: val_acc did not improve from 0.72360
# H3 {'loss': [4.220412560722612, 4.220412563061401, 4.220412564754462, 4.220412567597232], 'val_loss': [4.430780214736853, 4.430780214736853, 4.430780214736853, 4.430780214736853], 'val_acc': [0.7235986128570285, 0.7235986128570285, 0.7235986128570285, 0.7235986128570285], 'acc': [0.7367217921601191, 0.7367217917644151, 0.7367217905536788, 0.7367217910084431]}
# stopped_epoch3 1
# 4
# 0.7235986128570285
# best fit round 1 0.7235986128570285
# 3137/3137 [==============================] - 0s 114us/step
# 2019-01-20 15:09:00,541 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:08:58",
#     "fit_dt_test_start": "2019-01-20 15:08:58",
#     "fit_dt_train_duration_seconds": "214",
#     "fit_dt_train_end": "2019-01-20 15:08:57",
#     "fit_dt_train_start": "2019-01-20 15:05:23",
#     "fit_num_epochs": 6,
#     "fit_stopped_epoch1": 1,
#     "fit_stopped_epoch2": 1,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.11794708320051006,
#     "fit_train_acc": 0.7367217910438794,
#     "fit_train_loss": 4.22041256158883,
#     "fit_val_acc": 0.7235986128570285,
#     "fit_val_loss": 4.430780214736853,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 512,
#     "layer_3_size": 0,
#     "model_id": 195,
#     "model_param_count": 2626055,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/195/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:09:00,544 [MainThread  ] [INFO ]  model 195 test acc: 0.11794708320051006
# 2019-01-20 15:09:03,358 [MainThread  ] [INFO ]  Begin experiment for model_id=203 on GPU:3
# 2019-01-20 15:09:03,361 [MainThread  ] [INFO ]  Loading data
# 203   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 128, 'sequence_model': nan, 'layer_1_size': 512, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 203, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:09:04,544 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:09:04,547 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 310us/step - loss: 1.8159 - acc: 0.8673 - val_loss: 0.2852 - val_acc: 0.8956
#
# Epoch 00001: val_acc improved from -inf to 0.89555, saving model to /mnt/seals/models/203/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 293us/step - loss: 0.1989 - acc: 0.9220 - val_loss: 0.2254 - val_acc: 0.9059
#
# Epoch 00002: val_acc improved from 0.89555 to 0.90594, saving model to /mnt/seals/models/203/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.1703 - acc: 0.9307 - val_loss: 0.2049 - val_acc: 0.9000
#
# Epoch 00003: val_acc did not improve from 0.90594
# Epoch 4/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.1584 - acc: 0.9342 - val_loss: 0.1970 - val_acc: 0.9054
#
# Epoch 00004: val_acc did not improve from 0.90594
# Epoch 5/20
# 60553/60553 [==============================] - 17s 278us/step - loss: 0.1538 - acc: 0.9366 - val_loss: 0.2389 - val_acc: 0.8963
#
# Epoch 00005: val_acc did not improve from 0.90594
# H1 {'loss': [1.8159246559025675, 0.19889709713690215, 0.170300129238424, 0.1584465566402675, 0.15375541910983656], 'val_loss': [0.2852161432234704, 0.22536646345594266, 0.20489545479760793, 0.19699724153362805, 0.23888744974389198], 'val_acc': [0.8955530010754067, 0.9059353261460978, 0.9000312126359564, 0.9054006093454152, 0.8963327877832367], 'acc': [0.867320495047656, 0.9220234701706806, 0.9307265885283413, 0.9341922636093369, 0.93663404314803]}
# stopped_epoch1 2
# 5
# 0.9000312126359564
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 308us/step - loss: 0.1338 - acc: 0.9438 - val_loss: 0.1948 - val_acc: 0.9177
#
# Epoch 00001: val_acc improved from -inf to 0.91768, saving model to /mnt/seals/models/203/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 298us/step - loss: 0.1313 - acc: 0.9446 - val_loss: 0.2025 - val_acc: 0.9157
#
# Epoch 00002: val_acc did not improve from 0.91768
# Epoch 3/20
# 60553/60553 [==============================] - 17s 289us/step - loss: 0.1295 - acc: 0.9462 - val_loss: 0.1944 - val_acc: 0.9186
#
# Epoch 00003: val_acc improved from 0.91768 to 0.91861, saving model to /mnt/seals/models/203/model_round_2.h5
# Epoch 4/20
# 60553/60553 [==============================] - 18s 296us/step - loss: 0.1289 - acc: 0.9461 - val_loss: 0.1905 - val_acc: 0.9207
#
# Epoch 00004: val_acc improved from 0.91861 to 0.92068, saving model to /mnt/seals/models/203/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1271 - acc: 0.9474 - val_loss: 0.2214 - val_acc: 0.9095
#
# Epoch 00005: val_acc did not improve from 0.92068
# Epoch 6/20
# 60553/60553 [==============================] - 17s 287us/step - loss: 0.1263 - acc: 0.9477 - val_loss: 0.2040 - val_acc: 0.9145
#
# Epoch 00006: val_acc did not improve from 0.92068
# Epoch 7/20
# 60553/60553 [==============================] - 18s 291us/step - loss: 0.1259 - acc: 0.9481 - val_loss: 0.2271 - val_acc: 0.9103
#
# Epoch 00007: val_acc did not improve from 0.92068
# H2 {'loss': [0.13378952690570212, 0.1313047329321283, 0.12950324649995099, 0.12890429149210003, 0.1270555776341803, 0.1262608864664797, 0.1258728028768826], 'val_loss': [0.19476894912538273, 0.20252083796898573, 0.19437382424613944, 0.19053462223938236, 0.22139241904745383, 0.20399888464977647, 0.2270598410072731], 'val_acc': [0.9176766966107631, 0.9157160867844533, 0.9186124420879933, 0.920684446488331, 0.9095446211207456, 0.9144907042300485, 0.9103021303416042], 'acc': [0.9438296266358713, 0.9446270388225901, 0.946153447119827, 0.9461204172127659, 0.9473707973204043, 0.9477081638346135, 0.948106871138217]}
# stopped_epoch2 4
# 7
# 0.9095446211207456
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 19s 311us/step - loss: 0.1231 - acc: 0.9491 - val_loss: 0.2128 - val_acc: 0.9134
#
# Epoch 00001: val_acc improved from -inf to 0.91335, saving model to /mnt/seals/models/203/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 18s 292us/step - loss: 0.1214 - acc: 0.9503 - val_loss: 0.2103 - val_acc: 0.9134
#
# Epoch 00002: val_acc did not improve from 0.91335
# Epoch 3/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.1217 - acc: 0.9499 - val_loss: 0.2118 - val_acc: 0.9133
#
# Epoch 00003: val_acc did not improve from 0.91335
# Epoch 4/20
# 60553/60553 [==============================] - 17s 284us/step - loss: 0.1219 - acc: 0.9501 - val_loss: 0.2076 - val_acc: 0.9140
#
# Epoch 00004: val_acc improved from 0.91335 to 0.91402, saving model to /mnt/seals/models/203/model_round_3.h5
# Epoch 5/20
# 60553/60553 [==============================] - 17s 286us/step - loss: 0.1218 - acc: 0.9501 - val_loss: 0.2059 - val_acc: 0.9143
#
# Epoch 00005: val_acc improved from 0.91402 to 0.91433, saving model to /mnt/seals/models/203/model_round_3.h5
# Epoch 6/20
# 60553/60553 [==============================] - 18s 293us/step - loss: 0.1213 - acc: 0.9503 - val_loss: 0.2050 - val_acc: 0.9151
#
# Epoch 00006: val_acc improved from 0.91433 to 0.91514, saving model to /mnt/seals/models/203/model_round_3.h5
# Epoch 7/20
# 60553/60553 [==============================] - 17s 283us/step - loss: 0.1213 - acc: 0.9503 - val_loss: 0.2180 - val_acc: 0.9120
#
# Epoch 00007: val_acc did not improve from 0.91514
# Epoch 8/20
# 60553/60553 [==============================] - 17s 289us/step - loss: 0.1214 - acc: 0.9504 - val_loss: 0.2094 - val_acc: 0.9141
#
# Epoch 00008: val_acc did not improve from 0.91514
# Epoch 9/20
# 60553/60553 [==============================] - 17s 288us/step - loss: 0.1208 - acc: 0.9506 - val_loss: 0.2116 - val_acc: 0.9132
#
# Epoch 00009: val_acc did not improve from 0.91514
# H3 {'loss': [0.12309192877050029, 0.12139576910782468, 0.1216988107050652, 0.12185277502908815, 0.12182324854207488, 0.12127505300279158, 0.12130598592922169, 0.12142095631532479, 0.12077688197892693], 'val_loss': [0.21280369770504576, 0.21027380962410497, 0.21175072772087936, 0.2075812828518492, 0.2058504112088078, 0.20499319998234863, 0.2179687001410679, 0.20939264556652148, 0.2115799290681733], 'val_acc': [0.9133544432246826, 0.9133544429272171, 0.9133321624655911, 0.9140228323838299, 0.9143347472454412, 0.9151368135225006, 0.9120399397161701, 0.9141119521480758, 0.9132430447836035], 'acc': [0.9491213301321798, 0.9503410400675816, 0.949930536609762, 0.950135788766859, 0.9501310700659783, 0.9502844189407665, 0.9502702639612548, 0.9503953006671796, 0.9506359411235246]}
# stopped_epoch3 6
# 9
# 0.9120399397161701
# best fit round 3 0.9120399397161701
# 3137/3137 [==============================] - 0s 128us/step
# 2019-01-20 15:15:27,258 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:15:25",
#     "fit_dt_test_start": "2019-01-20 15:15:25",
#     "fit_dt_train_duration_seconds": "376",
#     "fit_dt_train_end": "2019-01-20 15:15:24",
#     "fit_dt_train_start": "2019-01-20 15:09:07",
#     "fit_num_epochs": 15,
#     "fit_stopped_epoch1": 2,
#     "fit_stopped_epoch2": 4,
#     "fit_stopped_epoch3": 6,
#     "fit_test_acc": 0.5913292955052598,
#     "fit_train_acc": 0.9502702639612548,
#     "fit_train_loss": 0.12130598592922169,
#     "fit_val_acc": 0.9120399397161701,
#     "fit_val_loss": 0.2179687001410679,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 512,
#     "layer_2_size": 128,
#     "layer_3_size": 0,
#     "model_id": 203,
#     "model_param_count": 2426375,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/203/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:15:27,260 [MainThread  ] [INFO ]  model 203 test acc: 0.5913292955052598
# 2019-01-20 15:15:30,770 [MainThread  ] [INFO ]  Begin experiment for model_id=211 on GPU:3
# 2019-01-20 15:15:30,773 [MainThread  ] [INFO ]  Loading data
# 211   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 512, 'sequence_model': nan, 'layer_1_size': 256, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 211, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:15:31,891 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:15:31,892 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 263us/step - loss: 0.3561 - acc: 0.9032 - val_loss: 0.2443 - val_acc: 0.9112
#
# Epoch 00001: val_acc improved from -inf to 0.91122, saving model to /mnt/seals/models/211/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 239us/step - loss: 0.2152 - acc: 0.9135 - val_loss: 0.2197 - val_acc: 0.9137
#
# Epoch 00002: val_acc improved from 0.91122 to 0.91369, saving model to /mnt/seals/models/211/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.2122 - acc: 0.9145 - val_loss: 0.2432 - val_acc: 0.9111
#
# Epoch 00003: val_acc did not improve from 0.91369
# Epoch 4/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.2099 - acc: 0.9150 - val_loss: 0.2187 - val_acc: 0.9143
#
# Epoch 00004: val_acc improved from 0.91369 to 0.91433, saving model to /mnt/seals/models/211/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.2108 - acc: 0.9147 - val_loss: 0.2370 - val_acc: 0.9131
#
# Epoch 00005: val_acc did not improve from 0.91433
# Epoch 6/20
# 60553/60553 [==============================] - 14s 238us/step - loss: 0.2105 - acc: 0.9150 - val_loss: 0.2204 - val_acc: 0.9151
#
# Epoch 00006: val_acc improved from 0.91433 to 0.91514, saving model to /mnt/seals/models/211/model_round_1.h5
# Epoch 7/20
# 60553/60553 [==============================] - 15s 242us/step - loss: 0.2094 - acc: 0.9150 - val_loss: 0.2413 - val_acc: 0.9120
#
# Epoch 00007: val_acc did not improve from 0.91514
# Epoch 8/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 0.2070 - acc: 0.9158 - val_loss: 0.2262 - val_acc: 0.9129
#
# Epoch 00008: val_acc did not improve from 0.91514
# Epoch 9/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.2094 - acc: 0.9150 - val_loss: 0.2237 - val_acc: 0.9129
#
# Epoch 00009: val_acc did not improve from 0.91514
# H1 {'loss': [0.3561396125900364, 0.21518645189081023, 0.21218417022420502, 0.2099050957807185, 0.21077988660620212, 0.21048127328521887, 0.20943991300443646, 0.2069820172177545, 0.20941492046696317], 'val_loss': [0.24433422419553388, 0.2197271904031411, 0.2432289455488036, 0.21868589413552753, 0.2369829033381182, 0.22043894560390612, 0.2413057299401711, 0.22616073699274142, 0.22373654712421479], 'val_acc': [0.9112156103792148, 0.9136886504093558, 0.9111264918048309, 0.9143347608916699, 0.9130648227683916, 0.9151368286560568, 0.9119508350854804, 0.9129088651888533, 0.9128643068312409], 'acc': [0.9032276595302071, 0.9135397605481944, 0.9145353473461469, 0.914995392586532, 0.914717007468458, 0.9149812375479598, 0.9149505683610459, 0.9157621368413684, 0.91501426714397]}
# stopped_epoch1 6
# 9
# 0.9119508350854804
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 258us/step - loss: 0.2009 - acc: 0.9169 - val_loss: 0.2214 - val_acc: 0.9137
#
# Epoch 00001: val_acc improved from -inf to 0.91369, saving model to /mnt/seals/models/211/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 253us/step - loss: 0.2006 - acc: 0.9170 - val_loss: 0.2249 - val_acc: 0.9140
#
# Epoch 00002: val_acc improved from 0.91369 to 0.91398, saving model to /mnt/seals/models/211/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 246us/step - loss: 0.2003 - acc: 0.9172 - val_loss: 0.2241 - val_acc: 0.9136
#
# Epoch 00003: val_acc did not improve from 0.91398
# Epoch 4/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1991 - acc: 0.9175 - val_loss: 0.2274 - val_acc: 0.9136
#
# Epoch 00004: val_acc did not improve from 0.91398
# Epoch 5/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1986 - acc: 0.9176 - val_loss: 0.2195 - val_acc: 0.9140
#
# Epoch 00005: val_acc did not improve from 0.91398
# H2 {'loss': [0.200931382668378, 0.20062606004278322, 0.2002676573504154, 0.199129178600087, 0.1986229305387187], 'val_loss': [0.22140462919651382, 0.22487270016820446, 0.22409575920103494, 0.2274161299838175, 0.21947402698095336], 'val_acc': [0.9136886507068213, 0.9139782859992029, 0.913644091568362, 0.9135549753737018, 0.9139782842144101], 'acc': [0.9168921972194017, 0.9170384685060002, 0.917191817350274, 0.9175103103957235, 0.9175976007311077]}
# stopped_epoch2 2
# 5
# 0.913644091568362
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.1983 - acc: 0.9176 - val_loss: 0.2212 - val_acc: 0.9140
#
# Epoch 00001: val_acc improved from -inf to 0.91398, saving model to /mnt/seals/models/211/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1990 - acc: 0.9175 - val_loss: 0.2219 - val_acc: 0.9134
#
# Epoch 00002: val_acc did not improve from 0.91398
# Epoch 3/20
# 60553/60553 [==============================] - 15s 250us/step - loss: 0.1984 - acc: 0.9176 - val_loss: 0.2226 - val_acc: 0.9138
#
# Epoch 00003: val_acc did not improve from 0.91398
# Epoch 4/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 0.1988 - acc: 0.9176 - val_loss: 0.2225 - val_acc: 0.9138
#
# Epoch 00004: val_acc did not improve from 0.91398
# H3 {'loss': [0.19831624034000223, 0.19898150469275105, 0.19838167193162223, 0.19881456092160207], 'val_loss': [0.22121887710305652, 0.22194234540666258, 0.2226477777091548, 0.22245928132935605], 'val_acc': [0.9139782868915993, 0.913443573363037, 0.9138446094762216, 0.9138446091787561], 'acc': [0.917574009340079, 0.917486718199506, 0.9175622119800485, 0.9175692905279682]}
# stopped_epoch3 1
# 4
# 0.913443573363037
# best fit round 2 0.913644091568362
# 3137/3137 [==============================] - 0s 154us/step
# 2019-01-20 15:20:15,629 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:20:13",
#     "fit_dt_test_start": "2019-01-20 15:20:13",
#     "fit_dt_train_duration_seconds": "277",
#     "fit_dt_train_end": "2019-01-20 15:20:12",
#     "fit_dt_train_start": "2019-01-20 15:15:35",
#     "fit_num_epochs": 12,
#     "fit_stopped_epoch1": 6,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 1,
#     "fit_test_acc": 0.43544788014026137,
#     "fit_train_acc": 0.917191817350274,
#     "fit_train_loss": 0.2002676573504154,
#     "fit_val_acc": 0.913644091568362,
#     "fit_val_loss": 0.22409575920103494,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 512,
#     "layer_3_size": 0,
#     "model_id": 211,
#     "model_param_count": 1315079,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/211/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:20:15,630 [MainThread  ] [INFO ]  model 211 test acc: 0.43544788014026137
# 2019-01-20 15:20:18,264 [MainThread  ] [INFO ]  Begin experiment for model_id=219 on GPU:3
# 2019-01-20 15:20:18,266 [MainThread  ] [INFO ]  Loading data
# 219   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 128, 'sequence_model': nan, 'layer_1_size': 256, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 219, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:20:19,395 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:20:19,397 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 274us/step - loss: 0.3581 - acc: 0.9030 - val_loss: 0.2135 - val_acc: 0.8956
#
# Epoch 00001: val_acc improved from -inf to 0.89558, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 254us/step - loss: 0.1966 - acc: 0.9145 - val_loss: 0.1969 - val_acc: 0.8958
#
# Epoch 00002: val_acc improved from 0.89558 to 0.89578, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1873 - acc: 0.9203 - val_loss: 0.1871 - val_acc: 0.9012
#
# Epoch 00003: val_acc improved from 0.89578 to 0.90121, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1800 - acc: 0.9248 - val_loss: 0.2154 - val_acc: 0.9032
#
# Epoch 00004: val_acc improved from 0.90121 to 0.90319, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 5/20
# 60553/60553 [==============================] - 15s 256us/step - loss: 0.1779 - acc: 0.9269 - val_loss: 0.2129 - val_acc: 0.8991
#
# Epoch 00005: val_acc did not improve from 0.90319
# Epoch 6/20
# 60553/60553 [==============================] - 16s 257us/step - loss: 0.1708 - acc: 0.9311 - val_loss: 0.2025 - val_acc: 0.9016
#
# Epoch 00006: val_acc did not improve from 0.90319
# Epoch 7/20
# 60553/60553 [==============================] - 15s 246us/step - loss: 0.1713 - acc: 0.9311 - val_loss: 0.1857 - val_acc: 0.9120
#
# Epoch 00007: val_acc improved from 0.90319 to 0.91200, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 8/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1659 - acc: 0.9339 - val_loss: 0.2141 - val_acc: 0.9147
#
# Epoch 00008: val_acc improved from 0.91200 to 0.91474, saving model to /mnt/seals/models/219/model_round_1.h5
# Epoch 9/20
# 60553/60553 [==============================] - 15s 242us/step - loss: 0.1642 - acc: 0.9348 - val_loss: 0.1880 - val_acc: 0.9138
#
# Epoch 00009: val_acc did not improve from 0.91474
# Epoch 10/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1665 - acc: 0.9340 - val_loss: 0.2133 - val_acc: 0.9085
#
# Epoch 00010: val_acc did not improve from 0.91474
# Epoch 11/20
# 60553/60553 [==============================] - 15s 240us/step - loss: 0.1610 - acc: 0.9358 - val_loss: 0.2220 - val_acc: 0.9039
#
# Epoch 00011: val_acc did not improve from 0.91474
# H1 {'loss': [0.35806316512149916, 0.19655895907524554, 0.18728532291566258, 0.17997240529079284, 0.17785384512348454, 0.17084472657220556, 0.17131422659998327, 0.1658955817740121, 0.16421716300620806, 0.166499552227435, 0.16101033354678454], 'val_loss': [0.21345488874895902, 0.19687612136304192, 0.18713644090214895, 0.21535889788560397, 0.21291152085279272, 0.20254390245664886, 0.18573682161695274, 0.21406209319179234, 0.1880141441906086, 0.2133464563361422, 0.22202040172337148], 'val_acc': [0.895575278562378, 0.895775796767703, 0.9012120295076614, 0.9031949206879938, 0.899095465076468, 0.9016353457850066, 0.9119953835523656, 0.9147357899400493, 0.9137777586096313, 0.9085197588539242, 0.9038633077648827], 'acc': [0.9030483555567758, 0.914481078076496, 0.9203389904322778, 0.9248144077868445, 0.9268999486832376, 0.9310592316670467, 0.931146523567529, 0.933866691612389, 0.9347679083714242, 0.9340129608052997, 0.9358248328590894]}
# stopped_epoch1 8
# 11
# 0.9137777586096313
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1462 - acc: 0.9429 - val_loss: 0.1970 - val_acc: 0.9119
#
# Epoch 00001: val_acc improved from -inf to 0.91193, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 257us/step - loss: 0.1441 - acc: 0.9435 - val_loss: 0.1985 - val_acc: 0.9101
#
# Epoch 00002: val_acc did not improve from 0.91193
# Epoch 3/20
# 60553/60553 [==============================] - 15s 251us/step - loss: 0.1423 - acc: 0.9444 - val_loss: 0.2136 - val_acc: 0.9062
#
# Epoch 00003: val_acc did not improve from 0.91193
# Epoch 4/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1406 - acc: 0.9448 - val_loss: 0.1880 - val_acc: 0.9155
#
# Epoch 00004: val_acc improved from 0.91193 to 0.91552, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 5/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.1406 - acc: 0.9446 - val_loss: 0.1927 - val_acc: 0.9157
#
# Epoch 00005: val_acc improved from 0.91552 to 0.91567, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 6/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.1400 - acc: 0.9452 - val_loss: 0.1873 - val_acc: 0.9147
#
# Epoch 00006: val_acc did not improve from 0.91567
# Epoch 7/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.1382 - acc: 0.9462 - val_loss: 0.1989 - val_acc: 0.9144
#
# Epoch 00007: val_acc did not improve from 0.91567
# Epoch 8/20
# 60553/60553 [==============================] - 15s 245us/step - loss: 0.1386 - acc: 0.9458 - val_loss: 0.1832 - val_acc: 0.9175
#
# Epoch 00008: val_acc improved from 0.91567 to 0.91748, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 9/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 0.1386 - acc: 0.9455 - val_loss: 0.1860 - val_acc: 0.9177
#
# Epoch 00009: val_acc improved from 0.91748 to 0.91765, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 10/20
# 60553/60553 [==============================] - 15s 248us/step - loss: 0.1383 - acc: 0.9460 - val_loss: 0.1914 - val_acc: 0.9164
#
# Epoch 00010: val_acc did not improve from 0.91765
# Epoch 11/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.1365 - acc: 0.9464 - val_loss: 0.1924 - val_acc: 0.9141
#
# Epoch 00011: val_acc did not improve from 0.91765
# Epoch 12/20
# 60553/60553 [==============================] - 15s 242us/step - loss: 0.1358 - acc: 0.9466 - val_loss: 0.1799 - val_acc: 0.9198
#
# Epoch 00012: val_acc improved from 0.91765 to 0.91982, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 13/20
# 60553/60553 [==============================] - 15s 249us/step - loss: 0.1362 - acc: 0.9465 - val_loss: 0.1805 - val_acc: 0.9214
#
# Epoch 00013: val_acc improved from 0.91982 to 0.92142, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 14/20
# 60553/60553 [==============================] - 16s 258us/step - loss: 0.1339 - acc: 0.9480 - val_loss: 0.1898 - val_acc: 0.9176
#
# Epoch 00014: val_acc did not improve from 0.92142
# Epoch 15/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1354 - acc: 0.9471 - val_loss: 0.1757 - val_acc: 0.9246
#
# Epoch 00015: val_acc improved from 0.92142 to 0.92461, saving model to /mnt/seals/models/219/model_round_2.h5
# Epoch 16/20
# 60553/60553 [==============================] - 15s 243us/step - loss: 0.1332 - acc: 0.9480 - val_loss: 0.1816 - val_acc: 0.9238
#
# Epoch 00016: val_acc did not improve from 0.92461
# Epoch 17/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1340 - acc: 0.9477 - val_loss: 0.1992 - val_acc: 0.9160
#
# Epoch 00017: val_acc did not improve from 0.92461
# Epoch 18/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.1336 - acc: 0.9476 - val_loss: 0.1869 - val_acc: 0.9215
#
# Epoch 00018: val_acc did not improve from 0.92461
# H2 {'loss': [0.14619506833799517, 0.14406630905253753, 0.1422713986189101, 0.14061306690376066, 0.14055074940148607, 0.14002337999576805, 0.13816670538042763, 0.1385535182441153, 0.13863801012368465, 0.1382878684462866, 0.13654079480374803, 0.135825983541261, 0.1361716654536616, 0.1338651638747565, 0.1353549902915301, 0.1331617473981854, 0.13402322981100978, 0.13360833220960616], 'val_loss': [0.19695137490426015, 0.19848661380340663, 0.21358677205709242, 0.18804433608122045, 0.19268028426006742, 0.18726526068771027, 0.1989370118861487, 0.18319508855371125, 0.18595481748069292, 0.19140450557878594, 0.1923873722925085, 0.17993702909125436, 0.18051811314640534, 0.18978440865679078, 0.17567365327925513, 0.1816392701191227, 0.19921445100105187, 0.1868977901419475], 'val_acc': [0.9119285476334156, 0.9101016148134685, 0.9062249528119807, 0.9155155680957469, 0.9156715298398018, 0.9146689437585404, 0.9144238674187021, 0.917476180822345, 0.917654416558152, 0.9163621961140885, 0.9140896731737771, 0.9198155424331622, 0.9214196783337679, 0.9176321366170905, 0.9246056695246205, 0.9238258818500279, 0.9159611645372525, 0.9215310790802045], 'acc': [0.9428670697705727, 0.9434969775616052, 0.9443698854896687, 0.9448440864163206, 0.9445774948429814, 0.9452074041823783, 0.9462360186558968, 0.9458090007711677, 0.9455282555491422, 0.9460095349567789, 0.9464223962860702, 0.946563948089239, 0.946509685770986, 0.9479629582142752, 0.9470876914638691, 0.9480195795025217, 0.9476727756101753, 0.9476019996977632]}
# stopped_epoch2 15
# 18
# 0.9238258818500279
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 280us/step - loss: 0.1322 - acc: 0.9487 - val_loss: 0.1890 - val_acc: 0.9205
#
# Epoch 00001: val_acc improved from -inf to 0.92048, saving model to /mnt/seals/models/219/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 16s 260us/step - loss: 0.1310 - acc: 0.9487 - val_loss: 0.1860 - val_acc: 0.9231
#
# Epoch 00002: val_acc improved from 0.92048 to 0.92314, saving model to /mnt/seals/models/219/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 16s 261us/step - loss: 0.1324 - acc: 0.9487 - val_loss: 0.1870 - val_acc: 0.9227
#
# Epoch 00003: val_acc did not improve from 0.92314
# Epoch 4/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.1318 - acc: 0.9484 - val_loss: 0.1868 - val_acc: 0.9228
#
# Epoch 00004: val_acc did not improve from 0.92314
# Epoch 5/20
# 60553/60553 [==============================] - 16s 259us/step - loss: 0.1326 - acc: 0.9484 - val_loss: 0.1862 - val_acc: 0.9237
#
# Epoch 00005: val_acc improved from 0.92314 to 0.92367, saving model to /mnt/seals/models/219/model_round_3.h5
# Epoch 6/20
# 60553/60553 [==============================] - 15s 246us/step - loss: 0.1314 - acc: 0.9487 - val_loss: 0.1860 - val_acc: 0.9227
#
# Epoch 00006: val_acc did not improve from 0.92367
# Epoch 7/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1308 - acc: 0.9488 - val_loss: 0.1853 - val_acc: 0.9238
#
# Epoch 00007: val_acc improved from 0.92367 to 0.92376, saving model to /mnt/seals/models/219/model_round_3.h5
# Epoch 8/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.1308 - acc: 0.9489 - val_loss: 0.1872 - val_acc: 0.9229
#
# Epoch 00008: val_acc did not improve from 0.92376
# Epoch 9/20
# 60553/60553 [==============================] - 15s 253us/step - loss: 0.1313 - acc: 0.9489 - val_loss: 0.1869 - val_acc: 0.9225
#
# Epoch 00009: val_acc did not improve from 0.92376
# Epoch 10/20
# 60553/60553 [==============================] - 15s 252us/step - loss: 0.1302 - acc: 0.9494 - val_loss: 0.1868 - val_acc: 0.9230
#
# Epoch 00010: val_acc did not improve from 0.92376
# H3 {'loss': [0.1321820444115903, 0.13100903315593188, 0.13242581805184664, 0.13175915844379568, 0.13257262335286957, 0.13135043741308047, 0.1307578979515095, 0.13082504728160413, 0.13126645407682525, 0.13019372262436538], 'val_loss': [0.18896632528609955, 0.1859860782019436, 0.1869581575532742, 0.18681633408301634, 0.18617194158467218, 0.1860362561657811, 0.18534323358379598, 0.18719786339563202, 0.18689223806038546, 0.18680411789168883], 'val_acc': [0.9204839345669642, 0.9231352110393927, 0.9226896205471965, 0.9228010195832065, 0.9236699251628859, 0.9226673439526216, 0.9237590434398044, 0.9229124177268201, 0.9225113839933594, 0.9229792558395781], 'acc': [0.948675439503164, 0.9487320602874292, 0.9486683616846391, 0.9484182850914077, 0.9484277221860554, 0.9487438563471488, 0.9488264276666641, 0.9488972040436839, 0.9488547395668032, 0.9494374640904995]}
# stopped_epoch3 7
# 10
# 0.9229124177268201
# best fit round 2 0.9238258818500279
# 3137/3137 [==============================] - 1s 173us/step
# 2019-01-20 15:30:28,761 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 2,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:30:27",
#     "fit_dt_test_start": "2019-01-20 15:30:26",
#     "fit_dt_train_duration_seconds": "603",
#     "fit_dt_train_end": "2019-01-20 15:30:25",
#     "fit_dt_train_start": "2019-01-20 15:20:22",
#     "fit_num_epochs": 33,
#     "fit_stopped_epoch1": 8,
#     "fit_stopped_epoch2": 15,
#     "fit_stopped_epoch3": 7,
#     "fit_test_acc": 0.5992986930188078,
#     "fit_train_acc": 0.9480195795025217,
#     "fit_train_loss": 0.1331617473981854,
#     "fit_val_acc": 0.9238258818500279,
#     "fit_val_loss": 0.1816392701191227,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 256,
#     "layer_2_size": 128,
#     "layer_3_size": 0,
#     "model_id": 219,
#     "model_param_count": 1213703,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/219/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:30:28,763 [MainThread  ] [INFO ]  model 219 test acc: 0.5992986930188078
# 2019-01-20 15:30:31,953 [MainThread  ] [INFO ]  Begin experiment for model_id=227 on GPU:3
# 2019-01-20 15:30:31,956 [MainThread  ] [INFO ]  Loading data
# 227   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 512, 'sequence_model': nan, 'layer_1_size': 128, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 227, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:30:33,143 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:30:33,151 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 268us/step - loss: 0.2326 - acc: 0.9100 - val_loss: 0.2381 - val_acc: 0.9131
#
# Epoch 00001: val_acc improved from -inf to 0.91311, saving model to /mnt/seals/models/227/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 235us/step - loss: 0.2203 - acc: 0.9113 - val_loss: 0.2440 - val_acc: 0.9095
#
# Epoch 00002: val_acc did not improve from 0.91311
# Epoch 3/20
# 60553/60553 [==============================] - 14s 235us/step - loss: 0.2145 - acc: 0.9137 - val_loss: 0.2217 - val_acc: 0.9149
#
# Epoch 00003: val_acc improved from 0.91311 to 0.91494, saving model to /mnt/seals/models/227/model_round_1.h5
# Epoch 4/20
# 60553/60553 [==============================] - 14s 237us/step - loss: 0.2123 - acc: 0.9143 - val_loss: 0.2279 - val_acc: 0.9142
#
# Epoch 00004: val_acc did not improve from 0.91494
# Epoch 5/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.2110 - acc: 0.9146 - val_loss: 0.2240 - val_acc: 0.9144
#
# Epoch 00005: val_acc did not improve from 0.91494
# Epoch 6/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.2090 - acc: 0.9151 - val_loss: 0.2292 - val_acc: 0.9135
#
# Epoch 00006: val_acc did not improve from 0.91494
# H1 {'loss': [0.23255856877312114, 0.22029947115365314, 0.2144760295052045, 0.21232214172126662, 0.2109907280512278, 0.2090156845732552], 'val_loss': [0.23813047702990692, 0.2439771846764101, 0.22173411056575965, 0.22790465359381415, 0.22401591218863884, 0.22917213121281516], 'val_acc': [0.9131093748420458, 0.9094555162669566, 0.9149363073273443, 0.9142233611119961, 0.9143793212943574, 0.9135104140042515], 'acc': [0.9099655578412571, 0.9112513281892589, 0.913683672517328, 0.9143253774528209, 0.9145872502229083, 0.915139304403093]}
# stopped_epoch1 3
# 6
# 0.9142233611119961
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 16s 266us/step - loss: 0.2021 - acc: 0.9166 - val_loss: 0.2233 - val_acc: 0.9133
#
# Epoch 00001: val_acc improved from -inf to 0.91331, saving model to /mnt/seals/models/227/model_round_2.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 236us/step - loss: 0.2014 - acc: 0.9167 - val_loss: 0.2214 - val_acc: 0.9137
#
# Epoch 00002: val_acc improved from 0.91331 to 0.91371, saving model to /mnt/seals/models/227/model_round_2.h5
# Epoch 3/20
# 60553/60553 [==============================] - 14s 237us/step - loss: 0.2014 - acc: 0.9168 - val_loss: 0.2240 - val_acc: 0.9135
#
# Epoch 00003: val_acc did not improve from 0.91371
# Epoch 4/20
# 60553/60553 [==============================] - 14s 231us/step - loss: 0.2004 - acc: 0.9171 - val_loss: 0.2228 - val_acc: 0.9135
#
# Epoch 00004: val_acc did not improve from 0.91371
# Epoch 5/20
# 60553/60553 [==============================] - 14s 233us/step - loss: 0.2007 - acc: 0.9171 - val_loss: 0.2188 - val_acc: 0.9122
#
# Epoch 00005: val_acc did not improve from 0.91371
# H2 {'loss': [0.20205235936518728, 0.20137613068522228, 0.2013771828302941, 0.20035081385961778, 0.20067719619398128], 'val_loss': [0.22332369663978618, 0.2214201930457179, 0.22398122472087814, 0.22277915535386622, 0.21881800973631038], 'val_acc': [0.9133098952039955, 0.9137109274501289, 0.9134658533784649, 0.9134658545683267, 0.9121736315214404], 'acc': [0.9165571898779598, 0.9167081783928687, 0.9167765959662482, 0.9171045262136382, 0.9170785735453267]}
# stopped_epoch2 2
# 5
# 0.9134658533784649
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 276us/step - loss: 0.1995 - acc: 0.9173 - val_loss: 0.2211 - val_acc: 0.9129
#
# Epoch 00001: val_acc improved from -inf to 0.91291, saving model to /mnt/seals/models/227/model_round_3.h5
# Epoch 2/20
# 60553/60553 [==============================] - 14s 236us/step - loss: 0.1992 - acc: 0.9174 - val_loss: 0.2213 - val_acc: 0.9132
#
# Epoch 00002: val_acc improved from 0.91291 to 0.91315, saving model to /mnt/seals/models/227/model_round_3.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 240us/step - loss: 0.1990 - acc: 0.9175 - val_loss: 0.2223 - val_acc: 0.9129
#
# Epoch 00003: val_acc did not improve from 0.91315
# Epoch 4/20
# 60553/60553 [==============================] - 14s 239us/step - loss: 0.1998 - acc: 0.9174 - val_loss: 0.2219 - val_acc: 0.9127
#
# Epoch 00004: val_acc did not improve from 0.91315
# Epoch 5/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.1992 - acc: 0.9174 - val_loss: 0.2217 - val_acc: 0.9127
#
# Epoch 00005: val_acc did not improve from 0.91315
# H3 {'loss': [0.1994606097824396, 0.19915696171116218, 0.19901536818803958, 0.19979025007422302, 0.1991937313251424], 'val_loss': [0.22108356620249567, 0.22134893586021323, 0.2223426043169244, 0.22194907236530567, 0.2216632195509603], 'val_acc': [0.9129088641477241, 0.9131539391117846, 0.9129088620654657, 0.9127083456449336, 0.9126860669681004], 'acc': [0.9172578737841781, 0.9173947071305822, 0.9174867158370937, 0.9173616788791783, 0.9174159417870499]}
# stopped_epoch3 2
# 5
# 0.9129088620654657
# best fit round 1 0.9142233611119961
# 3137/3137 [==============================] - 1s 270us/step
# 2019-01-20 15:34:48,525 [MainThread  ] [INFO ]  {
#     "architecture": "video_mlp_concat",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3137,
#     "data_total_rows_train": 60553,
#     "data_total_rows_valid": 6412,
#     "dropout": 0.2,
#     "fit_best_round": 1,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-20 15:34:46",
#     "fit_dt_test_start": "2019-01-20 15:34:45",
#     "fit_dt_train_duration_seconds": "248",
#     "fit_dt_train_end": "2019-01-20 15:34:44",
#     "fit_dt_train_start": "2019-01-20 15:30:36",
#     "fit_num_epochs": 10,
#     "fit_stopped_epoch1": 3,
#     "fit_stopped_epoch2": 2,
#     "fit_stopped_epoch3": 2,
#     "fit_test_acc": 0.4430985017532675,
#     "fit_train_acc": 0.9143253774528209,
#     "fit_train_loss": 0.21232214172126662,
#     "fit_val_acc": 0.9142233611119961,
#     "fit_val_loss": 0.22790465359381415,
#     "frame_size": [
#         299,
#         299
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 512,
#     "layer_3_size": 0,
#     "model_id": 227,
#     "model_param_count": 659591,
#     "model_weights_path": null,
#     "num_features": 1536,
#     "path_model": "/mnt/seals/models/227/",
#     "pooling": "max",
#     "pretrained_model_name": "inception_resnet_v2",
#     "sequence_length": 3,
#     "sequence_model": NaN,
#     "sequence_model_layers": NaN,
#     "verbose": true
# }
# 2019-01-20 15:34:48,527 [MainThread  ] [INFO ]  model 227 test acc: 0.4430985017532675
# 2019-01-20 15:34:50,724 [MainThread  ] [INFO ]  Begin experiment for model_id=235 on GPU:3
# 2019-01-20 15:34:50,728 [MainThread  ] [INFO ]  Loading data
# 235   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'layer_2_size': 128, 'sequence_model': nan, 'layer_1_size': 128, 'layer_3_size': 0, 'architecture': 'video_MLP_concat', 'dropout': 0.2, 'pooling': 'max', 'pretrained_model_name': 'inception_resnet_v2', 'model_id': 235, 'WORKER': 3, 'sequence_length': 3, 'sequence_model_layers': nan}
# 2019-01-20 15:34:51,892 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/inception_resnet_v2/max/
# 2019-01-20 15:34:51,894 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60553, valid=6412, test=3137
# Train on 60553 samples, validate on 6412 samples
# Epoch 1/20
# 60553/60553 [==============================] - 17s 279us/step - loss: 0.2577 - acc: 0.9076 - val_loss: 0.2209 - val_acc: 0.9144
#
# Epoch 00001: val_acc improved from -inf to 0.91442, saving model to /mnt/seals/models/235/model_round_1.h5
# Epoch 2/20
# 60553/60553 [==============================] - 15s 240us/step - loss: 0.2326 - acc: 0.9083 - val_loss: 0.2268 - val_acc: 0.9146
#
# Epoch 00002: val_acc improved from 0.91442 to 0.91460, saving model to /mnt/seals/models/235/model_round_1.h5
# Epoch 3/20
# 60553/60553 [==============================] - 15s 240us/step - loss: 0.2124 - acc: 0.9143 - val_loss: 0.2290 - val_acc: 0.9134
#
# Epoch 00003: val_acc did not improve from 0.91460
# Epoch 4/20
# 60553/60553 [==============================] - 15s 244us/step - loss: 0.2096 - acc: 0.9152 - val_loss: 0.2210 - val_acc: 0.9144
#
# Epoch 00004: val_acc did not improve from 0.91460
# Epoch 5/20
# 60553/60553 [==============================] - 15s 241us/step - loss: 0.2075 - acc: 0.9156 - val_loss: 0.2300 - val_acc: 0.9148
#
# Epoch 00005: val_acc improved from 0.91460 to 0.91478, saving model to /mnt/seals/models/235/model_round_1.h5
# Epoch 6/20
# 30912/60553 [==============>...............] - ETA: 6s - loss: 0.2074 - acc: 0.9156
