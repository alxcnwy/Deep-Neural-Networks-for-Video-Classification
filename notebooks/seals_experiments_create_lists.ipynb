# %%
WORKER_COUNT = 16

# %%
# Sync models
# gsutil -m rsync -r /mnt/seals/models/ gs://thesis-seals/models/ 
# aws s3 sync /mnt/seals/models s3://thesisvids/seals/models/

# %%
# whether to log each feature and sequence status
verbose = True

# %%
import gc
import os
import pandas as pd
pd.options.display.max_rows = 5000
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import itertools
import sys
sys.path.append('..')

# %%
# setup paths
pwd = os.getcwd().replace("notebooks","")
path_cache = pwd + 'cache/'
path_data = pwd + 'data/'

# %%
# setup logging
# any explicit log messages or uncaught errors to stdout and file /logs.log
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs")),
        logging.StreamHandler()
    ])
# init logger
logger = logging.getLogger()
# make logger aware of any uncaught exceptions
def handle_exception(exc_type, exc_value, exc_traceback):
    if issubclass(exc_type, KeyboardInterrupt):
        sys.__excepthook__(exc_type, exc_value, exc_traceback)
        return

    logger.error("Uncaught exception", exc_info=(exc_type, exc_value, exc_traceback))
sys.excepthook = handle_exception

# %%
from deepvideoclassification.pretrained_CNNs import pretrained_model_names, pretrained_model_names_bucketed

# %% [markdown]
# # Helper functions

# %%
def get_results():
    """
    Load the results of all completed models into a dataframe and return sorted on val_acc
    """
    
    path_models = pwd + 'models/'

    results = []

    for folder, subs, files in os.walk(path_models):
        for filename in files:
            if 'results.json' in filename:
                with open(os.path.abspath(os.path.join(folder, filename))) as f:
                    data = json.load(f)
                results.append(data)

    results = pd.DataFrame(results)        
    results.sort_values("fit_val_acc", inplace=True, ascending=False)
    return results

# %%
def remove_completed_experiments(experiments):
    """
    Helper function to remove the completed experiments from experiments dataframe
    """
    
    # get updated result set
    results = get_results()
    
    # merge results onto experiments
    experiments = pd.merge(experiments, results[['model_id','fit_val_acc']], left_on='model_id', right_on='model_id', how='left')
    experiments['done'] = (experiments['fit_val_acc']>0).astype(int)
    print("{}/{} experiments done".format(experiments[experiments['done'] == 1].shape[0], len(experiments)))
    
    # only keep experiments not done
    experiments = experiments[experiments['done'] == 0]

    # clean up
    del experiments['done']
    del experiments['fit_val_acc']
    
    # return experiments already done
    return experiments

# %%
def reassign_workers(experiments):
    """
    Helper function to reassign outstanding experiments to workers
    """
    
    
    # get updated result set
    results = get_results()
    
    # merge results onto experiments
    experiments = pd.merge(experiments, results[['model_id','fit_val_acc']], left_on='model_id', right_on='model_id', how='left')
    experiments['done'] = (experiments['fit_val_acc']>0).astype(int)
    
    # reassign workers
    global todo_idx
    todo_idx = 0
    
    def assign_not_done_to_worker(row):
        """ helper lambda"""
        global todo_idx
        if row['done'] == 0:
            todo_idx+=1
            return todo_idx % WORKER_COUNT
        else:
            return 0
    
    experiments['WORKER'] = experiments.apply(assign_not_done_to_worker, axis=1)
    
    # clean up
    del experiments['done']
    del experiments['fit_val_acc']
    
    return experiments

# %% [markdown]
# # Create list of experiments to be run

# %% [markdown]
# * batch 1 = run frozen image MLP, LRCNNs and concat models on 1 of each pretrained_model_name in buckets (bucketed on feature sizes and limited to max sequence_length of 10)
#
# * batch 2 = for best configurations from batch 1, run other pretrained models in buckets and run longer sequence lengths, maybe try different convolution kernel sizes
#
# * batch 3 = run trainable MLP and LRCNN on best performing frozen variants
#
# * batch 4 = run trainable but initializing with best CNN weights
#
# * batch 5 = run C3D models
#
# * batch 6 = analyze effect of dropout and pooling with best model

# %% [markdown]
# # Batch 1

# %%
experiment_batch_name = 'experiment_batch_1'

# %%
# init model id - need to make sure we pick up where we leave off don't overwrite it between batches
model_id_start = 0

# %%
# init list of experiments
experiments = []

# %%
pooling = 'max'
layer_sizes = [512, 256, 128, 0]
dropouts = [0.2]
sequence_lengths = [3,5,10]
sequence_models = ["LSTM", "SimpleRNN", "GRU", "Convolution1D"]
sequence_model_layer_counts = [1,2]

# %%
####################
### image_MLP_frozen 
####################

for pretrained_model_name in pretrained_model_names_bucketed:
    for layer_1_size in layer_sizes:
        for layer_2_size in layer_sizes:
            for layer_3_size in layer_sizes:
                for dropout in dropouts:

                    # build experiment parameters
                    experiment = {}
                    
                    experiment['architecture'] = 'image_MLP_frozen'
                    experiment['sequence_length'] = 1
                    experiment['pretrained_model_name'] = pretrained_model_name
                    experiment['layer_1_size'] = layer_1_size
                    experiment['layer_2_size'] = layer_2_size
                    experiment['layer_3_size'] = layer_3_size
                    experiment['dropout'] = dropout
                    experiment['pooling'] = 'max' # outperforms avg across all parameters
                    
                    # add to list of experiments
                    experiments.append(experiment)

# %%
####################
### video_MLP_concat
####################

for sequence_length in sequence_lengths:
    for pretrained_model_name in pretrained_model_names_bucketed:
        for layer_1_size in layer_sizes:
            for layer_2_size in layer_sizes:
                for layer_3_size in layer_sizes:
                    for dropout in dropouts:

                        # build experiment parameters
                        experiment = {}

                        experiment['architecture'] = 'video_MLP_concat'
                        experiment['pretrained_model_name'] = pretrained_model_name
                        experiment['layer_1_size'] = layer_1_size
                        experiment['layer_2_size'] = layer_2_size
                        experiment['layer_3_size'] = layer_3_size
                        experiment['dropout'] = dropout
                        experiment['pooling'] = 'max' # outperforms avg across all parameters
                        experiment['sequence_length'] = sequence_length

                        # add to list of experiments
                        experiments.append(experiment)

# %%
######################
### video_LRCNN_frozen
######################

for sequence_length in sequence_lengths:
    for pretrained_model_name in pretrained_model_names_bucketed:
        for layer_1_size in layer_sizes:
            for layer_2_size in layer_sizes:
                for layer_3_size in layer_sizes:
                    for dropout in dropouts:
                        for sequence_model in sequence_models:
                            for sequence_model_layers in sequence_model_layer_counts:

                                # build experiment parameters
                                experiment = {}

                                experiment['architecture'] = 'video_LRCNN_frozen'
                                experiment['pretrained_model_name'] = pretrained_model_name
                                experiment['layer_1_size'] = layer_1_size
                                experiment['layer_2_size'] = layer_2_size
                                experiment['layer_3_size'] = layer_3_size
                                experiment['dropout'] = dropout
                                experiment['pooling'] = 'max' # outperforms avg across all parameters
                                experiment['sequence_model'] = sequence_model
                                experiment['sequence_model_layers'] = sequence_model_layers
                                experiment['sequence_length'] = sequence_length

                                # add to list of experiments
                                experiments.append(experiment)

# %%
########################
### convert to dataframe
########################

experiments = pd.DataFrame(experiments)

### create model id column for this experiment batch
model_id_list = list(range(0,len(experiments)))
experiments['model_id'] = model_id_list

# assign to workers
experiments['WORKER'] = experiments['model_id'].apply(lambda x: x % WORKER_COUNT)

# %%
experiments.shape
# Out:
# (5376, 12)

# %%
############################################
### remove invalid experiment configurations
############################################

# Just won't run experiments for those model_ids - not an error that model ids not congituous count from 0!

# delete video experiments with 0 neurons in a layer with nonzero neurons in later layers
experiments = experiments[~((experiments['layer_1_size'] == 0) & (experiments['layer_2_size'] > 0))]
experiments = experiments[~((experiments['layer_1_size'] == 0) & (experiments['layer_3_size'] > 0))]
experiments = experiments[~((experiments['layer_2_size'] == 0) & (experiments['layer_3_size'] > 0))]

# delete video experiments where convolution_kernel_size > sequence_length (convolution_kernel_size defaults to 3 and not set in this batch)
experiments = experiments[~((experiments['sequence_model'] == 'Convolution1D') & (experiments['sequence_length']<=3))]

# %%
# delete LRCNN_frozen experiments with layer_1_size == 0
experiments = experiments[~((experiments['architecture'] == 'video_LRCNN_frozen') & (experiments['layer_1_size']==0))]

# %%
##################################
### output experiment batch to CSV
##################################
print(experiment_batch_name)
experiments.to_csv(pwd + "experiments/" + experiment_batch_name + '.csv', index=False)
# Out:
# experiment_batch_1

# %%
print(experiments.shape)
experiments.tail().T
# Out:
# (3054, 12)
#                                      5243                5244  \
# architecture           video_LRCNN_frozen  video_LRCNN_frozen
# dropout                               0.2                 0.2
# layer_1_size                          128                 128
# layer_2_size                            0                   0
# layer_3_size                            0                   0
# pooling                               max                 max
# pretrained_model_name            resnet50            resnet50
# sequence_length                        10                  10
# sequence_model                  SimpleRNN                 GRU
# sequence_model_layers                   2                   1
# model_id                             5243                5244
# WORKER                                  3                   4
#
#                                      5245                5246  \
# architecture           video_LRCNN_frozen  video_LRCNN_frozen
# dropout                               0.2                 0.2
# layer_1_size                          128                 128
# layer_2_size                            0                   0
# layer_3_size                            0                   0
# pooling                               max                 max
# pretrained_model_name            resnet50            resnet50
# sequence_length                        10                  10
# sequence_model                        GRU       Convolution1D
# sequence_model_layers                   2                   1
# model_id                             5245                5246
# WORKER                                  5                   6
#
#                                      5247
# architecture           video_LRCNN_frozen
# dropout                               0.2
# layer_1_size                          128
# layer_2_size                            0
# layer_3_size                            0
# pooling                               max
# pretrained_model_name            resnet50
# sequence_length                        10
# sequence_model              Convolution1D
# sequence_model_layers                   2
# model_id                             5247
# WORKER                                  7

# %%
# # upload to s3
# response = os.system("aws s3 cp " + pwd + "experiments/" + experiment_batch_name + '.csv s3://thesisvids/seals/' + experiment_batch_name + '.csv')
# if response == 0:
#     print("upload success")
# else:
#     print("upload error")

# %%
# # # upload to GCP
# response = os.system("gsutil cp " + pwd + "experiments/" + experiment_batch_name + '.csv gs://thesis-seals/' + experiment_batch_name + '.csv')
# if response == 0:
#     print("upload success")
# else:
#     print("upload error")

# %% [markdown]
# # Batch 2

# %%
# reload experiments
experiments = pd.read_csv(pwd + "experiments/experiment_batch_1.csv")
experiments.shape
# Out:
# (3054, 12)

# %%
# define experiment batch name
experiment_batch_name = 'experiment_batch_2'

# %%
# init model id - need to make sure we pick up where we leave off don't overwrite it between batches
model_id_start = pd.read_csv(pwd + "experiments/experiment_batch_1.csv")['model_id'].max() + 1
# read list of paths and find max there too to be double safe we don't overwrite model_ids
paths = os.listdir(path_models)
paths = [int(p) for p in paths]
model_id_start = max(model_id_start,max(paths) + 1)
print(model_id_start)
# Out:
# 5248

# %%
# remove experiments already completed
experiments = remove_completed_experiments(experiments)
experiments.shape
# Out:
# 3009/3054 experiments done
# (45, 12)

# %%
# get top 20 results from previous batch
results = get_results()

# %%
results.head(20).T
# Out:
#                                                   1698  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         2
# fit_dt_test_end                    2019-01-24 11:44:45
# fit_dt_test_start                  2019-01-24 11:44:42
# fit_dt_train_duration_seconds                      558
# fit_dt_train_end                   2019-01-24 11:44:39
# fit_dt_train_start                 2019-01-24 11:35:20
# fit_num_epochs                                      21
# fit_stopped_epoch1                                  12
# fit_stopped_epoch2                                   5
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.901695
# fit_train_acc                                 0.938977
# fit_train_loss                                0.163874
# fit_val_acc                                   0.961765
# fit_val_loss                                    0.1269
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       256
# model_id                                          3337
# model_param_count                              8000258
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3337/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   111   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                         7
# fit_dt_test_end                    2019-01-24 13:05:19
# fit_dt_test_start                  2019-01-24 13:05:12
# fit_dt_train_duration_seconds                      665
# fit_dt_train_end                   2019-01-24 13:05:04
# fit_dt_train_start                 2019-01-24 12:53:59
# fit_num_epochs                                      25
# fit_stopped_epoch1                                  10
# fit_stopped_epoch2                                   8
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.898305
# fit_train_acc                                 0.941143
# fit_train_loss                                0.167814
# fit_val_acc                                   0.961765
# fit_val_loss                                  0.123963
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       128
# layer_3_size                                       256
# model_id                                          3657
# model_param_count                              1410818
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3657/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2508  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               299
# data_total_rows_train                            10697
# data_total_rows_valid                             1370
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        27
# fit_dt_test_end                    2019-01-24 05:17:09
# fit_dt_test_start                  2019-01-24 05:16:41
# fit_dt_train_duration_seconds                      974
# fit_dt_train_end                   2019-01-24 05:16:17
# fit_dt_train_start                 2019-01-24 05:00:02
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   5
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.886288
# fit_train_acc                                 0.929326
# fit_train_loss                                0.209129
# fit_val_acc                                   0.960584
# fit_val_loss                                  0.164561
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       128
# model_id                                          1809
# model_param_count                              7541122
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/1809/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      3
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2952  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         5
# fit_dt_test_end                    2019-01-24 12:19:56
# fit_dt_test_start                  2019-01-24 12:19:50
# fit_dt_train_duration_seconds                      502
# fit_dt_train_end                   2019-01-24 12:19:44
# fit_dt_train_start                 2019-01-24 12:11:22
# fit_num_epochs                                      18
# fit_stopped_epoch1                                  10
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.877966
# fit_train_acc                                 0.938036
# fit_train_loss                                 0.17908
# fit_val_acc                                   0.960294
# fit_val_loss                                  0.135154
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                         0
# model_id                                          3545
# model_param_count                              2557698
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3545/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1591  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                         3
# fit_dt_test_end                    2019-01-24 11:52:11
# fit_dt_test_start                  2019-01-24 11:52:07
# fit_dt_train_duration_seconds                      577
# fit_dt_train_end                   2019-01-24 11:52:03
# fit_dt_train_start                 2019-01-24 11:42:25
# fit_num_epochs                                      27
# fit_stopped_epoch1                                  13
# fit_stopped_epoch2                                   7
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.888136
# fit_train_acc                                 0.923345
# fit_train_loss                                0.216913
# fit_val_acc                                   0.960294
# fit_val_loss                                  0.141367
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          3333
# model_param_count                              6820354
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3333/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2963  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               299
# data_total_rows_train                            10697
# data_total_rows_valid                             1370
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         0
# fit_dt_test_end                    2019-01-24 08:19:35
# fit_dt_test_start                  2019-01-24 08:19:35
# fit_dt_train_duration_seconds                      416
# fit_dt_train_end                   2019-01-24 08:19:33
# fit_dt_train_start                 2019-01-24 08:12:37
# fit_num_epochs                                      19
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   7
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.882943
# fit_train_acc                                 0.924371
# fit_train_loss                                0.211186
# fit_val_acc                                   0.959854
# fit_val_loss                                   0.14964
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                       256
# model_id                                          1833
# model_param_count                              6229762
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/1833/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      3
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1159  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         3
# fit_dt_test_end                    2019-01-24 11:59:48
# fit_dt_test_start                  2019-01-24 11:59:44
# fit_dt_train_duration_seconds                      496
# fit_dt_train_end                   2019-01-24 11:59:40
# fit_dt_train_start                 2019-01-24 11:51:23
# fit_num_epochs                                      18
# fit_stopped_epoch1                                   8
# fit_stopped_epoch2                                   6
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.894915
# fit_train_acc                                 0.936529
# fit_train_loss                                0.179927
# fit_val_acc                                   0.959559
# fit_val_loss                                  0.147221
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          3385
# model_param_count                              6032898
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3385/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2774  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         3
# fit_dt_test_end                    2019-01-24 11:51:29
# fit_dt_test_start                  2019-01-24 11:51:26
# fit_dt_train_duration_seconds                      484
# fit_dt_train_end                   2019-01-24 11:51:22
# fit_dt_train_start                 2019-01-24 11:43:17
# fit_num_epochs                                      16
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.891525
# fit_train_acc                                 0.934645
# fit_train_loss                                0.187476
# fit_val_acc                                   0.959559
# fit_val_loss                                  0.142083
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          3393
# model_param_count                              5902338
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3393/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1910  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                         3
# fit_dt_test_end                    2019-01-24 12:01:24
# fit_dt_test_start                  2019-01-24 12:01:20
# fit_dt_train_duration_seconds                      469
# fit_dt_train_end                   2019-01-24 12:01:15
# fit_dt_train_start                 2019-01-24 11:53:26
# fit_num_epochs                                      15
# fit_stopped_epoch1                                  10
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.898305
# fit_train_acc                                 0.943215
# fit_train_loss                                0.174112
# fit_val_acc                                   0.959559
# fit_val_loss                                  0.139414
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       256
# model_id                                          3401
# model_param_count                              5737730
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3401/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   651   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               299
# data_total_rows_train                            10697
# data_total_rows_valid                             1370
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        28
# fit_dt_test_end                    2019-01-24 06:51:22
# fit_dt_test_start                  2019-01-24 06:50:54
# fit_dt_train_duration_seconds                      982
# fit_dt_train_end                   2019-01-24 06:50:28
# fit_dt_train_start                 2019-01-24 06:34:06
# fit_num_epochs                                      13
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.882943
# fit_train_acc                                 0.933065
# fit_train_loss                                0.186984
# fit_val_acc                                   0.959124
# fit_val_loss                                  0.143537
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                         0
# model_id                                          1817
# model_param_count                              7345154
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/1817/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      3
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2622  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         4
# fit_dt_test_end                    2019-01-24 11:58:53
# fit_dt_test_start                  2019-01-24 11:58:48
# fit_dt_train_duration_seconds                      574
# fit_dt_train_end                   2019-01-24 11:58:44
# fit_dt_train_start                 2019-01-24 11:49:09
# fit_num_epochs                                      21
# fit_stopped_epoch1                                  11
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   5
# fit_test_acc                                  0.898305
# fit_train_acc                                 0.940202
# fit_train_loss                                0.172484
# fit_val_acc                                   0.958824
# fit_val_loss                                  0.130525
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       128
# model_id                                          3409
# model_param_count                              5655426
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3409/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1433  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         5
# fit_dt_test_end                    2019-01-24 12:11:13
# fit_dt_test_start                  2019-01-24 12:11:08
# fit_dt_train_duration_seconds                      511
# fit_dt_train_end                   2019-01-24 12:11:02
# fit_dt_train_start                 2019-01-24 12:02:31
# fit_num_epochs                                      19
# fit_stopped_epoch1                                  12
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.881356
# fit_train_acc                                 0.938224
# fit_train_loss                                0.178718
# fit_val_acc                                   0.958824
# fit_val_loss                                   0.14835
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          3513
# model_param_count                              2886146
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3513/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1471  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         3
# fit_dt_test_end                    2019-01-24 11:49:12
# fit_dt_test_start                  2019-01-24 11:49:09
# fit_dt_train_duration_seconds                      450
# fit_dt_train_end                   2019-01-24 11:49:05
# fit_dt_train_start                 2019-01-24 11:41:34
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   6
# fit_stopped_epoch2                                   4
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.891525
# fit_train_acc                                 0.938412
# fit_train_loss                                 0.17791
# fit_val_acc                                   0.958824
# fit_val_loss                                  0.131405
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          3329
# model_param_count                              8656386
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3329/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2301  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         6
# fit_dt_test_end                    2019-01-24 12:45:27
# fit_dt_test_start                  2019-01-24 12:45:21
# fit_dt_train_duration_seconds                      541
# fit_dt_train_end                   2019-01-24 12:45:14
# fit_dt_train_start                 2019-01-24 12:36:13
# fit_num_epochs                                      18
# fit_stopped_epoch1                                  10
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.901695
# fit_train_acc                                 0.938601
# fit_train_loss                                0.173428
# fit_val_acc                                   0.958824
# fit_val_loss                                  0.133575
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       512
# layer_3_size                                       256
# model_id                                          3593
# model_param_count                              3083522
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3593/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2459  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         5
# fit_dt_test_end                    2019-01-24 12:25:05
# fit_dt_test_start                  2019-01-24 12:24:59
# fit_dt_train_duration_seconds                      628
# fit_dt_train_end                   2019-01-24 12:24:53
# fit_dt_train_start                 2019-01-24 12:14:24
# fit_num_epochs                                      26
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   9
# fit_stopped_epoch3                                   7
# fit_test_acc                                  0.901695
# fit_train_acc                                 0.943498
# fit_train_loss                                0.167495
# fit_val_acc                                   0.958088
# fit_val_loss                                  0.140882
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          3585
# model_param_count                              3739650
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3585/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1612  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                         5
# fit_dt_test_end                    2019-01-24 12:36:38
# fit_dt_test_start                  2019-01-24 12:36:32
# fit_dt_train_duration_seconds                      602
# fit_dt_train_end                   2019-01-24 12:36:27
# fit_dt_train_start                 2019-01-24 12:26:24
# fit_num_epochs                                      24
# fit_stopped_epoch1                                  13
# fit_stopped_epoch2                                   6
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.894915
# fit_train_acc                                 0.935681
# fit_train_loss                                0.180129
# fit_val_acc                                   0.958088
# fit_val_loss                                  0.140712
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       256
# layer_3_size                                       128
# model_id                                          3633
# model_param_count                              1673090
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3633/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1035  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         4
# fit_dt_test_end                    2019-01-24 12:02:22
# fit_dt_test_start                  2019-01-24 12:02:18
# fit_dt_train_duration_seconds                      481
# fit_dt_train_end                   2019-01-24 12:02:13
# fit_dt_train_start                 2019-01-24 11:54:11
# fit_num_epochs                                      18
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   6
# fit_test_acc                                  0.891525
# fit_train_acc                                 0.938036
# fit_train_loss                                0.173071
# fit_val_acc                                   0.958088
# fit_val_loss                                  0.143812
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                         0
# model_id                                          3481
# model_param_count                              3936258
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3481/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1377  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         7
# fit_dt_test_end                    2019-01-24 12:59:35
# fit_dt_test_start                  2019-01-24 12:59:28
# fit_dt_train_duration_seconds                      617
# fit_dt_train_end                   2019-01-24 12:59:19
# fit_dt_train_start                 2019-01-24 12:49:01
# fit_num_epochs                                      24
# fit_stopped_epoch1                                  16
# fit_stopped_epoch2                                   4
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.898305
# fit_train_acc                                 0.944628
# fit_train_loss                                0.160485
# fit_val_acc                                   0.958088
# fit_val_loss                                  0.124902
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       128
# layer_3_size                                         0
# model_id                                          3673
# model_param_count                              1246466
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3673/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2668  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               295
# data_total_rows_train                            10619
# data_total_rows_valid                             1360
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                         4
# fit_dt_test_end                    2019-01-24 12:11:13
# fit_dt_test_start                  2019-01-24 12:11:09
# fit_dt_train_duration_seconds                      438
# fit_dt_train_end                   2019-01-24 12:11:04
# fit_dt_train_start                 2019-01-24 12:03:45
# fit_num_epochs                                      15
# fit_stopped_epoch1                                   6
# fit_stopped_epoch2                                   5
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.881356
# fit_train_acc                                 0.938695
# fit_train_loss                                0.176167
# fit_val_acc                                   0.958088
# fit_val_loss                                   0.12348
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          3457
# model_param_count                              5247490
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/3457/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      5
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1877
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                               299
# data_total_rows_train                            10697
# data_total_rows_valid                             1370
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        17
# fit_dt_test_end                    2019-01-24 03:14:54
# fit_dt_test_start                  2019-01-24 03:14:36
# fit_dt_train_duration_seconds                      865
# fit_dt_train_end                   2019-01-24 03:14:17
# fit_dt_train_start                 2019-01-24 02:59:52
# fit_num_epochs                                      28
# fit_stopped_epoch1                                  15
# fit_stopped_epoch2                                   8
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.882943
# fit_train_acc                                 0.925774
# fit_train_loss                                0.208026
# fit_val_acc                                   0.957664
# fit_val_loss                                  0.148863
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          1853
# model_param_count                              4524802
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/1853/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                      3
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True

# %%
# we'll create experiments with same parameters as best 20 so far but now with longer sequence lengths
results_top20 = results[['architecture','layer_1_size','layer_2_size', 'layer_3_size','dropout','pretrained_model_name','pooling','sequence_length','sequence_model','sequence_model_layers']].head(20)
sequence_lengths = [15, 20]

# %%
# init list for extra experiments to append to outstanding experiments
experiments_next = []

# init model_id
model_id = model_id_start

# %%
###############################
### Try other pretrained models
###############################

pretrained_model_names = ['xception','inception_v3']

for pretrained_model_name in pretrained_model_names:
    for result in results_top20.values:
        
        # convert result params to dict to create experiment from
        result_dict = dict(zip(results_top20.columns, result))

        experiment = {}                    
        experiment['architecture'] = 'video_lrcnn_frozen'
        experiment['sequence_model'] = result_dict['sequence_model']
        experiment['sequence_model_layers'] = result_dict['sequence_model_layers']
        experiment['sequence_length'] = sequence_length
        experiment['pretrained_model_name'] = pretrained_model_name
        experiment['layer_1_size'] = result_dict['layer_1_size']
        experiment['layer_2_size'] = result_dict['layer_2_size']
        experiment['layer_3_size'] = result_dict['layer_3_size']
        experiment['dropout'] = result_dict['dropout']
        experiment['pooling'] = 'max' # always outperforms avg
        
        experiment['model_id'] = model_id
        
        # assign to worker
        experiment['WORKER'] = model_id % WORKER_COUNT

        # increment unique model id
        model_id +=1
        
        # add to list of additional experiments
        experiments_next.append(experiment)

# %%
##############################
### Try otber sequence lengths
##############################

pretrained_model_names = ['xception','inception_v3','resnet50']

for sequence_length in sequence_lengths:
    for pretrained_model_name in pretrained_model_names:
        for result in results_top20.values:

            # convert result params to dict to create experiment from
            result_dict = dict(zip(results_top20.columns, result))

            experiment = {}                    
            experiment['architecture'] = 'video_lrcnn_frozen'
            experiment['sequence_model'] = result_dict['sequence_model']
            experiment['sequence_model_layers'] = result_dict['sequence_model_layers']
            experiment['sequence_length'] = sequence_length
            experiment['pretrained_model_name'] = pretrained_model_name
            experiment['layer_1_size'] = result_dict['layer_1_size']
            experiment['layer_2_size'] = result_dict['layer_2_size']
            experiment['layer_3_size'] = result_dict['layer_3_size']
            experiment['dropout'] = result_dict['dropout']
            experiment['pooling'] = 'max' # always outperforms avg

            experiment['model_id'] = model_id

            # assign to worker
            experiment['WORKER'] = model_id % WORKER_COUNT

            # increment unique model id
            model_id +=1

            # add to list of additional experiments
            experiments_next.append(experiment)

# %%
# convert to dataframe
experiments_next = pd.DataFrame(experiments_next)
experiments_next.shape
# Out:
# (160, 12)

# %%
# merge new experiments onto outstanding experiments
experiments = pd.concat([experiments, experiments_next], axis = 0)
experiments.shape
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# (205, 12)

# %%
experiments.tail(100)
# Out:
#      WORKER        architecture  dropout  layer_1_size  layer_2_size  \
# 60       12  video_lrcnn_frozen      0.2           512           512
# 61       13  video_lrcnn_frozen      0.2           128           128
# 62       14  video_lrcnn_frozen      0.2           512           512
# 63       15  video_lrcnn_frozen      0.2           256           128
# 64        0  video_lrcnn_frozen      0.2           512           512
# 65        1  video_lrcnn_frozen      0.2           512           256
# 66        2  video_lrcnn_frozen      0.2           512           256
# 67        3  video_lrcnn_frozen      0.2           512           128
# 68        4  video_lrcnn_frozen      0.2           512           128
# 69        5  video_lrcnn_frozen      0.2           512           512
# 70        6  video_lrcnn_frozen      0.2           512           128
# 71        7  video_lrcnn_frozen      0.2           256           256
# 72        8  video_lrcnn_frozen      0.2           512           512
# 73        9  video_lrcnn_frozen      0.2           128           512
# 74       10  video_lrcnn_frozen      0.2           128           512
# 75       11  video_lrcnn_frozen      0.2           128           256
# 76       12  video_lrcnn_frozen      0.2           256           512
# 77       13  video_lrcnn_frozen      0.2           128           128
# 78       14  video_lrcnn_frozen      0.2           256           512
# 79       15  video_lrcnn_frozen      0.2           512           256
# 80        0  video_lrcnn_frozen      0.2           512           512
# 81        1  video_lrcnn_frozen      0.2           128           128
# 82        2  video_lrcnn_frozen      0.2           512           512
# 83        3  video_lrcnn_frozen      0.2           256           128
# 84        4  video_lrcnn_frozen      0.2           512           512
# 85        5  video_lrcnn_frozen      0.2           512           256
# 86        6  video_lrcnn_frozen      0.2           512           256
# 87        7  video_lrcnn_frozen      0.2           512           128
# 88        8  video_lrcnn_frozen      0.2           512           128
# 89        9  video_lrcnn_frozen      0.2           512           512
# 90       10  video_lrcnn_frozen      0.2           512           128
# 91       11  video_lrcnn_frozen      0.2           256           256
# 92       12  video_lrcnn_frozen      0.2           512           512
# 93       13  video_lrcnn_frozen      0.2           128           512
# 94       14  video_lrcnn_frozen      0.2           128           512
# 95       15  video_lrcnn_frozen      0.2           128           256
# 96        0  video_lrcnn_frozen      0.2           256           512
# 97        1  video_lrcnn_frozen      0.2           128           128
# 98        2  video_lrcnn_frozen      0.2           256           512
# 99        3  video_lrcnn_frozen      0.2           512           256
# 100       4  video_lrcnn_frozen      0.2           512           512
# 101       5  video_lrcnn_frozen      0.2           128           128
# 102       6  video_lrcnn_frozen      0.2           512           512
# 103       7  video_lrcnn_frozen      0.2           256           128
# 104       8  video_lrcnn_frozen      0.2           512           512
# 105       9  video_lrcnn_frozen      0.2           512           256
# 106      10  video_lrcnn_frozen      0.2           512           256
# 107      11  video_lrcnn_frozen      0.2           512           128
# 108      12  video_lrcnn_frozen      0.2           512           128
# 109      13  video_lrcnn_frozen      0.2           512           512
# 110      14  video_lrcnn_frozen      0.2           512           128
# 111      15  video_lrcnn_frozen      0.2           256           256
# 112       0  video_lrcnn_frozen      0.2           512           512
# 113       1  video_lrcnn_frozen      0.2           128           512
# 114       2  video_lrcnn_frozen      0.2           128           512
# 115       3  video_lrcnn_frozen      0.2           128           256
# 116       4  video_lrcnn_frozen      0.2           256           512
# 117       5  video_lrcnn_frozen      0.2           128           128
# 118       6  video_lrcnn_frozen      0.2           256           512
# 119       7  video_lrcnn_frozen      0.2           512           256
# 120       8  video_lrcnn_frozen      0.2           512           512
# 121       9  video_lrcnn_frozen      0.2           128           128
# 122      10  video_lrcnn_frozen      0.2           512           512
# 123      11  video_lrcnn_frozen      0.2           256           128
# 124      12  video_lrcnn_frozen      0.2           512           512
# 125      13  video_lrcnn_frozen      0.2           512           256
# 126      14  video_lrcnn_frozen      0.2           512           256
# 127      15  video_lrcnn_frozen      0.2           512           128
# 128       0  video_lrcnn_frozen      0.2           512           128
# 129       1  video_lrcnn_frozen      0.2           512           512
# 130       2  video_lrcnn_frozen      0.2           512           128
# 131       3  video_lrcnn_frozen      0.2           256           256
# 132       4  video_lrcnn_frozen      0.2           512           512
# 133       5  video_lrcnn_frozen      0.2           128           512
# 134       6  video_lrcnn_frozen      0.2           128           512
# 135       7  video_lrcnn_frozen      0.2           128           256
# 136       8  video_lrcnn_frozen      0.2           256           512
# 137       9  video_lrcnn_frozen      0.2           128           128
# 138      10  video_lrcnn_frozen      0.2           256           512
# 139      11  video_lrcnn_frozen      0.2           512           256
# 140      12  video_lrcnn_frozen      0.2           512           512
# 141      13  video_lrcnn_frozen      0.2           128           128
# 142      14  video_lrcnn_frozen      0.2           512           512
# 143      15  video_lrcnn_frozen      0.2           256           128
# 144       0  video_lrcnn_frozen      0.2           512           512
# 145       1  video_lrcnn_frozen      0.2           512           256
# 146       2  video_lrcnn_frozen      0.2           512           256
# 147       3  video_lrcnn_frozen      0.2           512           128
# 148       4  video_lrcnn_frozen      0.2           512           128
# 149       5  video_lrcnn_frozen      0.2           512           512
# 150       6  video_lrcnn_frozen      0.2           512           128
# 151       7  video_lrcnn_frozen      0.2           256           256
# 152       8  video_lrcnn_frozen      0.2           512           512
# 153       9  video_lrcnn_frozen      0.2           128           512
# 154      10  video_lrcnn_frozen      0.2           128           512
# 155      11  video_lrcnn_frozen      0.2           128           256
# 156      12  video_lrcnn_frozen      0.2           256           512
# 157      13  video_lrcnn_frozen      0.2           128           128
# 158      14  video_lrcnn_frozen      0.2           256           512
# 159      15  video_lrcnn_frozen      0.2           512           256
#
#      layer_3_size  model_id pooling pretrained_model_name  sequence_length  \
# 60            256      5308     max          inception_v3               15
# 61            256      5309     max          inception_v3               15
# 62            128      5310     max          inception_v3               15
# 63              0      5311     max          inception_v3               15
# 64            512      5312     max          inception_v3               15
# 65            256      5313     max          inception_v3               15
# 66              0      5314     max          inception_v3               15
# 67            512      5315     max          inception_v3               15
# 68            256      5316     max          inception_v3               15
# 69              0      5317     max          inception_v3               15
# 70            128      5318     max          inception_v3               15
# 71              0      5319     max          inception_v3               15
# 72            512      5320     max          inception_v3               15
# 73            256      5321     max          inception_v3               15
# 74            512      5322     max          inception_v3               15
# 75            128      5323     max          inception_v3               15
# 76              0      5324     max          inception_v3               15
# 77              0      5325     max          inception_v3               15
# 78            512      5326     max          inception_v3               15
# 79              0      5327     max          inception_v3               15
# 80            256      5328     max              resnet50               15
# 81            256      5329     max              resnet50               15
# 82            128      5330     max              resnet50               15
# 83              0      5331     max              resnet50               15
# 84            512      5332     max              resnet50               15
# 85            256      5333     max              resnet50               15
# 86              0      5334     max              resnet50               15
# 87            512      5335     max              resnet50               15
# 88            256      5336     max              resnet50               15
# 89              0      5337     max              resnet50               15
# 90            128      5338     max              resnet50               15
# 91              0      5339     max              resnet50               15
# 92            512      5340     max              resnet50               15
# 93            256      5341     max              resnet50               15
# 94            512      5342     max              resnet50               15
# 95            128      5343     max              resnet50               15
# 96              0      5344     max              resnet50               15
# 97              0      5345     max              resnet50               15
# 98            512      5346     max              resnet50               15
# 99              0      5347     max              resnet50               15
# 100           256      5348     max              xception               20
# 101           256      5349     max              xception               20
# 102           128      5350     max              xception               20
# 103             0      5351     max              xception               20
# 104           512      5352     max              xception               20
# 105           256      5353     max              xception               20
# 106             0      5354     max              xception               20
# 107           512      5355     max              xception               20
# 108           256      5356     max              xception               20
# 109             0      5357     max              xception               20
# 110           128      5358     max              xception               20
# 111             0      5359     max              xception               20
# 112           512      5360     max              xception               20
# 113           256      5361     max              xception               20
# 114           512      5362     max              xception               20
# 115           128      5363     max              xception               20
# 116             0      5364     max              xception               20
# 117             0      5365     max              xception               20
# 118           512      5366     max              xception               20
# 119             0      5367     max              xception               20
# 120           256      5368     max          inception_v3               20
# 121           256      5369     max          inception_v3               20
# 122           128      5370     max          inception_v3               20
# 123             0      5371     max          inception_v3               20
# 124           512      5372     max          inception_v3               20
# 125           256      5373     max          inception_v3               20
# 126             0      5374     max          inception_v3               20
# 127           512      5375     max          inception_v3               20
# 128           256      5376     max          inception_v3               20
# 129             0      5377     max          inception_v3               20
# 130           128      5378     max          inception_v3               20
# 131             0      5379     max          inception_v3               20
# 132           512      5380     max          inception_v3               20
# 133           256      5381     max          inception_v3               20
# 134           512      5382     max          inception_v3               20
# 135           128      5383     max          inception_v3               20
# 136             0      5384     max          inception_v3               20
# 137             0      5385     max          inception_v3               20
# 138           512      5386     max          inception_v3               20
# 139             0      5387     max          inception_v3               20
# 140           256      5388     max              resnet50               20
# 141           256      5389     max              resnet50               20
# 142           128      5390     max              resnet50               20
# 143             0      5391     max              resnet50               20
# 144           512      5392     max              resnet50               20
# 145           256      5393     max              resnet50               20
# 146             0      5394     max              resnet50               20
# 147           512      5395     max              resnet50               20
# 148           256      5396     max              resnet50               20
# 149             0      5397     max              resnet50               20
# 150           128      5398     max              resnet50               20
# 151             0      5399     max              resnet50               20
# 152           512      5400     max              resnet50               20
# 153           256      5401     max              resnet50               20
# 154           512      5402     max              resnet50               20
# 155           128      5403     max              resnet50               20
# 156             0      5404     max              resnet50               20
# 157             0      5405     max              resnet50               20
# 158           512      5406     max              resnet50               20
# 159             0      5407     max              resnet50               20
#
#     sequence_model  sequence_model_layers
# 60            LSTM                    2.0
# 61            LSTM                    2.0
# 62            LSTM                    2.0
# 63            LSTM                    2.0
# 64             GRU                    2.0
# 65            LSTM                    2.0
# 66            LSTM                    2.0
# 67            LSTM                    2.0
# 68            LSTM                    2.0
# 69            LSTM                    2.0
# 70            LSTM                    2.0
# 71            LSTM                    2.0
# 72            LSTM                    2.0
# 73            LSTM                    2.0
# 74            LSTM                    2.0
# 75            LSTM                    2.0
# 76            LSTM                    2.0
# 77            LSTM                    2.0
# 78            LSTM                    2.0
# 79             GRU                    2.0
# 80            LSTM                    2.0
# 81            LSTM                    2.0
# 82            LSTM                    2.0
# 83            LSTM                    2.0
# 84             GRU                    2.0
# 85            LSTM                    2.0
# 86            LSTM                    2.0
# 87            LSTM                    2.0
# 88            LSTM                    2.0
# 89            LSTM                    2.0
# 90            LSTM                    2.0
# 91            LSTM                    2.0
# 92            LSTM                    2.0
# 93            LSTM                    2.0
# 94            LSTM                    2.0
# 95            LSTM                    2.0
# 96            LSTM                    2.0
# 97            LSTM                    2.0
# 98            LSTM                    2.0
# 99             GRU                    2.0
# 100           LSTM                    2.0
# 101           LSTM                    2.0
# 102           LSTM                    2.0
# 103           LSTM                    2.0
# 104            GRU                    2.0
# 105           LSTM                    2.0
# 106           LSTM                    2.0
# 107           LSTM                    2.0
# 108           LSTM                    2.0
# 109           LSTM                    2.0
# 110           LSTM                    2.0
# 111           LSTM                    2.0
# 112           LSTM                    2.0
# 113           LSTM                    2.0
# 114           LSTM                    2.0
# 115           LSTM                    2.0
# 116           LSTM                    2.0
# 117           LSTM                    2.0
# 118           LSTM                    2.0
# 119            GRU                    2.0
# 120           LSTM                    2.0
# 121           LSTM                    2.0
# 122           LSTM                    2.0
# 123           LSTM                    2.0
# 124            GRU                    2.0
# 125           LSTM                    2.0
# 126           LSTM                    2.0
# 127           LSTM                    2.0
# 128           LSTM                    2.0
# 129           LSTM                    2.0
# 130           LSTM                    2.0
# 131           LSTM                    2.0
# 132           LSTM                    2.0
# 133           LSTM                    2.0
# 134           LSTM                    2.0
# 135           LSTM                    2.0
# 136           LSTM                    2.0
# 137           LSTM                    2.0
# 138           LSTM                    2.0
# 139            GRU                    2.0
# 140           LSTM                    2.0
# 141           LSTM                    2.0
# 142           LSTM                    2.0
# 143           LSTM                    2.0
# 144            GRU                    2.0
# 145           LSTM                    2.0
# 146           LSTM                    2.0
# 147           LSTM                    2.0
# 148           LSTM                    2.0
# 149           LSTM                    2.0
# 150           LSTM                    2.0
# 151           LSTM                    2.0
# 152           LSTM                    2.0
# 153           LSTM                    2.0
# 154           LSTM                    2.0
# 155           LSTM                    2.0
# 156           LSTM                    2.0
# 157           LSTM                    2.0
# 158           LSTM                    2.0
# 159            GRU                    2.0

# %%
experiments['WORKER'].value_counts()
# Out:
# 3     19
# 5     18
# 1     18
# 4     17
# 0     17
# 2     16
# 15    10
# 14    10
# 13    10
# 12    10
# 11    10
# 10    10
# 9     10
# 8     10
# 7     10
# 6     10
# Name: WORKER, dtype: int64

# %%
experiments = reassign_workers(experiments)

# %%
experiments['WORKER'].value_counts()
# Out:
# 13    13
# 12    13
# 11    13
# 10    13
# 9     13
# 8     13
# 7     13
# 6     13
# 5     13
# 4     13
# 3     13
# 2     13
# 1     13
# 15    12
# 14    12
# 0     12
# Name: WORKER, dtype: int64

# %%
##################################
### output experiment batch to CSV
##################################
print(experiment_batch_name)
experiments.to_csv(pwd + "experiments/" + experiment_batch_name + '.csv', index=False)
# Out:
# experiment_batch_2

# %%
# # upload to s3
# response = os.system("aws s3 cp " + pwd + "experiments/" + experiment_batch_name + '.csv s3://thesisvids/seals/' + experiment_batch_name + '.csv')
# if response == 0:
#     print("upload success")
# else:
#     print("upload error")

# %%
# # upload to GCP
response = os.system("gsutil cp " + pwd + "experiments/" + experiment_batch_name + '.csv gs://thesis-seals/' + experiment_batch_name + '.csv')
if response == 0:
    print("upload success")
else:
    print("upload error")
# Out:
# upload success

# %% [markdown]
# # Batch 3

# %%
# run trainable MLP and LRCNN on best performing frozen variants

# %%
#######################
### image_MLP_trainable
#######################

architecture = 'video_LRCNN_trainable'

# %%
#########################
### video_LRCNN_trainable
#########################

architecture = 'video_LRCNN_trainable'

# %% [markdown]
# # Batch 4

# %%
# run trainable but initializing with best CNN weights

# %% [markdown]
# # Batch 5

# %% [markdown]
# # Analyze results from batch 1

# %% [markdown]
# ## load results.json for all models into dataframe

# %%
results = get_results()

# %%
results.head(20).T
# Out:
#                                                   1072  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        15
# fit_dt_test_end                    2019-01-24 07:02:41
# fit_dt_test_start                  2019-01-24 07:02:26
# fit_dt_train_duration_seconds                     3044
# fit_dt_train_end                   2019-01-24 07:02:13
# fit_dt_train_start                 2019-01-24 06:11:29
# fit_num_epochs                                      13
# fit_stopped_epoch1                                   3
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   5
# fit_test_acc                                  0.720128
# fit_train_acc                                 0.975014
# fit_train_loss                               0.0631126
# fit_val_acc                                   0.957799
# fit_val_loss                                  0.126539
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       256
# model_id                                          4489
# model_param_count                              3675143
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4489/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   188   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        31
# fit_dt_test_end                    2019-01-23 03:34:38
# fit_dt_test_start                  2019-01-23 03:34:06
# fit_dt_train_duration_seconds                     2353
# fit_dt_train_end                   2019-01-23 03:33:45
# fit_dt_train_start                 2019-01-23 02:54:32
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   3
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   8
# fit_test_acc                                  0.718211
# fit_train_acc                                 0.962239
# fit_train_loss                               0.0941855
# fit_val_acc                                   0.957509
# fit_val_loss                                   0.12245
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                         0
# model_id                                          4571
# model_param_count                               247047
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4571/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1888  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        26
# fit_dt_test_end                    2019-01-22 22:58:13
# fit_dt_test_start                  2019-01-22 22:57:46
# fit_dt_train_duration_seconds                     2099
# fit_dt_train_end                   2019-01-22 22:57:28
# fit_dt_train_start                 2019-01-22 22:22:28
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   5
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.725559
# fit_train_acc                                   0.9614
# fit_train_loss                               0.0962222
# fit_val_acc                                   0.956348
# fit_val_loss                                  0.119364
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          4411
# model_param_count                               723463
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4411/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2710  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        12
# fit_dt_test_end                    2019-01-24 03:25:23
# fit_dt_test_start                  2019-01-24 03:25:11
# fit_dt_train_duration_seconds                     3429
# fit_dt_train_end                   2019-01-24 03:25:01
# fit_dt_train_start                 2019-01-24 02:27:51
# fit_num_epochs                                      19
# fit_stopped_epoch1                                   9
# fit_stopped_epoch2                                   4
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.739297
# fit_train_acc                                 0.971963
# fit_train_loss                               0.0703405
# fit_val_acc                                   0.956125
# fit_val_loss                                  0.134741
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       128
# model_id                                          4437
# model_param_count                              1985415
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4437/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2657  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        27
# fit_dt_test_end                    2019-01-23 00:18:48
# fit_dt_test_start                  2019-01-23 00:18:20
# fit_dt_train_duration_seconds                     3032
# fit_dt_train_end                   2019-01-23 00:17:58
# fit_dt_train_start                 2019-01-22 23:27:25
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   2
# fit_stopped_epoch2                                   7
# fit_stopped_epoch3                                   5
# fit_test_acc                                  0.705431
# fit_train_acc                                 0.970104
# fit_train_loss                               0.0751278
# fit_val_acc                                    0.95541
# fit_val_loss                                  0.124405
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          4416
# model_param_count                              2234503
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4416/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                1
# verbose                                           True
#
#                                                   2604  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        15
# fit_dt_test_end                    2019-01-24 08:58:42
# fit_dt_test_start                  2019-01-24 08:58:26
# fit_dt_train_duration_seconds                     3092
# fit_dt_train_end                   2019-01-24 08:58:13
# fit_dt_train_start                 2019-01-24 08:06:40
# fit_num_epochs                                      16
# fit_stopped_epoch1                                   3
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   9
# fit_test_acc                                  0.751118
# fit_train_acc                                  0.97165
# fit_train_loss                               0.0703449
# fit_val_acc                                   0.955366
# fit_val_loss                                  0.150802
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          4613
# model_param_count                              3856263
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4613/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2956  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        28
# fit_dt_test_end                    2019-01-23 02:47:19
# fit_dt_test_start                  2019-01-23 02:46:50
# fit_dt_train_duration_seconds                     2599
# fit_dt_train_end                   2019-01-23 02:46:29
# fit_dt_train_start                 2019-01-23 02:03:09
# fit_num_epochs                                      20
# fit_stopped_epoch1                                   8
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   6
# fit_test_acc                                  0.715974
# fit_train_acc                                 0.964999
# fit_train_loss                               0.0854755
# fit_val_acc                                   0.955254
# fit_val_loss                                   0.14009
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                       256
# model_id                                          4555
# model_param_count                               575879
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4555/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2739  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        13
# fit_dt_test_end                    2019-01-24 04:40:24
# fit_dt_test_start                  2019-01-24 04:40:11
# fit_dt_train_duration_seconds                     2970
# fit_dt_train_end                   2019-01-24 04:40:00
# fit_dt_train_start                 2019-01-24 03:50:30
# fit_num_epochs                                      16
# fit_stopped_epoch1                                   9
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.715974
# fit_train_acc                                 0.971615
# fit_train_loss                                0.071042
# fit_val_acc                                   0.954874
# fit_val_loss                                  0.148972
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       128
# model_id                                          4501
# model_param_count                              2428167
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4501/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   3143  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        23
# fit_dt_test_end                    2019-01-22 20:03:14
# fit_dt_test_start                  2019-01-22 20:02:51
# fit_dt_train_duration_seconds                     2018
# fit_dt_train_end                   2019-01-22 20:02:34
# fit_dt_train_start                 2019-01-22 19:28:56
# fit_num_epochs                                      13
# fit_stopped_epoch1                                   4
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.743131
# fit_train_acc                                 0.961875
# fit_train_loss                               0.0955466
# fit_val_acc                                    0.95483
# fit_val_loss                                  0.142788
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       256
# model_id                                          4491
# model_param_count                              1903367
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4491/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   266   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        31
# fit_dt_test_end                    2019-01-23 02:54:16
# fit_dt_test_start                  2019-01-23 02:53:45
# fit_dt_train_duration_seconds                     2232
# fit_dt_train_end                   2019-01-23 02:53:25
# fit_dt_train_start                 2019-01-23 02:16:12
# fit_num_epochs                                      15
# fit_stopped_epoch1                                   6
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.733227
# fit_train_acc                                 0.966951
# fit_train_loss                               0.0808926
# fit_val_acc                                   0.954718
# fit_val_loss                                  0.149937
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          4547
# model_param_count                               905607
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4547/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   288   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       1
# fit_dt_test_duration_seconds                        16
# fit_dt_test_end                    2019-01-24 08:16:05
# fit_dt_test_start                  2019-01-24 08:15:48
# fit_dt_train_duration_seconds                     3145
# fit_dt_train_end                   2019-01-24 08:15:34
# fit_dt_train_start                 2019-01-24 07:23:09
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   7
# fit_test_acc                                  0.717891
# fit_train_acc                                 0.960804
# fit_train_loss                               0.0969487
# fit_val_acc                                   0.954718
# fit_val_loss                                  0.123454
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       256
# layer_3_size                                       512
# model_id                                          4645
# model_param_count                              1856647
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4645/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   3129  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        26
# fit_dt_test_end                    2019-01-22 22:31:36
# fit_dt_test_start                  2019-01-22 22:31:09
# fit_dt_train_duration_seconds                     2598
# fit_dt_train_end                   2019-01-22 22:30:53
# fit_dt_train_start                 2019-01-22 21:47:34
# fit_num_epochs                                      16
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   4
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.731629
# fit_train_acc                                 0.963791
# fit_train_loss                               0.0897246
# fit_val_acc                                   0.954584
# fit_val_loss                                  0.168421
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          4355
# model_param_count                              3675143
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4355/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   3205  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        12
# fit_dt_test_end                    2019-01-24 04:15:48
# fit_dt_test_start                  2019-01-24 04:15:36
# fit_dt_train_duration_seconds                     3505
# fit_dt_train_end                   2019-01-24 04:15:25
# fit_dt_train_start                 2019-01-24 03:16:59
# fit_num_epochs                                      20
# fit_stopped_epoch1                                   8
# fit_stopped_epoch2                                   6
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.719808
# fit_train_acc                                  0.97165
# fit_train_loss                               0.0714867
# fit_val_acc                                    0.95445
# fit_val_loss                                  0.139677
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          4421
# model_param_count                              2480007
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4421/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   3009  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        14
# fit_dt_test_end                    2019-01-24 06:08:33
# fit_dt_test_start                  2019-01-24 06:08:18
# fit_dt_train_duration_seconds                     2739
# fit_dt_train_end                   2019-01-24 06:08:06
# fit_dt_train_start                 2019-01-24 05:22:27
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.714377
# fit_train_acc                                 0.970312
# fit_train_loss                               0.0736213
# fit_val_acc                                   0.954428
# fit_val_loss                                  0.151277
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          4549
# model_param_count                              1397895
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4549/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   21    \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        17
# fit_dt_test_end                    2019-01-24 11:12:10
# fit_dt_test_start                  2019-01-24 11:11:52
# fit_dt_train_duration_seconds                     4573
# fit_dt_train_end                   2019-01-24 11:11:37
# fit_dt_train_start                 2019-01-24 09:55:24
# fit_num_epochs                                      23
# fit_stopped_epoch1                                   4
# fit_stopped_epoch2                                   7
# fit_stopped_epoch3                                   9
# fit_test_acc                                  0.747284
# fit_train_acc                                 0.976998
# fit_train_loss                               0.0573789
# fit_val_acc                                   0.954428
# fit_val_loss                                   0.13865
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          4609
# model_param_count                              4266503
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4609/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1989  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        16
# fit_dt_test_end                    2019-01-24 08:23:52
# fit_dt_test_start                  2019-01-24 08:23:36
# fit_dt_train_duration_seconds                     3430
# fit_dt_train_end                   2019-01-24 08:23:22
# fit_dt_train_start                 2019-01-24 07:26:12
# fit_num_epochs                                      15
# fit_stopped_epoch1                                   1
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   8
# fit_test_acc                                  0.727157
# fit_train_acc                                 0.973207
# fit_train_loss                               0.0657737
# fit_val_acc                                   0.954294
# fit_val_loss                                  0.135616
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       256
# layer_3_size                                       128
# model_id                                          4529
# model_param_count                              1641479
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4529/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   434   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        18
# fit_dt_test_end                    2019-01-24 11:52:30
# fit_dt_test_start                  2019-01-24 11:52:12
# fit_dt_train_duration_seconds                     4078
# fit_dt_train_end                   2019-01-24 11:51:57
# fit_dt_train_start                 2019-01-24 10:43:58
# fit_num_epochs                                      20
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   6
# fit_stopped_epoch3                                   6
# fit_test_acc                                  0.723642
# fit_train_acc                                 0.976899
# fit_train_loss                               0.0571156
# fit_val_acc                                   0.954204
# fit_val_loss                                  0.149119
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       256
# layer_3_size                                       512
# model_id                                          4641
# model_param_count                              2037255
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4641/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2991  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        25
# fit_dt_test_end                    2019-01-22 22:22:13
# fit_dt_test_start                  2019-01-22 22:21:48
# fit_dt_train_duration_seconds                     1787
# fit_dt_train_end                   2019-01-22 22:21:30
# fit_dt_train_start                 2019-01-22 21:51:43
# fit_num_epochs                                       9
# fit_stopped_epoch1                                   2
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.728115
# fit_train_acc                                 0.965428
# fit_train_loss                               0.0858048
# fit_val_acc                                   0.954026
# fit_val_loss                                  0.138702
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                       512
# model_id                                          4387
# model_param_count                              2036487
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4387/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   553   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        15
# fit_dt_test_end                    2019-01-24 09:04:38
# fit_dt_test_start                  2019-01-24 09:04:22
# fit_dt_train_duration_seconds                     1739
# fit_dt_train_end                   2019-01-24 09:04:09
# fit_dt_train_start                 2019-01-24 08:35:10
# fit_num_epochs                                      11
# fit_stopped_epoch1                                   1
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.684026
# fit_train_acc                                  0.96275
# fit_train_loss                               0.0923405
# fit_val_acc                                   0.954026
# fit_val_loss                                  0.125062
# frame_size                                  [224, 224]
# layer_1_size                                       128
# layer_2_size                                       256
# layer_3_size                                       256
# model_id                                          4648
# model_param_count                               428807
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4648/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                1
# verbose                                           True
#
#                                                   1117
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       1
# fit_dt_test_duration_seconds                        10
# fit_dt_test_end                    2019-01-24 00:57:23
# fit_dt_test_start                  2019-01-24 00:57:12
# fit_dt_train_duration_seconds                     2710
# fit_dt_train_end                   2019-01-24 00:57:03
# fit_dt_train_start                 2019-01-24 00:11:53
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   7
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   2
# fit_test_acc                                    0.7377
# fit_train_acc                                  0.96131
# fit_train_loss                               0.0980074
# fit_val_acc                                   0.953981
# fit_val_loss                                   0.13356
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       512
# layer_3_size                                       512
# model_id                                          4357
# model_param_count                              5774343
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4357/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True

# %% [markdown]
# > top 20 models all `video_lrcnn_frozen` with `vgg16` and `LSTM`, `SimpleRNN`, `GRU` sequence models and sequence_length = 10 ... we'll re-run these with sequence length = 15 and 20 for batch 2

# %%
# results[results['model_id'].isin([362, 550, 162, 133, 3115, 3125])].T

# %% [markdown]
# ## results per architecture

# %%
results[results['architecture'] == 'video_mlp_concat'].head(5).T
# Out:
#                                                  1074                    1192  \
# architecture                         video_mlp_concat        video_mlp_concat
# batch_size                                         32                      32
# convolution_kernel_size                             3                       3
# data_total_rows_test                             3137                    3135
# data_total_rows_train                           60553                   60509
# data_total_rows_valid                            6412                    6408
# dropout                                           0.2                     0.2
# fit_best_round                                      3                       3
# fit_dt_test_duration_seconds                        1                       0
# fit_dt_test_end                   2019-01-20 21:15:03     2019-01-20 23:33:37
# fit_dt_test_start                 2019-01-20 21:15:01     2019-01-20 23:33:36
# fit_dt_train_duration_seconds                     565                     462
# fit_dt_train_end                  2019-01-20 21:15:00     2019-01-20 23:33:35
# fit_dt_train_start                2019-01-20 21:05:35     2019-01-20 23:25:52
# fit_num_epochs                                     26                      20
# fit_stopped_epoch1                                 13                      11
# fit_stopped_epoch2                                  5                       3
# fit_stopped_epoch3                                  5                       3
# fit_test_acc                                 0.652215                 0.63126
# fit_train_acc                                0.968797                0.962327
# fit_train_loss                              0.0797652               0.0901754
# fit_val_acc                                  0.948735                0.948301
# fit_val_loss                                 0.154703                0.163788
# frame_size                                 [224, 224]              [224, 224]
# layer_1_size                                      128                     128
# layer_2_size                                      128                     256
# layer_3_size                                      128                     128
# model_id                                          362                     550
# model_param_count                              820487                 1377671
# model_weights_path                               None                    None
# num_features                                     2048                    2048
# path_model                     /mnt/seals/models/362/  /mnt/seals/models/550/
# pooling                                           max                     max
# pretrained_model_name                        resnet50                resnet50
# sequence_length                                     3                       5
# sequence_model                                    NaN                     NaN
# sequence_model_layers                             NaN                     NaN
# verbose                                          True                    True
#
#                                                  1701                    2883  \
# architecture                         video_mlp_concat        video_mlp_concat
# batch_size                                         32                      32
# convolution_kernel_size                             3                       3
# data_total_rows_test                             3137                    3137
# data_total_rows_train                           60553                   60553
# data_total_rows_valid                            6412                    6412
# dropout                                           0.2                     0.2
# fit_best_round                                      2                       1
# fit_dt_test_duration_seconds                        1                       0
# fit_dt_test_end                   2019-01-20 21:37:34     2019-01-20 20:46:20
# fit_dt_test_start                 2019-01-20 21:37:33     2019-01-20 20:46:20
# fit_dt_train_duration_seconds                     485                     697
# fit_dt_train_end                  2019-01-20 21:37:31     2019-01-20 20:46:19
# fit_dt_train_start                2019-01-20 21:29:26     2019-01-20 20:34:41
# fit_num_epochs                                     20                      31
# fit_stopped_epoch1                                  3                      19
# fit_stopped_epoch2                                  3                       5
# fit_stopped_epoch3                                 11                       4
# fit_test_acc                                 0.677399                0.667836
# fit_train_acc                                0.965065                0.959415
# fit_train_loss                              0.0911788                0.108582
# fit_val_acc                                  0.947821                0.947442
# fit_val_loss                                 0.147359                0.162217
# frame_size                                 [224, 224]              [224, 224]
# layer_1_size                                      128                     512
# layer_2_size                                      256                     512
# layer_3_size                                      256                     256
# model_id                                          357                     321
# model_param_count                              887175                 3542023
# model_weights_path                               None                    None
# num_features                                     2048                    2048
# path_model                     /mnt/seals/models/357/  /mnt/seals/models/321/
# pooling                                           max                     max
# pretrained_model_name                        resnet50                resnet50
# sequence_length                                     3                       3
# sequence_model                                    NaN                     NaN
# sequence_model_layers                             NaN                     NaN
# verbose                                          True                    True
#
#                                                  3131
# architecture                         video_mlp_concat
# batch_size                                         32
# convolution_kernel_size                             3
# data_total_rows_test                             3137
# data_total_rows_train                           60553
# data_total_rows_valid                            6412
# dropout                                           0.2
# fit_best_round                                      2
# fit_dt_test_duration_seconds                        0
# fit_dt_test_end                   2019-01-20 21:17:15
# fit_dt_test_start                 2019-01-20 21:17:14
# fit_dt_train_duration_seconds                     279
# fit_dt_train_end                  2019-01-20 21:17:13
# fit_dt_train_start                2019-01-20 21:12:34
# fit_num_epochs                                     12
# fit_stopped_epoch1                                  4
# fit_stopped_epoch2                                  4
# fit_stopped_epoch3                                  1
# fit_test_acc                                 0.651578
# fit_train_acc                                0.959091
# fit_train_loss                                0.10098
# fit_val_acc                                  0.947375
# fit_val_loss                                   0.1535
# frame_size                                 [224, 224]
# layer_1_size                                      128
# layer_2_size                                      128
# layer_3_size                                        0
# model_id                                          363
# model_param_count                              803975
# model_weights_path                               None
# num_features                                     2048
# path_model                     /mnt/seals/models/363/
# pooling                                           max
# pretrained_model_name                        resnet50
# sequence_length                                     3
# sequence_model                                    NaN
# sequence_model_layers                             NaN
# verbose                                          True

# %%
results[results['architecture'] == 'image_mlp_frozen'].head(5).T
# Out:
#                                                  2453                    2419  \
# architecture                         image_mlp_frozen        image_mlp_frozen
# batch_size                                         32                      32
# convolution_kernel_size                             3                       3
# data_total_rows_test                             3139                    3139
# data_total_rows_train                           60597                   60597
# data_total_rows_valid                            6416                    6416
# dropout                                           0.2                     0.2
# fit_best_round                                      2                       2
# fit_dt_test_duration_seconds                        2                       1
# fit_dt_test_end                   2019-01-20 14:25:08     2019-01-20 14:01:02
# fit_dt_test_start                 2019-01-20 14:25:05     2019-01-20 14:01:01
# fit_dt_train_duration_seconds                     264                     349
# fit_dt_train_end                  2019-01-20 14:25:03     2019-01-20 14:00:58
# fit_dt_train_start                2019-01-20 14:20:38     2019-01-20 13:55:09
# fit_num_epochs                                      9                      13
# fit_stopped_epoch1                                  2                       3
# fit_stopped_epoch2                                  3                       4
# fit_stopped_epoch3                                  1                       3
# fit_test_acc                                 0.668366                0.668684
# fit_train_acc                                 0.96592                0.970854
# fit_train_loss                              0.0835667                0.070594
# fit_val_acc                                  0.946495                0.944937
# fit_val_loss                                 0.149519                 0.16432
# frame_size                                 [224, 224]              [224, 224]
# layer_1_size                                      128                     512
# layer_2_size                                      512                     256
# layer_3_size                                      128                     256
# model_id                                          162                     133
# model_param_count                              394887                 1248007
# model_weights_path                               None                    None
# num_features                                     2048                    2048
# path_model                     /mnt/seals/models/162/  /mnt/seals/models/133/
# pooling                                           max                     max
# pretrained_model_name                        resnet50                resnet50
# sequence_length                                     1                       1
# sequence_model                                    NaN                     NaN
# sequence_model_layers                             NaN                     NaN
# verbose                                          True                    True
#
#                                                  1196                    2933  \
# architecture                         image_mlp_frozen        image_mlp_frozen
# batch_size                                         32                      32
# convolution_kernel_size                             3                       3
# data_total_rows_test                             3139                    3139
# data_total_rows_train                           60597                   60597
# data_total_rows_valid                            6416                    6416
# dropout                                           0.2                     0.2
# fit_best_round                                      2                       3
# fit_dt_test_duration_seconds                        1                       1
# fit_dt_test_end                   2019-01-20 14:07:05     2019-01-20 13:54:52
# fit_dt_test_start                 2019-01-20 14:07:04     2019-01-20 13:54:50
# fit_dt_train_duration_seconds                     191                     246
# fit_dt_train_end                  2019-01-20 14:07:02     2019-01-20 13:54:47
# fit_dt_train_start                2019-01-20 14:03:50     2019-01-20 13:50:40
# fit_num_epochs                                      8                      12
# fit_stopped_epoch1                                  1                       3
# fit_stopped_epoch2                                  1                       5
# fit_stopped_epoch3                                  3                       1
# fit_test_acc                                  0.65403                0.651163
# fit_train_acc                                0.966651                0.970197
# fit_train_loss                              0.0797823               0.0704162
# fit_val_acc                                  0.944714                 0.94467
# fit_val_loss                                 0.145101                0.161033
# frame_size                                 [224, 224]              [224, 224]
# layer_1_size                                      256                     128
# layer_2_size                                        0                       0
# layer_3_size                                      512                       0
# model_id                                          156                     175
# model_param_count                              526343                  263175
# model_weights_path                               None                    None
# num_features                                     2048                    2048
# path_model                     /mnt/seals/models/156/  /mnt/seals/models/175/
# pooling                                           max                     max
# pretrained_model_name                        resnet50                resnet50
# sequence_length                                     1                       1
# sequence_model                                    NaN                     NaN
# sequence_model_layers                             NaN                     NaN
# verbose                                          True                    True
#
#                                                  2205
# architecture                         image_mlp_frozen
# batch_size                                         32
# convolution_kernel_size                             3
# data_total_rows_test                             3139
# data_total_rows_train                           60597
# data_total_rows_valid                            6416
# dropout                                           0.2
# fit_best_round                                      2
# fit_dt_test_duration_seconds                        1
# fit_dt_test_end                   2019-01-20 14:13:38
# fit_dt_test_start                 2019-01-20 14:13:36
# fit_dt_train_duration_seconds                     286
# fit_dt_train_end                  2019-01-20 14:13:34
# fit_dt_train_start                2019-01-20 14:08:47
# fit_num_epochs                                     11
# fit_stopped_epoch1                                  2
# fit_stopped_epoch2                                  4
# fit_stopped_epoch3                                  2
# fit_test_acc                                 0.658809
# fit_train_acc                                0.966854
# fit_train_loss                              0.0816242
# fit_val_acc                                  0.944447
# fit_val_loss                                 0.145746
# frame_size                                 [224, 224]
# layer_1_size                                      128
# layer_2_size                                      512
# layer_3_size                                      256
# model_id                                          161
# model_param_count                              461447
# model_weights_path                               None
# num_features                                     2048
# path_model                     /mnt/seals/models/161/
# pooling                                           max
# pretrained_model_name                        resnet50
# sequence_length                                     1
# sequence_model                                    NaN
# sequence_model_layers                             NaN
# verbose                                          True

# %%
results[results['architecture'] == 'video_lrcnn_frozen'].head(5).T
# Out:
#                                                   1072  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        15
# fit_dt_test_end                    2019-01-24 07:02:41
# fit_dt_test_start                  2019-01-24 07:02:26
# fit_dt_train_duration_seconds                     3044
# fit_dt_train_end                   2019-01-24 07:02:13
# fit_dt_train_start                 2019-01-24 06:11:29
# fit_num_epochs                                      13
# fit_stopped_epoch1                                   3
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   5
# fit_test_acc                                  0.720128
# fit_train_acc                                 0.975014
# fit_train_loss                               0.0631126
# fit_val_acc                                   0.957799
# fit_val_loss                                  0.126539
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       256
# model_id                                          4489
# model_param_count                              3675143
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4489/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   188   \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        31
# fit_dt_test_end                    2019-01-23 03:34:38
# fit_dt_test_start                  2019-01-23 03:34:06
# fit_dt_train_duration_seconds                     2353
# fit_dt_train_end                   2019-01-23 03:33:45
# fit_dt_train_start                 2019-01-23 02:54:32
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   3
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   8
# fit_test_acc                                  0.718211
# fit_train_acc                                 0.962239
# fit_train_loss                               0.0941855
# fit_val_acc                                   0.957509
# fit_val_loss                                   0.12245
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                         0
# model_id                                          4571
# model_param_count                               247047
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4571/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1888  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        26
# fit_dt_test_end                    2019-01-22 22:58:13
# fit_dt_test_start                  2019-01-22 22:57:46
# fit_dt_train_duration_seconds                     2099
# fit_dt_train_end                   2019-01-22 22:57:28
# fit_dt_train_start                 2019-01-22 22:22:28
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   5
# fit_stopped_epoch3                                   1
# fit_test_acc                                  0.725559
# fit_train_acc                                   0.9614
# fit_train_loss                               0.0962222
# fit_val_acc                                   0.956348
# fit_val_loss                                  0.119364
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          4411
# model_param_count                               723463
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4411/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2710  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        12
# fit_dt_test_end                    2019-01-24 03:25:23
# fit_dt_test_start                  2019-01-24 03:25:11
# fit_dt_train_duration_seconds                     3429
# fit_dt_train_end                   2019-01-24 03:25:01
# fit_dt_train_start                 2019-01-24 02:27:51
# fit_num_epochs                                      19
# fit_stopped_epoch1                                   9
# fit_stopped_epoch2                                   4
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.739297
# fit_train_acc                                 0.971963
# fit_train_loss                               0.0703405
# fit_val_acc                                   0.956125
# fit_val_loss                                  0.134741
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       128
# model_id                                          4437
# model_param_count                              1985415
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4437/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2657
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        27
# fit_dt_test_end                    2019-01-23 00:18:48
# fit_dt_test_start                  2019-01-23 00:18:20
# fit_dt_train_duration_seconds                     3032
# fit_dt_train_end                   2019-01-23 00:17:58
# fit_dt_train_start                 2019-01-22 23:27:25
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   2
# fit_stopped_epoch2                                   7
# fit_stopped_epoch3                                   5
# fit_test_acc                                  0.705431
# fit_train_acc                                 0.970104
# fit_train_loss                               0.0751278
# fit_val_acc                                    0.95541
# fit_val_loss                                  0.124405
# frame_size                                  [224, 224]
# layer_1_size                                       512
# layer_2_size                                       128
# layer_3_size                                       512
# model_id                                          4416
# model_param_count                              2234503
# model_weights_path                                None
# num_features                                       512
# path_model                     /mnt/seals/models/4416/
# pooling                                            max
# pretrained_model_name                            vgg16
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                1
# verbose                                           True

# %% [markdown]
# ## analyze best combinations

# %%
results.groupby("sequence_model").agg('max')['fit_val_acc']
# Out:
# sequence_model
# Convolution1D    0.936084
# GRU              0.956125
# LSTM             0.957799
# SimpleRNN        0.957509
# Name: fit_val_acc, dtype: float64

# %%
results.groupby("sequence_length").agg('max')['fit_val_acc']
# Out:
# sequence_length
# 1.0     0.946495
# 3.0     0.949024
# 5.0     0.953295
# 10.0    0.957799
# Name: fit_val_acc, dtype: float64

# %%
results.groupby(["sequence_model","sequence_length"]).agg("max")['fit_val_acc'].unstack()
# Out:
# sequence_length      5.0       10.0      3.0
# sequence_model
# Convolution1D    0.936084  0.877953       NaN
# GRU              0.952180  0.956125  0.948178
# LSTM             0.952983  0.957799  0.949024
# SimpleRNN        0.953295  0.957509  0.947108

# %%
results.sort_values("fit_val_acc",ascending=False).head(30).plot(x='model_param_count',y='fit_val_acc', kind='scatter')

# %%
results.sort_values('fit_dt_test_end',ascending=False).head().T
# Out:
#                                                   2146  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        25
# fit_dt_test_end                    2019-01-24 22:05:41
# fit_dt_test_start                  2019-01-24 22:05:16
# fit_dt_train_duration_seconds                     3634
# fit_dt_train_end                   2019-01-24 22:04:55
# fit_dt_train_start                 2019-01-24 21:04:21
# fit_num_epochs                                      13
# fit_stopped_epoch1                                   5
# fit_stopped_epoch2                                   1
# fit_stopped_epoch3                                   4
# fit_test_acc                                  0.688818
# fit_train_acc                                 0.973375
# fit_train_loss                               0.0668112
# fit_val_acc                                   0.942728
# fit_val_loss                                  0.171968
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       256
# layer_3_size                                       512
# model_id                                          5029
# model_param_count                              3479047
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/5029/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   2291  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        24
# fit_dt_test_end                    2019-01-24 21:49:55
# fit_dt_test_start                  2019-01-24 21:49:30
# fit_dt_train_duration_seconds                     4208
# fit_dt_train_end                   2019-01-24 21:49:12
# fit_dt_train_start                 2019-01-24 20:39:04
# fit_num_epochs                                      17
# fit_stopped_epoch1                                   2
# fit_stopped_epoch2                                  10
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.694249
# fit_train_acc                                 0.977845
# fit_train_loss                               0.0553746
# fit_val_acc                                   0.947394
# fit_val_loss                                  0.149258
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       128
# layer_3_size                                       256
# model_id                                          5069
# model_param_count                              2247815
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/5069/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                     10
# sequence_model                                     GRU
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   1840  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       3
# fit_dt_test_duration_seconds                        23
# fit_dt_test_end                    2019-01-24 21:49:40
# fit_dt_test_start                  2019-01-24 21:49:16
# fit_dt_train_duration_seconds                     2506
# fit_dt_train_end                   2019-01-24 21:48:56
# fit_dt_train_start                 2019-01-24 21:07:09
# fit_num_epochs                                      19
# fit_stopped_epoch1                                  12
# fit_stopped_epoch2                                   2
# fit_stopped_epoch3                                   2
# fit_test_acc                                  0.690415
# fit_train_acc                                  0.96792
# fit_train_loss                               0.0828561
# fit_val_acc                                   0.945854
# fit_val_loss                                  0.134041
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       256
# layer_3_size                                         0
# model_id                                          5051
# model_param_count                               723207
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/5051/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   3017  \
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        24
# fit_dt_test_end                    2019-01-24 21:19:22
# fit_dt_test_start                  2019-01-24 21:18:57
# fit_dt_train_duration_seconds                     4337
# fit_dt_train_end                   2019-01-24 21:18:36
# fit_dt_train_start                 2019-01-24 20:06:19
# fit_num_epochs                                      14
# fit_stopped_epoch1                                   1
# fit_stopped_epoch2                                   3
# fit_stopped_epoch3                                   7
# fit_test_acc                                  0.676997
# fit_train_acc                                  0.97639
# fit_train_loss                               0.0601765
# fit_val_acc                                   0.949471
# fit_val_loss                                  0.142262
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       512
# layer_3_size                                       128
# model_id                                          5009
# model_param_count                              4591623
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/5009/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                     10
# sequence_model                                    LSTM
# sequence_model_layers                                2
# verbose                                           True
#
#                                                   72
# architecture                        video_lrcnn_frozen
# batch_size                                          32
# convolution_kernel_size                              3
# data_total_rows_test                              3130
# data_total_rows_train                            60399
# data_total_rows_valid                             6398
# dropout                                            0.2
# fit_best_round                                       2
# fit_dt_test_duration_seconds                        22
# fit_dt_test_end                    2019-01-24 21:06:44
# fit_dt_test_start                  2019-01-24 21:06:21
# fit_dt_train_duration_seconds                     2977
# fit_dt_train_end                   2019-01-24 21:06:02
# fit_dt_train_start                 2019-01-24 20:16:25
# fit_num_epochs                                      24
# fit_stopped_epoch1                                   2
# fit_stopped_epoch2                                  16
# fit_stopped_epoch3                                   3
# fit_test_acc                                  0.670288
# fit_train_acc                                 0.973136
# fit_train_loss                               0.0673626
# fit_val_acc                                   0.952731
# fit_val_loss                                  0.125597
# frame_size                                  [224, 224]
# layer_1_size                                       256
# layer_2_size                                       256
# layer_3_size                                       256
# model_id                                          5035
# model_param_count                              1378823
# model_weights_path                                None
# num_features                                      2048
# path_model                     /mnt/seals/models/5035/
# pooling                                            max
# pretrained_model_name                         resnet50
# sequence_length                                     10
# sequence_model                               SimpleRNN
# sequence_model_layers                                2
# verbose                                           True

# %% [markdown]
# # re-allocate experiments to workers

# %%
# remove experiments already done
experiments = remove_completed_experiments(experiments)

# %% [markdown]
# ## re-assign workers on the experiments that are not complete

# %%
# reassign outstanding experiments to workers
experiments = reassign_workers(experiments)

# %%
##################################
### output experiment batch to CSV
##################################
print(experiment_batch_name)
experiments.to_csv(pwd + "experiments/" + experiment_batch_name + '.csv', index=False)

# %% [markdown]
# # Debug experiment worker

# %%
from deepvideoclassification.architectures import Architecture

# %%
WORKER_ID = 0
GPU_ID = 7
experiment_batch_name = 'experiment_batch_1'

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(WORKER_ID)

# %%
# setup logging
# separate log file for each worker
import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s, [%(levelname)-8s] [%(filename)s:%(lineno)d] %(message)s',
    handlers=[
        logging.FileHandler("{0}/{1}.log".format(pwd, "logs_" + str(WORKER_ID))),
        logging.StreamHandler()
    ])
# init logger - will pass this to our architecture
logger = logging.getLogger()

logger.info("Start worker {} (GPU={}) processing {}".format(WORKER_ID, GPU_ID, experiment_batch_name))
# Out:
# 2019-01-23 12:45:52,601 [MainThread  ] [INFO ]  Start worker 0 (GPU=7) processing experiment_batch_1
# 2019-01-23 12:45:52,601 [MainThread  ] [INFO ]  Start worker 0 (GPU=7) processing experiment_batch_1

# %%
# load list of experiments
experiments = pd.read_csv(pwd + "experiments/" + experiment_batch_name + '.csv')

# %%
experiments[experiments['model_id'].isin([2495, 2463])]
# Out:
#             architecture  dropout  layer_1_size  layer_2_size  layer_3_size  \
# 1317  video_LRCNN_frozen      0.2           256           512             0
# 1349  video_LRCNN_frozen      0.2           256           256             0
#
#      pooling pretrained_model_name  sequence_length sequence_model  \
# 1317     max   inception_resnet_v2                5  Convolution1D
# 1349     max   inception_resnet_v2                5  Convolution1D
#
#       sequence_model_layers  model_id  WORKER
# 1317                    2.0      2463       0
# 1349                    2.0      2495       0
#             architecture  dropout  layer_1_size  layer_2_size  layer_3_size  \
# 1317  video_LRCNN_frozen      0.2           256           512             0
# 1349  video_LRCNN_frozen      0.2           256           256             0
#
#      pooling pretrained_model_name  sequence_length sequence_model  \
# 1317     max   inception_resnet_v2                5  Convolution1D
# 1349     max   inception_resnet_v2                5  Convolution1D
#
#       sequence_model_layers  model_id  WORKER
# 1317                    2.0      2463       0
# 1349                    2.0      2495       0

# %%
# for row in experiments.values:
debug_model_id = 5243

row = list(experiments[experiments['model_id'] == debug_model_id].values[0])

# get experiment params from dataframe row
experiment = dict(zip(experiments.columns, row))

# %%
experiment
# Out:
# {'WORKER': 6,
#  'architecture': 'video_LRCNN_frozen',
#  'dropout': 0.2,
#  'layer_1_size': 128,
#  'layer_2_size': 0,
#  'layer_3_size': 0,
#  'model_id': 5243,
#  'pooling': 'max',
#  'pretrained_model_name': 'resnet50',
#  'sequence_length': 10,
#  'sequence_model': 'SimpleRNN',
#  'sequence_model_layers': 2.0}
# {'WORKER': 6,
#  'architecture': 'video_LRCNN_frozen',
#  'dropout': 0.2,
#  'layer_1_size': 128,
#  'layer_2_size': 0,
#  'layer_3_size': 0,
#  'model_id': 5243,
#  'pooling': 'max',
#  'pretrained_model_name': 'resnet50',
#  'sequence_length': 10,
#  'sequence_model': 'SimpleRNN',
#  'sequence_model_layers': 2.0}

# %%
experiments[experiments['model_id'] == debug_model_id].T
# Out:
#                                      3049
# architecture           video_LRCNN_frozen
# dropout                               0.2
# layer_1_size                          128
# layer_2_size                            0
# layer_3_size                            0
# pooling                               max
# pretrained_model_name            resnet50
# sequence_length                        10
# sequence_model                  SimpleRNN
# sequence_model_layers                   2
# model_id                             5243
# WORKER                                  6
#                                      3049
# architecture           video_LRCNN_frozen
# dropout                               0.2
# layer_1_size                          128
# layer_2_size                            0
# layer_3_size                            0
# pooling                               max
# pretrained_model_name            resnet50
# sequence_length                        10
# sequence_model                  SimpleRNN
# sequence_model_layers                   2
# model_id                             5243
# WORKER                                  6

# %%
print(str(experiment["model_id"]) + "   " + "X"*60)
logging.info("Begin experiment for model_id={} on GPU:{} ".format(experiment['model_id'], os.environ["CUDA_VISIBLE_DEVICES"]))
print(experiment)

architecture = Architecture(model_id = experiment['model_id'], 
                            architecture = experiment['architecture'], 
                            sequence_length = experiment['sequence_length'], 
                            pretrained_model_name = experiment['pretrained_model_name'],
                            pooling = experiment['pooling'],
                            sequence_model = experiment['sequence_model'],
                            sequence_model_layers = experiment['sequence_model_layers'],
                            layer_1_size = experiment['layer_1_size'],
                            layer_2_size = experiment['layer_2_size'],
                            layer_3_size = experiment['layer_3_size'],
                            dropout = experiment['dropout'],
                            verbose=True)
# Out:
# 2019-01-23 12:45:54,879 [MainThread  ] [INFO ]  Begin experiment for model_id=5243 on GPU:0
# 2019-01-23 12:45:54,881 [MainThread  ] [INFO ]  Loading data
# 2019-01-23 12:45:54,879 [MainThread  ] [INFO ]  Begin experiment for model_id=5243 on GPU:0
# 2019-01-23 12:45:54,881 [MainThread  ] [INFO ]  Loading data
# 5243   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'resnet50', 'sequence_model_layers': 2.0, 'layer_2_size': 0, 'WORKER': 6, 'sequence_model': 'SimpleRNN', 'sequence_length': 10, 'dropout': 0.2, 'model_id': 5243, 'architecture': 'video_LRCNN_frozen', 'layer_1_size': 128, 'pooling': 'max', 'layer_3_size': 0}
# 5243   XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# {'pretrained_model_name': 'resnet50', 'sequence_model_layers': 2.0, 'layer_2_size': 0, 'WORKER': 6, 'sequence_model': 'SimpleRNN', 'sequence_length': 10, 'dropout': 0.2, 'model_id': 5243, 'architecture': 'video_LRCNN_frozen', 'layer_1_size': 128, 'pooling': 'max', 'layer_3_size': 0}
# 2019-01-23 12:45:55,849 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/resnet50/max/
# 2019-01-23 12:45:55,850 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# 2019-01-23 12:45:55,849 [MainThread  ] [INFO ]  Features already cached: /mnt/seals/cache/features/resnet50/max/
# 2019-01-23 12:45:55,850 [MainThread  ] [INFO ]  Loading features sequence data into memory [may take a few minutes]
# Done initializing data with #samples: train=60399, valid=6398, test=3130
# Done initializing data with #samples: train=60399, valid=6398, test=3130

# %%
architecture.train_model(epochs=1)
# Out:
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# 60399/60399 [==============================] - 48s 791us/step - loss: 0.1756 - acc: 0.9278 - val_loss: 0.1952 - val_acc: 0.9123
# 60399/60399 [==============================] - 48s 791us/step - loss: 0.1756 - acc: 0.9278 - val_loss: 0.1952 - val_acc: 0.9123
#
# Epoch 00001: val_acc improved from -inf to 0.91234, saving model to /mnt/seals/models/5243/model_round_1.h5
# H1 {'acc': [0.92784177456852], 'val_acc': [0.9123386935578096], 'val_loss': [0.195202600037392], 'loss': [0.17556339674761648]}
# stopped_epoch1 0
# 1
# 0.9123386935578096
#
# Epoch 00001: val_acc improved from -inf to 0.91234, saving model to /mnt/seals/models/5243/model_round_1.h5
# H1 {'acc': [0.92784177456852], 'val_acc': [0.9123386935578096], 'val_loss': [0.195202600037392], 'loss': [0.17556339674761648]}
# stopped_epoch1 0
# 1
# 0.9123386935578096
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# 60399/60399 [==============================] - 33s 549us/step - loss: 0.1475 - acc: 0.9401 - val_loss: 0.1882 - val_acc: 0.9115
# 60399/60399 [==============================] - 33s 549us/step - loss: 0.1475 - acc: 0.9401 - val_loss: 0.1882 - val_acc: 0.9115
#
# Epoch 00001: val_acc improved from -inf to 0.91151, saving model to /mnt/seals/models/5243/model_round_2.h5
# H2 {'acc': [0.9400983633696081], 'val_acc': [0.9115125459967348], 'val_loss': [0.1881785286743591], 'loss': [0.14746618541282766]}
# stopped_epoch2 0
# 1
# 0.9115125459967348
#
# Epoch 00001: val_acc improved from -inf to 0.91151, saving model to /mnt/seals/models/5243/model_round_2.h5
# H2 {'acc': [0.9400983633696081], 'val_acc': [0.9115125459967348], 'val_loss': [0.1881785286743591], 'loss': [0.14746618541282766]}
# stopped_epoch2 0
# 1
# 0.9115125459967348
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# Train on 60399 samples, validate on 6398 samples
# Epoch 1/1
# 60399/60399 [==============================] - 33s 549us/step - loss: 0.1395 - acc: 0.9434 - val_loss: 0.1865 - val_acc: 0.9132
# 60399/60399 [==============================] - 33s 549us/step - loss: 0.1395 - acc: 0.9434 - val_loss: 0.1865 - val_acc: 0.9132
#
# Epoch 00001: val_acc improved from -inf to 0.91319, saving model to /mnt/seals/models/5243/model_round_3.h5
# H3 {'acc': [0.9433718327210892], 'val_acc': [0.9131871765760676], 'val_loss': [0.18654302512064097], 'loss': [0.13948042428104288]}
# stopped_epoch3 0
# 1
# 0.9131871765760676
# best fit round 3 0.9131871765760676
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 128)               278656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 279,559
# Trainable params: 279,559
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 00001: val_acc improved from -inf to 0.91319, saving model to /mnt/seals/models/5243/model_round_3.h5
# H3 {'acc': [0.9433718327210892], 'val_acc': [0.9131871765760676], 'val_loss': [0.18654302512064097], 'loss': [0.13948042428104288]}
# stopped_epoch3 0
# 1
# 0.9131871765760676
# best fit round 3 0.9131871765760676
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 128)               278656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 279,559
# Trainable params: 279,559
# Non-trainable params: 0
# _________________________________________________________________
# 3130/3130 [==============================] - 1s 316us/step
# 3130/3130 [==============================] - 1s 316us/step
# 2019-01-23 12:48:06,960 [MainThread  ] [INFO ]  {
#     "architecture": "video_lrcnn_frozen",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3130,
#     "data_total_rows_train": 60399,
#     "data_total_rows_valid": 6398,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-23 12:48:05",
#     "fit_dt_test_start": "2019-01-23 12:48:04",
#     "fit_dt_train_duration_seconds": "118",
#     "fit_dt_train_end": "2019-01-23 12:48:04",
#     "fit_dt_train_start": "2019-01-23 12:46:05",
#     "fit_num_epochs": 3,
#     "fit_stopped_epoch1": 0,
#     "fit_stopped_epoch2": 0,
#     "fit_stopped_epoch3": 0,
#     "fit_test_acc": 0.5990415335463259,
#     "fit_train_acc": 0.9433718327210892,
#     "fit_train_loss": 0.13948042428104288,
#     "fit_val_acc": 0.9131871765760676,
#     "fit_val_loss": 0.18654302512064097,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 5243,
#     "model_param_count": 279559,
#     "model_weights_path": null,
#     "num_features": 2048,
#     "path_model": "/mnt/seals/models/5243/",
#     "pooling": "max",
#     "pretrained_model_name": "resnet50",
#     "sequence_length": 10,
#     "sequence_model": "SimpleRNN",
#     "sequence_model_layers": 2.0,
#     "verbose": true
# }
# 2019-01-23 12:48:06,961 [MainThread  ] [INFO ]  model 5243 test acc: 0.5990415335463259
# {'model_param_count': 279559, 'data_total_rows_valid': 6398, 'fit_dt_test_start': '2019-01-23 12:48:04', 'layer_2_size': 0, 'fit_train_acc': 0.9433718327210892, 'frame_size': (224, 224), 'fit_stopped_epoch2': 0, 'dropout': 0.2, 'model_id': 5243, 'path_model': '/mnt/seals/models/5243/', 'layer_1_size': 128, 'fit_stopped_epoch1': 0, 'fit_best_round': 3, 'sequence_model_layers': 2.0, 'fit_num_epochs': 3, 'fit_stopped_epoch3': 0, 'verbose': True, 'fit_dt_test_end': '2019-01-23 12:48:05', 'pretrained_model_name': 'resnet50', 'fit_dt_test_duration_seconds': '0', 'sequence_model': 'SimpleRNN', 'batch_size': 32, 'data_total_rows_train': 60399, 'architecture': 'video_lrcnn_frozen', 'data_total_rows_test': 3130, 'num_features': 2048, 'fit_dt_train_end': '2019-01-23 12:48:04', 'fit_val_acc': 0.9131871765760676, 'fit_test_acc': 0.5990415335463259, 'sequence_length': 10, 'pooling': 'max', 'fit_dt_train_duration_seconds': '118', 'fit_dt_train_start': '2019-01-23 12:46:05', 'layer_3_size': 0, 'model_weights_path': None, 'fit_val_loss': 0.18654302512064097, 'convolution_kernel_size': 3, 'fit_train_loss': 0.13948042428104288}
# gsutil -m rsync -r /mnt/seals/models/5243/ gs://thesis-penguins/models/5243/ -r
# 2019-01-23 12:48:06,960 [MainThread  ] [INFO ]  {
#     "architecture": "video_lrcnn_frozen",
#     "batch_size": 32,
#     "convolution_kernel_size": 3,
#     "data_total_rows_test": 3130,
#     "data_total_rows_train": 60399,
#     "data_total_rows_valid": 6398,
#     "dropout": 0.2,
#     "fit_best_round": 3,
#     "fit_dt_test_duration_seconds": "0",
#     "fit_dt_test_end": "2019-01-23 12:48:05",
#     "fit_dt_test_start": "2019-01-23 12:48:04",
#     "fit_dt_train_duration_seconds": "118",
#     "fit_dt_train_end": "2019-01-23 12:48:04",
#     "fit_dt_train_start": "2019-01-23 12:46:05",
#     "fit_num_epochs": 3,
#     "fit_stopped_epoch1": 0,
#     "fit_stopped_epoch2": 0,
#     "fit_stopped_epoch3": 0,
#     "fit_test_acc": 0.5990415335463259,
#     "fit_train_acc": 0.9433718327210892,
#     "fit_train_loss": 0.13948042428104288,
#     "fit_val_acc": 0.9131871765760676,
#     "fit_val_loss": 0.18654302512064097,
#     "frame_size": [
#         224,
#         224
#     ],
#     "layer_1_size": 128,
#     "layer_2_size": 0,
#     "layer_3_size": 0,
#     "model_id": 5243,
#     "model_param_count": 279559,
#     "model_weights_path": null,
#     "num_features": 2048,
#     "path_model": "/mnt/seals/models/5243/",
#     "pooling": "max",
#     "pretrained_model_name": "resnet50",
#     "sequence_length": 10,
#     "sequence_model": "SimpleRNN",
#     "sequence_model_layers": 2.0,
#     "verbose": true
# }
# 2019-01-23 12:48:06,961 [MainThread  ] [INFO ]  model 5243 test acc: 0.5990415335463259
# {'model_param_count': 279559, 'data_total_rows_valid': 6398, 'fit_dt_test_start': '2019-01-23 12:48:04', 'layer_2_size': 0, 'fit_train_acc': 0.9433718327210892, 'frame_size': (224, 224), 'fit_stopped_epoch2': 0, 'dropout': 0.2, 'model_id': 5243, 'path_model': '/mnt/seals/models/5243/', 'layer_1_size': 128, 'fit_stopped_epoch1': 0, 'fit_best_round': 3, 'sequence_model_layers': 2.0, 'fit_num_epochs': 3, 'fit_stopped_epoch3': 0, 'verbose': True, 'fit_dt_test_end': '2019-01-23 12:48:05', 'pretrained_model_name': 'resnet50', 'fit_dt_test_duration_seconds': '0', 'sequence_model': 'SimpleRNN', 'batch_size': 32, 'data_total_rows_train': 60399, 'architecture': 'video_lrcnn_frozen', 'data_total_rows_test': 3130, 'num_features': 2048, 'fit_dt_train_end': '2019-01-23 12:48:04', 'fit_val_acc': 0.9131871765760676, 'fit_test_acc': 0.5990415335463259, 'sequence_length': 10, 'pooling': 'max', 'fit_dt_train_duration_seconds': '118', 'fit_dt_train_start': '2019-01-23 12:46:05', 'layer_3_size': 0, 'model_weights_path': None, 'fit_val_loss': 0.18654302512064097, 'convolution_kernel_size': 3, 'fit_train_loss': 0.13948042428104288}
# gsutil -m rsync -r /mnt/seals/models/5243/ gs://thesis-penguins/models/5243/ -r
# XX
# upload error
# XX
# upload error
